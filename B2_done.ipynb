# %% [markdown]
# # BTS Digital Twin - B2 Pilot (`hcm0031`)
#
# Notebook này chạy pilot `B2` trên `round1 public_set/hcm0031`.
#
# Mặc định notebook sẽ:
#
# - clone repo hiện tại
# - cài `colmap` + `pycolmap`
# - tự dò `Dataset/VAI_NVS_DATA/phase1/public_set`
# - chạy `patch_match_stereo` + `stereo_fusion`
# - đóng gói artifact để tải về
#
# Nếu muốn đi tiếp tới `render/eval`, bật thêm `RUN_RENDER=1` và cung cấp `GS_REPO_URL`.

# %%
from pathlib import Path
import subprocess
import threading
import time

REPO_URL = 'https://github.com/ThongLuc2k3/BTS-Digital-Twin.git'
REPO_BRANCH = 'coordination/round1-status'
GITHUB_TOKEN = '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'
WORKDIR = '/content' if Path('/content').exists() else '/kaggle/working'

SCENE = 'hcm0031'
DATASET_ROOT_OVERRIDE = ''
DATASET_URL = 'https://drive.google.com/file/d/1GUflBBz4hrVtkMcHLfLMwUYk4HsJkXFu/view?usp=drive_link'
KAGGLE_DATASET = ''
KAGGLE_USERNAME = ''
KAGGLE_KEY = ''

RUN_DENSE = '1'
RUN_TRAIN = '0'
RUN_RENDER = '0'
RUN_EVAL = '0'

COLMAP_BIN_OVERRIDE = ''
BUILD_COLMAP_CUDA_IF_NEEDED = True
COLMAP_CUDA_ARCH = '75'

GS_REPO_URL = ''
GS_REPO_BRANCH = 'main'

PATCH_MATCH_MAX_IMAGE_SIZE = '1600'
PATCH_MATCH_GPU_INDEX = '0'
PATCH_MATCH_CACHE_SIZE = '8'


def run_and_stream(cmd, *, env=None, cwd=None, log_files=None, poll_seconds=15, check=True, label='cmd'):
    log_files = [Path(p) for p in (log_files or [])]
    print(f'[{label}] START:', ' '.join(map(str, cmd)), flush=True)
    proc = subprocess.Popen(
        cmd,
        cwd=cwd,
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )

    def _pump_stdout():
        assert proc.stdout is not None
        for line in proc.stdout:
            print(f'[{label}] {line.rstrip()}', flush=True)

    reader = threading.Thread(target=_pump_stdout, daemon=True)
    reader.start()

    offsets = {}
    last_heartbeat = 0.0
    try:
        while proc.poll() is None:
            now = time.time()
            if now - last_heartbeat >= poll_seconds:
                print(f'[{label}] still running...', flush=True)
                last_heartbeat = now
            for path in log_files:
                if not path.exists():
                    continue
                prev = offsets.get(path, 0)
                size = path.stat().st_size
                if size <= prev:
                    continue
                with path.open('r', encoding='utf-8', errors='replace') as f:
                    f.seek(prev)
                    chunk = f.read()
                offsets[path] = size
                if chunk.strip():
                    print(f'\n--- {path.name} ---', flush=True)
                    print(chunk.rstrip(), flush=True)
                    print(f'--- end {path.name} ---\n', flush=True)
            time.sleep(2)
    finally:
        rc = proc.wait()
        reader.join(timeout=5)
        for path in log_files:
            if path.exists():
                prev = offsets.get(path, 0)
                size = path.stat().st_size
                if size > prev:
                    with path.open('r', encoding='utf-8', errors='replace') as f:
                        f.seek(prev)
                        chunk = f.read()
                    if chunk.strip():
                        print(f'\n--- {path.name} (final) ---', flush=True)
                        print(chunk.rstrip(), flush=True)
                        print(f'--- end {path.name} ---\n', flush=True)
        print(f'[{label}] RETURN CODE =', rc, flush=True)

    if check and rc != 0:
        raise subprocess.CalledProcessError(rc, cmd)
    return rc


Path(WORKDIR).mkdir(parents=True, exist_ok=True)
print('Config ok')
print('WORKDIR =', WORKDIR)
print('PATCH_MATCH_MAX_IMAGE_SIZE =', PATCH_MATCH_MAX_IMAGE_SIZE)
print('PATCH_MATCH_CACHE_SIZE =', PATCH_MATCH_CACHE_SIZE)
# Out:
# Config ok
# WORKDIR = /content
# PATCH_MATCH_MAX_IMAGE_SIZE = 1600
# PATCH_MATCH_CACHE_SIZE = 8

# %%
import os
import subprocess

clone_url = REPO_URL
if GITHUB_TOKEN and 'github.com' in REPO_URL:
    clone_url = REPO_URL.replace('https://', f'https://{GITHUB_TOKEN}@')

project_dir = f'{WORKDIR}/project'
subprocess.run(['bash', '-lc', f'rm -rf "{project_dir}"'], check=True)
subprocess.run([
    'git', 'clone', '--depth', '1', '-b', REPO_BRANCH, clone_url, project_dir
], check=True)
print('Cloned repo ->', project_dir)
# Out:
# Cloned repo -> /content/project

# %%
import subprocess

subprocess.run([
    'bash', '-lc',
    'apt-get update && apt-get install -y colmap && python3 -m pip install --upgrade pip && python3 -m pip install pycolmap lpips'
], check=True)

subprocess.run(['bash', '-lc', 'colmap -h | head -n 5'], check=True)
subprocess.run(['python3', '-c', 'import pycolmap; print(pycolmap.__version__)'], check=True)
print('Installed colmap + pycolmap + lpips')
# Out:
# Installed colmap + pycolmap + lpips

# %% [markdown]
# ## CUDA / COLMAP check
#
# `patch_match_stereo` cua COLMAP bat buoc can ban `colmap` duoc build voi CUDA.
#
# Neu `colmap -h` in ra `without CUDA` thi khong duoc chay tiep bang `/usr/bin/colmap` hien tai.
#
# Cell mau ngay ben duoi se build `COLMAP` co CUDA trong notebook, verify lai, roi dat `COLMAP_BIN` moi de cell `B2` phia sau dung thang binary do.

# %%
import shutil
import subprocess
from pathlib import Path

print('==== nvidia-smi ====')
subprocess.run(['bash', '-lc', 'nvidia-smi'], check=False)

print('\n==== colmap help ====')
help_proc = subprocess.run(
    ['bash', '-lc', 'colmap -h | head -n 20'],
    text=True,
    capture_output=True,
    check=False,
)
print(help_proc.stdout)
print(help_proc.stderr)

colmap_path = shutil.which('colmap')
print('COLMAP path =', colmap_path)
colmap_bin_for_b2 = COLMAP_BIN_OVERRIDE or (colmap_path or '')

if colmap_path is None:
    raise SystemExit('Khong tim thay colmap trong PATH.')

full_help = (help_proc.stdout or '') + '\n' + (help_proc.stderr or '')
if 'without CUDA' in full_help:
    print('COLMAP hien tai without CUDA. Hay chay cell build COLMAP CUDA ngay ben duoi.')
else:
    print('COLMAP co CUDA support. Co the tiep tuc dense stereo.')

cuda_colmap_guess = Path(WORKDIR) / 'project' / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
if cuda_colmap_guess.exists():
    colmap_bin_for_b2 = str(cuda_colmap_guess)
    print('Tim thay COLMAP CUDA da build san:', colmap_bin_for_b2)

print('COLMAP_BIN se dung cho B2 =', colmap_bin_for_b2)
# Out:
# ==== nvidia-smi ====
#
# ==== colmap help ====
# COLMAP 3.7 -- Structure-from-Motion and Multi-View Stereo
#               (Commit Unknown on Unknown without CUDA)
#
# Usage:
#   colmap [command] [options]
#
# Documentation:
#   https://colmap.github.io/
#
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
#
#
#
# COLMAP path = /usr/bin/colmap
# COLMAP hien tai without CUDA. Hay chay cell build COLMAP CUDA ngay ben duoi.
# COLMAP_BIN se dung cho B2 = /usr/bin/colmap

# %%
import os
import shutil
import subprocess
from pathlib import Path

project_dir = Path(WORKDIR) / 'project'
build_script = project_dir / 'pipeline' / 'scripts' / 'build_colmap_cuda_notebook.sh'
cuda_colmap_bin = project_dir / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
build_log = Path(WORKDIR) / 'colmap_cuda_build.log'

need_build = BUILD_COLMAP_CUDA_IF_NEEDED
if COLMAP_BIN_OVERRIDE:
    colmap_bin_for_b2 = COLMAP_BIN_OVERRIDE
    need_build = False
    print('Dung COLMAP_BIN_OVERRIDE =', colmap_bin_for_b2)
elif cuda_colmap_bin.exists():
    colmap_bin_for_b2 = str(cuda_colmap_bin)
    need_build = False
    print('Tai su dung COLMAP CUDA da build =', colmap_bin_for_b2)
else:
    base_colmap = shutil.which('colmap') or ''
    help_proc = subprocess.run(
        ['bash', '-lc', 'colmap -h | head -n 20'],
        text=True,
        capture_output=True,
        check=False,
    )
    help_text = (help_proc.stdout or '') + '\n' + (help_proc.stderr or '')
    if base_colmap and 'without CUDA' not in help_text:
        colmap_bin_for_b2 = base_colmap
        need_build = False
        print('COLMAP san co da co CUDA =', colmap_bin_for_b2)

if need_build:
    assert build_script.exists(), f'Khong thay script build: {build_script}'
    env = os.environ.copy()
    env['CMAKE_CUDA_ARCHITECTURES'] = COLMAP_CUDA_ARCH
    env['GUI_ENABLED'] = 'OFF'
    env['BLAS_BACKEND'] = 'auto'
    run_and_stream(
        ['bash', str(build_script)],
        cwd=str(project_dir),
        env=env,
        log_files=[build_log],
        poll_seconds=20,
        label='build-colmap-cuda',
    )
    assert cuda_colmap_bin.exists(), f'Build xong nhung khong thay binary: {cuda_colmap_bin}'
    colmap_bin_for_b2 = str(cuda_colmap_bin)

verify_proc = subprocess.run(
    ['bash', '-lc', f'"{colmap_bin_for_b2}" -h | head -n 20'],
    text=True,
    capture_output=True,
    check=False,
)
print(verify_proc.stdout)
print(verify_proc.stderr)
verify_text = (verify_proc.stdout or '') + '\n' + (verify_proc.stderr or '')
if 'without CUDA' in verify_text:
    raise SystemExit('COLMAP_BIN moi van without CUDA. Khong duoc chay B2.')

print('COLMAP CUDA verify PASS')
print('COLMAP_BIN se dung cho B2 =', colmap_bin_for_b2)
# Out:
# [build-colmap-cuda] START: bash /content/project/pipeline/scripts/build_colmap_cuda_notebook.sh
# [build-colmap-cuda] still running...
# [build-colmap-cuda] Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# [build-colmap-cuda] Hit:2 https://cli.github.com/packages stable InRelease
# [build-colmap-cuda] Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# [build-colmap-cuda] Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# [build-colmap-cuda] Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# [build-colmap-cuda] Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# [build-colmap-cuda] Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Reading package lists...
# [build-colmap-cuda] W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# [build-colmap-cuda] Reading package lists...
# [build-colmap-cuda] Building dependency tree...
# [build-colmap-cuda] Reading state information...
# [build-colmap-cuda] build-essential is already the newest version (12.9ubuntu3).
# [build-colmap-cuda] cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# [build-colmap-cuda] git is already the newest version (1:2.34.1-1ubuntu1.17).
# [build-colmap-cuda] The following additional packages will be installed:
# [build-colmap-cuda]   curl googletest gstreamer1.0-plugins-base libboost-atomic1.74-dev
# [build-colmap-cuda]   libboost-atomic1.74.0 libboost-chrono1.74-dev libboost-chrono1.74.0
# [build-colmap-cuda]   libboost-date-time1.74-dev libboost-date-time1.74.0
# [build-colmap-cuda]   libboost-filesystem1.74.0 libboost-graph1.74-dev libboost-graph1.74.0
# [build-colmap-cuda]   libboost-iostreams1.74.0 libboost-program-options1.74-dev
# [build-colmap-cuda]   libboost-program-options1.74.0 libboost-regex1.74-dev libboost-regex1.74.0
# [build-colmap-cuda]   libboost-serialization1.74-dev libboost-serialization1.74.0
# [build-colmap-cuda]   libboost-system1.74-dev libboost-system1.74.0 libboost-test1.74-dev
# [build-colmap-cuda]   libboost-test1.74.0 libboost-thread-dev libboost-thread1.74-dev
# [build-colmap-cuda]   libboost-thread1.74.0 libbtf1 libcdparanoia0 libcharls2 libcurl4 libdcmtk16
# [build-colmap-cuda]   libegl-dev libexif12 libgdcm3.0 libgflags-dev libgl-dev libgles-dev libgles1
# [build-colmap-cuda]   libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libgmp-dev libgmpxx4ldbl
# [build-colmap-cuda]   libgphoto2-6 libgphoto2-l10n libgphoto2-port12 libgraphblas-dev
# [build-colmap-cuda]   libgraphblas6 libgstreamer-plugins-base1.0-0 libilmbase-dev libklu1 libldl2
# [build-colmap-cuda]   liblog4cplus-2.0.5 libmongoose2 libmpfr-dev libopencolorio1v5
# [build-colmap-cuda]   libopencv-core4.5d libopencv-imgcodecs4.5d libopencv-imgproc4.5d
# [build-colmap-cuda]   libopencv-videoio4.5d libopenimageio-doc libopenimageio2.2 libopenvdb8.1
# [build-colmap-cuda]   liborc-0.4-0 librbio2 libsliplu1 libsocket++1 libsqlite3-0 libsquish0
# [build-colmap-cuda]   libssl3 libtbb12 libtbb2 libtbbmalloc2 libtinyxml2.6.2v5 libumfpack5
# [build-colmap-cuda]   libunwind-dev libvisual-0.4-0 libyaml-cpp0.7
# [build-colmap-cuda] Suggested packages:
# [build-colmap-cuda]   gvfs libmpfi-dev libntl-dev libtbb-dev libcurl4-doc libidn11-dev
# [build-colmap-cuda]   libldap2-dev librtmp-dev libeigen3-doc libmpfrc++-dev gmp-doc libgmp10-doc
# [build-colmap-cuda]   gphoto2 libvisual-0.4-plugins libmpfr-doc sqlite3-doc libssl-doc
# [build-colmap-cuda] The following NEW packages will be installed:
# [build-colmap-cuda]   googletest gstreamer1.0-plugins-base libboost-atomic1.74-dev
# [build-colmap-cuda]   libboost-atomic1.74.0 libboost-chrono1.74-dev libboost-chrono1.74.0
# [build-colmap-cuda]   libboost-date-time1.74-dev libboost-date-time1.74.0
# [build-colmap-cuda]   libboost-filesystem1.74.0 libboost-graph-dev libboost-graph1.74-dev
# [build-colmap-cuda]   libboost-graph1.74.0 libboost-iostreams1.74.0 libboost-program-options-dev
# [build-colmap-cuda]   libboost-program-options1.74-dev libboost-program-options1.74.0
# [build-colmap-cuda]   libboost-regex1.74-dev libboost-regex1.74.0 libboost-serialization1.74-dev
# [build-colmap-cuda]   libboost-serialization1.74.0 libboost-system-dev libboost-system1.74-dev
# [build-colmap-cuda]   libboost-system1.74.0 libboost-test1.74-dev libboost-test1.74.0
# [build-colmap-cuda]   libboost-thread-dev libboost-thread1.74-dev libboost-thread1.74.0 libbtf1
# [build-colmap-cuda]   libcdparanoia0 libceres-dev libcgal-dev libcharls2 libdcmtk16 libegl-dev
# [build-colmap-cuda]   libeigen3-dev libexif12 libgdcm3.0 libgflags-dev libgl-dev libgl1-mesa-dev
# [build-colmap-cuda]   libgles-dev libgles1 libglew-dev libglu1-mesa libglu1-mesa-dev
# [build-colmap-cuda]   libglvnd-core-dev libglvnd-dev libglx-dev libgmock-dev libgmp-dev
# [build-colmap-cuda]   libgmpxx4ldbl libgoogle-glog-dev libgphoto2-6 libgphoto2-l10n
# [build-colmap-cuda]   libgphoto2-port12 libgraphblas-dev libgraphblas6
# [build-colmap-cuda]   libgstreamer-plugins-base1.0-0 libgtest-dev libilmbase-dev libklu1 libldl2
# [build-colmap-cuda]   liblog4cplus-2.0.5 libmetis-dev libmongoose2 libmpfr-dev libopencolorio1v5
# [build-colmap-cuda]   libopencv-core4.5d libopencv-imgcodecs4.5d libopencv-imgproc4.5d
# [build-colmap-cuda]   libopencv-videoio4.5d libopenexr-dev libopengl-dev libopenimageio-dev
# [build-colmap-cuda]   libopenimageio-doc libopenimageio2.2 libopenvdb8.1 liborc-0.4-0 librbio2
# [build-colmap-cuda]   libsliplu1 libsocket++1 libsquish0 libsuitesparse-dev libtbb12 libtbb2
# [build-colmap-cuda]   libtbbmalloc2 libtinyxml2.6.2v5 libumfpack5 libunwind-dev libvisual-0.4-0
# [build-colmap-cuda]   libyaml-cpp0.7 ninja-build openimageio-tools
# [build-colmap-cuda] The following packages will be upgraded:
# [build-colmap-cuda]   curl libcurl4 libcurl4-openssl-dev libsqlite3-0 libsqlite3-dev libssl-dev
# [build-colmap-cuda]   libssl3
# [build-colmap-cuda] 7 upgraded, 94 newly installed, 0 to remove and 154 not upgraded.
# [build-colmap-cuda] Need to get 68.0 MB of archives.
# [build-colmap-cuda] After this operation, 394 MB of additional disk space will be used.
# [build-colmap-cuda] Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl-dev amd64 3.0.2-0ubuntu1.25 [2,377 kB]
# [build-colmap-cuda] Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl3 amd64 3.0.2-0ubuntu1.25 [1,906 kB]
# [build-colmap-cuda] Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-dev amd64 3.37.2-2ubuntu0.7 [847 kB]
# [build-colmap-cuda] Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-0 amd64 3.37.2-2ubuntu0.7 [643 kB]
# [build-colmap-cuda] Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4-openssl-dev amd64 7.81.0-1ubuntu1.25 [387 kB]
# [build-colmap-cuda] Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 curl amd64 7.81.0-1ubuntu1.25 [194 kB]
# [build-colmap-cuda] Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4 amd64 7.81.0-1ubuntu1.25 [291 kB]
# [build-colmap-cuda] Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 googletest all 1.11.0-3 [541 kB]
# [build-colmap-cuda] Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# [build-colmap-cuda] Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# [build-colmap-cuda] Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.6 [848 kB]
# [build-colmap-cuda] Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# [build-colmap-cuda] Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.6 [712 kB]
# [build-colmap-cuda] Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-atomic1.74.0 amd64 1.74.0-14ubuntu3 [224 kB]
# [build-colmap-cuda] Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-atomic1.74-dev amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-chrono1.74.0 amd64 1.74.0-14ubuntu3 [232 kB]
# [build-colmap-cuda] Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-chrono1.74-dev amd64 1.74.0-14ubuntu3 [239 kB]
# [build-colmap-cuda] Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-date-time1.74.0 amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-serialization1.74.0 amd64 1.74.0-14ubuntu3 [327 kB]
# [build-colmap-cuda] Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-serialization1.74-dev amd64 1.74.0-14ubuntu3 [375 kB]
# [build-colmap-cuda] Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-date-time1.74-dev amd64 1.74.0-14ubuntu3 [226 kB]
# [build-colmap-cuda] Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-filesystem1.74.0 amd64 1.74.0-14ubuntu3 [264 kB]
# [build-colmap-cuda] Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-regex1.74.0 amd64 1.74.0-14ubuntu3 [511 kB]
# [build-colmap-cuda] Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74.0 amd64 1.74.0-14ubuntu3 [304 kB]
# [build-colmap-cuda] Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-regex1.74-dev amd64 1.74.0-14ubuntu3 [596 kB]
# [build-colmap-cuda] Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74.0 amd64 1.74.0-14ubuntu3 [446 kB]
# [build-colmap-cuda] Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74-dev amd64 1.74.0-14ubuntu3 [564 kB]
# [build-colmap-cuda] Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74-dev amd64 1.74.0-14ubuntu3 [335 kB]
# [build-colmap-cuda] Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph-dev amd64 1.74.0.3ubuntu7 [3,348 B]
# [build-colmap-cuda] Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-iostreams1.74.0 amd64 1.74.0-14ubuntu3 [245 kB]
# [build-colmap-cuda] Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options1.74.0 amd64 1.74.0-14ubuntu3 [311 kB]
# [build-colmap-cuda] Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options1.74-dev amd64 1.74.0-14ubuntu3 [380 kB]
# [build-colmap-cuda] Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options-dev amd64 1.74.0.3ubuntu7 [3,266 B]
# [build-colmap-cuda] Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-system1.74.0 amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-system1.74-dev amd64 1.74.0-14ubuntu3 [218 kB]
# [build-colmap-cuda] Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-system-dev amd64 1.74.0.3ubuntu7 [3,390 B]
# [build-colmap-cuda] Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74.0 amd64 1.74.0-14ubuntu3 [262 kB]
# [build-colmap-cuda] Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74-dev amd64 1.74.0-14ubuntu3 [272 kB]
# [build-colmap-cuda] Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread-dev amd64 1.74.0.3ubuntu7 [3,266 B]
# [build-colmap-cuda] Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbtf1 amd64 1:5.10.1+dfsg-4build1 [12.1 kB]
# [build-colmap-cuda] Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags-dev amd64 2.2.2-2 [93.7 kB]
# [build-colmap-cuda] Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunwind-dev amd64 1.3.2-2build2.1 [1,883 kB]
# [build-colmap-cuda] Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog-dev amd64 0.5.0+really0.4.0-2 [91.9 kB]
# [build-colmap-cuda] Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeigen3-dev all 3.4.0-2ubuntu2 [1,056 kB]
# [build-colmap-cuda] Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libklu1 amd64 1:5.10.1+dfsg-4build1 [77.6 kB]
# [build-colmap-cuda] Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldl2 amd64 1:5.10.1+dfsg-4build1 [11.7 kB]
# [build-colmap-cuda] Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmongoose2 amd64 1:5.10.1+dfsg-4build1 [33.5 kB]
# [build-colmap-cuda] Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libumfpack5 amd64 1:5.10.1+dfsg-4build1 [250 kB]
# [build-colmap-cuda] Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 librbio2 amd64 1:5.10.1+dfsg-4build1 [26.6 kB]
# [build-colmap-cuda] Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsliplu1 amd64 1:5.10.1+dfsg-4build1 [37.1 kB]
# [build-colmap-cuda] Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsuitesparse-dev amd64 1:5.10.1+dfsg-4build1 [1,058 kB]
# [build-colmap-cuda] Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres-dev amd64 2.0.0+dfsg1-5 [1,177 kB]
# [build-colmap-cuda] Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmpxx4ldbl amd64 2:6.2.1+dfsg-3ubuntu1 [9,580 B]
# [build-colmap-cuda] Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp-dev amd64 2:6.2.1+dfsg-3ubuntu1 [337 kB]
# [build-colmap-cuda] Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmpfr-dev amd64 4.1.0-3build3 [271 kB]
# [build-colmap-cuda] Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcgal-dev amd64 5.4-1 [4,784 kB]
# [build-colmap-cuda] Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcharls2 amd64 2.3.4-1 [87.0 kB]
# [build-colmap-cuda] Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdcmtk16 amd64 3.6.6-5 [5,434 kB]
# [build-colmap-cuda] Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# [build-colmap-cuda] Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# [build-colmap-cuda] Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# [build-colmap-cuda] Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libexif12 amd64 0.6.24-1ubuntu0.22.04.1 [92.7 kB]
# [build-colmap-cuda] Get:63 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsocket++1 amd64 1.12.13+git20131030.5d039ba-1 [84.3 kB]
# [build-colmap-cuda] Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgdcm3.0 amd64 3.0.10-1build2 [1,830 kB]
# [build-colmap-cuda] Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# [build-colmap-cuda] Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# [build-colmap-cuda] Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# [build-colmap-cuda] Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# [build-colmap-cuda] Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# [build-colmap-cuda] Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.4 [7,012 B]
# [build-colmap-cuda] Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# [build-colmap-cuda] Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# [build-colmap-cuda] Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# [build-colmap-cuda] Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgtest-dev amd64 1.11.0-3 [250 kB]
# [build-colmap-cuda] Get:75 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgmock-dev amd64 1.11.0-3 [128 kB]
# [build-colmap-cuda] Get:76 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-core4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,184 kB]
# [build-colmap-cuda] Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-port12 amd64 2.5.27-1ubuntu0.1 [57.9 kB]
# [build-colmap-cuda] Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-6 amd64 2.5.27-1ubuntu0.1 [727 kB]
# [build-colmap-cuda] Get:79 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-l10n all 2.5.27-1ubuntu0.1 [14.4 kB]
# [build-colmap-cuda] Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas6 amd64 6.1.4+dfsg-2 [20.1 MB]
# [build-colmap-cuda] Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas-dev amd64 6.1.4+dfsg-2 [54.4 kB]
# [build-colmap-cuda] Get:82 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase-dev amd64 2.5.7-2 [78.4 kB]
# [build-colmap-cuda] Get:83 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblog4cplus-2.0.5 amd64 2.0.5-3 [184 kB]
# [build-colmap-cuda] Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis-dev amd64 5.1.0.dfsg-7build2 [5,818 B]
# [build-colmap-cuda] Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinyxml2.6.2v5 amd64 2.6.2-6ubuntu0.22.04.1 [33.2 kB]
# [build-colmap-cuda] Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libyaml-cpp0.7 amd64 0.7.0+dfsg-8build1 [97.7 kB]
# [build-colmap-cuda] Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopencolorio1v5 amd64 1.1.1~dfsg0-7.1build1 [362 kB]
# [build-colmap-cuda] Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbbmalloc2 amd64 2021.5.0-7ubuntu2 [49.6 kB]
# [build-colmap-cuda] Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb12 amd64 2021.5.0-7ubuntu2 [84.8 kB]
# [build-colmap-cuda] Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr-dev amd64 2.5.7-1 [73.3 kB]
# [build-colmap-cuda] Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio-doc all 2.2.18.0+dfsg-1ubuntu2 [2,794 kB]
# [build-colmap-cuda] Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb2 amd64 2020.3-1ubuntu3 [101 kB]
# [build-colmap-cuda] Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenvdb8.1 amd64 8.1.0-3build1 [793 kB]
# [build-colmap-cuda] Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsquish0 amd64 1.15-1build1 [19.6 kB]
# [build-colmap-cuda] Get:95 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio2.2 amd64 2.2.18.0+dfsg-1ubuntu2 [2,305 kB]
# [build-colmap-cuda] Get:96 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ninja-build amd64 1.10.1-1 [111 kB]
# [build-colmap-cuda] Get:97 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio-dev amd64 2.2.18.0+dfsg-1ubuntu2 [384 kB]
# [build-colmap-cuda] Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openimageio-tools amd64 2.2.18.0+dfsg-1ubuntu2 [495 kB]
# [build-colmap-cuda] Get:99 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgproc4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,412 kB]
# [build-colmap-cuda] Get:100 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgcodecs4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [148 kB]
# [build-colmap-cuda] Get:101 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-videoio4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [213 kB]
# [build-colmap-cuda] debconf: unable to initialize frontend: Dialog
# [build-colmap-cuda] debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 101.)
# [build-colmap-cuda] debconf: falling back to frontend: Readline
# [build-colmap-cuda] debconf: unable to initialize frontend: Readline
# [build-colmap-cuda] debconf: (This frontend requires a controlling tty.)
# [build-colmap-cuda] debconf: falling back to frontend: Teletype
# [build-colmap-cuda] dpkg-preconfigure: unable to re-open stdin:
# [build-colmap-cuda] Fetched 68.0 MB in 4s (17.1 MB/s)
# [build-colmap-cuda] (Reading database ...
# [build-colmap-cuda] (Reading database ... 5%
# [build-colmap-cuda] (Reading database ... 10%
# [build-colmap-cuda] (Reading database ... 15%
# [build-colmap-cuda] (Reading database ... 20%
# [build-colmap-cuda] (Reading database ... 25%
# [build-colmap-cuda] (Reading database ... 30%
# [build-colmap-cuda] (Reading database ... 35%
# [build-colmap-cuda] (Reading database ... 40%
# [build-colmap-cuda] (Reading database ... 45%
# [build-colmap-cuda] (Reading database ... 50%
# [build-colmap-cuda] (Reading database ... 55%
# [build-colmap-cuda] (Reading database ... 60%
# [build-colmap-cuda] (Reading database ... 65%
# [build-colmap-cuda] (Reading database ... 70%
# [build-colmap-cuda] (Reading database ... 75%
# [build-colmap-cuda] (Reading database ... 80%
# [build-colmap-cuda] (Reading database ... 85%
# [build-colmap-cuda] (Reading database ... 90%
# [build-colmap-cuda] (Reading database ... 95%
# [build-colmap-cuda] (Reading database ... 100%
# [build-colmap-cuda] (Reading database ... 123747 files and directories currently installed.)
# [build-colmap-cuda] Preparing to unpack .../libssl-dev_3.0.2-0ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libssl-dev:amd64 (3.0.2-0ubuntu1.25) over (3.0.2-0ubuntu1.23) ...
# [build-colmap-cuda] Preparing to unpack .../libssl3_3.0.2-0ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libssl3:amd64 (3.0.2-0ubuntu1.25) over (3.0.2-0ubuntu1.23) ...
# [build-colmap-cuda] Setting up libssl3:amd64 (3.0.2-0ubuntu1.25) ...
# [build-colmap-cuda] debconf: unable to initialize frontend: Dialog
# [build-colmap-cuda] debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# [build-colmap-cuda] debconf: falling back to frontend: Readline
# [build-colmap-cuda] (Reading database ...
# [build-colmap-cuda] (Reading database ... 5%
# [build-colmap-cuda] (Reading database ... 10%
# [build-colmap-cuda] (Reading database ... 15%
# [build-colmap-cuda] (Reading database ... 20%
# [build-colmap-cuda] (Reading database ... 25%
# [build-colmap-cuda] (Reading database ... 30%
# [build-colmap-cuda] (Reading database ... 35%
# [build-colmap-cuda] (Reading database ... 40%
# [build-colmap-cuda] (Reading database ... 45%
# [build-colmap-cuda] (Reading database ... 50%
# [build-colmap-cuda] (Reading database ... 55%
# [build-colmap-cuda] (Reading database ... 60%
# [build-colmap-cuda] (Reading database ... 65%
# [build-colmap-cuda] (Reading database ... 70%
# [build-colmap-cuda] (Reading database ... 75%
# [build-colmap-cuda] (Reading database ... 80%
# [build-colmap-cuda] (Reading database ... 85%
# [build-colmap-cuda] (Reading database ... 90%
# [build-colmap-cuda] (Reading database ... 95%
# [build-colmap-cuda] (Reading database ... 100%
# [build-colmap-cuda] (Reading database ... 123747 files and directories currently installed.)
# [build-colmap-cuda] Preparing to unpack .../00-libsqlite3-dev_3.37.2-2ubuntu0.7_amd64.deb ...
# [build-colmap-cuda] Unpacking libsqlite3-dev:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# [build-colmap-cuda] Preparing to unpack .../01-libsqlite3-0_3.37.2-2ubuntu0.7_amd64.deb ...
# [build-colmap-cuda] Unpacking libsqlite3-0:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# [build-colmap-cuda] Preparing to unpack .../02-libcurl4-openssl-dev_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Preparing to unpack .../03-curl_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking curl (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Preparing to unpack .../04-libcurl4_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libcurl4:amd64 (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Selecting previously unselected package googletest.
# [build-colmap-cuda] Preparing to unpack .../05-googletest_1.11.0-3_all.deb ...
# [build-colmap-cuda] Unpacking googletest (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libcdparanoia0:amd64.
# [build-colmap-cuda] Preparing to unpack .../06-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# [build-colmap-cuda] Selecting previously unselected package liborc-0.4-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../07-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../08-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.6_amd64.deb ...
# [build-colmap-cuda] Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# [build-colmap-cuda] Selecting previously unselected package libvisual-0.4-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../09-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# [build-colmap-cuda] Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# [build-colmap-cuda] Preparing to unpack .../10-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.6_amd64.deb ...
# [build-colmap-cuda] Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.6) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-atomic1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../11-libboost-atomic1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-atomic1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-atomic1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../12-libboost-atomic1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-atomic1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-chrono1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../13-libboost-chrono1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-chrono1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-chrono1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../14-libboost-chrono1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-chrono1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-date-time1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../15-libboost-date-time1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-date-time1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-serialization1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../16-libboost-serialization1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-serialization1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-serialization1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../17-libboost-serialization1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-serialization1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-date-time1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../18-libboost-date-time1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-date-time1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-filesystem1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../19-libboost-filesystem1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-filesystem1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-regex1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../20-libboost-regex1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-regex1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../21-libboost-graph1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-regex1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../22-libboost-regex1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-regex1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-test1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../23-libboost-test1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-test1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-test1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../24-libboost-test1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-test1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../25-libboost-graph1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../26-libboost-graph-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-iostreams1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../27-libboost-iostreams1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../28-libboost-program-options1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../29-libboost-program-options1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../30-libboost-program-options-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-system1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../31-libboost-system1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-system1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-system1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../32-libboost-system1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-system1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-system-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../33-libboost-system-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-system-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../34-libboost-thread1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../35-libboost-thread1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] still running...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../36-libboost-thread-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libbtf1:amd64.
# [build-colmap-cuda] Preparing to unpack .../37-libbtf1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libbtf1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libgflags-dev.
# [build-colmap-cuda] Preparing to unpack .../38-libgflags-dev_2.2.2-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgflags-dev (2.2.2-2) ...
# [build-colmap-cuda] Selecting previously unselected package libunwind-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../39-libunwind-dev_1.3.2-2build2.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libunwind-dev:amd64 (1.3.2-2build2.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgoogle-glog-dev.
# [build-colmap-cuda] Preparing to unpack .../40-libgoogle-glog-dev_0.5.0+really0.4.0-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgoogle-glog-dev (0.5.0+really0.4.0-2) ...
# [build-colmap-cuda] Selecting previously unselected package libeigen3-dev.
# [build-colmap-cuda] Preparing to unpack .../41-libeigen3-dev_3.4.0-2ubuntu2_all.deb ...
# [build-colmap-cuda] Unpacking libeigen3-dev (3.4.0-2ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libklu1:amd64.
# [build-colmap-cuda] Preparing to unpack .../42-libklu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libklu1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libldl2:amd64.
# [build-colmap-cuda] Preparing to unpack .../43-libldl2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libldl2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libmongoose2:amd64.
# [build-colmap-cuda] Preparing to unpack .../44-libmongoose2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libmongoose2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libumfpack5:amd64.
# [build-colmap-cuda] Preparing to unpack .../45-libumfpack5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libumfpack5:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package librbio2:amd64.
# [build-colmap-cuda] Preparing to unpack .../46-librbio2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking librbio2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsliplu1:amd64.
# [build-colmap-cuda] Preparing to unpack .../47-libsliplu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsliplu1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsuitesparse-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../48-libsuitesparse-dev_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsuitesparse-dev:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libceres-dev.
# [build-colmap-cuda] Preparing to unpack .../49-libceres-dev_2.0.0+dfsg1-5_amd64.deb ...
# [build-colmap-cuda] Unpacking libceres-dev (2.0.0+dfsg1-5) ...
# [build-colmap-cuda] Selecting previously unselected package libgmpxx4ldbl:amd64.
# [build-colmap-cuda] Preparing to unpack .../50-libgmpxx4ldbl_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# [build-colmap-cuda] Selecting previously unselected package libgmp-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../51-libgmp-dev_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmp-dev:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# [build-colmap-cuda] Selecting previously unselected package libmpfr-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../52-libmpfr-dev_4.1.0-3build3_amd64.deb ...
# [build-colmap-cuda] Unpacking libmpfr-dev:amd64 (4.1.0-3build3) ...
# [build-colmap-cuda] Selecting previously unselected package libcgal-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../53-libcgal-dev_5.4-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libcgal-dev:amd64 (5.4-1) ...
# [build-colmap-cuda] Selecting previously unselected package libcharls2:amd64.
# [build-colmap-cuda] Preparing to unpack .../54-libcharls2_2.3.4-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libcharls2:amd64 (2.3.4-1) ...
# [build-colmap-cuda] Selecting previously unselected package libdcmtk16.
# [build-colmap-cuda] Preparing to unpack .../55-libdcmtk16_3.6.6-5_amd64.deb ...
# [build-colmap-cuda] Unpacking libdcmtk16 (3.6.6-5) ...
# [build-colmap-cuda] Selecting previously unselected package libglx-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../56-libglx-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglx-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../57-libgl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libegl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../58-libegl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libegl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libexif12:amd64.
# [build-colmap-cuda] Preparing to unpack .../59-libexif12_0.6.24-1ubuntu0.22.04.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libexif12:amd64 (0.6.24-1ubuntu0.22.04.1) ...
# [build-colmap-cuda] Selecting previously unselected package libsocket++1:amd64.
# [build-colmap-cuda] Preparing to unpack .../60-libsocket++1_1.12.13+git20131030.5d039ba-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsocket++1:amd64 (1.12.13+git20131030.5d039ba-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgdcm3.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../61-libgdcm3.0_3.0.10-1build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgdcm3.0:amd64 (3.0.10-1build2) ...
# [build-colmap-cuda] Selecting previously unselected package libgles1:amd64.
# [build-colmap-cuda] Preparing to unpack .../62-libgles1_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgles1:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgles-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../63-libgles-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgles-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglvnd-core-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../64-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopengl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../65-libopengl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglvnd-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../66-libglvnd-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgl1-mesa-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../67-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.4_amd64.deb ...
# [build-colmap-cuda] Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.4) ...
# [build-colmap-cuda] Selecting previously unselected package libglu1-mesa:amd64.
# [build-colmap-cuda] Preparing to unpack .../68-libglu1-mesa_9.0.2-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglu1-mesa-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../69-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglew-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../70-libglew-dev_2.2.0-4_amd64.deb ...
# [build-colmap-cuda] Unpacking libglew-dev:amd64 (2.2.0-4) ...
# [build-colmap-cuda] Selecting previously unselected package libgtest-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../71-libgtest-dev_1.11.0-3_amd64.deb ...
# [build-colmap-cuda] Unpacking libgtest-dev:amd64 (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libgmock-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../72-libgmock-dev_1.11.0-3_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmock-dev:amd64 (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-port12:amd64.
# [build-colmap-cuda] Preparing to unpack .../73-libgphoto2-port12_2.5.27-1ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-port12:amd64 (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-6:amd64.
# [build-colmap-cuda] Preparing to unpack .../74-libgphoto2-6_2.5.27-1ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-6:amd64 (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-l10n.
# [build-colmap-cuda] Preparing to unpack .../75-libgphoto2-l10n_2.5.27-1ubuntu0.1_all.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-l10n (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgraphblas6:amd64.
# [build-colmap-cuda] Preparing to unpack .../76-libgraphblas6_6.1.4+dfsg-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgraphblas6:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Selecting previously unselected package libgraphblas-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../77-libgraphblas-dev_6.1.4+dfsg-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgraphblas-dev:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Selecting previously unselected package libilmbase-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../78-libilmbase-dev_2.5.7-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libilmbase-dev:amd64 (2.5.7-2) ...
# [build-colmap-cuda] Selecting previously unselected package liblog4cplus-2.0.5:amd64.
# [build-colmap-cuda] Preparing to unpack .../79-liblog4cplus-2.0.5_2.0.5-3_amd64.deb ...
# [build-colmap-cuda] Unpacking liblog4cplus-2.0.5:amd64 (2.0.5-3) ...
# [build-colmap-cuda] Selecting previously unselected package libmetis-dev.
# [build-colmap-cuda] Preparing to unpack .../80-libmetis-dev_5.1.0.dfsg-7build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libmetis-dev (5.1.0.dfsg-7build2) ...
# [build-colmap-cuda] Selecting previously unselected package libtinyxml2.6.2v5:amd64.
# [build-colmap-cuda] Preparing to unpack .../81-libtinyxml2.6.2v5_2.6.2-6ubuntu0.22.04.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libtinyxml2.6.2v5:amd64 (2.6.2-6ubuntu0.22.04.1) ...
# [build-colmap-cuda] Selecting previously unselected package libyaml-cpp0.7:amd64.
# [build-colmap-cuda] Preparing to unpack .../82-libyaml-cpp0.7_0.7.0+dfsg-8build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libyaml-cpp0.7:amd64 (0.7.0+dfsg-8build1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencolorio1v5.
# [build-colmap-cuda] Preparing to unpack .../83-libopencolorio1v5_1.1.1~dfsg0-7.1build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencolorio1v5 (1.1.1~dfsg0-7.1build1) ...
# [build-colmap-cuda] Selecting previously unselected package libtbbmalloc2:amd64.
# [build-colmap-cuda] Preparing to unpack .../84-libtbbmalloc2_2021.5.0-7ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbbmalloc2:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libtbb12:amd64.
# [build-colmap-cuda] Preparing to unpack .../85-libtbb12_2021.5.0-7ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbb12:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-core4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../86-libopencv-core4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-core4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-imgproc4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../87-libopencv-imgproc4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-imgproc4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-imgcodecs4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../88-libopencv-imgcodecs4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-imgcodecs4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-videoio4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../89-libopencv-videoio4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-videoio4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenexr-dev.
# [build-colmap-cuda] Preparing to unpack .../90-libopenexr-dev_2.5.7-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenexr-dev (2.5.7-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio-doc.
# [build-colmap-cuda] Preparing to unpack .../91-libopenimageio-doc_2.2.18.0+dfsg-1ubuntu2_all.deb ...
# [build-colmap-cuda] Unpacking libopenimageio-doc (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libtbb2:amd64.
# [build-colmap-cuda] Preparing to unpack .../92-libtbb2_2020.3-1ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbb2:amd64 (2020.3-1ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libopenvdb8.1.
# [build-colmap-cuda] Preparing to unpack .../93-libopenvdb8.1_8.1.0-3build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenvdb8.1 (8.1.0-3build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsquish0:amd64.
# [build-colmap-cuda] Preparing to unpack .../94-libsquish0_1.15-1build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsquish0:amd64 (1.15-1build1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio2.2:amd64.
# [build-colmap-cuda] Preparing to unpack .../95-libopenimageio2.2_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenimageio2.2:amd64 (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package ninja-build.
# [build-colmap-cuda] Preparing to unpack .../96-ninja-build_1.10.1-1_amd64.deb ...
# [build-colmap-cuda] Unpacking ninja-build (1.10.1-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../97-libopenimageio-dev_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenimageio-dev:amd64 (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package openimageio-tools.
# [build-colmap-cuda] Preparing to unpack .../98-openimageio-tools_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking openimageio-tools (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Setting up libboost-chrono1.74.0:amd64 (1.74.0-14ubuntu3) ...
# ...
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/VLFeat/scalespace.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Factor.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Array.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PlyFile.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrixInterface.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MarchingCubes.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartition.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonReconClientServer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrixInterface.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MergePlyClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/ParameterPack.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BinaryNode.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Geometry.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PlyFile.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.client.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularTree.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BlockedVector.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Window.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyExceptions.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Reconstructors.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/CmdLineParser.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyAtomic.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PNG.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularGrid.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PPolynomial.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularTree.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyMiscellany.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Extrapolator.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Allocator.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PPolynomial.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Rasterizer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonReconClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/JPEG.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.WeightedSamples.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Reconstructors.streams.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/VertexFactory.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Rasterizer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Image.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrix.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.2D.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.System.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MAT.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.server.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.imp.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularGrid.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/LinearSolvers.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Ply.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MAT.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Socket.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.Initialize.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Geometry.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartitionClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Socket.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/VertexFactory.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/CmdLineParser.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrix.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartition.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.imp.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MergePlyClientServer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Window.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointExtent.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PNG.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PreProcessor.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Array.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartitionClientServer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Polynomial.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Polynomial.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BSplineData.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SurfaceTrimmer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Ply.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MultiThreading.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/JPEG.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.Evaluation.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/NestedVector.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.SortedTreeNodes.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BSplineData.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.3D.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Streams.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointExtent.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindGlew.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindDependencies.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindGlog.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindMetis.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindCHOLMOD.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/Findonnxruntime.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindCryptoPP.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda] -- Set non-toolchain portion of runtime path of "/content/project/.local/colmap-cuda/bin/colmap" to "$ORIGIN/../lib"
# [build-colmap-cuda] COLMAP 4.2.0.dev0 (Commit 7f66f79 on 2026-07-22 with CUDA)
# [build-colmap-cuda] Usage:
# [build-colmap-cuda]   colmap [command] [options]
# [build-colmap-cuda] Documentation:
# [build-colmap-cuda]   https://colmap.github.io/
# [build-colmap-cuda] Example usage:
# [build-colmap-cuda]   colmap help [ -h, --help ]
# [build-colmap-cuda]   colmap gui
# [build-colmap-cuda]   colmap gui -h [ --help ]
# [build-colmap-cuda]   colmap automatic_reconstructor -h [ --help ]
# [build-colmap-cuda]   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
# [build-colmap-cuda]   colmap feature_extractor --image_path IMAGES --database_path DATABASE
# [build-colmap-cuda]   colmap exhaustive_matcher --database_path DATABASE
# [build-colmap-cuda]   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
# [build-colmap-cuda]   ...
# [build-colmap-cuda] Available commands:
# [build-colmap-cuda]   help
# [build-colmap-cuda]   version
# [build-colmap-cuda]   gui
# [build-colmap-cuda]   automatic_reconstructor
# [build-colmap-cuda]   bundle_adjuster
# [build-colmap-cuda]   color_extractor
# [build-colmap-cuda]   database_cleaner
# [build-colmap-cuda]   database_creator
# [build-colmap-cuda]   database_merger
# [build-colmap-cuda]   advancing_front_mesher
# [build-colmap-cuda]   delaunay_mesher
# [build-colmap-cuda]   exhaustive_matcher
# [build-colmap-cuda]   feature_extractor
# [build-colmap-cuda]   feature_importer
# [build-colmap-cuda]   geometric_verifier
# [build-colmap-cuda]   global_mapper
# [build-colmap-cuda]   guided_geometric_verifier
# [build-colmap-cuda]   hierarchical_mapper
# [build-colmap-cuda]   image_deleter
# [build-colmap-cuda]   image_filterer
# [build-colmap-cuda]   image_rectifier
# [build-colmap-cuda]   image_registrator
# [build-colmap-cuda]   image_undistorter
# [build-colmap-cuda]   image_undistorter_standalone
# [build-colmap-cuda]   mapper
# [build-colmap-cuda]   matches_importer
# [build-colmap-cuda]   mesh_simplifier
# [build-colmap-cuda]   mesh_texturer
# [build-colmap-cuda]   model_aligner
# [build-colmap-cuda]   model_analyzer
# [build-colmap-cuda]   model_clusterer
# [build-colmap-cuda]   model_comparer
# [build-colmap-cuda]   model_converter
# [build-colmap-cuda]   model_cropper
# [build-colmap-cuda]   model_merger
# [build-colmap-cuda]   model_orientation_aligner
# [build-colmap-cuda]   model_splitter
# [build-colmap-cuda]   model_transformer
# [build-colmap-cuda]   patch_match_stereo
# [build-colmap-cuda]   point_filtering
# [build-colmap-cuda]   point_triangulator
# [build-colmap-cuda]   pose_prior_mapper
# [build-colmap-cuda]   poisson_mesher
# [build-colmap-cuda]   project_generator
# [build-colmap-cuda]   rig_configurator
# [build-colmap-cuda]   rotation_averager
# [build-colmap-cuda]   sequential_matcher
# [build-colmap-cuda]   spatial_matcher
# [build-colmap-cuda]   stereo_fusion
# [build-colmap-cuda]   transitive_matcher
# [build-colmap-cuda]   view_graph_calibrator
# [build-colmap-cuda]   vocab_tree_builder
# [build-colmap-cuda]   vocab_tree_matcher
# [build-colmap-cuda]   vocab_tree_retriever
# [build-colmap-cuda]
# [build-colmap-cuda] COLMAP CUDA build hoàn tất.
# [build-colmap-cuda] COLMAP_BIN=/content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda] Ví dụ chạy B2:
# [build-colmap-cuda]   export COLMAP_BIN=/content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda]   bash pipeline/scripts/05_run_b2_pilot.sh hcm0031
# [build-colmap-cuda] RETURN CODE = 0
# COLMAP 4.2.0.dev0 (Commit 7f66f79 on 2026-07-22 with CUDA)
# Usage:
#   colmap [command] [options]
# Documentation:
#   https://colmap.github.io/
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
# Available commands:
#   help
#   version
#   gui
#   automatic_reconstructor
#
#
# COLMAP CUDA verify PASS
# COLMAP_BIN se dung cho B2 = /content/project/.local/colmap-cuda/bin/colmap

# %% [markdown]
# Cell tren la mau dung cho Colab/Kaggle: neu `colmap` cai san la CPU-only thi no se build `COLMAP` co CUDA, verify lai, roi luu duong dan vao bien `colmap_bin_for_b2` de cell chay `B2` ben duoi dung thang binary moi.

# %%
import os
assert colmap_bin_for_b2, 'COLMAP_BIN cho B2 dang rong. Hay chay cell verify/build COLMAP truoc.'
os.environ['COLMAP_BIN'] = colmap_bin_for_b2
print('Exported COLMAP_BIN =', os.environ['COLMAP_BIN'])
# Out:
# Exported COLMAP_BIN = /content/project/.local/colmap-cuda/bin/colmap

# %%
import os
import re
import subprocess
from pathlib import Path

downloads_dir = Path(WORKDIR) / 'downloads'
downloads_dir.mkdir(parents=True, exist_ok=True)

if DATASET_URL:
    archive_path = downloads_dir / 'dataset_round1.zip'
    if 'drive.google.com' in DATASET_URL:
        subprocess.run(['python3', '-m', 'pip', 'install', 'gdown'], check=True)
        m = re.search(r'/d/([^/]+)', DATASET_URL)
        file_id = m.group(1) if m else ''
        assert file_id, 'Khong trich duoc file id tu Google Drive link'
        subprocess.run(['gdown', '--fuzzy', f'https://drive.google.com/uc?id={file_id}', '-O', str(archive_path)], check=True)
    else:
        subprocess.run(['bash', '-lc', f'wget -O "{archive_path}" "{DATASET_URL}"'], check=True)
    raw_dir = Path(WORKDIR) / '_dataset_round1_raw'
    subprocess.run(['bash', '-lc', f'rm -rf "{raw_dir}" && mkdir -p "{raw_dir}" && unzip -q "{archive_path}" -d "{raw_dir}"'], check=True)
    print('Da tai va giai nen dataset tu DATASET_URL ->', raw_dir)
elif KAGGLE_DATASET:
    if KAGGLE_USERNAME and KAGGLE_KEY:
        kaggle_dir = Path.home() / '.kaggle'
        kaggle_dir.mkdir(parents=True, exist_ok=True)
        (kaggle_dir / 'kaggle.json').write_text('{"username":"' + KAGGLE_USERNAME + '","key":"' + KAGGLE_KEY + '"}', encoding='utf-8')
        os.chmod(kaggle_dir / 'kaggle.json', 0o600)
    subprocess.run(['python3', '-m', 'pip', 'install', 'kaggle'], check=True)
    archive_path = downloads_dir / 'dataset_round1.zip'
    subprocess.run(['bash', '-lc', f'kaggle datasets download -d "{KAGGLE_DATASET}" -p "{downloads_dir}" -f "{archive_path.name}" || kaggle datasets download -d "{KAGGLE_DATASET}" -p "{downloads_dir}"'], check=True)
    if not archive_path.exists():
        zips = sorted(downloads_dir.glob('*.zip'))
        assert zips, 'Kaggle download xong nhung khong thay file zip'
        archive_path = zips[0]
    raw_dir = Path(WORKDIR) / '_dataset_round1_raw'
    subprocess.run(['bash', '-lc', f'rm -rf "{raw_dir}" && mkdir -p "{raw_dir}" && unzip -q "{archive_path}" -d "{raw_dir}"'], check=True)
    print('Da tai va giai nen dataset tu KAGGLE_DATASET ->', raw_dir)
else:
    print('Khong co DATASET_URL/KAGGLE_DATASET. Notebook se thu tu do dataset san co.')
# Out:
# Da tai va giai nen dataset tu DATASET_URL -> /content/_dataset_round1_raw

# %%
from pathlib import Path

expected_scene = SCENE
dataset_root = None

if DATASET_ROOT_OVERRIDE:
    p = Path(DATASET_ROOT_OVERRIDE)
    if (p / expected_scene / 'train' / 'images').is_dir() and (p / expected_scene / 'test' / 'images').is_dir():
        dataset_root = p

workdir_path = Path(WORKDIR)
candidates = [
    workdir_path / '_dataset_round1_raw',
    workdir_path / 'project' / 'Dataset' / 'VAI_NVS_DATA' / 'phase1' / 'public_set',
    workdir_path,
    Path('/kaggle/input'),
]

if dataset_root is None:
    for base in candidates:
        if not base.exists():
            continue
        if base.name == 'public_set' and (base / expected_scene / 'train' / 'images').is_dir():
            dataset_root = base
            break
        for p in base.rglob('public_set'):
            if (p / expected_scene / 'train' / 'images').is_dir() and (p / expected_scene / 'test' / 'images').is_dir():
                dataset_root = p
                break
        if dataset_root is not None:
            break

assert dataset_root is not None, 'Khong tim thay Dataset/VAI_NVS_DATA/phase1/public_set co scene hcm0031'
print('DATASET_ROOT =', dataset_root)
# Out:
# DATASET_ROOT = /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set

# %%
import subprocess
from pathlib import Path

need_gs_repo = RUN_TRAIN == '1' or RUN_RENDER == '1' or RUN_EVAL == '1'
gs_repo = ''

if need_gs_repo:
    assert GS_REPO_URL, 'Can GS_REPO_URL neu RUN_TRAIN=1 hoac RUN_RENDER=1 hoac RUN_EVAL=1'
    gs_clone_url = GS_REPO_URL
    if GITHUB_TOKEN and 'github.com' in GS_REPO_URL:
        gs_clone_url = GS_REPO_URL.replace('https://', f'https://{GITHUB_TOKEN}@')
    gs_repo_dir = f'{WORKDIR}/gs_repo'
    subprocess.run(['bash', '-lc', f'rm -rf "{gs_repo_dir}"'], check=True)
    subprocess.run([
        'git', 'clone', '--depth', '1', '-b', GS_REPO_BRANCH, gs_clone_url, gs_repo_dir
    ], check=True)
    gs_repo = gs_repo_dir
    print('GS_REPO =', gs_repo)
else:
    print('Khong can GS_REPO cho dense-only pilot')
# Out:
# Khong can GS_REPO cho dense-only pilot

# %%
import os
from pathlib import Path

env = os.environ.copy()
env['DATASET_ROOT'] = str(dataset_root)
env['COLMAP_BIN'] = colmap_bin_for_b2
env['RUN_DENSE'] = RUN_DENSE
env['RUN_TRAIN'] = RUN_TRAIN
env['RUN_RENDER'] = RUN_RENDER
env['RUN_EVAL'] = RUN_EVAL
env['PATCH_MATCH_MAX_IMAGE_SIZE'] = PATCH_MATCH_MAX_IMAGE_SIZE
env['PATCH_MATCH_GPU_INDEX'] = PATCH_MATCH_GPU_INDEX
env['PATCH_MATCH_CACHE_SIZE'] = PATCH_MATCH_CACHE_SIZE
if gs_repo:
    env['GS_REPO'] = gs_repo

scene_root = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
log_dir = scene_root / 'logs'
log_files = [
    log_dir / '04_patch_match_stereo.log',
    log_dir / '04_stereo_fusion.log',
    log_dir / '04_colmap_dense_summary.txt',
    log_dir / '05_b2_pilot_summary.txt',
]
if RUN_TRAIN == '1':
    log_files.append(scene_root / 'train.log')
if RUN_RENDER == '1':
    log_files.append(log_dir / '05_render_b2_pilot.log')
if RUN_EVAL == '1':
    log_files.append(log_dir / '05_eval_b2_pilot.log')

run_and_stream(
    ['bash', f'{WORKDIR}/project/pipeline/scripts/05_run_b2_pilot.sh', SCENE],
    env=env,
    log_files=log_files,
    poll_seconds=15,
    label='b2-pilot',
)
print('B2 pilot done')
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# I0723 10:23:08.758481 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:23:08.758482 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:23:08.758484 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:23:08.758486 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:23:08.758489 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:23:08.758491 18885 patch_match_options.cc:63] filter: 1
# I0723 10:23:08.758493 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:23:08.758496 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:23:08.758498 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:23:08.758500 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:23:08.758503 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:23:08.758504 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:23:08.758507 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:23:08.758509 18885 patch_match.cc:129] --- PatchMatch::Run ---
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:09.007297 18885 cudacc.cc:51] Initialization: 0.1175s
# I0723 10:23:09.849705 18885 cudacc.cc:51]  Sweep 1: 0.8424s
# I0723 10:23:10.897625 18885 cudacc.cc:51]  Sweep 2: 1.0478s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:11.713876 18885 cudacc.cc:51]  Sweep 3: 0.8162s
# I0723 10:23:12.719457 18885 cudacc.cc:51]  Sweep 4: 1.0055s
# I0723 10:23:12.719512 18885 cudacc.cc:51] Iteration 1: 3.7122s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:13.514385 18885 cudacc.cc:51]  Sweep 1: 0.7949s
# I0723 10:23:14.504220 18885 cudacc.cc:51]  Sweep 2: 0.9898s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:15.271720 18885 cudacc.cc:51]  Sweep 3: 0.7674s
# I0723 10:23:16.226822 18885 cudacc.cc:51]  Sweep 4: 0.9550s
# I0723 10:23:16.226881 18885 cudacc.cc:51] Iteration 2: 3.5074s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:16.982318 18885 cudacc.cc:51]  Sweep 1: 0.7554s
# I0723 10:23:17.926128 18885 cudacc.cc:51]  Sweep 2: 0.9438s
# I0723 10:23:18.665524 18885 cudacc.cc:51]  Sweep 3: 0.7393s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:19.582479 18885 cudacc.cc:51]  Sweep 4: 0.9169s
# I0723 10:23:19.582535 18885 cudacc.cc:51] Iteration 3: 3.3556s
# I0723 10:23:20.317093 18885 cudacc.cc:51]  Sweep 1: 0.7345s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:21.224581 18885 cudacc.cc:51]  Sweep 2: 0.9074s
# I0723 10:23:21.945137 18885 cudacc.cc:51]  Sweep 3: 0.7205s
# I0723 10:23:22.829488 18885 cudacc.cc:51]  Sweep 4: 0.8843s
# I0723 10:23:22.829546 18885 cudacc.cc:51] Iteration 4: 3.2470s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:23.550673 18885 cudacc.cc:51]  Sweep 1: 0.7211s
# I0723 10:23:24.429388 18885 cudacc.cc:51]  Sweep 2: 0.8787s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:25.140000 18885 cudacc.cc:51]  Sweep 3: 0.7105s
# I0723 10:23:25.936476 18885 cudacc.cc:51]  Sweep 4: 0.7964s
# I0723 10:23:25.936545 18885 cudacc.cc:51] Iteration 5: 3.1070s
# I0723 10:23:25.936565 18885 cudacc.cc:51] Total: 17.0471s
# I0723 10:23:25.936576 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160002_0289_V.JPG
# I0723 10:23:26.093780 18885 patch_match.cc:416] === Processing view 163 / 200 for DJI_20241227160005_0292_V.JPG ===
# I0723 10:23:26.093972 18885 patch_match.cc:466] Reading inputs...
# I0723 10:23:26.181121 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:23:26.181167 18885 patch_match.cc:57] ref_image_idx: 162
# I0723 10:23:26.181175 18885 patch_match.cc:64] src_image_idxs: 134 157 182 153 143 146 159 137 189 190 142 145 158 169 139 141 180 164 193 135
# I0723 10:23:26.181180 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:23:26.181182 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:23:26.181185 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:23:26.181187 18885 patch_match_options.cc:49] depth_min: 5.19088
# I0723 10:23:26.181200 18885 patch_match_options.cc:50] depth_max: 19.9373
# I0723 10:23:26.181205 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:23:26.181206 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:23:26.181209 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:23:26.181212 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:23:26.181216 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:23:26.181218 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:23:26.181221 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:23:26.181224 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:23:26.181227 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:23:26.181229 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:23:26.181232 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:23:26.181234 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:23:26.181237 18885 patch_match_options.cc:63] filter: 1
# I0723 10:23:26.181239 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:23:26.181243 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:23:26.181245 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:23:26.181248 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:23:26.181250 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:23:26.181253 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:23:26.181255 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:23:26.181258 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:23:26.442587 18885 cudacc.cc:51] Initialization: 0.1213s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:27.300081 18885 cudacc.cc:51]  Sweep 1: 0.8574s
# I0723 10:23:28.355930 18885 cudacc.cc:51]  Sweep 2: 1.0558s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:29.192791 18885 cudacc.cc:51]  Sweep 3: 0.8368s
# I0723 10:23:30.213475 18885 cudacc.cc:51]  Sweep 4: 1.0206s
# I0723 10:23:30.213536 18885 cudacc.cc:51] Iteration 1: 3.7709s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:31.016583 18885 cudacc.cc:51]  Sweep 1: 0.8030s
# I0723 10:23:32.008661 18885 cudacc.cc:51]  Sweep 2: 0.9920s
# I0723 10:23:32.792106 18885 cudacc.cc:51]  Sweep 3: 0.7834s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:33.763118 18885 cudacc.cc:51]  Sweep 4: 0.9709s
# I0723 10:23:33.763176 18885 cudacc.cc:51] Iteration 2: 3.5497s
# I0723 10:23:34.531615 18885 cudacc.cc:51]  Sweep 1: 0.7684s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:35.480823 18885 cudacc.cc:51]  Sweep 2: 0.9492s
# I0723 10:23:36.235021 18885 cudacc.cc:51]  Sweep 3: 0.7541s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:37.167514 18885 cudacc.cc:51]  Sweep 4: 0.9324s
# I0723 10:23:37.167563 18885 cudacc.cc:51] Iteration 3: 3.4044s
# I0723 10:23:37.913204 18885 cudacc.cc:51]  Sweep 1: 0.7456s
# I0723 10:23:38.827908 18885 cudacc.cc:51]  Sweep 2: 0.9146s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:39.564204 18885 cudacc.cc:51]  Sweep 3: 0.7362s
# I0723 10:23:40.464326 18885 cudacc.cc:51]  Sweep 4: 0.9000s
# I0723 10:23:40.464424 18885 cudacc.cc:51] Iteration 4: 3.2969s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:41.197371 18885 cudacc.cc:51]  Sweep 1: 0.7329s
# I0723 10:23:42.081568 18885 cudacc.cc:51]  Sweep 2: 0.8841s
# I0723 10:23:42.808988 18885 cudacc.cc:51]  Sweep 3: 0.7272s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:43.620482 18885 cudacc.cc:51]  Sweep 4: 0.8114s
# I0723 10:23:43.620544 18885 cudacc.cc:51] Iteration 5: 3.1561s
# I0723 10:23:43.620559 18885 cudacc.cc:51] Total: 17.2996s
# I0723 10:23:43.620568 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160005_0292_V.JPG
# I0723 10:23:43.790235 18885 patch_match.cc:416] === Processing view 164 / 200 for DJI_20241227160008_0295_V.JPG ===
# I0723 10:23:43.790427 18885 patch_match.cc:466] Reading inputs...
# I0723 10:23:43.874998 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:23:43.875039 18885 patch_match.cc:57] ref_image_idx: 163
# I0723 10:23:43.875047 18885 patch_match.cc:64] src_image_idxs: 165 136 138 183 144 187 181 182 169 191 159 188 148 147 186 160 174 145 171 142
# I0723 10:23:43.875051 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:23:43.875056 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:23:43.875057 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:23:43.875061 18885 patch_match_options.cc:49] depth_min: 4.97589
# I0723 10:23:43.875073 18885 patch_match_options.cc:50] depth_max: 19.5338
# I0723 10:23:43.875078 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:23:43.875082 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:23:43.875083 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:23:43.875087 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:23:43.875090 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:23:43.875093 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:23:43.875097 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:23:43.875100 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:23:43.875103 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:23:43.875106 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:23:43.875108 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:23:43.875111 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:23:43.875115 18885 patch_match_options.cc:63] filter: 1
# I0723 10:23:43.875118 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:23:43.875120 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:23:43.875123 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:23:43.875126 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:23:43.875129 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:23:43.875133 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:23:43.875134 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:23:43.875137 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:23:44.131189 18885 cudacc.cc:51] Initialization: 0.1244s
# I0723 10:23:44.978081 18885 cudacc.cc:51]  Sweep 1: 0.8468s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:46.033974 18885 cudacc.cc:51]  Sweep 2: 1.0558s
# I0723 10:23:46.866281 18885 cudacc.cc:51]  Sweep 3: 0.8322s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:47.890344 18885 cudacc.cc:51]  Sweep 4: 1.0240s
# I0723 10:23:47.890439 18885 cudacc.cc:51] Iteration 1: 3.7592s
# I0723 10:23:48.678697 18885 cudacc.cc:51]  Sweep 1: 0.7881s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:49.668339 18885 cudacc.cc:51]  Sweep 2: 0.9896s
# I0723 10:23:50.445726 18885 cudacc.cc:51]  Sweep 3: 0.7773s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:51.411885 18885 cudacc.cc:51]  Sweep 4: 0.9661s
# I0723 10:23:51.411944 18885 cudacc.cc:51] Iteration 2: 3.5214s
# I0723 10:23:52.161331 18885 cudacc.cc:51]  Sweep 1: 0.7494s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:53.107661 18885 cudacc.cc:51]  Sweep 2: 0.9463s
# I0723 10:23:53.863168 18885 cudacc.cc:51]  Sweep 3: 0.7554s
# I0723 10:23:54.789917 18885 cudacc.cc:51]  Sweep 4: 0.9267s
# I0723 10:23:54.789990 18885 cudacc.cc:51] Iteration 3: 3.3781s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:55.521000 18885 cudacc.cc:51]  Sweep 1: 0.7310s
# I0723 10:23:56.427809 18885 cudacc.cc:51]  Sweep 2: 0.9067s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:57.164796 18885 cudacc.cc:51]  Sweep 3: 0.7369s
# I0723 10:23:58.059276 18885 cudacc.cc:51]  Sweep 4: 0.8944s
# I0723 10:23:58.059330 18885 cudacc.cc:51] Iteration 4: 3.2694s
# I0723 10:23:58.776396 18885 cudacc.cc:51]  Sweep 1: 0.7170s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:23:59.652112 18885 cudacc.cc:51]  Sweep 2: 0.8756s
# I0723 10:24:00.381068 18885 cudacc.cc:51]  Sweep 3: 0.7289s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:01.183347 18885 cudacc.cc:51]  Sweep 4: 0.8022s
# I0723 10:24:01.183401 18885 cudacc.cc:51] Iteration 5: 3.1241s
# I0723 10:24:01.183449 18885 cudacc.cc:51] Total: 17.1769s
# I0723 10:24:01.183470 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160008_0295_V.JPG
# I0723 10:24:01.345184 18885 patch_match.cc:416] === Processing view 165 / 200 for DJI_20241227160004_0291_V.JPG ===
# I0723 10:24:01.345475 18885 patch_match.cc:466] Reading inputs...
# I0723 10:24:01.444274 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:24:01.444319 18885 patch_match.cc:57] ref_image_idx: 164
# I0723 10:24:01.444327 18885 patch_match.cc:64] src_image_idxs: 189 140 153 197 139 158 159 134 9 154 141 180 179 143 157 162 193 135 190 161
# I0723 10:24:01.444334 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:24:01.444336 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:24:01.444340 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:24:01.444343 18885 patch_match_options.cc:49] depth_min: 5.12439
# I0723 10:24:01.444357 18885 patch_match_options.cc:50] depth_max: 20.4716
# I0723 10:24:01.444363 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:24:01.444366 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:24:01.444370 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:24:01.444373 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:24:01.444378 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:24:01.444381 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:24:01.444386 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:24:01.444389 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:24:01.444393 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:24:01.444432 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:24:01.444437 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:24:01.444448 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:24:01.444453 18885 patch_match_options.cc:63] filter: 1
# I0723 10:24:01.444455 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:24:01.444459 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:24:01.444463 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:24:01.444466 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:24:01.444470 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:24:01.444473 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:24:01.444478 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:24:01.444480 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:24:01.710376 18885 cudacc.cc:51] Initialization: 0.1227s
# I0723 10:24:02.556782 18885 cudacc.cc:51]  Sweep 1: 0.8463s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:03.614880 18885 cudacc.cc:51]  Sweep 2: 1.0580s
# I0723 10:24:04.435168 18885 cudacc.cc:51]  Sweep 3: 0.8202s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:05.455461 18885 cudacc.cc:51]  Sweep 4: 1.0202s
# I0723 10:24:05.455525 18885 cudacc.cc:51] Iteration 1: 3.7451s
# I0723 10:24:06.252048 18885 cudacc.cc:51]  Sweep 1: 0.7965s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:07.250085 18885 cudacc.cc:51]  Sweep 2: 0.9980s
# I0723 10:24:08.022871 18885 cudacc.cc:51]  Sweep 3: 0.7727s
# I0723 10:24:08.987959 18885 cudacc.cc:51]  Sweep 4: 0.9650s
# I0723 10:24:08.988016 18885 cudacc.cc:51] Iteration 2: 3.5325s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:09.744179 18885 cudacc.cc:51]  Sweep 1: 0.7561s
# I0723 10:24:10.695719 18885 cudacc.cc:51]  Sweep 2: 0.9515s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:11.440810 18885 cudacc.cc:51]  Sweep 3: 0.7448s
# I0723 10:24:12.370651 18885 cudacc.cc:51]  Sweep 4: 0.9298s
# I0723 10:24:12.370704 18885 cudacc.cc:51] Iteration 3: 3.3827s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:13.108626 18885 cudacc.cc:51]  Sweep 1: 0.7379s
# I0723 10:24:14.023794 18885 cudacc.cc:51]  Sweep 2: 0.9151s
# I0723 10:24:14.754314 18885 cudacc.cc:51]  Sweep 3: 0.7305s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:15.652094 18885 cudacc.cc:51]  Sweep 4: 0.8977s
# I0723 10:24:15.652158 18885 cudacc.cc:51] Iteration 4: 3.2815s
# I0723 10:24:16.379112 18885 cudacc.cc:51]  Sweep 1: 0.7269s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:17.265620 18885 cudacc.cc:51]  Sweep 2: 0.8864s
# I0723 10:24:17.986892 18885 cudacc.cc:51]  Sweep 3: 0.7212s
# I0723 10:24:18.792775 18885 cudacc.cc:51]  Sweep 4: 0.8058s
# I0723 10:24:18.792860 18885 cudacc.cc:51] Iteration 5: 3.1407s
# I0723 10:24:18.792876 18885 cudacc.cc:51] Total: 17.2055s
# I0723 10:24:18.792883 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160004_0291_V.JPG
# I0723 10:24:19.027850 18885 patch_match.cc:416] === Processing view 166 / 200 for DJI_20241227160009_0296_V.JPG ===
# I0723 10:24:19.028069 18885 patch_match.cc:466] Reading inputs...
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:19.154805 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:24:19.154838 18885 patch_match.cc:57] ref_image_idx: 165
# I0723 10:24:19.154852 18885 patch_match.cc:64] src_image_idxs: 172 138 132 171 183 144 163 169 181 168 136 149 188 191 160 147 186 148 174 145
# I0723 10:24:19.154860 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:24:19.154867 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:24:19.154873 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:24:19.154878 18885 patch_match_options.cc:49] depth_min: 4.94128
# I0723 10:24:19.154896 18885 patch_match_options.cc:50] depth_max: 20.9912
# I0723 10:24:19.154904 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:24:19.154910 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:24:19.154917 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:24:19.154923 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:24:19.154932 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:24:19.154937 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:24:19.154943 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:24:19.154950 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:24:19.154958 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:24:19.154963 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:24:19.154969 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:24:19.154976 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:24:19.154982 18885 patch_match_options.cc:63] filter: 1
# I0723 10:24:19.154987 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:24:19.154994 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:24:19.155001 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:24:19.155007 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:24:19.155014 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:24:19.155019 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:24:19.155025 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:24:19.155031 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:24:19.477270 18885 cudacc.cc:51] Initialization: 0.1223s
# I0723 10:24:20.321540 18885 cudacc.cc:51]  Sweep 1: 0.8442s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:21.373076 18885 cudacc.cc:51]  Sweep 2: 1.0515s
# I0723 10:24:22.189459 18885 cudacc.cc:51]  Sweep 3: 0.8163s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:23.200976 18885 cudacc.cc:51]  Sweep 4: 1.0114s
# I0723 10:24:23.201030 18885 cudacc.cc:51] Iteration 1: 3.7237s
# I0723 10:24:23.986275 18885 cudacc.cc:51]  Sweep 1: 0.7852s
# I0723 10:24:24.975953 18885 cudacc.cc:51]  Sweep 2: 0.9896s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:25.740182 18885 cudacc.cc:51]  Sweep 3: 0.7642s
# I0723 10:24:26.700737 18885 cudacc.cc:51]  Sweep 4: 0.9605s
# I0723 10:24:26.700798 18885 cudacc.cc:51] Iteration 2: 3.4998s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:27.450680 18885 cudacc.cc:51]  Sweep 1: 0.7499s
# I0723 10:24:28.398440 18885 cudacc.cc:51]  Sweep 2: 0.9477s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:29.140939 18885 cudacc.cc:51]  Sweep 3: 0.7424s
# I0723 10:24:30.066406 18885 cudacc.cc:51]  Sweep 4: 0.9254s
# I0723 10:24:30.066493 18885 cudacc.cc:51] Iteration 3: 3.3657s
# I0723 10:24:30.797326 18885 cudacc.cc:51]  Sweep 1: 0.7308s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:31.707981 18885 cudacc.cc:51]  Sweep 2: 0.9106s
# I0723 10:24:32.435969 18885 cudacc.cc:51]  Sweep 3: 0.7279s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:33.327705 18885 cudacc.cc:51]  Sweep 4: 0.8917s
# I0723 10:24:33.327773 18885 cudacc.cc:51] Iteration 4: 3.2613s
# I0723 10:24:34.042431 18885 cudacc.cc:51]  Sweep 1: 0.7146s
# I0723 10:24:34.925982 18885 cudacc.cc:51]  Sweep 2: 0.8835s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:35.642654 18885 cudacc.cc:51]  Sweep 3: 0.7166s
# I0723 10:24:36.443674 18885 cudacc.cc:51]  Sweep 4: 0.8010s
# I0723 10:24:36.443734 18885 cudacc.cc:51] Iteration 5: 3.1160s
# I0723 10:24:36.443748 18885 cudacc.cc:51] Total: 17.0891s
# I0723 10:24:36.443754 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160009_0296_V.JPG
# I0723 10:24:36.599516 18885 patch_match.cc:416] === Processing view 167 / 200 for DJI_20241227160012_0299_V.JPG ===
# I0723 10:24:36.599694 18885 patch_match.cc:466] Reading inputs...
# I0723 10:24:36.687299 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:24:36.687340 18885 patch_match.cc:57] ref_image_idx: 166
# I0723 10:24:36.687347 18885 patch_match.cc:64] src_image_idxs: 192 177 148 167 195 155 168 160 151 132 171 170 174 176 150 191 133 149 175 194
# I0723 10:24:36.687351 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:24:36.687354 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:24:36.687356 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:24:36.687359 18885 patch_match_options.cc:49] depth_min: 5.12921
# I0723 10:24:36.687371 18885 patch_match_options.cc:50] depth_max: 18.125
# I0723 10:24:36.687376 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:24:36.687377 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:24:36.687381 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:24:36.687383 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:24:36.687386 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:24:36.687388 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:24:36.687391 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:24:36.687429 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:24:36.687438 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:24:36.687440 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:24:36.687449 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:24:36.687453 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:24:36.687455 18885 patch_match_options.cc:63] filter: 1
# I0723 10:24:36.687458 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:24:36.687460 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:24:36.687463 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:24:36.687465 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:24:36.687467 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:24:36.687470 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:24:36.687472 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:24:36.687474 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:24:36.946612 18885 cudacc.cc:51] Initialization: 0.1213s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:37.780517 18885 cudacc.cc:51]  Sweep 1: 0.8338s
# I0723 10:24:38.850293 18885 cudacc.cc:51]  Sweep 2: 1.0697s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:39.667538 18885 cudacc.cc:51]  Sweep 3: 0.8171s
# I0723 10:24:40.694222 18885 cudacc.cc:51]  Sweep 4: 1.0266s
# I0723 10:24:40.694286 18885 cudacc.cc:51] Iteration 1: 3.7477s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:41.480046 18885 cudacc.cc:51]  Sweep 1: 0.7857s
# I0723 10:24:42.486879 18885 cudacc.cc:51]  Sweep 2: 1.0068s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:43.256556 18885 cudacc.cc:51]  Sweep 3: 0.7696s
# I0723 10:24:44.229063 18885 cudacc.cc:51]  Sweep 4: 0.9725s
# I0723 10:24:44.229140 18885 cudacc.cc:51] Iteration 2: 3.5349s
# I0723 10:24:44.984540 18885 cudacc.cc:51]  Sweep 1: 0.7554s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:45.946868 18885 cudacc.cc:51]  Sweep 2: 0.9623s
# I0723 10:24:46.695664 18885 cudacc.cc:51]  Sweep 3: 0.7487s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:47.630096 18885 cudacc.cc:51]  Sweep 4: 0.9344s
# I0723 10:24:47.630167 18885 cudacc.cc:51] Iteration 3: 3.4010s
# I0723 10:24:48.367774 18885 cudacc.cc:51]  Sweep 1: 0.7376s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:49.293788 18885 cudacc.cc:51]  Sweep 2: 0.9260s
# I0723 10:24:50.025524 18885 cudacc.cc:51]  Sweep 3: 0.7317s
# I0723 10:24:50.927971 18885 cudacc.cc:51]  Sweep 4: 0.9024s
# I0723 10:24:50.928036 18885 cudacc.cc:51] Iteration 4: 3.2979s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:51.646720 18885 cudacc.cc:51]  Sweep 1: 0.7187s
# I0723 10:24:52.543284 18885 cudacc.cc:51]  Sweep 2: 0.8965s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:53.263378 18885 cudacc.cc:51]  Sweep 3: 0.7200s
# I0723 10:24:54.066606 18885 cudacc.cc:51]  Sweep 4: 0.8032s
# I0723 10:24:54.066668 18885 cudacc.cc:51] Iteration 5: 3.1387s
# I0723 10:24:54.066680 18885 cudacc.cc:51] Total: 17.2417s
# I0723 10:24:54.066686 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160012_0299_V.JPG
# I0723 10:24:54.225262 18885 patch_match.cc:416] === Processing view 168 / 200 for DJI_20241227160013_0300_V.JPG ===
# I0723 10:24:54.225431 18885 patch_match.cc:466] Reading inputs...
# I0723 10:24:54.311882 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:24:54.311937 18885 patch_match.cc:57] ref_image_idx: 167
# I0723 10:24:54.311945 18885 patch_match.cc:64] src_image_idxs: 149 178 133 168 155 194 170 185 156 152 173 175 150 176 192 195 166 148 177 151
# I0723 10:24:54.311950 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:24:54.311954 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:24:54.311955 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:24:54.311957 18885 patch_match_options.cc:49] depth_min: 5.09405
# I0723 10:24:54.311970 18885 patch_match_options.cc:50] depth_max: 19.8473
# I0723 10:24:54.311992 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:24:54.311995 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:24:54.311997 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:24:54.312000 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:24:54.312003 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:24:54.312005 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:24:54.312008 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:24:54.312011 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:24:54.312014 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:24:54.312016 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:24:54.312019 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:24:54.312021 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:24:54.312024 18885 patch_match_options.cc:63] filter: 1
# I0723 10:24:54.312026 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:24:54.312029 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:24:54.312032 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:24:54.312034 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:24:54.312037 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:24:54.312039 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:24:54.312042 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:24:54.312044 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:24:54.573926 18885 cudacc.cc:51] Initialization: 0.1202s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:55.416757 18885 cudacc.cc:51]  Sweep 1: 0.8428s
# I0723 10:24:56.487345 18885 cudacc.cc:51]  Sweep 2: 1.0705s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:24:57.304406 18885 cudacc.cc:51]  Sweep 3: 0.8170s
# I0723 10:24:58.328478 18885 cudacc.cc:51]  Sweep 4: 1.0240s
# I0723 10:24:58.328539 18885 cudacc.cc:51] Iteration 1: 3.7546s
# I0723 10:24:59.115352 18885 cudacc.cc:51]  Sweep 1: 0.7868s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:00.117705 18885 cudacc.cc:51]  Sweep 2: 1.0023s
# I0723 10:25:00.885367 18885 cudacc.cc:51]  Sweep 3: 0.7676s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:01.857611 18885 cudacc.cc:51]  Sweep 4: 0.9722s
# I0723 10:25:01.857700 18885 cudacc.cc:51] Iteration 2: 3.5292s
# I0723 10:25:02.608517 18885 cudacc.cc:51]  Sweep 1: 0.7504s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:03.562827 18885 cudacc.cc:51]  Sweep 2: 0.9542s
# I0723 10:25:04.302475 18885 cudacc.cc:51]  Sweep 3: 0.7396s
# I0723 10:25:05.232436 18885 cudacc.cc:51]  Sweep 4: 0.9299s
# I0723 10:25:05.232497 18885 cudacc.cc:51] Iteration 3: 3.3744s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:05.963869 18885 cudacc.cc:51]  Sweep 1: 0.7314s
# I0723 10:25:06.883517 18885 cudacc.cc:51]  Sweep 2: 0.9196s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:07.604278 18885 cudacc.cc:51]  Sweep 3: 0.7207s
# I0723 10:25:08.498279 18885 cudacc.cc:51]  Sweep 4: 0.8939s
# I0723 10:25:08.498338 18885 cudacc.cc:51] Iteration 4: 3.2659s
# I0723 10:25:09.211489 18885 cudacc.cc:51]  Sweep 1: 0.7131s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:10.100730 18885 cudacc.cc:51]  Sweep 2: 0.8892s
# I0723 10:25:10.811019 18885 cudacc.cc:51]  Sweep 3: 0.7102s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:11.612679 18885 cudacc.cc:51]  Sweep 4: 0.8016s
# I0723 10:25:11.612761 18885 cudacc.cc:51] Iteration 5: 3.1144s
# I0723 10:25:11.612795 18885 cudacc.cc:51] Total: 17.1593s
# I0723 10:25:11.612807 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160013_0300_V.JPG
# I0723 10:25:11.874105 18885 patch_match.cc:416] === Processing view 169 / 200 for DJI_20241227160011_0298_V.JPG ===
# I0723 10:25:11.874389 18885 patch_match.cc:466] Reading inputs...
# I0723 10:25:11.974488 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:25:11.974534 18885 patch_match.cc:57] ref_image_idx: 168
# I0723 10:25:11.974546 18885 patch_match.cc:64] src_image_idxs: 155 194 165 176 166 195 163 150 167 172 188 149 175 160 174 148 171 132 133 191
# I0723 10:25:11.974552 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:25:11.974556 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:25:11.974561 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:25:11.974565 18885 patch_match_options.cc:49] depth_min: 4.73054
# I0723 10:25:11.974581 18885 patch_match_options.cc:50] depth_max: 18.6354
# I0723 10:25:11.974587 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:25:11.974591 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:25:11.974596 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:25:11.974601 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:25:11.974606 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:25:11.974611 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:25:11.974617 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:25:11.974622 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:25:11.974627 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:25:11.974630 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:25:11.974635 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:25:11.974639 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:25:11.974644 18885 patch_match_options.cc:63] filter: 1
# I0723 10:25:11.974649 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:25:11.974654 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:25:11.974659 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:25:11.974663 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:25:11.974668 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:25:11.974671 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:25:11.974675 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:25:11.974694 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:25:12.275790 18885 cudacc.cc:51] Initialization: 0.1198s
# I0723 10:25:13.116452 18885 cudacc.cc:51]  Sweep 1: 0.8405s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:14.188042 18885 cudacc.cc:51]  Sweep 2: 1.0715s
# I0723 10:25:15.004360 18885 cudacc.cc:51]  Sweep 3: 0.8163s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:16.024837 18885 cudacc.cc:51]  Sweep 4: 1.0204s
# I0723 10:25:16.024892 18885 cudacc.cc:51] Iteration 1: 3.7490s
# I0723 10:25:16.815768 18885 cudacc.cc:51]  Sweep 1: 0.7909s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:17.818149 18885 cudacc.cc:51]  Sweep 2: 1.0023s
# I0723 10:25:18.587255 18885 cudacc.cc:51]  Sweep 3: 0.7690s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:19.551272 18885 cudacc.cc:51]  Sweep 4: 0.9638s
# I0723 10:25:19.551347 18885 cudacc.cc:51] Iteration 2: 3.5265s
# I0723 10:25:20.299041 18885 cudacc.cc:51]  Sweep 1: 0.7477s
# I0723 10:25:21.253866 18885 cudacc.cc:51]  Sweep 2: 0.9548s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:21.996487 18885 cudacc.cc:51]  Sweep 3: 0.7425s
# I0723 10:25:22.921465 18885 cudacc.cc:51]  Sweep 4: 0.9249s
# I0723 10:25:22.921521 18885 cudacc.cc:51] Iteration 3: 3.3702s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:23.649029 18885 cudacc.cc:51]  Sweep 1: 0.7275s
# I0723 10:25:24.570176 18885 cudacc.cc:51]  Sweep 2: 0.9211s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:25.303730 18885 cudacc.cc:51]  Sweep 3: 0.7335s
# I0723 10:25:26.194417 18885 cudacc.cc:51]  Sweep 4: 0.8906s
# I0723 10:25:26.194476 18885 cudacc.cc:51] Iteration 4: 3.2730s
# I0723 10:25:26.905125 18885 cudacc.cc:51]  Sweep 1: 0.7106s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:27.793440 18885 cudacc.cc:51]  Sweep 2: 0.8883s
# I0723 10:25:28.505817 18885 cudacc.cc:51]  Sweep 3: 0.7123s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:29.308573 18885 cudacc.cc:51]  Sweep 4: 0.8027s
# I0723 10:25:29.308627 18885 cudacc.cc:51] Iteration 5: 3.1142s
# I0723 10:25:29.308645 18885 cudacc.cc:51] Total: 17.1529s
# I0723 10:25:29.308657 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160011_0298_V.JPG
# I0723 10:25:29.461591 18885 patch_match.cc:416] === Processing view 170 / 200 for DJI_20241227160007_0294_V.JPG ===
# I0723 10:25:29.461876 18885 patch_match.cc:466] Reading inputs...
# I0723 10:25:29.551829 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:25:29.551875 18885 patch_match.cc:57] ref_image_idx: 169
# I0723 10:25:29.551888 18885 patch_match.cc:64] src_image_idxs: 138 144 182 136 146 159 147 141 180 162 183 186 189 163 137 145 158 187 181 142
# I0723 10:25:29.551900 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:25:29.551904 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:25:29.551906 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:25:29.551909 18885 patch_match_options.cc:49] depth_min: 4.78493
# I0723 10:25:29.551923 18885 patch_match_options.cc:50] depth_max: 19.3771
# I0723 10:25:29.551928 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:25:29.551930 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:25:29.551934 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:25:29.551937 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:25:29.551940 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:25:29.551961 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:25:29.551965 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:25:29.551970 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:25:29.551973 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:25:29.551976 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:25:29.551980 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:25:29.551982 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:25:29.551986 18885 patch_match_options.cc:63] filter: 1
# I0723 10:25:29.551990 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:25:29.551993 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:25:29.552001 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:25:29.552004 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:25:29.552008 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:25:29.552026 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:25:29.552029 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:25:29.552032 18885 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 10:25:29.808029 18885 cudacc.cc:51] Initialization: 0.1190s
# I0723 10:25:30.655412 18885 cudacc.cc:51]  Sweep 1: 0.8473s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:31.713097 18885 cudacc.cc:51]  Sweep 2: 1.0576s
# I0723 10:25:32.528486 18885 cudacc.cc:51]  Sweep 3: 0.8153s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:33.544713 18885 cudacc.cc:51]  Sweep 4: 1.0162s
# I0723 10:25:33.544771 18885 cudacc.cc:51] Iteration 1: 3.7367s
# I0723 10:25:34.335496 18885 cudacc.cc:51]  Sweep 1: 0.7907s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:35.328132 18885 cudacc.cc:51]  Sweep 2: 0.9926s
# I0723 10:25:36.097682 18885 cudacc.cc:51]  Sweep 3: 0.7695s
# I0723 10:25:37.062490 18885 cudacc.cc:51]  Sweep 4: 0.9647s
# I0723 10:25:37.062549 18885 cudacc.cc:51] Iteration 2: 3.5178s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:37.810384 18885 cudacc.cc:51]  Sweep 1: 0.7478s
# I0723 10:25:38.758195 18885 cudacc.cc:51]  Sweep 2: 0.9477s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:39.502233 18885 cudacc.cc:51]  Sweep 3: 0.7440s
# I0723 10:25:40.430985 18885 cudacc.cc:51]  Sweep 4: 0.9287s
# I0723 10:25:40.431047 18885 cudacc.cc:51] Iteration 3: 3.3685s
# I0723 10:25:41.161515 18885 cudacc.cc:51]  Sweep 1: 0.7304s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:42.074237 18885 cudacc.cc:51]  Sweep 2: 0.9127s
# I0723 10:25:42.800966 18885 cudacc.cc:51]  Sweep 3: 0.7264s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:43.694096 18885 cudacc.cc:51]  Sweep 4: 0.8931s
# I0723 10:25:43.694145 18885 cudacc.cc:51] Iteration 4: 3.2631s
# I0723 10:25:44.412583 18885 cudacc.cc:51]  Sweep 1: 0.7184s
# I0723 10:25:45.295102 18885 cudacc.cc:51]  Sweep 2: 0.8825s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:46.007653 18885 cudacc.cc:51]  Sweep 3: 0.7125s
# I0723 10:25:46.810881 18885 cudacc.cc:51]  Sweep 4: 0.8032s
# I0723 10:25:46.810945 18885 cudacc.cc:51] Iteration 5: 3.1168s
# I0723 10:25:46.810958 18885 cudacc.cc:51] Total: 17.1222s
# I0723 10:25:46.810966 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160007_0294_V.JPG
# I0723 10:25:46.981463 18885 patch_match.cc:416] === Processing view 171 / 200 for DJI_20241227160014_0301_V.JPG ===
# I0723 10:25:46.981639 18885 patch_match.cc:466] Reading inputs...
# I0723 10:25:47.072484 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:25:47.072536 18885 patch_match.cc:57] ref_image_idx: 170
# I0723 10:25:47.072546 18885 patch_match.cc:64] src_image_idxs: 196 167 185 156 179 150 192 198 168 194 176 166 155 184 151 177 178 152 173 154
# I0723 10:25:47.072551 18885 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 10:25:47.072553 18885 patch_match_options.cc:47] max_image_size: 1600
# I0723 10:25:47.072556 18885 patch_match_options.cc:48] gpu_index: 0
# I0723 10:25:47.072559 18885 patch_match_options.cc:49] depth_min: 5.14922
# I0723 10:25:47.072573 18885 patch_match_options.cc:50] depth_max: 19.7066
# I0723 10:25:47.072578 18885 patch_match_options.cc:51] window_radius: 5
# I0723 10:25:47.072580 18885 patch_match_options.cc:52] window_step: 1
# I0723 10:25:47.072583 18885 patch_match_options.cc:53] sigma_spatial: 5
# I0723 10:25:47.072587 18885 patch_match_options.cc:54] sigma_color: 0.2
# I0723 10:25:47.072592 18885 patch_match_options.cc:55] num_samples: 15
# I0723 10:25:47.072593 18885 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 10:25:47.072597 18885 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 10:25:47.072600 18885 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 10:25:47.072604 18885 patch_match_options.cc:59] num_iterations: 5
# I0723 10:25:47.072606 18885 patch_match_options.cc:60] geom_consistency: 1
# I0723 10:25:47.072609 18885 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 10:25:47.072613 18885 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 10:25:47.072615 18885 patch_match_options.cc:63] filter: 1
# I0723 10:25:47.072618 18885 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 10:25:47.072621 18885 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 10:25:47.072624 18885 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 10:25:47.072628 18885 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 10:25:47.072649 18885 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 10:25:47.072651 18885 patch_match_options.cc:69] allow_missing_files: 0
# I0723 10:25:47.072654 18885 patch_match_options.cc:70] num_threads: -1
# I0723 10:25:47.072657 18885 patch_match.cc:129] --- PatchMatch::Run ---
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:47.336862 18885 cudacc.cc:51] Initialization: 0.1222s
# I0723 10:25:48.183169 18885 cudacc.cc:51]  Sweep 1: 0.8462s
# I0723 10:25:49.253882 18885 cudacc.cc:51]  Sweep 2: 1.0707s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:50.071487 18885 cudacc.cc:51]  Sweep 3: 0.8175s
# I0723 10:25:51.099699 18885 cudacc.cc:51]  Sweep 4: 1.0282s
# I0723 10:25:51.099766 18885 cudacc.cc:51] Iteration 1: 3.7629s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:51.891086 18885 cudacc.cc:51]  Sweep 1: 0.7913s
# I0723 10:25:52.899956 18885 cudacc.cc:51]  Sweep 2: 1.0088s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:53.671123 18885 cudacc.cc:51]  Sweep 3: 0.7677s
# I0723 10:25:54.640147 18885 cudacc.cc:51]  Sweep 4: 0.9690s
# I0723 10:25:54.640208 18885 cudacc.cc:51] Iteration 2: 3.5405s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:55.396828 18885 cudacc.cc:51]  Sweep 1: 0.7566s
# I0723 10:25:56.356343 18885 cudacc.cc:51]  Sweep 2: 0.9595s
# I0723 10:25:57.103291 18885 cudacc.cc:51]  Sweep 3: 0.7469s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:58.034731 18885 cudacc.cc:51]  Sweep 4: 0.9314s
# I0723 10:25:58.034794 18885 cudacc.cc:51] Iteration 3: 3.3946s
# I0723 10:25:58.771457 18885 cudacc.cc:51]  Sweep 1: 0.7366s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:25:59.698215 18885 cudacc.cc:51]  Sweep 2: 0.9265s
# I0723 10:26:00.426555 18885 cudacc.cc:51]  Sweep 3: 0.7283s
# I0723 10:26:01.330513 18885 cudacc.cc:51]  Sweep 4: 0.9039s
# I0723 10:26:01.330564 18885 cudacc.cc:51] Iteration 4: 3.2958s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:26:02.055861 18885 cudacc.cc:51]  Sweep 1: 0.7253s
# I0723 10:26:02.950539 18885 cudacc.cc:51]  Sweep 2: 0.8946s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 10:26:03.670528 18885 cudacc.cc:51]  Sweep 3: 0.7199s
# I0723 10:26:04.480887 18885 cudacc.cc:51]  Sweep 4: 0.8103s
# I0723 10:26:04.480955 18885 cudacc.cc:51] Iteration 5: 3.1504s
# I0723 10:26:04.480973 18885 cudacc.cc:51] Total: 17.2665s
# I0723 10:26:04.480983 18885 patch_match.cc:525]
# Writing geometric output for DJI_20241227160014_0301_V.JPG
# I0723 10:26:04.720486 18885 patch_match.cc:416] === Processing view 172 / 200 for DJI_20241227160010_0297_V.JPG ===
# I0723 10:26:04.720702 18885 patch_match.cc:466] Reading inputs...
# I0723 10:26:04.818666 18885 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 10:26:04.818709 18885 patch_match.cc:57] ref_image_idx: 171
# ...
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:41:54.667704 42986 fusion.cc:310]  in 1.276s (3524819 points)
# I0723 10:41:54.667757 42986 fusion.cc:283] Fusing image [127/200] with index 71
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:41:55.651610 42986 fusion.cc:310]  in 0.984s (3539069 points)
# I0723 10:41:55.651664 42986 fusion.cc:283] Fusing image [128/200] with index 70
# I0723 10:41:56.855293 42986 fusion.cc:310]  in 1.204s (3553594 points)
# I0723 10:41:56.855350 42986 fusion.cc:283] Fusing image [129/200] with index 73
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 10:41:58.871182 42986 fusion.cc:310]  in 2.016s (3570382 points)
# I0723 10:41:58.871353 42986 fusion.cc:283] Fusing image [130/200] with index 72
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:00.186902 42986 fusion.cc:310]  in 1.316s (3583934 points)
# I0723 10:42:00.186944 42986 fusion.cc:283] Fusing image [131/200] with index 76
# I0723 10:42:01.216383 42986 fusion.cc:310]  in 1.029s (3598788 points)
# I0723 10:42:01.216465 42986 fusion.cc:283] Fusing image [132/200] with index 75
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:02.257926 42986 fusion.cc:310]  in 1.041s (3614011 points)
# I0723 10:42:02.257972 42986 fusion.cc:283] Fusing image [133/200] with index 74
# I0723 10:42:03.252097 42986 fusion.cc:310]  in 0.994s (3630554 points)
# I0723 10:42:03.252139 42986 fusion.cc:283] Fusing image [134/200] with index 54
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:04.321122 42986 fusion.cc:310]  in 1.069s (3645308 points)
# I0723 10:42:04.321168 42986 fusion.cc:283] Fusing image [135/200] with index 53
# I0723 10:42:05.410497 42986 fusion.cc:310]  in 1.089s (3660771 points)
# I0723 10:42:05.410548 42986 fusion.cc:283] Fusing image [136/200] with index 56
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:06.640690 42986 fusion.cc:310]  in 1.230s (3687394 points)
# I0723 10:42:06.640741 42986 fusion.cc:283] Fusing image [137/200] with index 55
# I0723 10:42:07.581745 42986 fusion.cc:310]  in 0.941s (3702121 points)
# I0723 10:42:07.581795 42986 fusion.cc:283] Fusing image [138/200] with index 57
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:08.519479 42986 fusion.cc:310]  in 0.938s (3715639 points)
# I0723 10:42:08.519529 42986 fusion.cc:283] Fusing image [139/200] with index 59
# I0723 10:42:09.241747 42986 fusion.cc:310]  in 0.722s (3721199 points)
# I0723 10:42:09.241794 42986 fusion.cc:283] Fusing image [140/200] with index 58
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:09.880124 42986 fusion.cc:310]  in 0.638s (3722959 points)
# I0723 10:42:09.880189 42986 fusion.cc:283] Fusing image [141/200] with index 60
# I0723 10:42:10.707228 42986 fusion.cc:310]  in 0.827s (3723638 points)
# I0723 10:42:10.707288 42986 fusion.cc:283] Fusing image [142/200] with index 61
# I0723 10:42:11.504114 42986 fusion.cc:310]  in 0.797s (3723638 points)
# I0723 10:42:11.504174 42986 fusion.cc:283] Fusing image [143/200] with index 51
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:12.925657 42986 fusion.cc:310]  in 1.421s (3728858 points)
# I0723 10:42:12.925720 42986 fusion.cc:283] Fusing image [144/200] with index 52
# I0723 10:42:13.641124 42986 fusion.cc:310]  in 0.715s (3731361 points)
# I0723 10:42:13.641177 42986 fusion.cc:283] Fusing image [145/200] with index 81
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:15.957989 42986 fusion.cc:310]  in 2.317s (3796633 points)
# I0723 10:42:15.958042 42986 fusion.cc:283] Fusing image [146/200] with index 82
# I0723 10:42:17.607730 42986 fusion.cc:310]  in 1.650s (3838164 points)
# I0723 10:42:17.607785 42986 fusion.cc:283] Fusing image [147/200] with index 80
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:19.100519 42986 fusion.cc:310]  in 1.493s (3870983 points)
# I0723 10:42:19.100571 42986 fusion.cc:283] Fusing image [148/200] with index 79
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:20.577615 42986 fusion.cc:310]  in 1.477s (3904598 points)
# I0723 10:42:20.577667 42986 fusion.cc:283] Fusing image [149/200] with index 78
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:21.981838 42986 fusion.cc:310]  in 1.404s (3934082 points)
# I0723 10:42:21.981895 42986 fusion.cc:283] Fusing image [150/200] with index 77
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:23.724489 42986 fusion.cc:310]  in 1.743s (3967101 points)
# I0723 10:42:23.724551 42986 fusion.cc:283] Fusing image [151/200] with index 102
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:26.584583 42986 fusion.cc:310]  in 2.860s (4002681 points)
# I0723 10:42:26.584641 42986 fusion.cc:283] Fusing image [152/200] with index 103
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:28.122689 42986 fusion.cc:310]  in 1.538s (4031571 points)
# I0723 10:42:28.122740 42986 fusion.cc:283] Fusing image [153/200] with index 100
# I0723 10:42:29.506441 42986 fusion.cc:310]  in 1.384s (4057228 points)
# I0723 10:42:29.506497 42986 fusion.cc:283] Fusing image [154/200] with index 99
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:30.850356 42986 fusion.cc:310]  in 1.344s (4081069 points)
# I0723 10:42:30.850445 42986 fusion.cc:283] Fusing image [155/200] with index 101
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:32.219682 42986 fusion.cc:310]  in 1.369s (4107491 points)
# I0723 10:42:32.219725 42986 fusion.cc:283] Fusing image [156/200] with index 98
# I0723 10:42:33.406740 42986 fusion.cc:310]  in 1.187s (4131272 points)
# I0723 10:42:33.406962 42986 fusion.cc:283] Fusing image [157/200] with index 97
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:34.582302 42986 fusion.cc:310]  in 1.175s (4154663 points)
# I0723 10:42:34.582351 42986 fusion.cc:283] Fusing image [158/200] with index 94
# I0723 10:42:35.735563 42986 fusion.cc:310]  in 1.153s (4178271 points)
# I0723 10:42:35.735616 42986 fusion.cc:283] Fusing image [159/200] with index 96
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:37.197291 42986 fusion.cc:310]  in 1.462s (4204107 points)
# I0723 10:42:37.197345 42986 fusion.cc:283] Fusing image [160/200] with index 95
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:40.270013 42986 fusion.cc:310]  in 3.073s (4245713 points)
# I0723 10:42:40.270074 42986 fusion.cc:283] Fusing image [161/200] with index 93
# I0723 10:42:41.657634 42986 fusion.cc:310]  in 1.388s (4277897 points)
# I0723 10:42:41.657686 42986 fusion.cc:283] Fusing image [162/200] with index 92
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:42.908809 42986 fusion.cc:310]  in 1.251s (4305339 points)
# I0723 10:42:42.908865 42986 fusion.cc:283] Fusing image [163/200] with index 91
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:44.112785 42986 fusion.cc:310]  in 1.204s (4331022 points)
# I0723 10:42:44.112840 42986 fusion.cc:283] Fusing image [164/200] with index 90
# I0723 10:42:45.329711 42986 fusion.cc:310]  in 1.217s (4357346 points)
# I0723 10:42:45.329793 42986 fusion.cc:283] Fusing image [165/200] with index 89
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:46.451079 42986 fusion.cc:310]  in 1.121s (4381256 points)
# I0723 10:42:46.451148 42986 fusion.cc:283] Fusing image [166/200] with index 88
# I0723 10:42:47.513331 42986 fusion.cc:310]  in 1.062s (4403668 points)
# I0723 10:42:47.513386 42986 fusion.cc:283] Fusing image [167/200] with index 86
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:48.537503 42986 fusion.cc:310]  in 1.024s (4420452 points)
# I0723 10:42:48.537559 42986 fusion.cc:283] Fusing image [168/200] with index 87
# I0723 10:42:49.481057 42986 fusion.cc:310]  in 0.944s (4435285 points)
# I0723 10:42:49.481107 42986 fusion.cc:283] Fusing image [169/200] with index 85
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:50.390686 42986 fusion.cc:310]  in 0.910s (4449268 points)
# I0723 10:42:50.390758 42986 fusion.cc:283] Fusing image [170/200] with index 84
# I0723 10:42:51.712997 42986 fusion.cc:310]  in 1.322s (4459488 points)
# I0723 10:42:51.713085 42986 fusion.cc:283] Fusing image [171/200] with index 83
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:53.057060 42986 fusion.cc:310]  in 1.344s (4466834 points)
# I0723 10:42:53.057132 42986 fusion.cc:283] Fusing image [172/200] with index 130
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:54.363281 42986 fusion.cc:310]  in 1.306s (4474565 points)
# I0723 10:42:54.363328 42986 fusion.cc:283] Fusing image [173/200] with index 131
# I0723 10:42:54.967795 42986 fusion.cc:310]  in 0.604s (4477603 points)
# I0723 10:42:54.967849 42986 fusion.cc:283] Fusing image [174/200] with index 129
# I0723 10:42:55.509258 42986 fusion.cc:310]  in 0.541s (4479121 points)
# I0723 10:42:55.509338 42986 fusion.cc:283] Fusing image [175/200] with index 128
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:55.992905 42986 fusion.cc:310]  in 0.484s (4480102 points)
# I0723 10:42:55.992957 42986 fusion.cc:283] Fusing image [176/200] with index 127
# I0723 10:42:56.451560 42986 fusion.cc:310]  in 0.459s (4481030 points)
# I0723 10:42:56.451609 42986 fusion.cc:283] Fusing image [177/200] with index 126
# I0723 10:42:56.874229 42986 fusion.cc:310]  in 0.423s (4481795 points)
# I0723 10:42:56.874276 42986 fusion.cc:283] Fusing image [178/200] with index 125
# I0723 10:42:57.294023 42986 fusion.cc:310]  in 0.420s (4482488 points)
# I0723 10:42:57.294064 42986 fusion.cc:283] Fusing image [179/200] with index 124
# I0723 10:42:57.713225 42986 fusion.cc:310]  in 0.419s (4483080 points)
# I0723 10:42:57.713274 42986 fusion.cc:283] Fusing image [180/200] with index 123
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:58.145341 42986 fusion.cc:310]  in 0.432s (4483667 points)
# I0723 10:42:58.145426 42986 fusion.cc:283] Fusing image [181/200] with index 122
# I0723 10:42:58.589061 42986 fusion.cc:310]  in 0.444s (4484100 points)
# I0723 10:42:58.589110 42986 fusion.cc:283] Fusing image [182/200] with index 121
# I0723 10:42:58.995770 42986 fusion.cc:310]  in 0.407s (4484407 points)
# I0723 10:42:58.995822 42986 fusion.cc:283] Fusing image [183/200] with index 120
# I0723 10:42:59.505564 42986 fusion.cc:310]  in 0.510s (4485830 points)
# I0723 10:42:59.505615 42986 fusion.cc:283] Fusing image [184/200] with index 119
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:42:59.974301 42986 fusion.cc:310]  in 0.469s (4486848 points)
# I0723 10:42:59.974350 42986 fusion.cc:283] Fusing image [185/200] with index 118
# I0723 10:43:00.423197 42986 fusion.cc:310]  in 0.449s (4487816 points)
# I0723 10:43:00.423245 42986 fusion.cc:283] Fusing image [186/200] with index 117
# I0723 10:43:00.870142 42986 fusion.cc:310]  in 0.447s (4489084 points)
# I0723 10:43:00.870223 42986 fusion.cc:283] Fusing image [187/200] with index 116
# I0723 10:43:01.362112 42986 fusion.cc:310]  in 0.492s (4490700 points)
# I0723 10:43:01.362161 42986 fusion.cc:283] Fusing image [188/200] with index 115
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 10:43:01.819324 42986 fusion.cc:310]  in 0.457s (4492157 points)
# I0723 10:43:01.819370 42986 fusion.cc:283] Fusing image [189/200] with index 114
# I0723 10:43:02.295734 42986 fusion.cc:310]  in 0.476s (4493391 points)
# I0723 10:43:02.295780 42986 fusion.cc:283] Fusing image [190/200] with index 113
# I0723 10:43:02.723289 42986 fusion.cc:310]  in 0.428s (4494458 points)
# I0723 10:43:02.723335 42986 fusion.cc:283] Fusing image [191/200] with index 112
# I0723 10:43:03.141302 42986 fusion.cc:310]  in 0.418s (4495666 points)
# I0723 10:43:03.141356 42986 fusion.cc:283] Fusing image [192/200] with index 111
# I0723 10:43:03.566663 42986 fusion.cc:310]  in 0.425s (4496677 points)
# I0723 10:43:03.566728 42986 fusion.cc:283] Fusing image [193/200] with index 110
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:43:04.025820 42986 fusion.cc:310]  in 0.459s (4497538 points)
# I0723 10:43:04.025871 42986 fusion.cc:283] Fusing image [194/200] with index 109
# I0723 10:43:04.479960 42986 fusion.cc:310]  in 0.454s (4498100 points)
# I0723 10:43:04.480016 42986 fusion.cc:283] Fusing image [195/200] with index 108
# I0723 10:43:05.214253 42986 fusion.cc:310]  in 0.734s (4498974 points)
# I0723 10:43:05.214306 42986 fusion.cc:283] Fusing image [196/200] with index 107
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:43:05.892756 42986 fusion.cc:310]  in 0.678s (4499561 points)
# I0723 10:43:05.892812 42986 fusion.cc:283] Fusing image [197/200] with index 106
# I0723 10:43:06.889521 42986 fusion.cc:310]  in 0.997s (4500065 points)
# I0723 10:43:06.889773 42986 fusion.cc:283] Fusing image [198/200] with index 105
# I0723 10:43:07.636466 42986 fusion.cc:310]  in 0.747s (4500073 points)
# I0723 10:43:07.636525 42986 fusion.cc:283] Fusing image [199/200] with index 104
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:43:08.153676 42986 fusion.cc:310]  in 0.517s (4500073 points)
# I0723 10:43:08.153714 42986 fusion.cc:283] Fusing image [200/200] with index 199
# I0723 10:43:08.804469 42986 fusion.cc:310]  in 0.651s (4500073 points)
# I0723 10:43:09.421793 42986 fusion.cc:337] Number of fused points: 4500073
# I0723 10:43:09.421835 42986 timer.cc:90] Elapsed time: 8.523 [minutes]
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 10:43:10.466825 42986 mvs.cc:370] Writing output: "/content/project/pipeline/work/hcm0031/colmap/dense/fused.ply"
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] COLMAP dense pilot xong: scene=hcm0031
# [b2-pilot] PatchMatch: 5923s | StereoFusion: 519s
# [b2-pilot] Depth maps: 400 | Normal maps: 400 | Consistency graphs: 0
# [b2-pilot] Fused PLY: /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# [b2-pilot] Summary: /content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# [b2-pilot] B2 pilot workflow xong: scene=hcm0031
# [b2-pilot] Summary: /content/project/pipeline/work/hcm0031/logs/05_b2_pilot_summary.txt
#
# --- 04_colmap_dense_summary.txt (final) ---
# scene=hcm0031
# dense_dir=/content/project/pipeline/work/hcm0031/colmap/dense
# colmap_bin=/content/project/.local/colmap-cuda/bin/colmap
# patch_match_seconds=5923
# stereo_fusion_seconds=519
# depth_map_files=400
# normal_map_files=400
# consistency_graph_files=0
# fused_ply=/content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# fused_ply_bytes=121502206
# patch_log=/content/project/pipeline/work/hcm0031/logs/04_patch_match_stereo.log
# fusion_log=/content/project/pipeline/work/hcm0031/logs/04_stereo_fusion.log
# --- end 04_colmap_dense_summary.txt ---
#
#
# --- 05_b2_pilot_summary.txt (final) ---
# scene=hcm0031
# dataset_root=/content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set
# work_root=/content/project/pipeline/work
# run_dense=1
# run_train=0
# run_render=0
# run_eval=0
# source_mode=prepared
# model_dir=/content/project/pipeline/work/hcm0031/gs_model
# render_out_dir=/content/project/pipeline/work/hcm0031/renders_b2_pilot
# eval_out_csv=/content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# tower_bbox3d_json=/content/project/pipeline/work/hcm0031/tower_bbox3d.json
# skyline_top_frac=0.3
# dense_summary=/content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# render_log=/content/project/pipeline/work/hcm0031/logs/05_render_b2_pilot.log
# eval_log=/content/project/pipeline/work/hcm0031/logs/05_eval_b2_pilot.log
# --- end 05_b2_pilot_summary.txt ---
#
# [b2-pilot] RETURN CODE = 0
# B2 pilot done

# %%
from pathlib import Path
work_dir = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
logs_dir = work_dir / 'logs'

for p in [
    logs_dir / '04_colmap_dense_summary.txt',
    logs_dir / '04_patch_match_stereo.log',
    logs_dir / '04_stereo_fusion.log',
    work_dir / 'colmap' / 'dense' / 'fused.ply',
    work_dir / 'eval_metrics_b2_pilot.csv',
    work_dir / 'eval_metrics_b2_pilot_tower_crop.csv',
    work_dir / 'eval_metrics_b2_pilot_skyline_crop.csv',
]:
    print(('OK  ' if p.exists() else 'MISS'), p)
# Out:
# OK   /content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# OK   /content/project/pipeline/work/hcm0031/logs/04_patch_match_stereo.log
# OK   /content/project/pipeline/work/hcm0031/logs/04_stereo_fusion.log
# OK   /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_tower_crop.csv
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_skyline_crop.csv

# %%
import subprocess
from pathlib import Path

scene_root = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
artifact_dir = Path(WORKDIR) / 'b2_pilot_artifacts'
artifact_dir.mkdir(parents=True, exist_ok=True)

subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_colmap_dense_summary.txt" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_patch_match_stereo.log" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_stereo_fusion.log" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/05_b2_pilot_summary.txt" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/colmap/dense/fused.ply" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot_tower_crop.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot_skyline_crop.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)

subprocess.run(['bash', '-lc', f'cd "{WORKDIR}" && zip -r b2_pilot_artifacts.zip b2_pilot_artifacts >/dev/null'], check=True)
print('Artifact zip:', Path(WORKDIR) / 'b2_pilot_artifacts.zip')
# Out:
# Artifact zip: /content/b2_pilot_artifacts.zip

# %%
from pathlib import Path

zip_candidates = [
    Path(WORKDIR) / 'b2_pilot_artifacts.zip',
    Path('b2_pilot_artifacts.zip').resolve(),
]
zip_path = next((p for p in zip_candidates if p.exists()), None)
assert zip_path is not None, 'Khong tim thay b2_pilot_artifacts.zip de download'
print('Zip san sang:', zip_path)
print('Notebook dang chay tren Kaggle. Hay tai thu cong file nay tu sidebar:', zip_path)
# Out:
# Zip san sang: /content/b2_pilot_artifacts.zip
# Notebook dang chay tren Kaggle. Hay tai thu cong file nay tu sidebar: /content/b2_pilot_artifacts.zip

# %%
# =========================
# CELL 1 - Config + checks
# =========================
from pathlib import Path

WORKDIR = '/content' if Path('/content').exists() else '/kaggle/working'
SCENE = 'hcm0031'
PROJECT_DIR = Path(WORKDIR) / 'project'
DATASET_ROOT = Path(WORKDIR) / '_dataset_round1_raw' / 'VAI_NVS_DATA' / 'phase1' / 'public_set'
COLMAP_BIN = PROJECT_DIR / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
GS_REPO = Path(WORKDIR) / 'gaussian-splatting'
GS_REPO_BRANCH = 'main'

checks = [
    PROJECT_DIR,
    DATASET_ROOT,
    COLMAP_BIN,
    PROJECT_DIR / 'pipeline' / 'work' / SCENE / 'colmap' / 'dense' / 'fused.ply',
]
for p in checks:
    print(p, 'OK' if p.exists() else 'MISS')
# Out:
# /content/project OK
# /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set OK
# /content/project/.local/colmap-cuda/bin/colmap OK
# /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply OK

# %%
# ======================================
# CELL 2 - Clone GS repo only if missing
# ======================================
import subprocess

GS_REPO_URL = "https://github.com/graphdeco-inria/gaussian-splatting.git"

if GS_REPO.exists():
    print("GS_REPO da ton tai:", GS_REPO)
else:
    subprocess.run(
        ["git", "clone", "--depth", "1", "-b", GS_REPO_BRANCH, GS_REPO_URL, str(GS_REPO)],
        check=True,
    )
    print("Cloned:", GS_REPO)
# Out:
# GS_REPO da ton tai: /content/gaussian-splatting

# %%
# ======================================================
# CELL 3 - Install minimal GS deps + CUDA extensions
# ======================================================
from pathlib import Path

assert GS_REPO.exists(), GS_REPO

run_and_stream(
    ['bash', '-lc', f'cd "{GS_REPO}" && git submodule update --init --recursive'],
    label='gs-submodules',
)

run_and_stream(
    ['bash', '-lc', 'python3 -m pip install --upgrade pip setuptools wheel ninja'],
    label='gs-pip-core',
)

run_and_stream(
    ['bash', '-lc', 'python3 -m pip install plyfile tqdm lpips opencv-python imageio imageio-ffmpeg'],
    label='gs-pip-deps',
)

run_and_stream(
    ['bash', '-lc', 'python3 -c "import torch; print(torch.__version__)"'],
    label='gs-check-torch',
)

build_logs_dir = Path(WORKDIR) / 'gs_build_logs'
build_logs_dir.mkdir(parents=True, exist_ok=True)

build_steps = [
    (
        'diff_gaussian_rasterization',
        GS_REPO / 'submodules' / 'diff-gaussian-rasterization',
        build_logs_dir / 'diff_gaussian_rasterization.log',
    ),
    (
        'simple_knn',
        GS_REPO / 'submodules' / 'simple-knn',
        build_logs_dir / 'simple_knn.log',
    ),
]

for name, src_dir, log_path in build_steps:
    assert src_dir.exists(), src_dir
    run_and_stream(
        ['bash', '-lc', f'cd "{src_dir}" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .'],
        log_files=[log_path],
        poll_seconds=20,
        label=name,
    )
    print(f'Installed: {name}')

print('Gaussian Splatting minimal deps + extensions installed')
# Out:
# [gs-submodules] START: bash -lc cd "/content/gaussian-splatting" && git submodule update --init --recursive
# [gs-submodules] still running...
# [gs-submodules] RETURN CODE = 0
# [gs-pip-core] START: bash -lc python3 -m pip install --upgrade pip setuptools wheel ninja
# [gs-pip-core] still running...
# [gs-pip-core] Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.1.2)
# [gs-pip-core] Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (81.0.0)
# [gs-pip-core] Collecting setuptools
# [gs-pip-core]   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# [gs-pip-core] Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.47.0)
# [gs-pip-core] Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (1.13.0)
# [gs-pip-core] Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.2)
# [gs-pip-core] Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# [gs-pip-core] Installing collected packages: setuptools
# [gs-pip-core]   Attempting uninstall: setuptools
# [gs-pip-core]     Found existing installation: setuptools 81.0.0
# [gs-pip-core]     Uninstalling setuptools-81.0.0:
# [gs-pip-core]       Successfully uninstalled setuptools-81.0.0
# [gs-pip-core] ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# [gs-pip-core] ipython 7.34.0 requires jedi>=0.16, which is not installed.
# [gs-pip-core] torch 2.11.0+cu128 requires setuptools<82, but you have setuptools 83.0.0 which is incompatible.
# [gs-pip-core] Successfully installed setuptools-83.0.0
# [gs-pip-core] RETURN CODE = 0
# [gs-pip-deps] START: bash -lc python3 -m pip install plyfile tqdm lpips opencv-python imageio imageio-ffmpeg
# [gs-pip-deps] still running...
# [gs-pip-deps] Requirement already satisfied: plyfile in /usr/local/lib/python3.12/dist-packages (1.1.4)
# [gs-pip-deps] Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# [gs-pip-deps] Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# [gs-pip-deps] Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (5.0.0.93)
# [gs-pip-deps] Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.3)
# [gs-pip-deps] Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (0.6.0)
# [gs-pip-deps] Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from plyfile) (2.0.2)
# [gs-pip-deps] Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.11.0+cu128)
# [gs-pip-deps] Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.26.0+cu128)
# [gs-pip-deps] Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# [gs-pip-deps] Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio) (11.3.0)
# [gs-pip-deps] Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.29.7)
# [gs-pip-deps] Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.16.0)
# [gs-pip-deps] Collecting setuptools<82 (from torch>=0.4.0->lpips)
# [gs-pip-deps]   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# [gs-pip-deps] Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.14.0)
# [gs-pip-deps] Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.1)
# [gs-pip-deps] Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# [gs-pip-deps] Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# [gs-pip-deps] Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.1)
# [gs-pip-deps] Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.9.7)
# [gs-pip-deps] Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.19.0.56)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# [gs-pip-deps] Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.28.9)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.5)
# [gs-pip-deps] Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.0)
# [gs-pip-deps] Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.4.1)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (11.3.3.83)
# [gs-pip-deps] Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (1.13.1.3)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (10.3.9.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (11.7.3.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.5.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=0.4.0->lpips) (1.5.6)
# [gs-pip-deps] Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# [gs-pip-deps] Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# [gs-pip-deps] Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# [gs-pip-deps] Installing collected packages: setuptools
# [gs-pip-deps]   Attempting uninstall: setuptools
# [gs-pip-deps]     Found existing installation: setuptools 83.0.0
# [gs-pip-deps]     Uninstalling setuptools-83.0.0:
# [gs-pip-deps]       Successfully uninstalled setuptools-83.0.0
# [gs-pip-deps] ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# [gs-pip-deps] ipython 7.34.0 requires jedi>=0.16, which is not installed.
# [gs-pip-deps] Successfully installed setuptools-81.0.0
# [gs-pip-deps] RETURN CODE = 0
# [gs-check-torch] START: bash -lc python3 -c "import torch; print(torch.__version__)"
# [gs-check-torch] still running...
# [gs-check-torch] 2.11.0+cu128
# [gs-check-torch] RETURN CODE = 0
# [diff_gaussian_rasterization] START: bash -lc cd "/content/gaussian-splatting/submodules/diff-gaussian-rasterization" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] Processing ./.
# [diff_gaussian_rasterization]   Preparing metadata (pyproject.toml): started
# [diff_gaussian_rasterization]   Preparing metadata (pyproject.toml): finished with status 'done'
# [diff_gaussian_rasterization] Building wheels for collected packages: diff_gaussian_rasterization
# [diff_gaussian_rasterization]   Building wheel for diff_gaussian_rasterization (pyproject.toml): started
# [diff_gaussian_rasterization]   Building wheel for diff_gaussian_rasterization (pyproject.toml): finished with status 'done'
# [diff_gaussian_rasterization]   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3816789 sha256=68e91a4513b643c1cb343021e18961503a8ef24033497807491ac58c82c12349
# [diff_gaussian_rasterization]   Stored in directory: /root/.cache/pip/wheels/01/e0/e8/f40a1cd6a1d5760cbd3036081bdad5b36c41fc11c786d4a404
# [diff_gaussian_rasterization] Successfully built diff_gaussian_rasterization
# [diff_gaussian_rasterization] Installing collected packages: diff_gaussian_rasterization
# [diff_gaussian_rasterization]   Attempting uninstall: diff_gaussian_rasterization
# [diff_gaussian_rasterization]     Found existing installation: diff_gaussian_rasterization 0.0.0
# [diff_gaussian_rasterization]     Uninstalling diff_gaussian_rasterization-0.0.0:
# [diff_gaussian_rasterization]       Successfully uninstalled diff_gaussian_rasterization-0.0.0
# [diff_gaussian_rasterization] Successfully installed diff_gaussian_rasterization-0.0.0
# [diff_gaussian_rasterization] RETURN CODE = 0
# Installed: diff_gaussian_rasterization
# [simple_knn] START: bash -lc cd "/content/gaussian-splatting/submodules/simple-knn" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .
# [simple_knn] still running...
# [simple_knn] Processing ./.
# [simple_knn]   Preparing metadata (pyproject.toml): started
# [simple_knn]   Preparing metadata (pyproject.toml): finished with status 'done'
# [simple_knn] Building wheels for collected packages: simple_knn
# [simple_knn]   Building wheel for simple_knn (pyproject.toml): started
# [simple_knn]   Building wheel for simple_knn (pyproject.toml): finished with status 'done'
# [simple_knn]   Created wheel for simple_knn: filename=simple_knn-0.0.0-cp312-cp312-linux_x86_64.whl size=3555554 sha256=45ec2e60e0878784aba93f0017204d9e6a93cd7f5eeadaa5b151a82ff7a2e0f2
# [simple_knn]   Stored in directory: /root/.cache/pip/wheels/0a/f2/1b/255828ebad94ea248378281b7926639d83ce4f394f0052800d
# [simple_knn] Successfully built simple_knn
# [simple_knn] Installing collected packages: simple_knn
# [simple_knn]   Attempting uninstall: simple_knn
# [simple_knn]     Found existing installation: simple_knn 0.0.0
# [simple_knn]     Uninstalling simple_knn-0.0.0:
# [simple_knn]       Successfully uninstalled simple_knn-0.0.0
# [simple_knn] Successfully installed simple_knn-0.0.0
# [simple_knn] RETURN CODE = 0
# Installed: simple_knn
# Gaussian Splatting minimal deps + extensions installed

# %%
# ==================================================
# CELL 4 - Quick import test for GS + eval packages
# ==================================================
import sys

sys.path.insert(0, str(GS_REPO))

import cv2
import diff_gaussian_rasterization
import lpips
import simple_knn

print("Imports OK")
print("GS_REPO =", GS_REPO)
# Out:
# Imports OK
# GS_REPO = /content/gaussian-splatting

# %%
# ================================================
# CELL 5 - Run train + render + eval for B2 debug
# ================================================
import os
from pathlib import Path

assert PROJECT_DIR.exists(), PROJECT_DIR
assert DATASET_ROOT.exists(), DATASET_ROOT
assert COLMAP_BIN.exists(), COLMAP_BIN
assert GS_REPO.exists(), GS_REPO

env = os.environ.copy()
env['DATASET_ROOT'] = str(DATASET_ROOT)
env['COLMAP_BIN'] = str(COLMAP_BIN)
env['GS_REPO'] = str(GS_REPO)

env['RUN_DENSE'] = '0'
env['RUN_TRAIN'] = '1'
env['RUN_RENDER'] = '1'
env['RUN_EVAL'] = '1'
env['SOURCE_MODE'] = 'prepared'
env['ITERATION'] = '-1'

scene_root = PROJECT_DIR / 'pipeline' / 'work' / SCENE
log_files = [
    scene_root / 'train.log',
    scene_root / 'logs' / '05_render_b2_pilot.log',
    scene_root / 'logs' / '05_eval_b2_pilot.log',
    scene_root / 'logs' / '05_b2_pilot_summary.txt',
]

run_and_stream(
    ['bash', str(PROJECT_DIR / 'pipeline' / 'scripts' / '05_run_b2_pilot.sh'), SCENE],
    env=env,
    log_files=log_files,
    poll_seconds=15,
    label='b2-train-render-eval',
)

print('B2 train/render/eval done')
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Training progress:  36%|███▋      | 10880/30000 [02:45<04:15, 74.87it/s, Loss=0.0892800, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10880/30000 [02:45<04:15, 74.87it/s, Loss=0.0766803, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10890/30000 [02:45<04:17, 74.08it/s, Loss=0.0766803, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10890/30000 [02:46<04:17, 74.08it/s, Loss=0.0537259, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10900/30000 [02:46<04:16, 74.38it/s, Loss=0.0537259, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10900/30000 [02:46<04:16, 74.38it/s, Loss=0.0699526, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10910/30000 [02:46<04:16, 74.40it/s, Loss=0.0699526, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10910/30000 [02:46<04:16, 74.40it/s, Loss=0.0698101, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10920/30000 [02:46<04:15, 74.56it/s, Loss=0.0698101, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10920/30000 [02:46<04:15, 74.56it/s, Loss=0.0775263, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10930/30000 [02:46<04:11, 75.97it/s, Loss=0.0775263, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10930/30000 [02:46<04:11, 75.97it/s, Loss=0.0611245, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10940/30000 [02:46<04:11, 75.66it/s, Loss=0.0611245, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10940/30000 [02:46<04:11, 75.66it/s, Loss=0.0616703, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10950/30000 [02:46<04:11, 75.74it/s, Loss=0.0616703, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10950/30000 [02:46<04:11, 75.74it/s, Loss=0.0653379, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10960/30000 [02:46<04:11, 75.71it/s, Loss=0.0653379, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10960/30000 [02:47<04:11, 75.71it/s, Loss=0.0528777, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10970/30000 [02:47<04:13, 75.11it/s, Loss=0.0528777, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10970/30000 [02:47<04:13, 75.11it/s, Loss=0.0720523, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10980/30000 [02:47<04:16, 74.25it/s, Loss=0.0720523, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10980/30000 [02:47<04:16, 74.25it/s, Loss=0.0573746, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10990/30000 [02:47<04:14, 74.56it/s, Loss=0.0573746, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10990/30000 [02:47<04:14, 74.56it/s, Loss=0.0670430, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11000/30000 [02:47<04:13, 74.89it/s, Loss=0.0670430, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11000/30000 [02:47<04:13, 74.89it/s, Loss=0.0638731, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11010/30000 [02:47<04:11, 75.51it/s, Loss=0.0638731, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11010/30000 [02:47<04:11, 75.51it/s, Loss=0.0601832, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11020/30000 [02:47<04:12, 75.08it/s, Loss=0.0601832, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11020/30000 [02:47<04:12, 75.08it/s, Loss=0.0674749, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11030/30000 [02:47<04:15, 74.34it/s, Loss=0.0674749, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11030/30000 [02:47<04:15, 74.34it/s, Loss=0.0619811, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11040/30000 [02:47<04:14, 74.45it/s, Loss=0.0619811, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11040/30000 [02:48<04:14, 74.45it/s, Loss=0.0663603, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11050/30000 [02:48<04:13, 74.77it/s, Loss=0.0663603, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11050/30000 [02:48<04:13, 74.77it/s, Loss=0.0616840, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11060/30000 [02:48<04:15, 74.20it/s, Loss=0.0616840, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11060/30000 [02:48<04:15, 74.20it/s, Loss=0.0623057, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11070/30000 [02:48<04:11, 75.33it/s, Loss=0.0623057, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11070/30000 [02:48<04:11, 75.33it/s, Loss=0.0659225, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11080/30000 [02:48<04:11, 75.14it/s, Loss=0.0659225, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11080/30000 [02:48<04:11, 75.14it/s, Loss=0.0648214, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11090/30000 [02:48<04:11, 75.19it/s, Loss=0.0648214, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11090/30000 [02:48<04:11, 75.19it/s, Loss=0.0686051, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11100/30000 [02:48<04:12, 74.88it/s, Loss=0.0686051, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11100/30000 [02:48<04:12, 74.88it/s, Loss=0.0661203, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11110/30000 [02:48<04:14, 74.10it/s, Loss=0.0661203, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11110/30000 [02:49<04:14, 74.10it/s, Loss=0.0668918, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11120/30000 [02:49<04:11, 75.11it/s, Loss=0.0668918, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11120/30000 [02:49<04:11, 75.11it/s, Loss=0.0709069, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11130/30000 [02:49<04:10, 75.32it/s, Loss=0.0709069, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11130/30000 [02:49<04:10, 75.32it/s, Loss=0.0578409, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11140/30000 [02:49<04:10, 75.38it/s, Loss=0.0578409, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11140/30000 [02:49<04:10, 75.38it/s, Loss=0.0584312, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11150/30000 [02:49<04:08, 75.92it/s, Loss=0.0584312, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11150/30000 [02:49<04:08, 75.92it/s, Loss=0.0578067, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11160/30000 [02:49<04:13, 74.45it/s, Loss=0.0578067, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11160/30000 [02:49<04:13, 74.45it/s, Loss=0.0669484, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11170/30000 [02:49<04:20, 72.27it/s, Loss=0.0669484, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11170/30000 [02:49<04:20, 72.27it/s, Loss=0.0782662, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11180/30000 [02:49<04:32, 69.04it/s, Loss=0.0782662, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11180/30000 [02:50<04:32, 69.04it/s, Loss=0.0763666, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11190/30000 [02:50<04:29, 69.86it/s, Loss=0.0763666, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11190/30000 [02:50<04:29, 69.86it/s, Loss=0.0528497, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11200/30000 [02:50<04:32, 69.03it/s, Loss=0.0528497, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11200/30000 [02:50<04:32, 69.03it/s, Loss=0.0653744, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11210/30000 [02:50<04:32, 69.04it/s, Loss=0.0653744, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11210/30000 [02:50<04:32, 69.04it/s, Loss=0.0621729, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11220/30000 [02:50<04:35, 68.09it/s, Loss=0.0621729, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11220/30000 [02:50<04:35, 68.09it/s, Loss=0.0630447, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11230/30000 [02:50<04:29, 69.59it/s, Loss=0.0630447, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11230/30000 [02:50<04:29, 69.59it/s, Loss=0.0653991, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11240/30000 [02:50<04:27, 70.07it/s, Loss=0.0653991, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11240/30000 [02:50<04:27, 70.07it/s, Loss=0.0469742, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11250/30000 [02:50<04:27, 70.16it/s, Loss=0.0469742, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11250/30000 [02:51<04:27, 70.16it/s, Loss=0.0716694, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11260/30000 [02:51<04:29, 69.55it/s, Loss=0.0716694, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11260/30000 [02:51<04:29, 69.55it/s, Loss=0.0535247, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11270/30000 [02:51<04:27, 69.96it/s, Loss=0.0535247, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11270/30000 [02:51<04:27, 69.96it/s, Loss=0.0495466, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11280/30000 [02:51<04:24, 70.68it/s, Loss=0.0495466, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11280/30000 [02:51<04:24, 70.68it/s, Loss=0.0715558, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11290/30000 [02:51<04:18, 72.43it/s, Loss=0.0715558, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11290/30000 [02:51<04:18, 72.43it/s, Loss=0.0599287, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11300/30000 [02:51<04:17, 72.61it/s, Loss=0.0599287, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11300/30000 [02:51<04:17, 72.61it/s, Loss=0.0713471, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11310/30000 [02:51<04:25, 70.38it/s, Loss=0.0713471, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11310/30000 [02:51<04:25, 70.38it/s, Loss=0.0686045, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11320/30000 [02:51<04:29, 69.33it/s, Loss=0.0686045, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11320/30000 [02:52<04:29, 69.33it/s, Loss=0.0682790, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11330/30000 [02:52<04:32, 68.40it/s, Loss=0.0682790, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11330/30000 [02:52<04:32, 68.40it/s, Loss=0.0576651, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11340/30000 [02:52<04:36, 67.45it/s, Loss=0.0576651, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11340/30000 [02:52<04:36, 67.45it/s, Loss=0.0582498, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11350/30000 [02:52<04:29, 69.19it/s, Loss=0.0582498, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11350/30000 [02:52<04:29, 69.19it/s, Loss=0.0570188, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11360/30000 [02:52<04:24, 70.39it/s, Loss=0.0570188, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11360/30000 [02:52<04:24, 70.39it/s, Loss=0.0564307, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11370/30000 [02:52<04:21, 71.37it/s, Loss=0.0564307, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11370/30000 [02:52<04:21, 71.37it/s, Loss=0.0559782, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11380/30000 [02:52<04:17, 72.27it/s, Loss=0.0559782, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11380/30000 [02:52<04:17, 72.27it/s, Loss=0.0621112, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11390/30000 [02:52<04:14, 73.10it/s, Loss=0.0621112, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11390/30000 [02:52<04:14, 73.10it/s, Loss=0.0485763, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11400/30000 [02:52<04:12, 73.74it/s, Loss=0.0485763, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11400/30000 [02:53<04:12, 73.74it/s, Loss=0.0587784, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11410/30000 [02:53<04:16, 72.59it/s, Loss=0.0587784, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11410/30000 [02:53<04:16, 72.59it/s, Loss=0.0655105, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11420/30000 [02:53<04:13, 73.40it/s, Loss=0.0655105, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11420/30000 [02:53<04:13, 73.40it/s, Loss=0.0573174, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11430/30000 [02:53<04:11, 73.87it/s, Loss=0.0573174, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11430/30000 [02:53<04:11, 73.87it/s, Loss=0.0707518, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11440/30000 [02:53<04:11, 73.84it/s, Loss=0.0707518, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11440/30000 [02:53<04:11, 73.84it/s, Loss=0.0609788, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11450/30000 [02:53<04:09, 74.35it/s, Loss=0.0609788, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11450/30000 [02:53<04:09, 74.35it/s, Loss=0.0573156, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11460/30000 [02:53<04:10, 74.10it/s, Loss=0.0573156, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11460/30000 [02:53<04:10, 74.10it/s, Loss=0.0670489, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11470/30000 [02:53<04:09, 74.41it/s, Loss=0.0670489, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11470/30000 [02:54<04:09, 74.41it/s, Loss=0.0854811, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11480/30000 [02:54<04:08, 74.62it/s, Loss=0.0854811, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11480/30000 [02:54<04:08, 74.62it/s, Loss=0.0605880, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11490/30000 [02:54<04:07, 74.70it/s, Loss=0.0605880, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11490/30000 [02:54<04:07, 74.70it/s, Loss=0.0570452, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11500/30000 [02:54<04:03, 76.10it/s, Loss=0.0570452, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11500/30000 [02:54<04:03, 76.10it/s, Loss=0.0495884, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11510/30000 [02:54<04:03, 75.99it/s, Loss=0.0495884, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11510/30000 [02:54<04:03, 75.99it/s, Loss=0.0644558, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11520/30000 [02:54<04:04, 75.71it/s, Loss=0.0644558, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11520/30000 [02:54<04:04, 75.71it/s, Loss=0.0615939, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11530/30000 [02:54<04:05, 75.30it/s, Loss=0.0615939, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11530/30000 [02:54<04:05, 75.30it/s, Loss=0.0658955, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11540/30000 [02:54<04:07, 74.55it/s, Loss=0.0658955, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11540/30000 [02:54<04:07, 74.55it/s, Loss=0.0650181, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11550/30000 [02:54<04:06, 74.91it/s, Loss=0.0650181, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11550/30000 [02:55<04:06, 74.91it/s, Loss=0.0594687, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11560/30000 [02:55<04:05, 75.15it/s, Loss=0.0594687, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11560/30000 [02:55<04:05, 75.15it/s, Loss=0.0544651, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11570/30000 [02:55<04:04, 75.31it/s, Loss=0.0544651, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11570/30000 [02:55<04:04, 75.31it/s, Loss=0.0532837, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11580/30000 [02:55<04:03, 75.61it/s, Loss=0.0532837, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11580/30000 [02:55<04:03, 75.61it/s, Loss=0.0546526, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11590/30000 [02:55<04:04, 75.24it/s, Loss=0.0546526, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11590/30000 [02:55<04:04, 75.24it/s, Loss=0.0724493, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11600/30000 [02:55<04:04, 75.36it/s, Loss=0.0724493, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11600/30000 [02:55<04:04, 75.36it/s, Loss=0.0616905, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11610/30000 [02:55<04:02, 75.83it/s, Loss=0.0616905, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11610/30000 [02:55<04:02, 75.83it/s, Loss=0.0578932, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11620/30000 [02:55<04:03, 75.33it/s, Loss=0.0578932, Depth Loss=0.0000000]
# Training progress:  39%|███▊      | 11620/30000 [02:56<04:03, 75.33it/s, Loss=0.0660213, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11630/30000 [02:56<04:03, 75.45it/s, Loss=0.0660213, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11630/30000 [02:56<04:03, 75.45it/s, Loss=0.0585189, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11640/30000 [02:56<04:05, 74.82it/s, Loss=0.0585189, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11640/30000 [02:56<04:05, 74.82it/s, Loss=0.0678945, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11650/30000 [02:56<04:02, 75.61it/s, Loss=0.0678945, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11650/30000 [02:56<04:02, 75.61it/s, Loss=0.0631064, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11660/30000 [02:56<04:03, 75.34it/s, Loss=0.0631064, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11660/30000 [02:56<04:03, 75.34it/s, Loss=0.0627889, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11670/30000 [02:56<03:59, 76.53it/s, Loss=0.0627889, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11670/30000 [02:56<03:59, 76.53it/s, Loss=0.0530762, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11680/30000 [02:56<04:03, 75.22it/s, Loss=0.0530762, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11680/30000 [02:56<04:03, 75.22it/s, Loss=0.0671594, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11690/30000 [02:56<04:01, 75.93it/s, Loss=0.0671594, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11690/30000 [02:56<04:01, 75.93it/s, Loss=0.0716279, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11700/30000 [02:56<03:59, 76.38it/s, Loss=0.0716279, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11700/30000 [02:57<03:59, 76.38it/s, Loss=0.0784668, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11710/30000 [02:57<03:55, 77.66it/s, Loss=0.0784668, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11710/30000 [02:57<03:55, 77.66it/s, Loss=0.0571238, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11720/30000 [02:57<04:00, 75.89it/s, Loss=0.0571238, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11720/30000 [02:57<04:00, 75.89it/s, Loss=0.0659659, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11730/30000 [02:57<03:59, 76.22it/s, Loss=0.0659659, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11730/30000 [02:57<03:59, 76.22it/s, Loss=0.0622266, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11740/30000 [02:57<04:02, 75.42it/s, Loss=0.0622266, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11740/30000 [02:57<04:02, 75.42it/s, Loss=0.0644226, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11750/30000 [02:57<04:03, 74.88it/s, Loss=0.0644226, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11750/30000 [02:57<04:03, 74.88it/s, Loss=0.0531429, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11760/30000 [02:57<04:03, 74.84it/s, Loss=0.0531429, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11760/30000 [02:57<04:03, 74.84it/s, Loss=0.0628173, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11770/30000 [02:57<04:04, 74.42it/s, Loss=0.0628173, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11770/30000 [02:58<04:04, 74.42it/s, Loss=0.0524448, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11780/30000 [02:58<04:03, 74.72it/s, Loss=0.0524448, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11780/30000 [02:58<04:03, 74.72it/s, Loss=0.0547390, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11790/30000 [02:58<04:04, 74.39it/s, Loss=0.0547390, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11790/30000 [02:58<04:04, 74.39it/s, Loss=0.0478153, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11800/30000 [02:58<04:10, 72.69it/s, Loss=0.0478153, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11800/30000 [02:58<04:10, 72.69it/s, Loss=0.0544292, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11810/30000 [02:58<04:07, 73.59it/s, Loss=0.0544292, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11810/30000 [02:58<04:07, 73.59it/s, Loss=0.0666650, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11820/30000 [02:58<04:05, 74.19it/s, Loss=0.0666650, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11820/30000 [02:58<04:05, 74.19it/s, Loss=0.0549225, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11830/30000 [02:58<04:02, 74.81it/s, Loss=0.0549225, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11830/30000 [02:58<04:02, 74.81it/s, Loss=0.0738199, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11840/30000 [02:58<04:00, 75.50it/s, Loss=0.0738199, Depth Loss=0.0000000]
# Training progress:  39%|███▉      | 11840/30000 [02:58<04:00, 75.50it/s, Loss=0.0576029, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11850/30000 [02:58<04:02, 74.77it/s, Loss=0.0576029, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11850/30000 [02:59<04:02, 74.77it/s, Loss=0.0525249, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11860/30000 [02:59<04:00, 75.28it/s, Loss=0.0525249, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11860/30000 [02:59<04:00, 75.28it/s, Loss=0.0648321, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11870/30000 [02:59<04:01, 74.99it/s, Loss=0.0648321, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11870/30000 [02:59<04:01, 74.99it/s, Loss=0.0604771, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11880/30000 [02:59<03:59, 75.63it/s, Loss=0.0604771, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11880/30000 [02:59<03:59, 75.63it/s, Loss=0.0745417, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11890/30000 [02:59<03:58, 75.85it/s, Loss=0.0745417, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11890/30000 [02:59<03:58, 75.85it/s, Loss=0.0598260, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11900/30000 [02:59<03:57, 76.21it/s, Loss=0.0598260, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11900/30000 [02:59<03:57, 76.21it/s, Loss=0.0601646, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11910/30000 [02:59<03:58, 75.86it/s, Loss=0.0601646, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11910/30000 [02:59<03:58, 75.86it/s, Loss=0.0516942, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11920/30000 [02:59<03:59, 75.35it/s, Loss=0.0516942, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11920/30000 [03:00<03:59, 75.35it/s, Loss=0.0540671, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11930/30000 [03:00<03:58, 75.86it/s, Loss=0.0540671, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11930/30000 [03:00<03:58, 75.86it/s, Loss=0.0523315, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11940/30000 [03:00<04:03, 74.27it/s, Loss=0.0523315, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11940/30000 [03:00<04:03, 74.27it/s, Loss=0.0556276, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11950/30000 [03:00<04:07, 73.01it/s, Loss=0.0556276, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11950/30000 [03:00<04:07, 73.01it/s, Loss=0.0599358, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11960/30000 [03:00<04:06, 73.22it/s, Loss=0.0599358, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11960/30000 [03:00<04:06, 73.22it/s, Loss=0.0656692, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11970/30000 [03:00<04:08, 72.48it/s, Loss=0.0656692, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11970/30000 [03:00<04:08, 72.48it/s, Loss=0.0674720, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11980/30000 [03:00<04:05, 73.48it/s, Loss=0.0674720, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11980/30000 [03:00<04:05, 73.48it/s, Loss=0.1030305, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11990/30000 [03:00<04:03, 73.82it/s, Loss=0.1030305, Depth Loss=0.0000000]
# Training progress:  40%|███▉      | 11990/30000 [03:00<04:03, 73.82it/s, Loss=0.0550143, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12000/30000 [03:00<04:00, 74.90it/s, Loss=0.0550143, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12000/30000 [03:02<04:00, 74.90it/s, Loss=0.0465752, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12010/30000 [03:02<18:56, 15.83it/s, Loss=0.0465752, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12010/30000 [03:02<18:56, 15.83it/s, Loss=0.0439671, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12020/30000 [03:02<14:33, 20.59it/s, Loss=0.0439671, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12020/30000 [03:03<14:33, 20.59it/s, Loss=0.0557024, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12030/30000 [03:03<11:32, 25.97it/s, Loss=0.0557024, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12030/30000 [03:03<11:32, 25.97it/s, Loss=0.0651245, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12040/30000 [03:03<09:21, 32.00it/s, Loss=0.0651245, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12040/30000 [03:03<09:21, 32.00it/s, Loss=0.0520919, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12050/30000 [03:03<07:46, 38.45it/s, Loss=0.0520919, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12050/30000 [03:03<07:46, 38.45it/s, Loss=0.0527471, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12060/30000 [03:03<06:42, 44.53it/s, Loss=0.0527471, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12060/30000 [03:03<06:42, 44.53it/s, Loss=0.0530639, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12070/30000 [03:03<05:54, 50.64it/s, Loss=0.0530639, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12070/30000 [03:03<05:54, 50.64it/s, Loss=0.0629036, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12080/30000 [03:03<05:21, 55.68it/s, Loss=0.0629036, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12080/30000 [03:03<05:21, 55.68it/s, Loss=0.0544112, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12090/30000 [03:03<04:56, 60.38it/s, Loss=0.0544112, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12090/30000 [03:04<04:56, 60.38it/s, Loss=0.0667743, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12100/30000 [03:04<04:43, 63.21it/s, Loss=0.0667743, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12100/30000 [03:04<04:43, 63.21it/s, Loss=0.0474984, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12110/30000 [03:04<04:29, 66.42it/s, Loss=0.0474984, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12110/30000 [03:04<04:29, 66.42it/s, Loss=0.0526818, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12120/30000 [03:04<04:24, 67.65it/s, Loss=0.0526818, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12120/30000 [03:04<04:24, 67.65it/s, Loss=0.0642995, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12130/30000 [03:04<04:21, 68.33it/s, Loss=0.0642995, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12130/30000 [03:04<04:21, 68.33it/s, Loss=0.0478481, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12140/30000 [03:04<04:26, 67.06it/s, Loss=0.0478481, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12140/30000 [03:04<04:26, 67.06it/s, Loss=0.0807757, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12150/30000 [03:04<04:25, 67.29it/s, Loss=0.0807757, Depth Loss=0.0000000]
# Training progress:  40%|████      | 12150/30000 [03:04<04:25, 67.29it/s, Loss=0.0616818, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12160/30000 [03:04<04:23, 67.61it/s, Loss=0.0616818, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12160/30000 [03:05<04:23, 67.61it/s, Loss=0.0465744, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12170/30000 [03:05<04:18, 68.98it/s, Loss=0.0465744, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12170/30000 [03:05<04:18, 68.98it/s, Loss=0.0457940, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12180/30000 [03:05<04:12, 70.49it/s, Loss=0.0457940, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12180/30000 [03:05<04:12, 70.49it/s, Loss=0.0842232, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12190/30000 [03:05<04:05, 72.56it/s, Loss=0.0842232, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12190/30000 [03:05<04:05, 72.56it/s, Loss=0.0623324, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12200/30000 [03:05<03:59, 74.20it/s, Loss=0.0623324, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12200/30000 [03:05<03:59, 74.20it/s, Loss=0.0566293, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12210/30000 [03:05<04:02, 73.26it/s, Loss=0.0566293, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12210/30000 [03:05<04:02, 73.26it/s, Loss=0.0631288, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12220/30000 [03:05<03:59, 74.39it/s, Loss=0.0631288, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12220/30000 [03:05<03:59, 74.39it/s, Loss=0.0662950, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12230/30000 [03:05<03:56, 75.09it/s, Loss=0.0662950, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12230/30000 [03:05<03:56, 75.09it/s, Loss=0.0565211, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12240/30000 [03:05<03:54, 75.77it/s, Loss=0.0565211, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12240/30000 [03:06<03:54, 75.77it/s, Loss=0.0577223, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12250/30000 [03:06<03:55, 75.49it/s, Loss=0.0577223, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12250/30000 [03:06<03:55, 75.49it/s, Loss=0.0521490, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12260/30000 [03:06<03:53, 75.85it/s, Loss=0.0521490, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12260/30000 [03:06<03:53, 75.85it/s, Loss=0.0509204, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12270/30000 [03:06<03:55, 75.38it/s, Loss=0.0509204, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12270/30000 [03:06<03:55, 75.38it/s, Loss=0.0599734, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12280/30000 [03:06<03:57, 74.52it/s, Loss=0.0599734, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12280/30000 [03:06<03:57, 74.52it/s, Loss=0.0768934, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12290/30000 [03:06<03:56, 74.95it/s, Loss=0.0768934, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12290/30000 [03:06<03:56, 74.95it/s, Loss=0.0693520, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12300/30000 [03:06<03:56, 74.97it/s, Loss=0.0693520, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12300/30000 [03:06<03:56, 74.97it/s, Loss=0.0645331, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12310/30000 [03:06<03:57, 74.52it/s, Loss=0.0645331, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12310/30000 [03:07<03:57, 74.52it/s, Loss=0.0546067, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12320/30000 [03:07<03:56, 74.62it/s, Loss=0.0546067, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12320/30000 [03:07<03:56, 74.62it/s, Loss=0.0509702, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12330/30000 [03:07<03:55, 74.97it/s, Loss=0.0509702, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12330/30000 [03:07<03:55, 74.97it/s, Loss=0.0582504, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12340/30000 [03:07<03:58, 73.89it/s, Loss=0.0582504, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12340/30000 [03:07<03:58, 73.89it/s, Loss=0.0553902, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12350/30000 [03:07<03:57, 74.43it/s, Loss=0.0553902, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12350/30000 [03:07<03:57, 74.43it/s, Loss=0.0496271, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12360/30000 [03:07<03:57, 74.23it/s, Loss=0.0496271, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12360/30000 [03:07<03:57, 74.23it/s, Loss=0.0519507, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12370/30000 [03:07<03:59, 73.52it/s, Loss=0.0519507, Depth Loss=0.0000000]
# Training progress:  41%|████      | 12370/30000 [03:07<03:59, 73.52it/s, Loss=0.0524090, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12380/30000 [03:07<04:03, 72.29it/s, Loss=0.0524090, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12380/30000 [03:08<04:03, 72.29it/s, Loss=0.0575543, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12390/30000 [03:08<04:02, 72.61it/s, Loss=0.0575543, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12390/30000 [03:08<04:02, 72.61it/s, Loss=0.0914272, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12400/30000 [03:08<03:53, 75.23it/s, Loss=0.0914272, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12400/30000 [03:08<03:53, 75.23it/s, Loss=0.0531005, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12410/30000 [03:08<03:50, 76.30it/s, Loss=0.0531005, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12410/30000 [03:08<03:50, 76.30it/s, Loss=0.0484332, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12420/30000 [03:08<03:51, 76.04it/s, Loss=0.0484332, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12420/30000 [03:08<03:51, 76.04it/s, Loss=0.0686755, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12430/30000 [03:08<03:48, 76.77it/s, Loss=0.0686755, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12430/30000 [03:08<03:48, 76.77it/s, Loss=0.0588988, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12440/30000 [03:08<03:50, 76.10it/s, Loss=0.0588988, Depth Loss=0.0000000]
# Training progress:  41%|████▏     | 12440/30000 [03:08<03:50, 76.10it/s, Loss=0.0495165, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12450/30000 [03:08<03:51, 75.81it/s, Loss=0.0495165, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12450/30000 [03:08<03:51, 75.81it/s, Loss=0.0543638, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12460/30000 [03:08<03:54, 74.95it/s, Loss=0.0543638, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12460/30000 [03:09<03:54, 74.95it/s, Loss=0.0491789, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12470/30000 [03:09<03:54, 74.88it/s, Loss=0.0491789, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12470/30000 [03:09<03:54, 74.88it/s, Loss=0.0648525, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12480/30000 [03:09<03:52, 75.51it/s, Loss=0.0648525, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12480/30000 [03:09<03:52, 75.51it/s, Loss=0.0587691, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12490/30000 [03:09<03:52, 75.33it/s, Loss=0.0587691, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12490/30000 [03:09<03:52, 75.33it/s, Loss=0.0533395, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12500/30000 [03:09<03:54, 74.72it/s, Loss=0.0533395, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12500/30000 [03:09<03:54, 74.72it/s, Loss=0.0570748, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12510/30000 [03:09<03:54, 74.47it/s, Loss=0.0570748, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12510/30000 [03:09<03:54, 74.47it/s, Loss=0.0590031, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12520/30000 [03:09<03:56, 73.82it/s, Loss=0.0590031, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12520/30000 [03:09<03:56, 73.82it/s, Loss=0.0471704, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12530/30000 [03:09<03:57, 73.62it/s, Loss=0.0471704, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12530/30000 [03:09<03:57, 73.62it/s, Loss=0.0634059, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12540/30000 [03:09<03:57, 73.52it/s, Loss=0.0634059, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12540/30000 [03:10<03:57, 73.52it/s, Loss=0.0579206, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12550/30000 [03:10<03:54, 74.49it/s, Loss=0.0579206, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12550/30000 [03:10<03:54, 74.49it/s, Loss=0.0481456, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12560/30000 [03:10<03:53, 74.78it/s, Loss=0.0481456, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12560/30000 [03:10<03:53, 74.78it/s, Loss=0.0688168, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12570/30000 [03:10<03:55, 73.92it/s, Loss=0.0688168, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12570/30000 [03:10<03:55, 73.92it/s, Loss=0.0560579, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12580/30000 [03:10<03:54, 74.42it/s, Loss=0.0560579, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12580/30000 [03:10<03:54, 74.42it/s, Loss=0.0550425, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12590/30000 [03:10<03:55, 73.92it/s, Loss=0.0550425, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12590/30000 [03:10<03:55, 73.92it/s, Loss=0.0539276, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12600/30000 [03:10<03:57, 73.19it/s, Loss=0.0539276, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12600/30000 [03:10<03:57, 73.19it/s, Loss=0.0568479, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12610/30000 [03:10<03:54, 74.29it/s, Loss=0.0568479, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12610/30000 [03:11<03:54, 74.29it/s, Loss=0.0456280, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12620/30000 [03:11<03:54, 74.11it/s, Loss=0.0456280, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12620/30000 [03:11<03:54, 74.11it/s, Loss=0.0509623, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12630/30000 [03:11<03:53, 74.32it/s, Loss=0.0509623, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12630/30000 [03:11<03:53, 74.32it/s, Loss=0.0637692, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12640/30000 [03:11<03:51, 74.98it/s, Loss=0.0637692, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12640/30000 [03:11<03:51, 74.98it/s, Loss=0.0498125, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12650/30000 [03:11<03:51, 74.87it/s, Loss=0.0498125, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12650/30000 [03:11<03:51, 74.87it/s, Loss=0.0602279, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12660/30000 [03:11<03:51, 74.83it/s, Loss=0.0602279, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12660/30000 [03:11<03:51, 74.83it/s, Loss=0.0624656, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12670/30000 [03:11<03:56, 73.37it/s, Loss=0.0624656, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12670/30000 [03:11<03:56, 73.37it/s, Loss=0.0625649, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12680/30000 [03:11<03:52, 74.56it/s, Loss=0.0625649, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12680/30000 [03:12<03:52, 74.56it/s, Loss=0.0508427, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12690/30000 [03:12<03:51, 74.62it/s, Loss=0.0508427, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12690/30000 [03:12<03:51, 74.62it/s, Loss=0.0739899, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12700/30000 [03:12<03:50, 74.94it/s, Loss=0.0739899, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12700/30000 [03:12<03:50, 74.94it/s, Loss=0.0546675, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12710/30000 [03:12<03:51, 74.69it/s, Loss=0.0546675, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12710/30000 [03:12<03:51, 74.69it/s, Loss=0.0536884, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12720/30000 [03:12<03:50, 74.83it/s, Loss=0.0536884, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12720/30000 [03:12<03:50, 74.83it/s, Loss=0.0564084, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12730/30000 [03:12<03:50, 75.06it/s, Loss=0.0564084, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12730/30000 [03:12<03:50, 75.06it/s, Loss=0.0591911, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12740/30000 [03:12<03:52, 74.38it/s, Loss=0.0591911, Depth Loss=0.0000000]
# Training progress:  42%|████▏     | 12740/30000 [03:12<03:52, 74.38it/s, Loss=0.0657193, Depth Loss=0.0000000]
# Training progress:  42%|████▎     | 12750/30000 [03:12<03:53, 73.87it/s, Loss=0.0657193, Depth Loss=0.0000000]
# Training progress:  42%|████▎     | 12750/30000 [03:12<03:53, 73.87it/s, Loss=0.0663273, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12760/30000 [03:12<03:52, 74.16it/s, Loss=0.0663273, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12760/30000 [03:13<03:52, 74.16it/s, Loss=0.0506416, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12770/30000 [03:13<03:51, 74.46it/s, Loss=0.0506416, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12770/30000 [03:13<03:51, 74.46it/s, Loss=0.0536478, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12780/30000 [03:13<03:50, 74.75it/s, Loss=0.0536478, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12780/30000 [03:13<03:50, 74.75it/s, Loss=0.0575638, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12790/30000 [03:13<03:51, 74.28it/s, Loss=0.0575638, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12790/30000 [03:13<03:51, 74.28it/s, Loss=0.0630996, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12800/30000 [03:13<03:49, 74.93it/s, Loss=0.0630996, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12800/30000 [03:13<03:49, 74.93it/s, Loss=0.0574413, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12810/30000 [03:13<03:49, 75.06it/s, Loss=0.0574413, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12810/30000 [03:13<03:49, 75.06it/s, Loss=0.0496005, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12820/30000 [03:13<03:49, 74.95it/s, Loss=0.0496005, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12820/30000 [03:13<03:49, 74.95it/s, Loss=0.0575041, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12830/30000 [03:13<03:52, 74.00it/s, Loss=0.0575041, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12830/30000 [03:14<03:52, 74.00it/s, Loss=0.0630669, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12840/30000 [03:14<03:49, 74.65it/s, Loss=0.0630669, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12840/30000 [03:14<03:49, 74.65it/s, Loss=0.0543314, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12850/30000 [03:14<03:50, 74.45it/s, Loss=0.0543314, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12850/30000 [03:14<03:50, 74.45it/s, Loss=0.0652229, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12860/30000 [03:14<03:50, 74.44it/s, Loss=0.0652229, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12860/30000 [03:14<03:50, 74.44it/s, Loss=0.0473671, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12870/30000 [03:14<03:50, 74.19it/s, Loss=0.0473671, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12870/30000 [03:14<03:50, 74.19it/s, Loss=0.0664008, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12880/30000 [03:14<03:48, 74.94it/s, Loss=0.0664008, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12880/30000 [03:14<03:48, 74.94it/s, Loss=0.0674533, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12890/30000 [03:14<03:49, 74.46it/s, Loss=0.0674533, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12890/30000 [03:14<03:49, 74.46it/s, Loss=0.0612578, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12900/30000 [03:14<03:53, 73.19it/s, Loss=0.0612578, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12900/30000 [03:14<03:53, 73.19it/s, Loss=0.0543488, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12910/30000 [03:14<03:50, 74.26it/s, Loss=0.0543488, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12910/30000 [03:15<03:50, 74.26it/s, Loss=0.0610466, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12920/30000 [03:15<03:54, 72.85it/s, Loss=0.0610466, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12920/30000 [03:15<03:54, 72.85it/s, Loss=0.0557225, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12930/30000 [03:15<03:57, 71.74it/s, Loss=0.0557225, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12930/30000 [03:15<03:57, 71.74it/s, Loss=0.0702282, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12940/30000 [03:15<03:57, 71.85it/s, Loss=0.0702282, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12940/30000 [03:15<03:57, 71.85it/s, Loss=0.0597344, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12950/30000 [03:15<03:53, 73.05it/s, Loss=0.0597344, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12950/30000 [03:15<03:53, 73.05it/s, Loss=0.0596754, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12960/30000 [03:15<03:55, 72.41it/s, Loss=0.0596754, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12960/30000 [03:15<03:55, 72.41it/s, Loss=0.0629551, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12970/30000 [03:15<03:54, 72.76it/s, Loss=0.0629551, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12970/30000 [03:15<03:54, 72.76it/s, Loss=0.0544874, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12980/30000 [03:15<04:01, 70.37it/s, Loss=0.0544874, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12980/30000 [03:16<04:01, 70.37it/s, Loss=0.0523173, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12990/30000 [03:16<03:57, 71.62it/s, Loss=0.0523173, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 12990/30000 [03:16<03:57, 71.62it/s, Loss=0.0534022, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 13000/30000 [03:16<03:52, 72.97it/s, Loss=0.0534022, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 13000/30000 [03:16<03:52, 72.97it/s, Loss=0.0680519, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 13010/30000 [03:16<03:51, 73.44it/s, Loss=0.0680519, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 13010/30000 [03:16<03:51, 73.44it/s, Loss=0.0662609, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 13020/30000 [03:16<03:50, 73.62it/s, Loss=0.0662609, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 13020/30000 [03:16<03:50, 73.62it/s, Loss=0.0801460, Depth Loss=0.0000000]
# Training progress:  43%|████▎     | 13030/30000 [03:16<03:52, 73.07it/s, Loss=0.0801460, Depth Loss=0.0000000]
# ...
# Training progress:  98%|█████████▊| 29500/30000 [10:02<00:15, 33.23it/s, Loss=0.0487068, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29510/30000 [10:02<00:14, 33.72it/s, Loss=0.0487068, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29510/30000 [10:02<00:14, 33.72it/s, Loss=0.0299262, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29520/30000 [10:02<00:14, 34.27it/s, Loss=0.0299262, Depth Loss=0.0000000]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
#
# --- train.log ---
#
# Training progress:  98%|█████████▊| 29520/30000 [10:02<00:14, 34.27it/s, Loss=0.0379392, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29530/30000 [10:02<00:14, 33.24it/s, Loss=0.0379392, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29530/30000 [10:03<00:14, 33.24it/s, Loss=0.0345851, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29540/30000 [10:03<00:13, 33.54it/s, Loss=0.0345851, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29540/30000 [10:03<00:13, 33.54it/s, Loss=0.0297869, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29550/30000 [10:03<00:13, 34.51it/s, Loss=0.0297869, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29550/30000 [10:03<00:13, 34.51it/s, Loss=0.0308148, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29560/30000 [10:03<00:12, 34.42it/s, Loss=0.0308148, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29560/30000 [10:04<00:12, 34.42it/s, Loss=0.0507033, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29570/30000 [10:04<00:12, 34.67it/s, Loss=0.0507033, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29570/30000 [10:04<00:12, 34.67it/s, Loss=0.0419102, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29580/30000 [10:04<00:11, 35.63it/s, Loss=0.0419102, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29580/30000 [10:04<00:11, 35.63it/s, Loss=0.0268495, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29590/30000 [10:04<00:11, 35.14it/s, Loss=0.0268495, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  99%|█████████▊| 29590/30000 [10:04<00:11, 35.14it/s, Loss=0.0373495, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29600/30000 [10:04<00:11, 34.77it/s, Loss=0.0373495, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29600/30000 [10:05<00:11, 34.77it/s, Loss=0.0274476, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29610/30000 [10:05<00:11, 34.73it/s, Loss=0.0274476, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29610/30000 [10:05<00:11, 34.73it/s, Loss=0.0283161, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29620/30000 [10:05<00:10, 35.19it/s, Loss=0.0283161, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29620/30000 [10:05<00:10, 35.19it/s, Loss=0.0329640, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29630/30000 [10:05<00:10, 35.34it/s, Loss=0.0329640, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29630/30000 [10:06<00:10, 35.34it/s, Loss=0.0387624, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29640/30000 [10:06<00:10, 35.72it/s, Loss=0.0387624, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29640/30000 [10:06<00:10, 35.72it/s, Loss=0.0352103, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29650/30000 [10:06<00:09, 35.77it/s, Loss=0.0352103, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29650/30000 [10:06<00:09, 35.77it/s, Loss=0.0334182, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29660/30000 [10:06<00:09, 35.82it/s, Loss=0.0334182, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  99%|█████████▉| 29660/30000 [10:06<00:09, 35.82it/s, Loss=0.0304160, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29670/30000 [10:06<00:09, 35.23it/s, Loss=0.0304160, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29670/30000 [10:07<00:09, 35.23it/s, Loss=0.0370972, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29680/30000 [10:07<00:08, 35.62it/s, Loss=0.0370972, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29680/30000 [10:07<00:08, 35.62it/s, Loss=0.0302728, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29690/30000 [10:07<00:08, 35.74it/s, Loss=0.0302728, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29690/30000 [10:07<00:08, 35.74it/s, Loss=0.0273816, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29700/30000 [10:07<00:08, 35.78it/s, Loss=0.0273816, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29700/30000 [10:07<00:08, 35.78it/s, Loss=0.0303233, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29710/30000 [10:07<00:08, 35.64it/s, Loss=0.0303233, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29710/30000 [10:08<00:08, 35.64it/s, Loss=0.0341517, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29720/30000 [10:08<00:07, 35.31it/s, Loss=0.0341517, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29720/30000 [10:08<00:07, 35.31it/s, Loss=0.0345098, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29730/30000 [10:08<00:07, 35.31it/s, Loss=0.0345098, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  99%|█████████▉| 29730/30000 [10:08<00:07, 35.31it/s, Loss=0.0344856, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29740/30000 [10:08<00:07, 36.72it/s, Loss=0.0344856, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29740/30000 [10:09<00:07, 36.72it/s, Loss=0.0305432, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29750/30000 [10:09<00:06, 36.64it/s, Loss=0.0305432, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29750/30000 [10:09<00:06, 36.64it/s, Loss=0.0518428, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29760/30000 [10:09<00:06, 36.65it/s, Loss=0.0518428, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29760/30000 [10:09<00:06, 36.65it/s, Loss=0.0370635, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29770/30000 [10:09<00:06, 35.86it/s, Loss=0.0370635, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29770/30000 [10:09<00:06, 35.86it/s, Loss=0.0401262, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29780/30000 [10:09<00:06, 36.23it/s, Loss=0.0401262, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29780/30000 [10:10<00:06, 36.23it/s, Loss=0.0436180, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29790/30000 [10:10<00:05, 36.20it/s, Loss=0.0436180, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29790/30000 [10:10<00:05, 36.20it/s, Loss=0.0515255, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29800/30000 [10:10<00:05, 36.12it/s, Loss=0.0515255, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29800/30000 [10:10<00:05, 36.12it/s, Loss=0.0370132, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29810/30000 [10:10<00:05, 36.35it/s, Loss=0.0370132, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  99%|█████████▉| 29810/30000 [10:11<00:05, 36.35it/s, Loss=0.0316014, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29820/30000 [10:11<00:04, 36.25it/s, Loss=0.0316014, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29820/30000 [10:11<00:04, 36.25it/s, Loss=0.0301379, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29830/30000 [10:11<00:04, 36.20it/s, Loss=0.0301379, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29830/30000 [10:11<00:04, 36.20it/s, Loss=0.0299114, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29840/30000 [10:11<00:04, 35.77it/s, Loss=0.0299114, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29840/30000 [10:11<00:04, 35.77it/s, Loss=0.0410523, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29850/30000 [10:11<00:04, 35.90it/s, Loss=0.0410523, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29850/30000 [10:12<00:04, 35.90it/s, Loss=0.0391045, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29860/30000 [10:12<00:03, 36.07it/s, Loss=0.0391045, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29860/30000 [10:12<00:03, 36.07it/s, Loss=0.0361450, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29870/30000 [10:12<00:03, 34.74it/s, Loss=0.0361450, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29870/30000 [10:12<00:03, 34.74it/s, Loss=0.0422306, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29880/30000 [10:12<00:03, 34.31it/s, Loss=0.0422306, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress: 100%|█████████▉| 29880/30000 [10:13<00:03, 34.31it/s, Loss=0.0385117, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29890/30000 [10:13<00:03, 34.18it/s, Loss=0.0385117, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29890/30000 [10:13<00:03, 34.18it/s, Loss=0.0422814, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29900/30000 [10:13<00:02, 34.89it/s, Loss=0.0422814, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29900/30000 [10:13<00:02, 34.89it/s, Loss=0.0338530, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29910/30000 [10:13<00:02, 34.63it/s, Loss=0.0338530, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29910/30000 [10:13<00:02, 34.63it/s, Loss=0.0312911, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29920/30000 [10:13<00:02, 36.68it/s, Loss=0.0312911, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29920/30000 [10:14<00:02, 36.68it/s, Loss=0.0468316, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29930/30000 [10:14<00:01, 37.44it/s, Loss=0.0468316, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29930/30000 [10:14<00:01, 37.44it/s, Loss=0.0334825, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29940/30000 [10:14<00:01, 36.64it/s, Loss=0.0334825, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29940/30000 [10:14<00:01, 36.64it/s, Loss=0.0288083, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29950/30000 [10:14<00:01, 37.46it/s, Loss=0.0288083, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress: 100%|█████████▉| 29950/30000 [10:14<00:01, 37.46it/s, Loss=0.0301887, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29960/30000 [10:14<00:01, 37.64it/s, Loss=0.0301887, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29960/30000 [10:15<00:01, 37.64it/s, Loss=0.0441632, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29970/30000 [10:15<00:00, 37.89it/s, Loss=0.0441632, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29970/30000 [10:15<00:00, 37.89it/s, Loss=0.0375732, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29980/30000 [10:15<00:00, 37.09it/s, Loss=0.0375732, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29980/30000 [10:15<00:00, 37.09it/s, Loss=0.0357492, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29990/30000 [10:15<00:00, 36.46it/s, Loss=0.0357492, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29990/30000 [10:16<00:00, 36.46it/s, Loss=0.0377882, Depth Loss=0.0000000]
# Training progress: 100%|██████████| 30000/30000 [10:16<00:00, 34.78it/s, Loss=0.0377882, Depth Loss=0.0000000]
# Training progress: 100%|██████████| 30000/30000 [10:16<00:00, 48.70it/s, Loss=0.0377882, Depth Loss=0.0000000]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
#
# --- train.log ---
#
# [ITER 2000] Saving Gaussians [23/07 11:42:37]
#
# [ITER 2000] Saving Checkpoint [23/07 11:42:38]
#
# [ITER 4000] Saving Gaussians [23/07 11:43:06]
#
# [ITER 4000] Saving Checkpoint [23/07 11:43:07]
#
# [ITER 6000] Saving Gaussians [23/07 11:43:35]
#
# [ITER 6000] Saving Checkpoint [23/07 11:43:36]
#
# [ITER 8000] Saving Gaussians [23/07 11:44:05]
#
# [ITER 8000] Saving Checkpoint [23/07 11:44:07]
#
# [ITER 10000] Saving Gaussians [23/07 11:44:38]
#
# [ITER 10000] Saving Checkpoint [23/07 11:44:40]
#
# [ITER 12000] Saving Gaussians [23/07 11:45:09]
#
# [ITER 12000] Saving Checkpoint [23/07 11:45:10]
#
# [ITER 15000] Saving Gaussians [23/07 11:45:53]
#
# [ITER 15000] Saving Checkpoint [23/07 11:45:55]
#
# [ITER 30000] Evaluating train: L1 0.025682808086276057 PSNR 29.157006072998048 [23/07 11:52:25]
#
# [ITER 30000] Saving Gaussians [23/07 11:52:25]
#
# [ITER 30000] Saving Checkpoint [23/07 11:52:27]
#
# Training complete. [23/07 11:52:27]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] [hcm0031] tiến độ: 30000/30000
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] [hcm0031] tiến độ: 30000/30000
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] [hcm0031] tiến độ: 30000/30000
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
#
# --- train.log ---
# :29]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
# [b2-train-render-eval] [hcm0031] tiến độ: 30000/30000
# [b2-train-render-eval] Xong. Model dir: /content/project/pipeline/work/hcm0031/gs_model
# [b2-train-render-eval] Point cloud cuối: /content/project/pipeline/work/hcm0031/gs_model/point_cloud/iteration_30000/point_cloud.ply
# [b2-train-render-eval] Checkpoint resume: /content/project/pipeline/work/hcm0031/gs_model/chkpnt30000.pth
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
#
# --- 05_eval_b2_pilot.log ---
# tils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# --- end 05_eval_b2_pilot.log ---
#
#
# --- 05_eval_b2_pilot.log ---
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#
#   0%|          | 0.00/233M [00:00<?, ?B/s]
#   2%|▏         | 3.88M/233M [00:00<00:05, 40.2MB/s]
#   4%|▍         | 8.75M/233M [00:00<00:05, 46.6MB/s]
#  11%|█▏        | 26.2M/233M [00:00<00:01, 109MB/s]
#  21%|██        | 49.4M/233M [00:00<00:01, 161MB/s]
#  29%|██▉       | 68.5M/233M [00:00<00:00, 175MB/s]
#  38%|███▊      | 87.5M/233M [00:00<00:00, 183MB/s]
#  46%|████▌     | 106M/233M [00:00<00:00, 187MB/s]
#  53%|█████▎    | 124M/233M [00:00<00:00, 174MB/s]
#  62%|██████▏   | 144M/233M [00:00<00:00, 183MB/s]
#  69%|██████▉   | 162M/233M [00:01<00:00, 184MB/s]
#  77%|███████▋  | 180M/233M [00:01<00:00, 179MB/s]
#  84%|████████▍ | 197M/233M [00:01<00:00, 176MB/s]
#  92%|█████████▏| 214M/233M [00:01<00:00, 170MB/s]
# 100%|█████████▉| 232M/233M [00:01<00:00, 177MB/s]
# 100%|██████████| 233M/233M [00:01<00:00, 167MB/s]
# --- end 05_eval_b2_pilot.log ---
#
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
#
# --- 05_eval_b2_pilot.log ---
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# Scene: hcm0031
# Images: 50
# PSNR mean : 10.5148
# SSIM mean : 0.3596
# LPIPS mean: 0.4233
# Score mean: 0.4016
# Saved CSV : /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# --- end 05_eval_b2_pilot.log ---
#
# [b2-train-render-eval] B2 pilot workflow xong: scene=hcm0031
# [b2-train-render-eval] Summary: /content/project/pipeline/work/hcm0031/logs/05_b2_pilot_summary.txt
# [b2-train-render-eval] RETURN CODE = 0
# B2 train/render/eval done

# %%
# ==========================================
# CELL 6 - Read quick logs / output presence
# ==========================================
from pathlib import Path

scene_root = Path(WORKDIR) / "project" / "pipeline" / "work" / SCENE
for p in [
    scene_root / "eval_metrics_b2_pilot.csv",
    scene_root / "eval_metrics_b2_pilot_tower_crop.csv",
    scene_root / "eval_metrics_b2_pilot_skyline_crop.csv",
    scene_root / "logs" / "05_render_b2_pilot.log",
    scene_root / "logs" / "05_eval_b2_pilot.log",
]:
    print("\n====", p, "====")
    if p.exists():
        text = p.read_text(encoding="utf-8", errors="replace")
        print(text[-4000:])
    else:
        print("missing")
# Out:
# ==== /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv ====
# 58475,0.5383598804473877,0.35667953703249766
# DJI_20241227155416_0044_V,11.615463442844472,0.38280925,0.5075036883354187,0.381534089727654
# DJI_20241227155417_0045_V,11.43429808179626,0.39223826,0.494157999753952,0.388614066383844
# DJI_20241227155431_0059_V,10.629865057699277,0.34341565,0.5051267743110657,0.3647531719650769
# DJI_20241227155432_0060_V,10.467510050557955,0.33506843,0.5070916414260864,0.36048895493759453
# DJI_20241227155433_0061_V,10.33686577017794,0.3315435,0.5062206983566284,0.35899597279642165
# DJI_20241227155438_0066_V,10.334113011144384,0.33753118,0.5355987548828125,0.34902452689041363
# DJI_20241227155450_0072_V,12.00147403953029,0.394109,0.45755887031555176,0.40721800528034885
# DJI_20241227155507_0089_V,10.543435774200594,0.35113633,0.46520277857780457,0.382520407211503
# DJI_20241227155533_0101_V,11.029456926456703,0.37474117,0.42731550335884094,0.40767288132352597
# DJI_20241227155536_0104_V,11.093388900629117,0.35831296,0.4447507858276367,0.39615393224639556
# DJI_20241227155543_0111_V,11.250977508459473,0.35610887,0.46767371892929077,0.38726904864450684
# DJI_20241227155545_0113_V,11.351186322820537,0.34495807,0.48606711626052856,0.37716769151480406
# DJI_20241227155546_0114_V,11.128482575582588,0.33028126,0.5070773363113403,0.36302433821777774
# DJI_20241227155547_0115_V,11.218096404714545,0.34017906,0.518639087677002,0.3619066809978673
# DJI_20241227155552_0120_V,11.512908849880274,0.36342612,0.45918774604797363,0.39443018146613346
# DJI_20241227155556_0124_V,10.787278264824794,0.34121287,0.4877322316169739,0.3719946435097709
# DJI_20241227155557_0125_V,11.00070924106512,0.33321854,0.4715212881565094,0.3773613065805002
# DJI_20241227155715_0174_V,10.068011043746704,0.40055886,0.3659096956253052,0.43421186064648293
# DJI_20241227155730_0189_V,10.429547069758918,0.42521787,0.33869343996047974,0.4546652784245655
# DJI_20241227155740_0199_V,10.767349801638392,0.42564213,0.37680351734161377,0.4415753436218421
# DJI_20241227155741_0200_V,10.579366734752147,0.4125823,0.3743464946746826,0.43751230389552764
# DJI_20241227155753_0204_V,10.141725079493938,0.4043477,0.3706739544868469,0.43388506612942945
# DJI_20241227155754_0205_V,9.971711999922583,0.39470565,0.3714350759983063,0.4296679435178613
# DJI_20241227155809_0220_V,10.125127730788495,0.40026262,0.3699797987937927,0.43283764897597854
# DJI_20241227155810_0221_V,9.973685258009473,0.3947235,0.38640573620796204,0.42369687744008566
# DJI_20241227155847_0234_V,10.350648647134534,0.3704413,0.35722801089286804,0.43034508279314654
# DJI_20241227155849_0236_V,10.464352274813255,0.36147925,0.3986358940601349,0.4117755407385707
# DJI_20241227155850_0237_V,10.383513278361933,0.35403633,0.36479175090789795,0.4225953025018977
# DJI_20241227155906_0247_V,9.784066951228711,0.3364099,0.4165486693382263,0.3930078999754997
# DJI_20241227155912_0253_V,10.113920565053329,0.34753957,0.36642324924468994,0.4183760928845674
# DJI_20241227155914_0255_V,10.133889823625886,0.36615923,0.377323716878891,0.4197216183511639
# DJI_20241227155915_0256_V,10.281170548529165,0.34774986,0.3816447854042053,0.413354069838111
# DJI_20241227155927_0264_V,10.041251226669019,0.3493464,0.41371777653694153,0.39956432249787727
# DJI_20241227155930_0267_V,10.524362801333133,0.342219,0.4141262173652649,0.4001613883901826
# DJI_20241227155946_0279_V,10.306138228262052,0.31261262,0.41328108310699463,0.3903081919603621
# DJI_20241227155948_0281_V,10.246427311966501,0.33286706,0.41784876585006714,0.3941991713909488
# DJI_20241227155954_0287_V,10.156892250592698,0.33115932,0.38682085275650024,0.4055608064568948
# DJI_20241227160006_0293_V,10.147831031046087,0.32329085,0.423601895570755,0.388433493306409
# DJI_20241227160018_0304_V,10.286214862880376,0.32020596,0.39687153697013855,0.39903046437869827
# DJI_20241227160031_0313_V,10.59426145061542,0.31343094,0.3907124996185303,0.4013098643007689
# DJI_20241227160044_0321_V,10.148931292562427,0.3037578,0.4298786520957947,0.38006945698183026
# DJI_20241227160048_0325_V,10.127367347715486,0.30860963,0.4018101692199707,0.3926230178489577
#
#
# ==== /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_tower_crop.csv ====
# missing
#
# ==== /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_skyline_crop.csv ====
# missing
#
# ==== /content/project/pipeline/work/hcm0031/logs/05_render_b2_pilot.log ====
# Render 50 pose | scene=hcm0031 | iteration=30000 | sh_degree=3 | antialiasing=True
#   10/50 -> DJI_20241227155557_0125_V.png
#   20/50 -> DJI_20241227155345_0025_V.png
#   30/50 -> DJI_20241227155547_0115_V.png
#   40/50 -> DJI_20241227155352_0032_V.png
#   50/50 -> DJI_20241227155507_0089_V.png
#
#
# ==== /content/project/pipeline/work/hcm0031/logs/05_eval_b2_pilot.log ====
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#
#   0%|          | 0.00/233M [00:00<?, ?B/s]
#   2%|▏         | 3.88M/233M [00:00<00:05, 40.2MB/s]
#   4%|▍         | 8.75M/233M [00:00<00:05, 46.6MB/s]
#  11%|█▏        | 26.2M/233M [00:00<00:01, 109MB/s]
#  21%|██        | 49.4M/233M [00:00<00:01, 161MB/s]
#  29%|██▉       | 68.5M/233M [00:00<00:00, 175MB/s]
#  38%|███▊      | 87.5M/233M [00:00<00:00, 183MB/s]
#  46%|████▌     | 106M/233M [00:00<00:00, 187MB/s]
#  53%|█████▎    | 124M/233M [00:00<00:00, 174MB/s]
#  62%|██████▏   | 144M/233M [00:00<00:00, 183MB/s]
#  69%|██████▉   | 162M/233M [00:01<00:00, 184MB/s]
#  77%|███████▋  | 180M/233M [00:01<00:00, 179MB/s]
#  84%|████████▍ | 197M/233M [00:01<00:00, 176MB/s]
#  92%|█████████▏| 214M/233M [00:01<00:00, 170MB/s]
# 100%|█████████▉| 232M/233M [00:01<00:00, 177MB/s]
# 100%|██████████| 233M/233M [00:01<00:00, 167MB/s]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# Scene: hcm0031
# Images: 50
# PSNR mean : 10.5148
# SSIM mean : 0.3596
# LPIPS mean: 0.4233
# Score mean: 0.4016
# Saved CSV : /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv

# %%
# ==================================================
# CELL 7 - Compare full-image / tower / skyline M0
# ==================================================
import pandas as pd
from pathlib import Path

SCENE = "hcm0031"
work_dir = Path(WORKDIR) / "project" / "pipeline" / "work" / SCENE

comparisons = [
    ("full_image", work_dir / "eval_metrics.csv", work_dir / "eval_metrics_b2_pilot.csv"),
    ("tower_crop", work_dir / "eval_metrics_m0_tower_crop.csv", work_dir / "eval_metrics_b2_pilot_tower_crop.csv"),
    ("skyline_crop", work_dir / "eval_metrics_m0_skyline_crop.csv", work_dir / "eval_metrics_b2_pilot_skyline_crop.csv"),
]

metric_candidates = ["psnr", "ssim", "lpips", "score"]


def pick_row(df, label):
    if len(df) == 1:
        return df.iloc[0]
    for key in ["image_name", "filename", "name"]:
        if key in df.columns:
            raise SystemExit(f"{label} co nhieu dong theo tung anh; can file tong hop 1 dong.")
    return df.iloc[0]


rows = []

for region, baseline_path, b2_path in comparisons:
    if not baseline_path.exists() or not b2_path.exists():
        rows.append(
            {
                "region": region,
                "status": "missing",
                "baseline_file": baseline_path.name,
                "b2_file": b2_path.name,
            }
        )
        continue

    baseline_df = pd.read_csv(baseline_path)
    b2_df = pd.read_csv(b2_path)

    base = pick_row(baseline_df, f"{region} baseline")
    b2 = pick_row(b2_df, f"{region} b2")

    row = {
        "region": region,
        "status": "ok",
        "baseline_file": baseline_path.name,
        "b2_file": b2_path.name,
    }

    for metric in metric_candidates:
        if metric in baseline_df.columns and metric in b2_df.columns:
            base_val = float(base[metric])
            b2_val = float(b2[metric])
            delta = b2_val - base_val

            if metric == "lpips":
                verdict = "better" if delta < 0 else "worse" if delta > 0 else "same"
            else:
                verdict = "better" if delta > 0 else "worse" if delta < 0 else "same"

            row[f"{metric}_base"] = base_val
            row[f"{metric}_b2"] = b2_val
            row[f"{metric}_delta"] = delta
            row[f"{metric}_verdict"] = verdict

    rows.append(row)

summary_df = pd.DataFrame(rows)

display_cols = ["region", "status"]
for metric in metric_candidates:
    display_cols += [
        f"{metric}_base",
        f"{metric}_b2",
        f"{metric}_delta",
        f"{metric}_verdict",
    ]

display_df = summary_df.reindex(columns=display_cols)

for col in display_df.columns:
    if col.endswith(("_base", "_b2", "_delta")):
        display_df[col] = display_df[col].map(lambda x: f"{x:.6f}" if pd.notna(x) else "")

print("So sanh baseline vs B2 cho 3 vung:")
print(display_df.to_string(index=False))
# Out:
# So sanh baseline vs B2 cho 3 vung:
#       region  status psnr_base psnr_b2 psnr_delta  psnr_verdict ssim_base ssim_b2 ssim_delta  ssim_verdict lpips_base lpips_b2 lpips_delta  lpips_verdict score_base score_b2 score_delta  score_verdict
#   full_image missing                                        NaN                                        NaN                                            NaN                                            NaN
#   tower_crop missing                                        NaN                                        NaN                                            NaN                                            NaN
# skyline_crop missing                                        NaN                                        NaN                                            NaN                                            NaN

# %%
from pathlib import Path
import subprocess

zip_path = Path(WORKDIR) / 'b2_bundle_hcm0031.zip'
assert zip_path.exists(), f'Khong tim thay zip: {zip_path}'
subprocess.run(['bash', '-lc', f'ls -lh "{zip_path}"'], check=True)

# %%
from pathlib import Path
import csv
import zipfile


SCENE = "hcm0031"
AUTO_DOWNLOAD = True
HEAVY_FILE_MB = 30

WORK_CANDIDATES = [
    Path(f"/content/project/pipeline/work/{SCENE}"),
    Path(f"/kaggle/working/project/pipeline/work/{SCENE}"),
    Path(f"/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/pipeline/work/{SCENE}"),
]


def find_scene_root() -> Path:
    for path in WORK_CANDIDATES:
        if path.exists():
            return path
    raise FileNotFoundError(f"Khong tim thay thu muc work cua scene {SCENE}")


def human_size(size_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    value = float(size_bytes)
    unit_idx = 0
    while value >= 1024 and unit_idx < len(units) - 1:
        value /= 1024
        unit_idx += 1
    return f"{value:.2f} {units[unit_idx]}"


def size_gb(size_bytes: int) -> float:
    return size_bytes / (1024 ** 3)


def ensure_parent(path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)


def write_manifest(rows: list[tuple[int, Path]], out_csv: Path) -> None:
    ensure_parent(out_csv)
    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["size_bytes", "size_human", "path"])
        for size, path in rows:
            writer.writerow([size, human_size(size), str(path)])


def build_zip_from_files(base_root: Path, files: list[Path], zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(files):
            zf.write(path, arcname=path.relative_to(base_root))
    return zip_path


def build_zip_from_dir(src_dir: Path, zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(src_dir.rglob("*")):
            if path.is_file():
                zf.write(path, arcname=path.relative_to(src_dir.parent))
    return zip_path


def download_paths(paths: list[Path]) -> None:
    if not AUTO_DOWNLOAD:
        return
    try:
        from google.colab import files
    except Exception:
        print("Khong phat hien google.colab, chi tao file, khong tu dong download.")
        return

    print("\n=== BAT DAU DOWNLOAD ===")
    for path in paths:
        print(path)
        files.download(str(path))


def gather_light_files(scene_root: Path) -> list[Path]:
    gs_model = scene_root / "gs_model"
    dense_sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"
    logs_dir = scene_root / "logs"

    candidates = [
        gs_model / "cfg_args",
        gs_model / "cameras.json",
        gs_model / "exposure.json",
        gs_model / "input.ply",
        gs_model / "pipeline_train_flags.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        logs_dir / "05_b2_pilot_summary.txt",
        logs_dir / "05_render_b2_pilot.log",
        logs_dir / "05_eval_b2_pilot.log",
        logs_dir / "04_colmap_dense_summary.txt",
        logs_dir / "04_stereo_fusion.log",
        scene_root / "train.log",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "03_train_3dgs.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "render_round1_test_poses.py",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "eval_round1_metrics.py",
        scene_root.parent.parent.parent / "trick" / SCENE / "default.env",
        dense_sparse0 / "cameras.bin",
        dense_sparse0 / "frames.bin",
        dense_sparse0 / "images.bin",
        dense_sparse0 / "points3D.bin",
        dense_sparse0 / "points3D.ply",
        dense_sparse0 / "rigs.bin",
        scene_root / "colmap" / "dense" / "fused.ply",
    ]

    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def gather_heavy_files(scene_root: Path) -> list[Path]:
    candidates = [
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "_curated_download" / "colmap_dense_images.zip",
        scene_root / "_curated_download" / "renders_images.zip",
    ]
    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def main() -> None:
    scene_root = find_scene_root()
    curated_root = scene_root / "_curated_download"
    curated_root.mkdir(parents=True, exist_ok=True)

    colmap_images_dir = scene_root / "colmap" / "dense" / "images"
    renders_dir = scene_root / "renders_b2_pilot"
    if not renders_dir.exists():
        renders_dir = scene_root / "renders"

    colmap_images_zip = curated_root / "colmap_dense_images.zip"
    renders_zip = curated_root / "renders_images.zip"
    light_zip = curated_root / f"{SCENE}_light_bundle.zip"

    if colmap_images_dir.exists():
        build_zip_from_dir(colmap_images_dir, colmap_images_zip)
    if renders_dir.exists():
        build_zip_from_dir(renders_dir, renders_zip)

    light_files = gather_light_files(scene_root)
    build_zip_from_files(scene_root.parent.parent.parent, light_files, light_zip)

    heavy_files = gather_heavy_files(scene_root)
    light_size = light_zip.stat().st_size if light_zip.exists() else 0
    light_rows = [(path.stat().st_size, path) for path in light_files]
    light_rows.sort(key=lambda item: (item[0], str(item[1])))
    heavy_rows = [(path.stat().st_size, path) for path in heavy_files]
    heavy_rows.sort(key=lambda item: (item[0], str(item[1])))

    light_manifest = curated_root / "light_bundle_manifest.csv"
    heavy_manifest = curated_root / "heavy_files_manifest.csv"
    write_manifest(light_rows, light_manifest)
    write_manifest(heavy_rows, heavy_manifest)

    print("=== CURATED DOWNLOAD PLAN ===")
    print("scene_root       :", scene_root)
    print("curated_root     :", curated_root)
    print("light_zip        :", light_zip)
    print("light_zip_size   :", human_size(light_size))
    print(f"light_zip_gb     : {size_gb(light_size):.3f} GB")
    print("light_file_count :", len(light_files))
    print("heavy_file_count :", len(heavy_rows))
    print("heavy_threshold  :", f">{HEAVY_FILE_MB} MB")
    print("light_manifest   :", light_manifest)
    print("heavy_manifest   :", heavy_manifest)

    print("\n=== HEAVY FILES ===")
    for size, path in heavy_rows:
        print(f"{human_size(size):>10}  {path}")

    total_bytes = light_size + sum(size for size, _ in heavy_rows)
    print("\n=== TOTAL ===")
    print("total_size       :", human_size(total_bytes))
    print(f"total_size_gb    : {size_gb(total_bytes):.3f} GB")

    download_paths([light_zip] + [path for _, path in heavy_rows])


if __name__ == "__main__":
    main()
# Out:
# === CURATED DOWNLOAD PLAN ===
# scene_root       : /content/project/pipeline/work/hcm0031
# curated_root     : /content/project/pipeline/work/hcm0031/_curated_download
# light_zip        : /content/project/pipeline/work/hcm0031/_curated_download/hcm0031_light_bundle.zip
# light_zip_size   : 149.34 MB
# light_zip_gb     : 0.146 GB
# light_file_count : 24
# heavy_file_count : 4
# heavy_threshold  : >30 MB
# light_manifest   : /content/project/pipeline/work/hcm0031/_curated_download/light_bundle_manifest.csv
# heavy_manifest   : /content/project/pipeline/work/hcm0031/_curated_download/heavy_files_manifest.csv
#
# === HEAVY FILES ===
#   34.78 MB  /content/project/pipeline/work/hcm0031/gs_model/point_cloud/iteration_30000/point_cloud.ply
#   82.06 MB  /content/project/pipeline/work/hcm0031/_curated_download/renders_images.zip
#  100.99 MB  /content/project/pipeline/work/hcm0031/gs_model/chkpnt30000.pth
#  151.18 MB  /content/project/pipeline/work/hcm0031/_curated_download/colmap_dense_images.zip
#
# === TOTAL ===
# total_size       : 518.36 MB
# total_size_gb    : 0.506 GB
#
# === BAT DAU DOWNLOAD ===
# /content/project/pipeline/work/hcm0031/_curated_download/hcm0031_light_bundle.zip
# /content/project/pipeline/work/hcm0031/gs_model/point_cloud/iteration_30000/point_cloud.ply
# /content/project/pipeline/work/hcm0031/_curated_download/renders_images.zip
# /content/project/pipeline/work/hcm0031/gs_model/chkpnt30000.pth
# /content/project/pipeline/work/hcm0031/_curated_download/colmap_dense_images.zip

# %%
from pathlib import Path
import csv
import zipfile


SCENE = "hcm0031"
AUTO_DOWNLOAD = True
AUDIT_ONLY = False
HEAVY_FILE_MB = 30

WORK_CANDIDATES = [
    Path(f"/content/project/pipeline/work/{SCENE}"),
    Path(f"/kaggle/working/project/pipeline/work/{SCENE}"),
    Path(f"/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/pipeline/work/{SCENE}"),
]


def find_scene_root() -> Path:
    for path in WORK_CANDIDATES:
        if path.exists():
            return path
    raise FileNotFoundError(f"Khong tim thay thu muc work cua scene {SCENE}")


def human_size(size_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    value = float(size_bytes)
    unit_idx = 0
    while value >= 1024 and unit_idx < len(units) - 1:
        value /= 1024
        unit_idx += 1
    return f"{value:.2f} {units[unit_idx]}"


def size_gb(size_bytes: int) -> float:
    return size_bytes / (1024 ** 3)


def ensure_parent(path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)


def write_manifest(rows: list[tuple[int, Path]], out_csv: Path) -> None:
    ensure_parent(out_csv)
    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["size_bytes", "size_human", "path"])
        for size, path in rows:
            writer.writerow([size, human_size(size), str(path)])


def build_zip_from_files(base_root: Path, files: list[Path], zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(files):
            zf.write(path, arcname=path.relative_to(base_root))
    return zip_path


def build_zip_from_dir(src_dir: Path, zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(src_dir.rglob("*")):
            if path.is_file():
                zf.write(path, arcname=path.relative_to(src_dir.parent))
    return zip_path


def download_paths(paths: list[Path]) -> None:
    if not AUTO_DOWNLOAD:
        return
    try:
        from google.colab import files
    except Exception:
        print("Khong phat hien google.colab, chi tao file, khong tu dong download.")
        return

    print("\n=== BAT DAU DOWNLOAD ===")
    for path in paths:
        print(path)
        files.download(str(path))


def gather_light_files(scene_root: Path) -> list[Path]:
    gs_model = scene_root / "gs_model"
    dense_sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"
    logs_dir = scene_root / "logs"

    candidates = [
        gs_model / "cfg_args",
        gs_model / "cameras.json",
        gs_model / "exposure.json",
        gs_model / "input.ply",
        gs_model / "pipeline_train_flags.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        logs_dir / "05_b2_pilot_summary.txt",
        logs_dir / "05_render_b2_pilot.log",
        logs_dir / "05_eval_b2_pilot.log",
        logs_dir / "04_colmap_dense_summary.txt",
        logs_dir / "04_stereo_fusion.log",
        scene_root / "train.log",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "03_train_3dgs.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "render_round1_test_poses.py",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "eval_round1_metrics.py",
        scene_root.parent.parent.parent / "trick" / SCENE / "default.env",
        dense_sparse0 / "cameras.bin",
        dense_sparse0 / "frames.bin",
        dense_sparse0 / "images.bin",
        dense_sparse0 / "points3D.bin",
        dense_sparse0 / "points3D.ply",
        dense_sparse0 / "rigs.bin",
        scene_root / "colmap" / "dense" / "fused.ply",
    ]

    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def gather_heavy_files(scene_root: Path) -> list[Path]:
    candidates = [
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "_curated_download" / "colmap_dense_images.zip",
        scene_root / "_curated_download" / "renders_images.zip",
    ]
    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def b2_required_paths(scene_root: Path) -> list[Path]:
    curated_root = scene_root / "_curated_download"
    dense_sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"
    return [
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
        scene_root / "gs_model" / "cfg_args",
        scene_root / "gs_model" / "cameras.json",
        scene_root / "gs_model" / "exposure.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        scene_root / "colmap" / "dense" / "fused.ply",
        dense_sparse0 / "cameras.bin",
        dense_sparse0 / "frames.bin",
        dense_sparse0 / "images.bin",
        dense_sparse0 / "points3D.bin",
        dense_sparse0 / "points3D.ply",
        dense_sparse0 / "rigs.bin",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "03_train_3dgs.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "render_round1_test_poses.py",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "eval_round1_metrics.py",
        scene_root.parent.parent.parent / "trick" / SCENE / "default.env",
        curated_root / f"{SCENE}_light_bundle.zip",
        curated_root / "colmap_dense_images.zip",
        curated_root / "renders_images.zip",
    ]


def print_b2_audit(scene_root: Path) -> None:
    required = b2_required_paths(scene_root)
    total_existing = 0
    missing = []

    print("=== B2 AUDIT CHECKLIST ===")
    for path in required:
        if path.exists() and path.is_file():
            size = path.stat().st_size
            total_existing += size
            print(f"[OK]   {human_size(size):>10}  {path}")
        else:
            missing.append(path)
            print(f"[MISS] {'-':>10}  {path}")

    print("\n=== B2 AUDIT SUMMARY ===")
    print("required_count   :", len(required))
    print("missing_count    :", len(missing))
    print("existing_total   :", human_size(total_existing))
    print(f"existing_total_gb: {size_gb(total_existing):.3f} GB")
    print("b2_ready         :", "YES" if not missing else "NO")

    if missing:
        print("\n=== THIEU CHO B2 ===")
        for path in missing:
            print(path)


def main() -> None:
    scene_root = find_scene_root()
    if AUDIT_ONLY:
        print_b2_audit(scene_root)
        return

    curated_root = scene_root / "_curated_download"
    curated_root.mkdir(parents=True, exist_ok=True)

    colmap_images_dir = scene_root / "colmap" / "dense" / "images"
    renders_dir = scene_root / "renders_b2_pilot"
    if not renders_dir.exists():
        renders_dir = scene_root / "renders"

    colmap_images_zip = curated_root / "colmap_dense_images.zip"
    renders_zip = curated_root / "renders_images.zip"
    light_zip = curated_root / f"{SCENE}_light_bundle.zip"

    if colmap_images_dir.exists():
        build_zip_from_dir(colmap_images_dir, colmap_images_zip)
    if renders_dir.exists():
        build_zip_from_dir(renders_dir, renders_zip)

    light_files = gather_light_files(scene_root)
    build_zip_from_files(scene_root.parent.parent.parent, light_files, light_zip)

    heavy_files = gather_heavy_files(scene_root)
    light_size = light_zip.stat().st_size if light_zip.exists() else 0
    light_rows = [(path.stat().st_size, path) for path in light_files]
    light_rows.sort(key=lambda item: (item[0], str(item[1])))
    heavy_rows = [(path.stat().st_size, path) for path in heavy_files]
    heavy_rows.sort(key=lambda item: (item[0], str(item[1])))

    light_manifest = curated_root / "light_bundle_manifest.csv"
    heavy_manifest = curated_root / "heavy_files_manifest.csv"
    write_manifest(light_rows, light_manifest)
    write_manifest(heavy_rows, heavy_manifest)

    print("=== CURATED DOWNLOAD PLAN ===")
    print("scene_root       :", scene_root)
    print("curated_root     :", curated_root)
    print("light_zip        :", light_zip)
    print("light_zip_size   :", human_size(light_size))
    print(f"light_zip_gb     : {size_gb(light_size):.3f} GB")
    print("light_file_count :", len(light_files))
    print("heavy_file_count :", len(heavy_rows))
    print("heavy_threshold  :", f">{HEAVY_FILE_MB} MB")
    print("light_manifest   :", light_manifest)
    print("heavy_manifest   :", heavy_manifest)

    print("\n=== HEAVY FILES ===")
    for size, path in heavy_rows:
        print(f"{human_size(size):>10}  {path}")

    total_bytes = light_size + sum(size for size, _ in heavy_rows)
    print("\n=== TOTAL ===")
    print("total_size       :", human_size(total_bytes))
    print(f"total_size_gb    : {size_gb(total_bytes):.3f} GB")

    download_paths([light_zip] + [path for _, path in heavy_rows])


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_958/4121230348.py in <cell line: 0>()
#     248
#     249 if __name__ == "__main__":
# --> 250     main()
#
# /tmp/ipykernel_958/4121230348.py in main()
#     204
#     205     if colmap_images_dir.exists():
# --> 206         build_zip_from_dir(colmap_images_dir, colmap_images_zip)
#     207     if renders_dir.exists():
#     208         build_zip_from_dir(renders_dir, renders_zip)
#
# /tmp/ipykernel_958/4121230348.py in build_zip_from_dir(src_dir, zip_path)
#      63         for path in sorted(src_dir.rglob("*")):
#      64             if path.is_file():
# ---> 65                 zf.write(path, arcname=path.relative_to(src_dir.parent))
#      66     return zip_path
#      67
#
# /usr/lib/python3.12/zipfile/__init__.py in write(self, filename, arcname, compress_type, compresslevel)
#    1884
#    1885             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1886                 shutil.copyfileobj(src, dest, 1024*8)
#    1887
#    1888     def writestr(self, zinfo_or_arcname, data,
#
# /usr/lib/python3.12/shutil.py in copyfileobj(fsrc, fdst, length)
#     202     fdst_write = fdst.write
#     203     while buf := fsrc_read(length):
# --> 204         fdst_write(buf)
#     205
#     206 def _samefile(src, dst):
#
# /usr/lib/python3.12/zipfile/__init__.py in write(self, data)
#    1233         self._crc = crc32(data, self._crc)
#    1234         if self._compressor:
# -> 1235             data = self._compressor.compress(data)
#    1236             self._compress_size += len(data)
#    1237         self._fileobj.write(data)
#
# KeyboardInterrupt:

# %%
from pathlib import Path
import csv
import os
import subprocess
import zipfile


SCENE = "hcm0031"
MODE = "reeval_latest"  # "package" | "reeval_latest"
AUTO_DOWNLOAD = False
INCLUDE_RENDERS_ARCHIVE = True
PSNR_MAX = 30.0

DATASET_ROOT = os.environ.get("DATASET_ROOT", "")

WORK_CANDIDATES = [
    Path(f"/content/project/pipeline/work/{SCENE}"),
    Path(f"/kaggle/working/project/pipeline/work/{SCENE}"),
    Path(f"/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/pipeline/work/{SCENE}"),
]

GS_REPO_CANDIDATES = [
    Path("/content/gaussian-splatting"),
    Path("/content/project/gaussian-splatting"),
    Path("/content/project/submodules/gaussian-splatting"),
    Path("/kaggle/working/gaussian-splatting"),
    Path("/kaggle/working/project/gaussian-splatting"),
    Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/gaussian-splatting"),
]

DATASET_ROOT_CANDIDATES = [
    Path("/content/project/Dataset/VAI_NVS_DATA/phase1/public_set"),
    Path("/content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set"),
    Path("/kaggle/working/project/Dataset/VAI_NVS_DATA/phase1/public_set"),
    Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/Dataset/VAI_NVS_DATA/phase1/public_set"),
]


def find_scene_root() -> Path:
    for path in WORK_CANDIDATES:
        if path.exists():
            return path
    raise FileNotFoundError(f"Khong tim thay thu muc work cua scene {SCENE}")


def find_gs_repo() -> Path:
    env_path = os.environ.get("GS_REPO", "")
    if env_path:
        env_repo = Path(env_path)
        if (env_repo / "train.py").exists():
            return env_repo

    for path in GS_REPO_CANDIDATES:
        if (path / "train.py").exists():
            os.environ["GS_REPO"] = str(path)
            return path

    raise FileNotFoundError(
        "Khong tu dong tim thay GS_REPO. Hay set tay, vi du: "
        "os.environ['GS_REPO'] = '/content/gaussian-splatting'"
    )


def find_dataset_root() -> Path:
    env_path = DATASET_ROOT or os.environ.get("DATASET_ROOT", "")
    if env_path:
        env_root = Path(env_path)
        if (env_root / SCENE / "test" / "test_poses.csv").exists():
            return env_root

    for path in DATASET_ROOT_CANDIDATES:
        if (path / SCENE / "test" / "test_poses.csv").exists():
            os.environ["DATASET_ROOT"] = str(path)
            return path

    search_bases = [
        Path("/content"),
        Path("/content/_dataset_round1_raw"),
        Path("/kaggle/working"),
        Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin"),
    ]
    for base in search_bases:
        if not base.exists():
            continue
        for path in base.rglob("public_set"):
            if (path / SCENE / "test" / "test_poses.csv").exists():
                os.environ["DATASET_ROOT"] = str(path)
                return path

    raise FileNotFoundError(
        "Khong tu dong tim thay Dataset/VAI_NVS_DATA/phase1/public_set co "
        f"scene {SCENE} va file test/test_poses.csv"
    )


def human_size(size_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    value = float(size_bytes)
    unit_idx = 0
    while value >= 1024 and unit_idx < len(units) - 1:
        value /= 1024
        unit_idx += 1
    return f"{value:.2f} {units[unit_idx]}"


def size_gb(size_bytes: int) -> float:
    return size_bytes / (1024 ** 3)


def ensure_parent(path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)


def build_zip_from_files(base_root: Path, files: list[Path], zip_path: Path) -> None:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(files):
            zf.write(path, arcname=path.relative_to(base_root))


def build_zip_from_dir(src_dir: Path, zip_path: Path) -> None:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(src_dir.rglob("*")):
            if path.is_file():
                zf.write(path, arcname=path.relative_to(src_dir.parent))


def download_paths(paths: list[Path]) -> None:
    if not AUTO_DOWNLOAD:
        return
    try:
        from google.colab import files
    except Exception:
        print("Khong phat hien google.colab, chi tao file, khong tu dong download.")
        return

    print("\n=== BAT DAU DOWNLOAD ===")
    for path in paths:
        print(path)
        files.download(str(path))


def project_root_from_scene(scene_root: Path) -> Path:
    return scene_root.parent.parent.parent


def gather_minimal_light_files(scene_root: Path) -> list[Path]:
    project_root = project_root_from_scene(scene_root)
    gs_model = scene_root / "gs_model"
    sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"

    candidates = [
        gs_model / "cfg_args",
        gs_model / "cameras.json",
        gs_model / "exposure.json",
        gs_model / "pipeline_train_flags.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        project_root / "pipeline" / "scripts" / "03_train_3dgs.sh",
        project_root / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        project_root / "pipeline" / "scripts" / "render_round1_test_poses.py",
        project_root / "pipeline" / "scripts" / "eval_round1_metrics.py",
        project_root / "trick" / SCENE / "default.env",
        sparse0 / "cameras.bin",
        sparse0 / "frames.bin",
        sparse0 / "images.bin",
        sparse0 / "points3D.bin",
        sparse0 / "points3D.ply",
        sparse0 / "rigs.bin",
    ]
    return [path for path in candidates if path.exists() and path.is_file()]


def package_b2_minimal(scene_root: Path) -> None:
    curated_root = scene_root / "_curated_b2_minimal"
    curated_root.mkdir(parents=True, exist_ok=True)

    project_root = project_root_from_scene(scene_root)
    light_files = gather_minimal_light_files(scene_root)
    light_zip = curated_root / f"{SCENE}_b2_light.zip"
    build_zip_from_files(project_root, light_files, light_zip)

    heavy_files = [
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
    ]
    heavy_files = [path for path in heavy_files if path.exists() and path.is_file()]

    archives = []
    dense_images_dir = scene_root / "colmap" / "dense" / "images"
    if dense_images_dir.exists():
        dense_images_zip = curated_root / "colmap_dense_images.zip"
        build_zip_from_dir(dense_images_dir, dense_images_zip)
        archives.append(dense_images_zip)

    renders_dir = scene_root / "renders_b2_pilot"
    if not renders_dir.exists():
        renders_dir = scene_root / "renders"
    if INCLUDE_RENDERS_ARCHIVE and renders_dir.exists():
        renders_zip = curated_root / "renders_images.zip"
        build_zip_from_dir(renders_dir, renders_zip)
        archives.append(renders_zip)

    print("=== B2 MINIMAL PACKAGE ===")
    print("scene_root        :", scene_root)
    print("curated_root      :", curated_root)
    print("light_zip         :", light_zip)
    print("light_zip_size    :", human_size(light_zip.stat().st_size))
    print(f"light_zip_gb      : {size_gb(light_zip.stat().st_size):.3f} GB")

    print("\n=== KEEP ===")
    print(light_zip)
    for path in archives:
        print(path)
    for path in heavy_files:
        print(path)

    print("\n=== KHONG CAN TAI ===")
    print("colmap/dense/stereo/depth_maps/*")
    print("colmap/dense/stereo/normal_maps/*")
    print("colmap/dense/fused.ply.vis")
    print("gs_model/events.out.tfevents*")
    print("train.log")
    print("gs_model/input.ply")
    print("logs/*")
    print("_download_ready/all_filtered/* neu da co bo curated moi")

    all_downloads = [light_zip] + archives + heavy_files
    total_bytes = sum(path.stat().st_size for path in all_downloads)
    print("\n=== TOTAL DOWNLOAD ===")
    print("count             :", len(all_downloads))
    print("total_size        :", human_size(total_bytes))
    print(f"total_size_gb     : {size_gb(total_bytes):.3f} GB")

    download_paths(all_downloads)


def find_latest_iteration(scene_root: Path) -> int:
    point_cloud_root = scene_root / "gs_model" / "point_cloud"
    iterations = []
    for path in point_cloud_root.glob("iteration_*"):
        if path.is_dir():
            try:
                iterations.append(int(path.name.split("_")[-1]))
            except ValueError:
                continue
    if not iterations:
        raise FileNotFoundError(f"Khong tim thay iteration_* trong {point_cloud_root}")
    return max(iterations)


def validate_reeval_prereqs(project_root: Path) -> None:
    gs_repo_path = find_gs_repo()
    dataset_root = find_dataset_root()
    dataset_scene_root = dataset_root / SCENE
    test_poses_csv = dataset_scene_root / "test" / "test_poses.csv"
    test_images_dir = dataset_scene_root / "test" / "images"
    if not test_poses_csv.exists():
        raise FileNotFoundError(f"Khong thay test_poses.csv: {test_poses_csv}")
    if not test_images_dir.exists():
        raise FileNotFoundError(f"Khong thay test/images: {test_images_dir}")

    scripts_dir = project_root / "pipeline" / "scripts"
    for script_name in ["render_round1_test_poses.py", "eval_round1_metrics.py"]:
        script_path = scripts_dir / script_name
        if not script_path.exists():
            raise FileNotFoundError(f"Khong thay script: {script_path}")


def reevaluate_latest_scene(scene_root: Path) -> None:
    project_root = project_root_from_scene(scene_root)
    validate_reeval_prereqs(project_root)
    gs_repo_path = find_gs_repo()
    dataset_root = find_dataset_root()
    scripts_dir = project_root / "pipeline" / "scripts"
    logs_dir = scene_root / "logs"
    logs_dir.mkdir(parents=True, exist_ok=True)

    latest_iter = find_latest_iteration(scene_root)
    model_dir = scene_root / "gs_model"
    render_out_dir = scene_root / f"renders_b2_latest_iter_{latest_iter}"
    eval_out_csv = scene_root / f"eval_metrics_b2_latest_iter_{latest_iter}.csv"
    render_log = logs_dir / f"05_render_b2_latest_iter_{latest_iter}.log"
    eval_log = logs_dir / f"05_eval_b2_latest_iter_{latest_iter}.log"

    render_cmd = [
        "python3",
        str(scripts_dir / "render_round1_test_poses.py"),
        "--scene",
        SCENE,
        "--dataset_root",
        str(dataset_root),
        "--model_dir",
        str(model_dir),
        "--iteration",
        str(latest_iter),
        "--out_dir",
        str(render_out_dir),
    ]
    eval_cmd = [
        "python3",
        str(scripts_dir / "eval_round1_metrics.py"),
        "--scene",
        SCENE,
        "--dataset_root",
        str(dataset_root),
        "--renders_dir",
        str(render_out_dir),
        "--out_csv",
        str(eval_out_csv),
        "--psnr_max",
        str(PSNR_MAX),
    ]

    print("=== REEVAL LATEST SCENE ===")
    print("scene             :", SCENE)
    print("scene_root        :", scene_root)
    print("dataset_root      :", dataset_root)
    print("gs_repo           :", gs_repo_path)
    print("latest_iteration  :", latest_iter)
    print("render_out_dir    :", render_out_dir)
    print("eval_out_csv      :", eval_out_csv)
    print("psnr_max          :", PSNR_MAX)

    env = os.environ.copy()
    with open(render_log, "w", encoding="utf-8") as f:
        subprocess.run(render_cmd, check=True, env=env, stdout=f, stderr=subprocess.STDOUT)
    with open(eval_log, "w", encoding="utf-8") as f:
        subprocess.run(eval_cmd, check=True, env=env, stdout=f, stderr=subprocess.STDOUT)

    print("render_log        :", render_log)
    print("eval_log          :", eval_log)

    if not eval_out_csv.exists():
        raise FileNotFoundError(f"Khong thay file eval csv: {eval_out_csv}")

    with open(eval_out_csv, newline="", encoding="utf-8") as f:
        rows = list(csv.DictReader(f))
    if not rows:
        raise RuntimeError("CSV eval rong, khong co metric nao.")

    psnr_vals = [float(row["psnr"]) for row in rows]
    ssim_vals = [float(row["ssim"]) for row in rows]
    lpips_vals = [float(row["lpips"]) for row in rows]
    score_vals = [float(row["score"]) for row in rows]

    print("\n=== EVAL SUMMARY ===")
    print("images            :", len(rows))
    print(f"PSNR mean         : {sum(psnr_vals) / len(psnr_vals):.4f}")
    print(f"SSIM mean         : {sum(ssim_vals) / len(ssim_vals):.4f}")
    print(f"LPIPS mean        : {sum(lpips_vals) / len(lpips_vals):.4f}")
    print(f"Score mean        : {sum(score_vals) / len(score_vals):.4f}")
    print(f"PSNR min          : {min(psnr_vals):.4f}")
    print(f"SSIM min          : {min(ssim_vals):.4f}")
    print(f"LPIPS max         : {max(lpips_vals):.4f}")
    print(f"Score min         : {min(score_vals):.4f}")

    worst_rows = sorted(rows, key=lambda row: float(row["score"]))[:10]
    print("\n=== TOP 10 ANH TE NHAT ===")
    for idx, row in enumerate(worst_rows, start=1):
        print(
            f"{idx:>2}. {row['image']} | "
            f"score={float(row['score']):.4f} | "
            f"psnr={float(row['psnr']):.4f} | "
            f"ssim={float(row['ssim']):.4f} | "
            f"lpips={float(row['lpips']):.4f}"
        )


def main() -> None:
    scene_root = find_scene_root()
    if MODE == "package":
        package_b2_minimal(scene_root)
        return
    if MODE == "reeval_latest":
        reevaluate_latest_scene(scene_root)
        return
    raise ValueError(f"MODE khong hop le: {MODE}")


if __name__ == "__main__":
    main()
# Out:
# === REEVAL LATEST SCENE ===
# scene             : hcm0031
# scene_root        : /content/project/pipeline/work/hcm0031
# dataset_root      : /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set
# gs_repo           : /content/gaussian-splatting
# latest_iteration  : 30000
# render_out_dir    : /content/project/pipeline/work/hcm0031/renders_b2_latest_iter_30000
# eval_out_csv      : /content/project/pipeline/work/hcm0031/eval_metrics_b2_latest_iter_30000.csv
# psnr_max          : 30.0
# render_log        : /content/project/pipeline/work/hcm0031/logs/05_render_b2_latest_iter_30000.log
# eval_log          : /content/project/pipeline/work/hcm0031/logs/05_eval_b2_latest_iter_30000.log
#
# === EVAL SUMMARY ===
# images            : 50
# PSNR mean         : 10.5148
# SSIM mean         : 0.3596
# LPIPS mean        : 0.4233
# Score mean        : 0.4437
# PSNR min          : 9.7841
# SSIM min          : 0.3038
# LPIPS max         : 0.5384
# Score min         : 0.3904
#
# === TOP 10 ANH TE NHAT ===
#  1. DJI_20241227155438_0066_V | score=0.3904 | psnr=10.3341 | ssim=0.3375 | lpips=0.5356
#  2. DJI_20241227155433_0061_V | score=0.4003 | psnr=10.3369 | ssim=0.3315 | lpips=0.5062
#  3. DJI_20241227155413_0041_V | score=0.4008 | psnr=11.0413 | ssim=0.3526 | lpips=0.5384
#  4. DJI_20241227155432_0060_V | score=0.4024 | psnr=10.4675 | ssim=0.3351 | lpips=0.5071
#  5. DJI_20241227155411_0039_V | score=0.4032 | psnr=10.8517 | ssim=0.3553 | lpips=0.5299
#  6. DJI_20241227155547_0115_V | score=0.4068 | psnr=11.2181 | ssim=0.3402 | lpips=0.5186
#  7. DJI_20241227155431_0059_V | score=0.4073 | psnr=10.6299 | ssim=0.3434 | lpips=0.5051
#  8. DJI_20241227155546_0114_V | score=0.4075 | psnr=11.1285 | ssim=0.3303 | lpips=0.5071
#  9. DJI_20241227155556_0124_V | score=0.4151 | psnr=10.7873 | ssim=0.3412 | lpips=0.4877
# 10. DJI_20241227160044_0321_V | score=0.4207 | psnr=10.1489 | ssim=0.3038 | lpips=0.4299
