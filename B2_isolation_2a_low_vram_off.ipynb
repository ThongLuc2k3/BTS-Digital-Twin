# %% [markdown]
# # BTS Digital Twin - B2 Isolation 2a - LOW_VRAM_PROFILE=0 (override) (`hcm0031`)
#
# Notebook này chạy pilot `B2` trên `round1 public_set/hcm0031`.
#
# Mặc định notebook sẽ:
#
# - clone repo hiện tại
# - cài `colmap` + `pycolmap`
# - tự dò `Dataset/VAI_NVS_DATA/phase1/public_set`
# - chạy `patch_match_stereo` + `stereo_fusion`
# - đóng gói artifact để tải về
#
# Nếu muốn đi tiếp tới `render/eval`, bật thêm `RUN_RENDER=1` và cung cấp `GS_REPO_URL`.

# %%
from pathlib import Path
import subprocess
import threading
import time

REPO_URL = 'https://github.com/ThongLuc2k3/BTS-Digital-Twin.git'
REPO_BRANCH = 'coordination/round1-status'
GITHUB_TOKEN = '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'
WORKDIR = '/content' if Path('/content').exists() else '/kaggle/working'

SCENE = 'hcm0031'
DATASET_ROOT_OVERRIDE = ''
DATASET_URL = 'https://drive.google.com/file/d/1GUflBBz4hrVtkMcHLfLMwUYk4HsJkXFu/view?usp=drive_link'
KAGGLE_DATASET = ''
KAGGLE_USERNAME = ''
KAGGLE_KEY = ''

RUN_DENSE = '1'
RUN_TRAIN = '0'
RUN_RENDER = '0'
RUN_EVAL = '0'

COLMAP_BIN_OVERRIDE = ''
BUILD_COLMAP_CUDA_IF_NEEDED = True
COLMAP_CUDA_ARCH = '75'

GS_REPO_URL = ''
GS_REPO_BRANCH = 'main'

PATCH_MATCH_MAX_IMAGE_SIZE = '1600'
PATCH_MATCH_GPU_INDEX = '0'
PATCH_MATCH_CACHE_SIZE = '8'


def run_and_stream(cmd, *, env=None, cwd=None, log_files=None, poll_seconds=15, check=True, label='cmd'):
    log_files = [Path(p) for p in (log_files or [])]
    print(f'[{label}] START:', ' '.join(map(str, cmd)), flush=True)
    proc = subprocess.Popen(
        cmd,
        cwd=cwd,
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )

    def _pump_stdout():
        assert proc.stdout is not None
        for line in proc.stdout:
            print(f'[{label}] {line.rstrip()}', flush=True)

    reader = threading.Thread(target=_pump_stdout, daemon=True)
    reader.start()

    offsets = {}
    last_heartbeat = 0.0
    try:
        while proc.poll() is None:
            now = time.time()
            if now - last_heartbeat >= poll_seconds:
                print(f'[{label}] still running...', flush=True)
                last_heartbeat = now
            for path in log_files:
                if not path.exists():
                    continue
                prev = offsets.get(path, 0)
                size = path.stat().st_size
                if size <= prev:
                    continue
                with path.open('r', encoding='utf-8', errors='replace') as f:
                    f.seek(prev)
                    chunk = f.read()
                offsets[path] = size
                if chunk.strip():
                    print(f'\n--- {path.name} ---', flush=True)
                    print(chunk.rstrip(), flush=True)
                    print(f'--- end {path.name} ---\n', flush=True)
            time.sleep(2)
    finally:
        rc = proc.wait()
        reader.join(timeout=5)
        for path in log_files:
            if path.exists():
                prev = offsets.get(path, 0)
                size = path.stat().st_size
                if size > prev:
                    with path.open('r', encoding='utf-8', errors='replace') as f:
                        f.seek(prev)
                        chunk = f.read()
                    if chunk.strip():
                        print(f'\n--- {path.name} (final) ---', flush=True)
                        print(chunk.rstrip(), flush=True)
                        print(f'--- end {path.name} ---\n', flush=True)
        print(f'[{label}] RETURN CODE =', rc, flush=True)

    if check and rc != 0:
        raise subprocess.CalledProcessError(rc, cmd)
    return rc


Path(WORKDIR).mkdir(parents=True, exist_ok=True)
print('Config ok')
print('WORKDIR =', WORKDIR)
print('PATCH_MATCH_MAX_IMAGE_SIZE =', PATCH_MATCH_MAX_IMAGE_SIZE)
print('PATCH_MATCH_CACHE_SIZE =', PATCH_MATCH_CACHE_SIZE)
# Out:
# Config ok
# WORKDIR = /content
# PATCH_MATCH_MAX_IMAGE_SIZE = 1600
# PATCH_MATCH_CACHE_SIZE = 8

# %%
import os
import subprocess

clone_url = REPO_URL
if GITHUB_TOKEN and 'github.com' in REPO_URL:
    clone_url = REPO_URL.replace('https://', f'https://{GITHUB_TOKEN}@')

project_dir = f'{WORKDIR}/project'
subprocess.run(['bash', '-lc', f'rm -rf "{project_dir}"'], check=True)
subprocess.run([
    'git', 'clone', '--depth', '1', '-b', REPO_BRANCH, clone_url, project_dir
], check=True)
print('Cloned repo ->', project_dir)
# Out:
# Cloning into '/content/project'...
# Cloned repo -> /content/project

# %%
import subprocess

subprocess.run([
    'bash', '-lc',
    'apt-get update && apt-get install -y colmap && python3 -m pip install --upgrade pip && python3 -m pip install pycolmap lpips'
], check=True)

subprocess.run(['bash', '-lc', 'colmap -h | head -n 5'], check=True)
subprocess.run(['python3', '-c', 'import pycolmap; print(pycolmap.__version__)'], check=True)
print('Installed colmap + pycolmap + lpips')
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,849 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [101 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.6 MB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,131 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,455 kB]
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [43.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,752 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,313 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,141 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,480 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [92.7 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,616 kB]
# Get:25 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [84.1 kB]
# Fetched 44.1 MB in 4s (11.7 MB/s)
# Reading package lists...
# Reading package lists...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libamd2 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libcamd2 libccolamd2 libceres2
#   libcholmod3 libcolamd2 libcxsparse3 libdouble-conversion3 libevdev2
#   libfreeimage3 libgflags2.2 libglew2.2 libgoogle-glog0v5 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libinput-bin libinput10 libmd4c0
#   libmetis5 libmtdev1 libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5
#   libqt5svg5 libqt5widgets5 libraw20 libspqr2 libsuitesparseconfig5
#   libwacom-bin libwacom-common libwacom9 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxcomposite1 libxkbcommon-x11-0 libxtst6
#   qt5-gtk-platformtheme qttranslations5-l10n session-migration
# Suggested packages:
#   glew-utils gvfs qt5-image-formats-plugins qtwayland5
# The following NEW packages will be installed:
#   at-spi2-core colmap gsettings-desktop-schemas libamd2 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libcamd2 libccolamd2 libceres2
#   libcholmod3 libcolamd2 libcxsparse3 libdouble-conversion3 libevdev2
#   libfreeimage3 libgflags2.2 libglew2.2 libgoogle-glog0v5 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libinput-bin libinput10 libmd4c0
#   libmetis5 libmtdev1 libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5
#   libqt5svg5 libqt5widgets5 libraw20 libspqr2 libsuitesparseconfig5
#   libwacom-bin libwacom-common libwacom9 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxcomposite1 libxkbcommon-x11-0 libxtst6
#   qt5-gtk-platformtheme qttranslations5-l10n session-migration
# 0 upgraded, 55 newly installed, 0 to remove and 182 not upgraded.
# Need to get 21.3 MB of archives.
# After this operation, 82.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdouble-conversion3 amd64 3.1.7-4 [39.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.4 [20.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.4 [131 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libamd2 amd64 1:5.10.1+dfsg-4build1 [21.6 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcamd2 amd64 1:5.10.1+dfsg-4build1 [23.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libccolamd2 amd64 1:5.10.1+dfsg-4build1 [25.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis5 amd64 5.1.0.dfsg-7build2 [181 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcholmod3 amd64 1:5.10.1+dfsg-4build1 [346 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcxsparse3 amd64 1:5.10.1+dfsg-4build1 [70.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags2.2 amd64 2.2.2-2 [78.1 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog0v5 amd64 0.5.0+really0.4.0-2 [60.3 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspqr2 amd64 1:5.10.1+dfsg-4build1 [71.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres2 amd64 2.0.0+dfsg1-5 [834 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraw20 amd64 0.20.2-2ubuntu2.22.04.3 [342 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libfreeimage3 amd64 3.18.0+ds2-6ubuntu5.1 [294 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew2.2 amd64 2.2.0-4 [196 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 colmap amd64 3.7-2 [2,998 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2.2 [69.6 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Fetched 21.3 MB in 1s (14.9 MB/s)
# Selecting previously unselected package libdouble-conversion3:amd64.
# (Reading database ... 125186 files and directories currently installed.)
# Preparing to unpack .../00-libdouble-conversion3_3.1.7-4_amd64.deb ...
# Unpacking libdouble-conversion3:amd64 (3.1.7-4) ...
# Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../01-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../02-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../03-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../04-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../05-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../06-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../07-libinput-bin_1.20.0-1ubuntu0.4_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.4) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../08-libinput10_1.20.0-1ubuntu0.4_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.4) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../09-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../10-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../11-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../12-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../13-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../14-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../15-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../16-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../17-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../18-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../19-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../20-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../21-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../22-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../23-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../24-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../25-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../26-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../27-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../28-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../29-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../30-libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../31-libcamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../32-libccolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../33-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../34-libmetis5_5.1.0.dfsg-7build2_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../35-libcholmod3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../36-libcxsparse3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../37-libgflags2.2_2.2.2-2_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-2) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../38-libgoogle-glog0v5_0.5.0+really0.4.0-2_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../39-libspqr2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libceres2.
# Preparing to unpack .../40-libceres2_2.0.0+dfsg1-5_amd64.deb ...
# Unpacking libceres2 (2.0.0+dfsg1-5) ...
# Selecting previously unselected package libraw20:amd64.
# Preparing to unpack .../41-libraw20_0.20.2-2ubuntu2.22.04.3_amd64.deb ...
# Unpacking libraw20:amd64 (0.20.2-2ubuntu2.22.04.3) ...
# Selecting previously unselected package libfreeimage3:amd64.
# Preparing to unpack .../42-libfreeimage3_3.18.0+ds2-6ubuntu5.1_amd64.deb ...
# Unpacking libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Selecting previously unselected package libglew2.2:amd64.
# Preparing to unpack .../43-libglew2.2_2.2.0-4_amd64.deb ...
# Unpacking libglew2.2:amd64 (2.2.0-4) ...
# Selecting previously unselected package colmap.
# Preparing to unpack .../44-colmap_3.7-2_amd64.deb ...
# Unpacking colmap (3.7-2) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../45-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../46-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../47-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../48-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../49-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../50-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../51-libgtk-3-bin_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../52-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../53-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../54-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libdouble-conversion3:amd64 (3.1.7-4) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libraw20:amd64 (0.20.2-2ubuntu2.22.04.3) ...
# Setting up libglew2.2:amd64 (2.2.0-4) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libgflags2.2 (2.2.2-2) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.4) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Setting up libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.4) ...
# Setting up libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libceres2 (2.0.0+dfsg1-5) ...
# Setting up colmap (3.7-2) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.8 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.1.2
# Collecting pycolmap
#   Downloading pycolmap-4.1.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pycolmap) (2.0.2)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.25.0+cu128)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=0.4.0->lpips) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.2.1->lpips) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Downloading pycolmap-4.1.1-cp312-cp312-manylinux_2_28_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 55.3 MB/s  0:00:00
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
# Installing collected packages: pycolmap, lpips
#
# Successfully installed lpips-0.1.4 pycolmap-4.1.1
# COLMAP 3.7 -- Structure-from-Motion and Multi-View Stereo
#               (Commit Unknown on Unknown without CUDA)
#
# Usage:
#   colmap [command] [options]
# 4.1.1
# Installed colmap + pycolmap + lpips

# %% [markdown]
# ## CUDA / COLMAP check
#
# `patch_match_stereo` cua COLMAP bat buoc can ban `colmap` duoc build voi CUDA.
#
# Neu `colmap -h` in ra `without CUDA` thi khong duoc chay tiep bang `/usr/bin/colmap` hien tai.
#
# Cell mau ngay ben duoi se build `COLMAP` co CUDA trong notebook, verify lai, roi dat `COLMAP_BIN` moi de cell `B2` phia sau dung thang binary do.

# %%
import shutil
import subprocess
from pathlib import Path

print('==== nvidia-smi ====')
subprocess.run(['bash', '-lc', 'nvidia-smi'], check=False)

print('\n==== colmap help ====')
help_proc = subprocess.run(
    ['bash', '-lc', 'colmap -h | head -n 20'],
    text=True,
    capture_output=True,
    check=False,
)
print(help_proc.stdout)
print(help_proc.stderr)

colmap_path = shutil.which('colmap')
print('COLMAP path =', colmap_path)
colmap_bin_for_b2 = COLMAP_BIN_OVERRIDE or (colmap_path or '')

if colmap_path is None:
    raise SystemExit('Khong tim thay colmap trong PATH.')

full_help = (help_proc.stdout or '') + '\n' + (help_proc.stderr or '')
if 'without CUDA' in full_help:
    print('COLMAP hien tai without CUDA. Hay chay cell build COLMAP CUDA ngay ben duoi.')
else:
    print('COLMAP co CUDA support. Co the tiep tuc dense stereo.')

cuda_colmap_guess = Path(WORKDIR) / 'project' / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
if cuda_colmap_guess.exists():
    colmap_bin_for_b2 = str(cuda_colmap_guess)
    print('Tim thay COLMAP CUDA da build san:', colmap_bin_for_b2)

print('COLMAP_BIN se dung cho B2 =', colmap_bin_for_b2)
# Out:
# ==== nvidia-smi ====
# Sat Jul 25 11:50:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   49C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#
# ==== colmap help ====
# COLMAP 3.7 -- Structure-from-Motion and Multi-View Stereo
#               (Commit Unknown on Unknown without CUDA)
#
# Usage:
#   colmap [command] [options]
#
# Documentation:
#   https://colmap.github.io/
#
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
#
#
#
# COLMAP path = /usr/bin/colmap
# COLMAP hien tai without CUDA. Hay chay cell build COLMAP CUDA ngay ben duoi.
# COLMAP_BIN se dung cho B2 = /usr/bin/colmap

# %%
import os
import shutil
import subprocess
from pathlib import Path

project_dir = Path(WORKDIR) / 'project'
build_script = project_dir / 'pipeline' / 'scripts' / 'build_colmap_cuda_notebook.sh'
cuda_colmap_bin = project_dir / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
build_log = Path(WORKDIR) / 'colmap_cuda_build.log'

need_build = BUILD_COLMAP_CUDA_IF_NEEDED
if COLMAP_BIN_OVERRIDE:
    colmap_bin_for_b2 = COLMAP_BIN_OVERRIDE
    need_build = False
    print('Dung COLMAP_BIN_OVERRIDE =', colmap_bin_for_b2)
elif cuda_colmap_bin.exists():
    colmap_bin_for_b2 = str(cuda_colmap_bin)
    need_build = False
    print('Tai su dung COLMAP CUDA da build =', colmap_bin_for_b2)
else:
    base_colmap = shutil.which('colmap') or ''
    help_proc = subprocess.run(
        ['bash', '-lc', 'colmap -h | head -n 20'],
        text=True,
        capture_output=True,
        check=False,
    )
    help_text = (help_proc.stdout or '') + '\n' + (help_proc.stderr or '')
    if base_colmap and 'without CUDA' not in help_text:
        colmap_bin_for_b2 = base_colmap
        need_build = False
        print('COLMAP san co da co CUDA =', colmap_bin_for_b2)

if need_build:
    assert build_script.exists(), f'Khong thay script build: {build_script}'
    env = os.environ.copy()
    env['CMAKE_CUDA_ARCHITECTURES'] = COLMAP_CUDA_ARCH
    env['GUI_ENABLED'] = 'OFF'
    env['BLAS_BACKEND'] = 'auto'
    run_and_stream(
        ['bash', str(build_script)],
        cwd=str(project_dir),
        env=env,
        log_files=[build_log],
        poll_seconds=20,
        label='build-colmap-cuda',
    )
    assert cuda_colmap_bin.exists(), f'Build xong nhung khong thay binary: {cuda_colmap_bin}'
    colmap_bin_for_b2 = str(cuda_colmap_bin)

verify_proc = subprocess.run(
    ['bash', '-lc', f'"{colmap_bin_for_b2}" -h | head -n 20'],
    text=True,
    capture_output=True,
    check=False,
)
print(verify_proc.stdout)
print(verify_proc.stderr)
verify_text = (verify_proc.stdout or '') + '\n' + (verify_proc.stderr or '')
if 'without CUDA' in verify_text:
    raise SystemExit('COLMAP_BIN moi van without CUDA. Khong duoc chay B2.')

print('COLMAP CUDA verify PASS')
print('COLMAP_BIN se dung cho B2 =', colmap_bin_for_b2)
# Out:
# [build-colmap-cuda] START: bash /content/project/pipeline/scripts/build_colmap_cuda_notebook.sh
# [build-colmap-cuda] still running...
# [build-colmap-cuda] Hit:1 https://cli.github.com/packages stable InRelease
# [build-colmap-cuda] Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# [build-colmap-cuda] Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# [build-colmap-cuda] Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# [build-colmap-cuda] Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# [build-colmap-cuda] Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# [build-colmap-cuda] Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Reading package lists...
# [build-colmap-cuda] W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# [build-colmap-cuda] Reading package lists...
# [build-colmap-cuda] Building dependency tree...
# [build-colmap-cuda] Reading state information...
# [build-colmap-cuda] build-essential is already the newest version (12.9ubuntu3).
# [build-colmap-cuda] libboost-system-dev is already the newest version (1.74.0.3ubuntu7).
# [build-colmap-cuda] libopenexr-dev is already the newest version (2.5.7-1).
# [build-colmap-cuda] libopenexr-dev set to manually installed.
# [build-colmap-cuda] cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# [build-colmap-cuda] git is already the newest version (1:2.34.1-1ubuntu1.17).
# [build-colmap-cuda] The following additional packages will be installed:
# [build-colmap-cuda]   curl googletest gstreamer1.0-plugins-base libboost-atomic1.74-dev
# [build-colmap-cuda]   libboost-atomic1.74.0 libboost-chrono1.74-dev libboost-chrono1.74.0
# [build-colmap-cuda]   libboost-date-time1.74-dev libboost-date-time1.74.0 libboost-graph1.74-dev
# [build-colmap-cuda]   libboost-graph1.74.0 libboost-iostreams1.74.0
# [build-colmap-cuda]   libboost-program-options1.74-dev libboost-program-options1.74.0
# [build-colmap-cuda]   libboost-regex1.74-dev libboost-regex1.74.0 libboost-serialization1.74-dev
# [build-colmap-cuda]   libboost-serialization1.74.0 libboost-test1.74-dev libboost-test1.74.0
# [build-colmap-cuda]   libboost-thread-dev libboost-thread1.74-dev libboost-thread1.74.0 libbtf1
# [build-colmap-cuda]   libcdparanoia0 libcharls2 libcurl4 libdcmtk16 libegl-dev libgdcm3.0
# [build-colmap-cuda]   libgflags-dev libgl-dev libgles-dev libgles1 libglu1-mesa libglu1-mesa-dev
# [build-colmap-cuda]   libglvnd-core-dev libgmp-dev libgmpxx4ldbl libgphoto2-6 libgphoto2-l10n
# [build-colmap-cuda]   libgphoto2-port12 libgraphblas-dev libgraphblas6
# [build-colmap-cuda]   libgstreamer-plugins-base1.0-0 libklu1 libldl2 liblog4cplus-2.0.5
# [build-colmap-cuda]   libmongoose2 libmpfr-dev libopencolorio1v5 libopencv-core4.5d
# [build-colmap-cuda]   libopencv-imgcodecs4.5d libopencv-imgproc4.5d libopencv-videoio4.5d
# [build-colmap-cuda]   libopenimageio-doc libopenimageio2.2 libopenvdb8.1 liborc-0.4-0 librbio2
# [build-colmap-cuda]   libsliplu1 libsocket++1 libsqlite3-0 libsquish0 libssl3 libtbb12 libtbb2
# [build-colmap-cuda]   libtbbmalloc2 libtinyxml2.6.2v5 libumfpack5 libunwind-dev libvisual-0.4-0
# [build-colmap-cuda]   libyaml-cpp0.7
# [build-colmap-cuda] Suggested packages:
# [build-colmap-cuda]   gvfs libmpfi-dev libntl-dev libtbb-dev libcurl4-doc libidn11-dev
# [build-colmap-cuda]   libldap2-dev librtmp-dev libeigen3-doc libmpfrc++-dev gmp-doc libgmp10-doc
# [build-colmap-cuda]   gphoto2 libvisual-0.4-plugins libmpfr-doc sqlite3-doc libssl-doc
# [build-colmap-cuda] The following NEW packages will be installed:
# [build-colmap-cuda]   googletest gstreamer1.0-plugins-base libboost-atomic1.74-dev
# [build-colmap-cuda]   libboost-atomic1.74.0 libboost-chrono1.74-dev libboost-chrono1.74.0
# [build-colmap-cuda]   libboost-date-time1.74-dev libboost-date-time1.74.0 libboost-graph-dev
# [build-colmap-cuda]   libboost-graph1.74-dev libboost-graph1.74.0 libboost-iostreams1.74.0
# [build-colmap-cuda]   libboost-program-options-dev libboost-program-options1.74-dev
# [build-colmap-cuda]   libboost-program-options1.74.0 libboost-regex1.74-dev libboost-regex1.74.0
# [build-colmap-cuda]   libboost-serialization1.74-dev libboost-serialization1.74.0
# [build-colmap-cuda]   libboost-test1.74-dev libboost-test1.74.0 libboost-thread-dev
# [build-colmap-cuda]   libboost-thread1.74-dev libboost-thread1.74.0 libbtf1 libcdparanoia0
# [build-colmap-cuda]   libceres-dev libcgal-dev libcharls2 libdcmtk16 libegl-dev libeigen3-dev
# [build-colmap-cuda]   libgdcm3.0 libgflags-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1
# [build-colmap-cuda]   libglew-dev libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev
# [build-colmap-cuda]   libglx-dev libgmock-dev libgmp-dev libgmpxx4ldbl libgoogle-glog-dev
# [build-colmap-cuda]   libgphoto2-6 libgphoto2-l10n libgphoto2-port12 libgraphblas-dev
# [build-colmap-cuda]   libgraphblas6 libgstreamer-plugins-base1.0-0 libgtest-dev libklu1 libldl2
# [build-colmap-cuda]   liblog4cplus-2.0.5 libmetis-dev libmongoose2 libmpfr-dev libopencolorio1v5
# [build-colmap-cuda]   libopencv-core4.5d libopencv-imgcodecs4.5d libopencv-imgproc4.5d
# [build-colmap-cuda]   libopencv-videoio4.5d libopengl-dev libopenimageio-dev libopenimageio-doc
# [build-colmap-cuda]   libopenimageio2.2 libopenvdb8.1 liborc-0.4-0 librbio2 libsliplu1
# [build-colmap-cuda]   libsocket++1 libsquish0 libsuitesparse-dev libtbb12 libtbb2 libtbbmalloc2
# [build-colmap-cuda]   libtinyxml2.6.2v5 libumfpack5 libunwind-dev libvisual-0.4-0 libyaml-cpp0.7
# [build-colmap-cuda]   ninja-build openimageio-tools
# [build-colmap-cuda] The following packages will be upgraded:
# [build-colmap-cuda]   curl libcurl4 libcurl4-openssl-dev libsqlite3-0 libsqlite3-dev libssl-dev
# [build-colmap-cuda]   libssl3
# [build-colmap-cuda] 7 upgraded, 87 newly installed, 0 to remove and 175 not upgraded.
# [build-colmap-cuda] Need to get 67.0 MB of archives.
# [build-colmap-cuda] After this operation, 386 MB of additional disk space will be used.
# [build-colmap-cuda] Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl-dev amd64 3.0.2-0ubuntu1.25 [2,377 kB]
# [build-colmap-cuda] Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-core4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,184 kB]
# [build-colmap-cuda] Get:3 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgproc4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,412 kB]
# [build-colmap-cuda] Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl3 amd64 3.0.2-0ubuntu1.25 [1,906 kB]
# [build-colmap-cuda] Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-dev amd64 3.37.2-2ubuntu0.7 [847 kB]
# [build-colmap-cuda] Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-0 amd64 3.37.2-2ubuntu0.7 [643 kB]
# [build-colmap-cuda] Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4-openssl-dev amd64 7.81.0-1ubuntu1.25 [387 kB]
# [build-colmap-cuda] Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 curl amd64 7.81.0-1ubuntu1.25 [194 kB]
# [build-colmap-cuda] Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4 amd64 7.81.0-1ubuntu1.25 [291 kB]
# [build-colmap-cuda] Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 googletest all 1.11.0-3 [541 kB]
# [build-colmap-cuda] Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgcodecs4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [148 kB]
# [build-colmap-cuda] Get:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-videoio4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [213 kB]
# [build-colmap-cuda] Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# [build-colmap-cuda] Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# [build-colmap-cuda] Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.6 [848 kB]
# [build-colmap-cuda] Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# [build-colmap-cuda] Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.6 [712 kB]
# [build-colmap-cuda] Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-atomic1.74.0 amd64 1.74.0-14ubuntu3 [224 kB]
# [build-colmap-cuda] Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-atomic1.74-dev amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-chrono1.74.0 amd64 1.74.0-14ubuntu3 [232 kB]
# [build-colmap-cuda] Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-chrono1.74-dev amd64 1.74.0-14ubuntu3 [239 kB]
# [build-colmap-cuda] Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-date-time1.74.0 amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-serialization1.74.0 amd64 1.74.0-14ubuntu3 [327 kB]
# [build-colmap-cuda] Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-serialization1.74-dev amd64 1.74.0-14ubuntu3 [375 kB]
# [build-colmap-cuda] Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-date-time1.74-dev amd64 1.74.0-14ubuntu3 [226 kB]
# [build-colmap-cuda] Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-regex1.74.0 amd64 1.74.0-14ubuntu3 [511 kB]
# [build-colmap-cuda] Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74.0 amd64 1.74.0-14ubuntu3 [304 kB]
# [build-colmap-cuda] Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-regex1.74-dev amd64 1.74.0-14ubuntu3 [596 kB]
# [build-colmap-cuda] Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74.0 amd64 1.74.0-14ubuntu3 [446 kB]
# [build-colmap-cuda] Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74-dev amd64 1.74.0-14ubuntu3 [564 kB]
# [build-colmap-cuda] Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74-dev amd64 1.74.0-14ubuntu3 [335 kB]
# [build-colmap-cuda] Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph-dev amd64 1.74.0.3ubuntu7 [3,348 B]
# [build-colmap-cuda] Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-iostreams1.74.0 amd64 1.74.0-14ubuntu3 [245 kB]
# [build-colmap-cuda] Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options1.74.0 amd64 1.74.0-14ubuntu3 [311 kB]
# [build-colmap-cuda] Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options1.74-dev amd64 1.74.0-14ubuntu3 [380 kB]
# [build-colmap-cuda] Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options-dev amd64 1.74.0.3ubuntu7 [3,266 B]
# [build-colmap-cuda] Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74.0 amd64 1.74.0-14ubuntu3 [262 kB]
# [build-colmap-cuda] Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74-dev amd64 1.74.0-14ubuntu3 [272 kB]
# [build-colmap-cuda] Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread-dev amd64 1.74.0.3ubuntu7 [3,266 B]
# [build-colmap-cuda] Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbtf1 amd64 1:5.10.1+dfsg-4build1 [12.1 kB]
# [build-colmap-cuda] Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags-dev amd64 2.2.2-2 [93.7 kB]
# [build-colmap-cuda] Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunwind-dev amd64 1.3.2-2build2.1 [1,883 kB]
# [build-colmap-cuda] Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog-dev amd64 0.5.0+really0.4.0-2 [91.9 kB]
# [build-colmap-cuda] Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeigen3-dev all 3.4.0-2ubuntu2 [1,056 kB]
# [build-colmap-cuda] Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libklu1 amd64 1:5.10.1+dfsg-4build1 [77.6 kB]
# [build-colmap-cuda] Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldl2 amd64 1:5.10.1+dfsg-4build1 [11.7 kB]
# [build-colmap-cuda] Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmongoose2 amd64 1:5.10.1+dfsg-4build1 [33.5 kB]
# [build-colmap-cuda] Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libumfpack5 amd64 1:5.10.1+dfsg-4build1 [250 kB]
# [build-colmap-cuda] Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 librbio2 amd64 1:5.10.1+dfsg-4build1 [26.6 kB]
# [build-colmap-cuda] Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsliplu1 amd64 1:5.10.1+dfsg-4build1 [37.1 kB]
# [build-colmap-cuda] Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsuitesparse-dev amd64 1:5.10.1+dfsg-4build1 [1,058 kB]
# [build-colmap-cuda] Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres-dev amd64 2.0.0+dfsg1-5 [1,177 kB]
# [build-colmap-cuda] Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmpxx4ldbl amd64 2:6.2.1+dfsg-3ubuntu1 [9,580 B]
# [build-colmap-cuda] Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp-dev amd64 2:6.2.1+dfsg-3ubuntu1 [337 kB]
# [build-colmap-cuda] Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmpfr-dev amd64 4.1.0-3build3 [271 kB]
# [build-colmap-cuda] Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcgal-dev amd64 5.4-1 [4,784 kB]
# [build-colmap-cuda] Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcharls2 amd64 2.3.4-1 [87.0 kB]
# [build-colmap-cuda] Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdcmtk16 amd64 3.6.6-5 [5,434 kB]
# [build-colmap-cuda] Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# [build-colmap-cuda] Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# [build-colmap-cuda] Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# [build-colmap-cuda] Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsocket++1 amd64 1.12.13+git20131030.5d039ba-1 [84.3 kB]
# [build-colmap-cuda] Get:63 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgdcm3.0 amd64 3.0.10-1build2 [1,830 kB]
# [build-colmap-cuda] Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# [build-colmap-cuda] Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# [build-colmap-cuda] Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# [build-colmap-cuda] Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# [build-colmap-cuda] Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# [build-colmap-cuda] Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.4 [7,012 B]
# [build-colmap-cuda] Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# [build-colmap-cuda] Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# [build-colmap-cuda] Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# [build-colmap-cuda] Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgtest-dev amd64 1.11.0-3 [250 kB]
# [build-colmap-cuda] Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgmock-dev amd64 1.11.0-3 [128 kB]
# [build-colmap-cuda] Get:75 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-port12 amd64 2.5.27-1ubuntu0.1 [57.9 kB]
# [build-colmap-cuda] Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-6 amd64 2.5.27-1ubuntu0.1 [727 kB]
# [build-colmap-cuda] Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-l10n all 2.5.27-1ubuntu0.1 [14.4 kB]
# [build-colmap-cuda] Get:78 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas6 amd64 6.1.4+dfsg-2 [20.1 MB]
# [build-colmap-cuda] Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas-dev amd64 6.1.4+dfsg-2 [54.4 kB]
# [build-colmap-cuda] Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblog4cplus-2.0.5 amd64 2.0.5-3 [184 kB]
# [build-colmap-cuda] Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis-dev amd64 5.1.0.dfsg-7build2 [5,818 B]
# [build-colmap-cuda] Get:82 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinyxml2.6.2v5 amd64 2.6.2-6ubuntu0.22.04.1 [33.2 kB]
# [build-colmap-cuda] Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libyaml-cpp0.7 amd64 0.7.0+dfsg-8build1 [97.7 kB]
# [build-colmap-cuda] Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopencolorio1v5 amd64 1.1.1~dfsg0-7.1build1 [362 kB]
# [build-colmap-cuda] Get:85 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbbmalloc2 amd64 2021.5.0-7ubuntu2 [49.6 kB]
# [build-colmap-cuda] Get:86 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb12 amd64 2021.5.0-7ubuntu2 [84.8 kB]
# [build-colmap-cuda] Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio-doc all 2.2.18.0+dfsg-1ubuntu2 [2,794 kB]
# [build-colmap-cuda] Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb2 amd64 2020.3-1ubuntu3 [101 kB]
# [build-colmap-cuda] Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenvdb8.1 amd64 8.1.0-3build1 [793 kB]
# [build-colmap-cuda] Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsquish0 amd64 1.15-1build1 [19.6 kB]
# [build-colmap-cuda] Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio2.2 amd64 2.2.18.0+dfsg-1ubuntu2 [2,305 kB]
# [build-colmap-cuda] Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ninja-build amd64 1.10.1-1 [111 kB]
# [build-colmap-cuda] Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio-dev amd64 2.2.18.0+dfsg-1ubuntu2 [384 kB]
# [build-colmap-cuda] Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openimageio-tools amd64 2.2.18.0+dfsg-1ubuntu2 [495 kB]
# [build-colmap-cuda] debconf: unable to initialize frontend: Dialog
# [build-colmap-cuda] debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 94.)
# [build-colmap-cuda] debconf: falling back to frontend: Readline
# [build-colmap-cuda] debconf: unable to initialize frontend: Readline
# [build-colmap-cuda] debconf: (This frontend requires a controlling tty.)
# [build-colmap-cuda] debconf: falling back to frontend: Teletype
# [build-colmap-cuda] dpkg-preconfigure: unable to re-open stdin:
# [build-colmap-cuda] Fetched 67.0 MB in 5s (12.4 MB/s)
# [build-colmap-cuda] (Reading database ...
# [build-colmap-cuda] (Reading database ... 5%
# [build-colmap-cuda] (Reading database ... 10%
# [build-colmap-cuda] (Reading database ... 15%
# [build-colmap-cuda] (Reading database ... 20%
# [build-colmap-cuda] (Reading database ... 25%
# [build-colmap-cuda] (Reading database ... 30%
# [build-colmap-cuda] (Reading database ... 35%
# [build-colmap-cuda] (Reading database ... 40%
# [build-colmap-cuda] (Reading database ... 45%
# [build-colmap-cuda] (Reading database ... 50%
# [build-colmap-cuda] (Reading database ... 55%
# [build-colmap-cuda] (Reading database ... 60%
# [build-colmap-cuda] (Reading database ... 65%
# [build-colmap-cuda] (Reading database ... 70%
# [build-colmap-cuda] (Reading database ... 75%
# [build-colmap-cuda] (Reading database ... 80%
# [build-colmap-cuda] (Reading database ... 85%
# [build-colmap-cuda] (Reading database ... 90%
# [build-colmap-cuda] (Reading database ... 95%
# [build-colmap-cuda] (Reading database ... 100%
# [build-colmap-cuda] (Reading database ... 126490 files and directories currently installed.)
# [build-colmap-cuda] Preparing to unpack .../libssl-dev_3.0.2-0ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libssl-dev:amd64 (3.0.2-0ubuntu1.25) over (3.0.2-0ubuntu1.23) ...
# [build-colmap-cuda] Preparing to unpack .../libssl3_3.0.2-0ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libssl3:amd64 (3.0.2-0ubuntu1.25) over (3.0.2-0ubuntu1.23) ...
# [build-colmap-cuda] Setting up libssl3:amd64 (3.0.2-0ubuntu1.25) ...
# [build-colmap-cuda] debconf: unable to initialize frontend: Dialog
# [build-colmap-cuda] debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# [build-colmap-cuda] debconf: falling back to frontend: Readline
# [build-colmap-cuda] (Reading database ...
# [build-colmap-cuda] (Reading database ... 5%
# [build-colmap-cuda] (Reading database ... 10%
# [build-colmap-cuda] (Reading database ... 15%
# [build-colmap-cuda] (Reading database ... 20%
# [build-colmap-cuda] (Reading database ... 25%
# [build-colmap-cuda] (Reading database ... 30%
# [build-colmap-cuda] (Reading database ... 35%
# [build-colmap-cuda] (Reading database ... 40%
# [build-colmap-cuda] (Reading database ... 45%
# [build-colmap-cuda] (Reading database ... 50%
# [build-colmap-cuda] (Reading database ... 55%
# [build-colmap-cuda] (Reading database ... 60%
# [build-colmap-cuda] (Reading database ... 65%
# [build-colmap-cuda] (Reading database ... 70%
# [build-colmap-cuda] (Reading database ... 75%
# [build-colmap-cuda] (Reading database ... 80%
# [build-colmap-cuda] (Reading database ... 85%
# [build-colmap-cuda] (Reading database ... 90%
# [build-colmap-cuda] (Reading database ... 95%
# [build-colmap-cuda] (Reading database ... 100%
# [build-colmap-cuda] (Reading database ... 126490 files and directories currently installed.)
# [build-colmap-cuda] Preparing to unpack .../00-libsqlite3-dev_3.37.2-2ubuntu0.7_amd64.deb ...
# [build-colmap-cuda] Unpacking libsqlite3-dev:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# [build-colmap-cuda] Preparing to unpack .../01-libsqlite3-0_3.37.2-2ubuntu0.7_amd64.deb ...
# [build-colmap-cuda] Unpacking libsqlite3-0:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# [build-colmap-cuda] Preparing to unpack .../02-libcurl4-openssl-dev_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Preparing to unpack .../03-curl_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking curl (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Preparing to unpack .../04-libcurl4_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libcurl4:amd64 (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Selecting previously unselected package googletest.
# [build-colmap-cuda] Preparing to unpack .../05-googletest_1.11.0-3_all.deb ...
# [build-colmap-cuda] Unpacking googletest (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libcdparanoia0:amd64.
# [build-colmap-cuda] Preparing to unpack .../06-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# [build-colmap-cuda] Selecting previously unselected package liborc-0.4-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../07-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../08-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.6_amd64.deb ...
# [build-colmap-cuda] Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# [build-colmap-cuda] Selecting previously unselected package libvisual-0.4-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../09-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# [build-colmap-cuda] Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# [build-colmap-cuda] Preparing to unpack .../10-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.6_amd64.deb ...
# [build-colmap-cuda] Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.6) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-atomic1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../11-libboost-atomic1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-atomic1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-atomic1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../12-libboost-atomic1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-atomic1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-chrono1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../13-libboost-chrono1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-chrono1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-chrono1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../14-libboost-chrono1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-chrono1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-date-time1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../15-libboost-date-time1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-date-time1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-serialization1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../16-libboost-serialization1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-serialization1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-serialization1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../17-libboost-serialization1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-serialization1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-date-time1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../18-libboost-date-time1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-date-time1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-regex1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../19-libboost-regex1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-regex1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../20-libboost-graph1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-regex1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../21-libboost-regex1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-regex1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-test1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../22-libboost-test1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-test1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-test1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../23-libboost-test1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-test1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../24-libboost-graph1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../25-libboost-graph-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-iostreams1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../26-libboost-iostreams1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../27-libboost-program-options1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../28-libboost-program-options1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../29-libboost-program-options-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../30-libboost-thread1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../31-libboost-thread1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../32-libboost-thread-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libbtf1:amd64.
# [build-colmap-cuda] Preparing to unpack .../33-libbtf1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libbtf1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libgflags-dev.
# [build-colmap-cuda] Preparing to unpack .../34-libgflags-dev_2.2.2-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgflags-dev (2.2.2-2) ...
# [build-colmap-cuda] Selecting previously unselected package libunwind-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../35-libunwind-dev_1.3.2-2build2.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libunwind-dev:amd64 (1.3.2-2build2.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgoogle-glog-dev.
# [build-colmap-cuda] Preparing to unpack .../36-libgoogle-glog-dev_0.5.0+really0.4.0-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgoogle-glog-dev (0.5.0+really0.4.0-2) ...
# [build-colmap-cuda] Selecting previously unselected package libeigen3-dev.
# [build-colmap-cuda] Preparing to unpack .../37-libeigen3-dev_3.4.0-2ubuntu2_all.deb ...
# [build-colmap-cuda] Unpacking libeigen3-dev (3.4.0-2ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libklu1:amd64.
# [build-colmap-cuda] Preparing to unpack .../38-libklu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libklu1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libldl2:amd64.
# [build-colmap-cuda] Preparing to unpack .../39-libldl2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libldl2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libmongoose2:amd64.
# [build-colmap-cuda] Preparing to unpack .../40-libmongoose2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libmongoose2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libumfpack5:amd64.
# [build-colmap-cuda] Preparing to unpack .../41-libumfpack5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libumfpack5:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package librbio2:amd64.
# [build-colmap-cuda] Preparing to unpack .../42-librbio2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking librbio2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsliplu1:amd64.
# [build-colmap-cuda] Preparing to unpack .../43-libsliplu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsliplu1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsuitesparse-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../44-libsuitesparse-dev_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsuitesparse-dev:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libceres-dev.
# [build-colmap-cuda] Preparing to unpack .../45-libceres-dev_2.0.0+dfsg1-5_amd64.deb ...
# [build-colmap-cuda] Unpacking libceres-dev (2.0.0+dfsg1-5) ...
# [build-colmap-cuda] Selecting previously unselected package libgmpxx4ldbl:amd64.
# [build-colmap-cuda] Preparing to unpack .../46-libgmpxx4ldbl_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# [build-colmap-cuda] Selecting previously unselected package libgmp-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../47-libgmp-dev_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmp-dev:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# [build-colmap-cuda] Selecting previously unselected package libmpfr-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../48-libmpfr-dev_4.1.0-3build3_amd64.deb ...
# [build-colmap-cuda] Unpacking libmpfr-dev:amd64 (4.1.0-3build3) ...
# [build-colmap-cuda] Selecting previously unselected package libcgal-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../49-libcgal-dev_5.4-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libcgal-dev:amd64 (5.4-1) ...
# [build-colmap-cuda] Selecting previously unselected package libcharls2:amd64.
# [build-colmap-cuda] Preparing to unpack .../50-libcharls2_2.3.4-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libcharls2:amd64 (2.3.4-1) ...
# [build-colmap-cuda] Selecting previously unselected package libdcmtk16.
# [build-colmap-cuda] Preparing to unpack .../51-libdcmtk16_3.6.6-5_amd64.deb ...
# [build-colmap-cuda] Unpacking libdcmtk16 (3.6.6-5) ...
# [build-colmap-cuda] Selecting previously unselected package libglx-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../52-libglx-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglx-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../53-libgl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libegl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../54-libegl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libegl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libsocket++1:amd64.
# [build-colmap-cuda] Preparing to unpack .../55-libsocket++1_1.12.13+git20131030.5d039ba-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsocket++1:amd64 (1.12.13+git20131030.5d039ba-1) ...
# [build-colmap-cuda] still running...
# [build-colmap-cuda] Selecting previously unselected package libgdcm3.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../56-libgdcm3.0_3.0.10-1build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgdcm3.0:amd64 (3.0.10-1build2) ...
# [build-colmap-cuda] Selecting previously unselected package libgles1:amd64.
# [build-colmap-cuda] Preparing to unpack .../57-libgles1_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgles1:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgles-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../58-libgles-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgles-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglvnd-core-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../59-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopengl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../60-libopengl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglvnd-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../61-libglvnd-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgl1-mesa-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../62-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.4_amd64.deb ...
# [build-colmap-cuda] Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.4) ...
# [build-colmap-cuda] Selecting previously unselected package libglu1-mesa:amd64.
# [build-colmap-cuda] Preparing to unpack .../63-libglu1-mesa_9.0.2-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglu1-mesa-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../64-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglew-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../65-libglew-dev_2.2.0-4_amd64.deb ...
# [build-colmap-cuda] Unpacking libglew-dev:amd64 (2.2.0-4) ...
# [build-colmap-cuda] Selecting previously unselected package libgtest-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../66-libgtest-dev_1.11.0-3_amd64.deb ...
# [build-colmap-cuda] Unpacking libgtest-dev:amd64 (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libgmock-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../67-libgmock-dev_1.11.0-3_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmock-dev:amd64 (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-port12:amd64.
# [build-colmap-cuda] Preparing to unpack .../68-libgphoto2-port12_2.5.27-1ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-port12:amd64 (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-6:amd64.
# [build-colmap-cuda] Preparing to unpack .../69-libgphoto2-6_2.5.27-1ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-6:amd64 (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-l10n.
# [build-colmap-cuda] Preparing to unpack .../70-libgphoto2-l10n_2.5.27-1ubuntu0.1_all.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-l10n (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgraphblas6:amd64.
# [build-colmap-cuda] Preparing to unpack .../71-libgraphblas6_6.1.4+dfsg-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgraphblas6:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Selecting previously unselected package libgraphblas-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../72-libgraphblas-dev_6.1.4+dfsg-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgraphblas-dev:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Selecting previously unselected package liblog4cplus-2.0.5:amd64.
# [build-colmap-cuda] Preparing to unpack .../73-liblog4cplus-2.0.5_2.0.5-3_amd64.deb ...
# [build-colmap-cuda] Unpacking liblog4cplus-2.0.5:amd64 (2.0.5-3) ...
# [build-colmap-cuda] Selecting previously unselected package libmetis-dev.
# [build-colmap-cuda] Preparing to unpack .../74-libmetis-dev_5.1.0.dfsg-7build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libmetis-dev (5.1.0.dfsg-7build2) ...
# [build-colmap-cuda] Selecting previously unselected package libtinyxml2.6.2v5:amd64.
# [build-colmap-cuda] Preparing to unpack .../75-libtinyxml2.6.2v5_2.6.2-6ubuntu0.22.04.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libtinyxml2.6.2v5:amd64 (2.6.2-6ubuntu0.22.04.1) ...
# [build-colmap-cuda] Selecting previously unselected package libyaml-cpp0.7:amd64.
# [build-colmap-cuda] Preparing to unpack .../76-libyaml-cpp0.7_0.7.0+dfsg-8build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libyaml-cpp0.7:amd64 (0.7.0+dfsg-8build1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencolorio1v5.
# [build-colmap-cuda] Preparing to unpack .../77-libopencolorio1v5_1.1.1~dfsg0-7.1build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencolorio1v5 (1.1.1~dfsg0-7.1build1) ...
# [build-colmap-cuda] Selecting previously unselected package libtbbmalloc2:amd64.
# [build-colmap-cuda] Preparing to unpack .../78-libtbbmalloc2_2021.5.0-7ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbbmalloc2:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libtbb12:amd64.
# [build-colmap-cuda] Preparing to unpack .../79-libtbb12_2021.5.0-7ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbb12:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-core4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../80-libopencv-core4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-core4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-imgproc4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../81-libopencv-imgproc4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-imgproc4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-imgcodecs4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../82-libopencv-imgcodecs4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-imgcodecs4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-videoio4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../83-libopencv-videoio4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-videoio4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio-doc.
# [build-colmap-cuda] Preparing to unpack .../84-libopenimageio-doc_2.2.18.0+dfsg-1ubuntu2_all.deb ...
# [build-colmap-cuda] Unpacking libopenimageio-doc (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libtbb2:amd64.
# [build-colmap-cuda] Preparing to unpack .../85-libtbb2_2020.3-1ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbb2:amd64 (2020.3-1ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libopenvdb8.1.
# [build-colmap-cuda] Preparing to unpack .../86-libopenvdb8.1_8.1.0-3build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenvdb8.1 (8.1.0-3build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsquish0:amd64.
# [build-colmap-cuda] Preparing to unpack .../87-libsquish0_1.15-1build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsquish0:amd64 (1.15-1build1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio2.2:amd64.
# [build-colmap-cuda] Preparing to unpack .../88-libopenimageio2.2_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenimageio2.2:amd64 (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package ninja-build.
# [build-colmap-cuda] Preparing to unpack .../89-ninja-build_1.10.1-1_amd64.deb ...
# [build-colmap-cuda] Unpacking ninja-build (1.10.1-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../90-libopenimageio-dev_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenimageio-dev:amd64 (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package openimageio-tools.
# [build-colmap-cuda] Preparing to unpack .../91-openimageio-tools_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking openimageio-tools (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Setting up libboost-chrono1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libtbbmalloc2:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Setting up libsquish0:amd64 (1.15-1build1) ...
# [build-colmap-cuda] Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# [build-colmap-cuda] Setting up libboost-atomic1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libunwind-dev:amd64 (1.3.2-2build2.1) ...
# [build-colmap-cuda] Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Setting up libopenimageio-doc (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Setting up libcharls2:amd64 (2.3.4-1) ...
# [build-colmap-cuda] Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# [build-colmap-cuda] Setting up libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libmetis-dev (5.1.0.dfsg-7build2) ...
# [build-colmap-cuda] Setting up libboost-program-options1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libdcmtk16 (3.6.6-5) ...
# [build-colmap-cuda] Setting up libgraphblas6:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Setting up libboost-chrono1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libsqlite3-0:amd64 (3.37.2-2ubuntu0.7) ...
# [build-colmap-cuda] Setting up libtbb2:amd64 (2020.3-1ubuntu3) ...
# [build-colmap-cuda] Setting up libldl2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Setting up liblog4cplus-2.0.5:amd64 (2.0.5-3) ...
# [build-colmap-cuda] Setting up libopenvdb8.1 (8.1.0-3build1) ...
# [build-colmap-cuda] Setting up libtbb12:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Setting up libgphoto2-l10n (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Setting up googletest (1.11.0-3) ...
# [build-colmap-cuda] Setting up libbtf1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Setting up ninja-build (1.10.1-1) ...
# [build-colmap-cuda] Setting up libboost-program-options1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libsliplu1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Setting up libmongoose2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Setting up libgraphblas-dev:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Setting up libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# [build-colmap-cuda] Setting up libumfpack5:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Setting up libboost-test1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libsqlite3-dev:amd64 (3.37.2-2ubuntu0.7) ...
# [build-colmap-cuda] Setting up libboost-program-options-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Setting up libyaml-cpp0.7:amd64 (0.7.0+dfsg-8build1) ...
# [build-colmap-cuda] Setting up libgles1:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Setting up libboost-regex1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Setting up libssl-dev:amd64 (3.0.2-0ubuntu1.25) ...
# ...
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BlockedVector.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Image.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/NestedVector.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PPolynomial.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.SortedTreeNodes.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Window.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Allocator.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyExceptions.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Ply.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PlyFile.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.imp.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyMiscellany.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.WeightedSamples.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.2D.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/JPEG.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.Initialize.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularTree.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularGrid.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MarchingCubes.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/CmdLineParser.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.imp.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BSplineData.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MAT.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/VertexFactory.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartition.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrix.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonReconClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrix.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Rasterizer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointExtent.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BSplineData.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Ply.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Window.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyAtomic.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrixInterface.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MAT.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.server.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BinaryNode.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Reconstructors.streams.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Array.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartition.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MergePlyClientServer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PNG.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Geometry.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.3D.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Polynomial.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Extrapolator.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Socket.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Factor.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.client.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularTree.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartitionClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Polynomial.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.System.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PlyFile.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrixInterface.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Socket.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/JPEG.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Reconstructors.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/LSD
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/LSD/lsd.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/CuTexImage.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/CLTexImage.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/SiftMatchCU.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/LiteWindow.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/SiftMatch.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/PyramidGL.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/ShaderMan.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/FrameBufferObject.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/ProgramCG.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/ProgramCL.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/PyramidCU.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/PyramidCL.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/SiftPyramid.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/ProgramCU.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/GLTexImage.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/ProgramGLSL.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/SiftGPU.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/GlobalUtil.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/SiftGPU/ProgramGPU.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindCryptoPP.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindMetis.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/Findonnxruntime.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindGlew.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindCHOLMOD.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindDependencies.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindGlog.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda] -- Set non-toolchain portion of runtime path of "/content/project/.local/colmap-cuda/bin/colmap" to "$ORIGIN/../lib"
# [build-colmap-cuda] COLMAP 4.2.0.dev0 (Commit fff58c7 on 2026-07-23 with CUDA)
# [build-colmap-cuda] Usage:
# [build-colmap-cuda]   colmap [command] [options]
# [build-colmap-cuda] Documentation:
# [build-colmap-cuda]   https://colmap.github.io/
# [build-colmap-cuda] Example usage:
# [build-colmap-cuda]   colmap help [ -h, --help ]
# [build-colmap-cuda]   colmap gui
# [build-colmap-cuda]   colmap gui -h [ --help ]
# [build-colmap-cuda]   colmap automatic_reconstructor -h [ --help ]
# [build-colmap-cuda]   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
# [build-colmap-cuda]   colmap feature_extractor --image_path IMAGES --database_path DATABASE
# [build-colmap-cuda]   colmap exhaustive_matcher --database_path DATABASE
# [build-colmap-cuda]   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
# [build-colmap-cuda]   ...
# [build-colmap-cuda] Available commands:
# [build-colmap-cuda]   help
# [build-colmap-cuda]   version
# [build-colmap-cuda]   gui
# [build-colmap-cuda]   automatic_reconstructor
# [build-colmap-cuda]   bundle_adjuster
# [build-colmap-cuda]   color_extractor
# [build-colmap-cuda]   database_cleaner
# [build-colmap-cuda]   database_creator
# [build-colmap-cuda]   database_merger
# [build-colmap-cuda]   advancing_front_mesher
# [build-colmap-cuda]   delaunay_mesher
# [build-colmap-cuda]   exhaustive_matcher
# [build-colmap-cuda]   feature_extractor
# [build-colmap-cuda]   feature_importer
# [build-colmap-cuda]   geometric_verifier
# [build-colmap-cuda]   global_mapper
# [build-colmap-cuda]   guided_geometric_verifier
# [build-colmap-cuda]   hierarchical_mapper
# [build-colmap-cuda]   image_deleter
# [build-colmap-cuda]   image_filterer
# [build-colmap-cuda]   image_rectifier
# [build-colmap-cuda]   image_registrator
# [build-colmap-cuda]   image_undistorter
# [build-colmap-cuda]   image_undistorter_standalone
# [build-colmap-cuda]   mapper
# [build-colmap-cuda]   matches_importer
# [build-colmap-cuda]   mesh_simplifier
# [build-colmap-cuda]   mesh_texturer
# [build-colmap-cuda]   model_aligner
# [build-colmap-cuda]   model_analyzer
# [build-colmap-cuda]   model_clusterer
# [build-colmap-cuda]   model_comparer
# [build-colmap-cuda]   model_converter
# [build-colmap-cuda]   model_cropper
# [build-colmap-cuda]   model_merger
# [build-colmap-cuda]   model_orientation_aligner
# [build-colmap-cuda]   model_splitter
# [build-colmap-cuda]   model_transformer
# [build-colmap-cuda]   patch_match_stereo
# [build-colmap-cuda]   point_filtering
# [build-colmap-cuda]   point_triangulator
# [build-colmap-cuda]   pose_prior_mapper
# [build-colmap-cuda]   poisson_mesher
# [build-colmap-cuda]   project_generator
# [build-colmap-cuda]   rig_configurator
# [build-colmap-cuda]   rotation_averager
# [build-colmap-cuda]   sequential_matcher
# [build-colmap-cuda]   spatial_matcher
# [build-colmap-cuda]   stereo_fusion
# [build-colmap-cuda]   transitive_matcher
# [build-colmap-cuda]   view_graph_calibrator
# [build-colmap-cuda]   vocab_tree_builder
# [build-colmap-cuda]   vocab_tree_matcher
# [build-colmap-cuda]   vocab_tree_retriever
# [build-colmap-cuda]
# [build-colmap-cuda] COLMAP CUDA build hoàn tất.
# [build-colmap-cuda] COLMAP_BIN=/content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda] Ví dụ chạy B2:
# [build-colmap-cuda]   export COLMAP_BIN=/content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda]   bash pipeline/scripts/05_run_b2_pilot.sh hcm0031
# [build-colmap-cuda] RETURN CODE = 0
# COLMAP 4.2.0.dev0 (Commit fff58c7 on 2026-07-23 with CUDA)
# Usage:
#   colmap [command] [options]
# Documentation:
#   https://colmap.github.io/
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
# Available commands:
#   help
#   version
#   gui
#   automatic_reconstructor
#
#
# COLMAP CUDA verify PASS
# COLMAP_BIN se dung cho B2 = /content/project/.local/colmap-cuda/bin/colmap

# %% [markdown]
# Cell tren la mau dung cho Colab/Kaggle: neu `colmap` cai san la CPU-only thi no se build `COLMAP` co CUDA, verify lai, roi luu duong dan vao bien `colmap_bin_for_b2` de cell chay `B2` ben duoi dung thang binary moi.

# %%
import os
assert colmap_bin_for_b2, 'COLMAP_BIN cho B2 dang rong. Hay chay cell verify/build COLMAP truoc.'
os.environ['COLMAP_BIN'] = colmap_bin_for_b2
print('Exported COLMAP_BIN =', os.environ['COLMAP_BIN'])
# Out:
# Exported COLMAP_BIN = /content/project/.local/colmap-cuda/bin/colmap

# %%
import os
import re
import subprocess
from pathlib import Path

downloads_dir = Path(WORKDIR) / 'downloads'
downloads_dir.mkdir(parents=True, exist_ok=True)

if DATASET_URL:
    archive_path = downloads_dir / 'dataset_round1.zip'
    if 'drive.google.com' in DATASET_URL:
        subprocess.run(['python3', '-m', 'pip', 'install', 'gdown'], check=True)
        m = re.search(r'/d/([^/]+)', DATASET_URL)
        file_id = m.group(1) if m else ''
        assert file_id, 'Khong trich duoc file id tu Google Drive link'
        subprocess.run(['gdown', '--fuzzy', f'https://drive.google.com/uc?id={file_id}', '-O', str(archive_path)], check=True)
    else:
        subprocess.run(['bash', '-lc', f'wget -O "{archive_path}" "{DATASET_URL}"'], check=True)
    raw_dir = Path(WORKDIR) / '_dataset_round1_raw'
    subprocess.run(['bash', '-lc', f'rm -rf "{raw_dir}" && mkdir -p "{raw_dir}" && unzip -q "{archive_path}" -d "{raw_dir}"'], check=True)
    print('Da tai va giai nen dataset tu DATASET_URL ->', raw_dir)
elif KAGGLE_DATASET:
    if KAGGLE_USERNAME and KAGGLE_KEY:
        kaggle_dir = Path.home() / '.kaggle'
        kaggle_dir.mkdir(parents=True, exist_ok=True)
        (kaggle_dir / 'kaggle.json').write_text('{"username":"' + KAGGLE_USERNAME + '","key":"' + KAGGLE_KEY + '"}', encoding='utf-8')
        os.chmod(kaggle_dir / 'kaggle.json', 0o600)
    subprocess.run(['python3', '-m', 'pip', 'install', 'kaggle'], check=True)
    archive_path = downloads_dir / 'dataset_round1.zip'
    subprocess.run(['bash', '-lc', f'kaggle datasets download -d "{KAGGLE_DATASET}" -p "{downloads_dir}" -f "{archive_path.name}" || kaggle datasets download -d "{KAGGLE_DATASET}" -p "{downloads_dir}"'], check=True)
    if not archive_path.exists():
        zips = sorted(downloads_dir.glob('*.zip'))
        assert zips, 'Kaggle download xong nhung khong thay file zip'
        archive_path = zips[0]
    raw_dir = Path(WORKDIR) / '_dataset_round1_raw'
    subprocess.run(['bash', '-lc', f'rm -rf "{raw_dir}" && mkdir -p "{raw_dir}" && unzip -q "{archive_path}" -d "{raw_dir}"'], check=True)
    print('Da tai va giai nen dataset tu KAGGLE_DATASET ->', raw_dir)
else:
    print('Khong co DATASET_URL/KAGGLE_DATASET. Notebook se thu tu do dataset san co.')
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.4.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1GUflBBz4hrVtkMcHLfLMwUYk4HsJkXFu
# From (redirected): https://drive.google.com/uc?id=1GUflBBz4hrVtkMcHLfLMwUYk4HsJkXFu&confirm=t&uuid=bff48020-0de0-4797-b9e1-60ffc48db227
# To: /content/downloads/dataset_round1.zip
# 100%|██████████| 2.75G/2.75G [00:24<00:00, 113MB/s]
# Da tai va giai nen dataset tu DATASET_URL -> /content/_dataset_round1_raw

# %%
from pathlib import Path

expected_scene = SCENE
dataset_root = None

if DATASET_ROOT_OVERRIDE:
    p = Path(DATASET_ROOT_OVERRIDE)
    if (p / expected_scene / 'train' / 'images').is_dir() and (p / expected_scene / 'test' / 'images').is_dir():
        dataset_root = p

workdir_path = Path(WORKDIR)
candidates = [
    workdir_path / '_dataset_round1_raw',
    workdir_path / 'project' / 'Dataset' / 'VAI_NVS_DATA' / 'phase1' / 'public_set',
    workdir_path,
    Path('/kaggle/input'),
]

if dataset_root is None:
    for base in candidates:
        if not base.exists():
            continue
        if base.name == 'public_set' and (base / expected_scene / 'train' / 'images').is_dir():
            dataset_root = base
            break
        for p in base.rglob('public_set'):
            if (p / expected_scene / 'train' / 'images').is_dir() and (p / expected_scene / 'test' / 'images').is_dir():
                dataset_root = p
                break
        if dataset_root is not None:
            break

assert dataset_root is not None, 'Khong tim thay Dataset/VAI_NVS_DATA/phase1/public_set co scene hcm0031'
print('DATASET_ROOT =', dataset_root)
# Out:
# DATASET_ROOT = /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set

# %%
import subprocess
from pathlib import Path

need_gs_repo = RUN_TRAIN == '1' or RUN_RENDER == '1' or RUN_EVAL == '1'
gs_repo = ''

if need_gs_repo:
    assert GS_REPO_URL, 'Can GS_REPO_URL neu RUN_TRAIN=1 hoac RUN_RENDER=1 hoac RUN_EVAL=1'
    gs_clone_url = GS_REPO_URL
    if GITHUB_TOKEN and 'github.com' in GS_REPO_URL:
        gs_clone_url = GS_REPO_URL.replace('https://', f'https://{GITHUB_TOKEN}@')
    gs_repo_dir = f'{WORKDIR}/gs_repo'
    subprocess.run(['bash', '-lc', f'rm -rf "{gs_repo_dir}"'], check=True)
    subprocess.run([
        'git', 'clone', '--depth', '1', '-b', GS_REPO_BRANCH, gs_clone_url, gs_repo_dir
    ], check=True)
    gs_repo = gs_repo_dir
    print('GS_REPO =', gs_repo)
else:
    print('Khong can GS_REPO cho dense-only pilot')
# Out:
# Khong can GS_REPO cho dense-only pilot

# %%
import os
from pathlib import Path

env = os.environ.copy()
env['DATASET_ROOT'] = str(dataset_root)
env['COLMAP_BIN'] = colmap_bin_for_b2
env['RUN_DENSE'] = RUN_DENSE
env['RUN_TRAIN'] = RUN_TRAIN
env['RUN_RENDER'] = RUN_RENDER
env['RUN_EVAL'] = RUN_EVAL
env['PATCH_MATCH_MAX_IMAGE_SIZE'] = PATCH_MATCH_MAX_IMAGE_SIZE
env['PATCH_MATCH_GPU_INDEX'] = PATCH_MATCH_GPU_INDEX
env['PATCH_MATCH_CACHE_SIZE'] = PATCH_MATCH_CACHE_SIZE
if gs_repo:
    env['GS_REPO'] = gs_repo

scene_root = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
log_dir = scene_root / 'logs'
log_files = [
    log_dir / '04_patch_match_stereo.log',
    log_dir / '04_stereo_fusion.log',
    log_dir / '04_colmap_dense_summary.txt',
    log_dir / '05_b2_pilot_summary.txt',
]
if RUN_TRAIN == '1':
    log_files.append(scene_root / 'train.log')
if RUN_RENDER == '1':
    log_files.append(log_dir / '05_render_b2_pilot.log')
if RUN_EVAL == '1':
    log_files.append(log_dir / '05_eval_b2_pilot.log')

run_and_stream(
    ['bash', f'{WORKDIR}/project/pipeline/scripts/05_run_b2_pilot.sh', SCENE],
    env=env,
    log_files=log_files,
    poll_seconds=15,
    label='b2-pilot',
)
print('B2 pilot done')
# Out:
# [b2-pilot] START: bash /content/project/pipeline/scripts/05_run_b2_pilot.sh hcm0031
# [b2-pilot] still running...
# [b2-pilot] I20260725 12:10:28.317834 134115078141056 images.cc:122]  => Reconstruction with 200 images and 147065 points
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0725 13:51:38.490898  5377 fusion.cc:310]  in 0.307s (4495613 points)
# I0725 13:51:38.490937  5377 fusion.cc:283] Fusing image [193/200] with index 110
# I0725 13:51:38.759910  5377 fusion.cc:310]  in 0.269s (4496479 points)
# I0725 13:51:38.759963  5377 fusion.cc:283] Fusing image [194/200] with index 109
# I0725 13:51:39.008219  5377 fusion.cc:310]  in 0.248s (4497042 points)
# I0725 13:51:39.008296  5377 fusion.cc:283] Fusing image [195/200] with index 108
# I0725 13:51:39.269474  5377 fusion.cc:310]  in 0.261s (4497915 points)
# I0725 13:51:39.269528  5377 fusion.cc:283] Fusing image [196/200] with index 107
# I0725 13:51:39.520573  5377 fusion.cc:310]  in 0.251s (4498502 points)
# I0725 13:51:39.520664  5377 fusion.cc:283] Fusing image [197/200] with index 106
# I0725 13:51:39.829946  5377 fusion.cc:310]  in 0.309s (4499004 points)
# I0725 13:51:39.830009  5377 fusion.cc:283] Fusing image [198/200] with index 105
# I0725 13:51:40.101583  5377 fusion.cc:310]  in 0.272s (4499012 points)
# I0725 13:51:40.101650  5377 fusion.cc:283] Fusing image [199/200] with index 104
# I0725 13:51:40.330492  5377 fusion.cc:310]  in 0.229s (4499012 points)
# I0725 13:51:40.330547  5377 fusion.cc:283] Fusing image [200/200] with index 199
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0725 13:51:40.722882  5377 fusion.cc:310]  in 0.392s (4499012 points)
# I0725 13:51:41.312915  5377 fusion.cc:337] Number of fused points: 4499012
# I0725 13:51:41.312960  5377 timer.cc:90] Elapsed time: 3.826 [minutes]
# I0725 13:51:42.201583  5377 mvs.cc:370] Writing output: "/content/project/pipeline/work/hcm0031/colmap/dense/fused.ply"
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] COLMAP dense pilot xong: scene=hcm0031
# [b2-pilot] PatchMatch: 5769s | StereoFusion: 234s
# [b2-pilot] Depth maps: 400 | Normal maps: 400 | Consistency graphs: 0
# [b2-pilot] Fused PLY: /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# [b2-pilot] Summary: /content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# [b2-pilot] B2 pilot workflow xong: scene=hcm0031
# [b2-pilot] Summary: /content/project/pipeline/work/hcm0031/logs/05_b2_pilot_summary.txt
#
# --- 04_colmap_dense_summary.txt (final) ---
# scene=hcm0031
# dense_dir=/content/project/pipeline/work/hcm0031/colmap/dense
# colmap_bin=/content/project/.local/colmap-cuda/bin/colmap
# patch_match_seconds=5769
# stereo_fusion_seconds=234
# depth_map_files=400
# normal_map_files=400
# consistency_graph_files=0
# fused_ply=/content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# fused_ply_bytes=121473559
# patch_log=/content/project/pipeline/work/hcm0031/logs/04_patch_match_stereo.log
# fusion_log=/content/project/pipeline/work/hcm0031/logs/04_stereo_fusion.log
# --- end 04_colmap_dense_summary.txt ---
#
#
# --- 05_b2_pilot_summary.txt (final) ---
# scene=hcm0031
# dataset_root=/content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set
# work_root=/content/project/pipeline/work
# run_dense=1
# run_train=0
# run_render=0
# run_eval=0
# source_mode=prepared
# model_dir=/content/project/pipeline/work/hcm0031/gs_model
# render_out_dir=/content/project/pipeline/work/hcm0031/renders_b2_pilot
# eval_out_csv=/content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# tower_bbox3d_json=/content/project/pipeline/work/hcm0031/tower_bbox3d.json
# skyline_top_frac=0.3
# dense_summary=/content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# render_log=/content/project/pipeline/work/hcm0031/logs/05_render_b2_pilot.log
# eval_log=/content/project/pipeline/work/hcm0031/logs/05_eval_b2_pilot.log
# --- end 05_b2_pilot_summary.txt ---
#
# [b2-pilot] RETURN CODE = 0
# B2 pilot done

# %%
from pathlib import Path
work_dir = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
logs_dir = work_dir / 'logs'

for p in [
    logs_dir / '04_colmap_dense_summary.txt',
    logs_dir / '04_patch_match_stereo.log',
    logs_dir / '04_stereo_fusion.log',
    work_dir / 'colmap' / 'dense' / 'fused.ply',
    work_dir / 'eval_metrics_b2_pilot.csv',
    work_dir / 'eval_metrics_b2_pilot_tower_crop.csv',
    work_dir / 'eval_metrics_b2_pilot_skyline_crop.csv',
]:
    print(('OK  ' if p.exists() else 'MISS'), p)
# Out:
# OK   /content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# OK   /content/project/pipeline/work/hcm0031/logs/04_patch_match_stereo.log
# OK   /content/project/pipeline/work/hcm0031/logs/04_stereo_fusion.log
# OK   /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_tower_crop.csv
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_skyline_crop.csv

# %%
import subprocess
from pathlib import Path

scene_root = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
artifact_dir = Path(WORKDIR) / 'b2_pilot_artifacts'
artifact_dir.mkdir(parents=True, exist_ok=True)

subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_colmap_dense_summary.txt" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_patch_match_stereo.log" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_stereo_fusion.log" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/05_b2_pilot_summary.txt" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/colmap/dense/fused.ply" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot_tower_crop.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot_skyline_crop.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)

subprocess.run(['bash', '-lc', f'cd "{WORKDIR}" && zip -r b2_pilot_artifacts.zip b2_pilot_artifacts >/dev/null'], check=True)
print('Artifact zip:', Path(WORKDIR) / 'b2_pilot_artifacts.zip')
# Out:
# Artifact zip: /content/b2_pilot_artifacts.zip

# %%
from pathlib import Path

zip_candidates = [
    Path(WORKDIR) / 'b2_pilot_artifacts.zip',
    Path('b2_pilot_artifacts.zip').resolve(),
]
zip_path = next((p for p in zip_candidates if p.exists()), None)
assert zip_path is not None, 'Khong tim thay b2_pilot_artifacts.zip de download'
print('Zip san sang:', zip_path)
print('Notebook dang chay tren Kaggle. Hay tai thu cong file nay tu sidebar:', zip_path)
# Out:
# Zip san sang: /content/b2_pilot_artifacts.zip
# Notebook dang chay tren Kaggle. Hay tai thu cong file nay tu sidebar: /content/b2_pilot_artifacts.zip

# %%
# =========================
# CELL 1 - Config + checks
# =========================
from pathlib import Path

WORKDIR = '/content' if Path('/content').exists() else '/kaggle/working'
SCENE = 'hcm0031'
PROJECT_DIR = Path(WORKDIR) / 'project'
DATASET_ROOT = Path(WORKDIR) / '_dataset_round1_raw' / 'VAI_NVS_DATA' / 'phase1' / 'public_set'
COLMAP_BIN = PROJECT_DIR / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
GS_REPO = Path(WORKDIR) / 'gaussian-splatting'
GS_REPO_BRANCH = 'main'

checks = [
    PROJECT_DIR,
    DATASET_ROOT,
    COLMAP_BIN,
    PROJECT_DIR / 'pipeline' / 'work' / SCENE / 'colmap' / 'dense' / 'fused.ply',
]
for p in checks:
    print(p, 'OK' if p.exists() else 'MISS')
# Out:
# /content/project OK
# /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set OK
# /content/project/.local/colmap-cuda/bin/colmap OK
# /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply OK

# %%
# ======================================
# CELL 2 - Clone GS repo only if missing
# ======================================
import subprocess

GS_REPO_URL = "https://github.com/graphdeco-inria/gaussian-splatting.git"

if GS_REPO.exists():
    print("GS_REPO da ton tai:", GS_REPO)
else:
    subprocess.run(
        ["git", "clone", "--depth", "1", "-b", GS_REPO_BRANCH, GS_REPO_URL, str(GS_REPO)],
        check=True,
    )
    print("Cloned:", GS_REPO)
# Out:
# Cloning into '/content/gaussian-splatting'...
# Cloned: /content/gaussian-splatting

# %%
# ======================================================
# CELL 3 - Install minimal GS deps + CUDA extensions
# ======================================================
from pathlib import Path

assert GS_REPO.exists(), GS_REPO

run_and_stream(
    ['bash', '-lc', f'cd "{GS_REPO}" && git submodule update --init --recursive'],
    label='gs-submodules',
)

run_and_stream(
    ['bash', '-lc', 'python3 -m pip install --upgrade pip setuptools wheel ninja'],
    label='gs-pip-core',
)

run_and_stream(
    ['bash', '-lc', 'python3 -m pip install plyfile tqdm lpips opencv-python imageio imageio-ffmpeg'],
    label='gs-pip-deps',
)

run_and_stream(
    ['bash', '-lc', 'python3 -c "import torch; print(torch.__version__)"'],
    label='gs-check-torch',
)

build_logs_dir = Path(WORKDIR) / 'gs_build_logs'
build_logs_dir.mkdir(parents=True, exist_ok=True)

build_steps = [
    (
        'diff_gaussian_rasterization',
        GS_REPO / 'submodules' / 'diff-gaussian-rasterization',
        build_logs_dir / 'diff_gaussian_rasterization.log',
    ),
    (
        'simple_knn',
        GS_REPO / 'submodules' / 'simple-knn',
        build_logs_dir / 'simple_knn.log',
    ),
]

for name, src_dir, log_path in build_steps:
    assert src_dir.exists(), src_dir
    run_and_stream(
        ['bash', '-lc', f'cd "{src_dir}" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .'],
        log_files=[log_path],
        poll_seconds=20,
        label=name,
    )
    print(f'Installed: {name}')

print('Gaussian Splatting minimal deps + extensions installed')
# Out:
# [gs-submodules] START: bash -lc cd "/content/gaussian-splatting" && git submodule update --init --recursive
# [gs-submodules] still running...
# [gs-submodules] Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core.git) registered for path 'SIBR_viewers'
# [gs-submodules] Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization.git) registered for path 'submodules/diff-gaussian-rasterization'
# [gs-submodules] Submodule 'submodules/fused-ssim' (https://github.com/rahul-goel/fused-ssim.git) registered for path 'submodules/fused-ssim'
# [gs-submodules] Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# [gs-submodules] Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/diff-gaussian-rasterization'...
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/fused-ssim'...
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/simple-knn'...
# [gs-submodules] Submodule path 'SIBR_viewers': checked out 'd8856f60c5384cc1975439193bb627d77d917d77'
# [gs-submodules] Submodule path 'submodules/diff-gaussian-rasterization': checked out '9c5c2028f6fbee2be239bc4c9421ff894fe4fbe0'
# [gs-submodules] Submodule 'third_party/glm' (https://github.com/g-truc/glm.git) registered for path 'submodules/diff-gaussian-rasterization/third_party/glm'
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/diff-gaussian-rasterization/third_party/glm'...
# [gs-submodules] Submodule path 'submodules/diff-gaussian-rasterization/third_party/glm': checked out '5c46b9c07008ae65cb81ab79cd677ecc1934b903'
# [gs-submodules] Submodule path 'submodules/fused-ssim': checked out '1272e21a282342e89537159e4bad508b19b34157'
# [gs-submodules] Submodule path 'submodules/simple-knn': checked out '86710c2d4b46680c02301765dd79e465819c8f19'
# [gs-submodules] RETURN CODE = 0
# [gs-pip-core] START: bash -lc python3 -m pip install --upgrade pip setuptools wheel ninja
# [gs-pip-core] still running...
# [gs-pip-core] Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.1.2)
# [gs-pip-core] Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (81.0.0)
# [gs-pip-core] Collecting setuptools
# [gs-pip-core]   Downloading setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# [gs-pip-core] Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.47.0)
# [gs-pip-core] Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (1.13.0)
# [gs-pip-core] Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.1)
# [gs-pip-core] Downloading setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# [gs-pip-core]    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.4 MB/s  0:00:00
# [gs-pip-core] Installing collected packages: setuptools
# [gs-pip-core]   Attempting uninstall: setuptools
# [gs-pip-core]     Found existing installation: setuptools 81.0.0
# [gs-pip-core]     Uninstalling setuptools-81.0.0:
# [gs-pip-core]       Successfully uninstalled setuptools-81.0.0
# [gs-pip-core] Successfully installed setuptools-83.0.0
# [gs-pip-core] RETURN CODE = 0
# [gs-pip-deps] START: bash -lc python3 -m pip install plyfile tqdm lpips opencv-python imageio imageio-ffmpeg
# [gs-pip-deps] still running...
# [gs-pip-deps] Collecting plyfile
# [gs-pip-deps]   Downloading plyfile-1.1.4-py3-none-any.whl.metadata (43 kB)
# [gs-pip-deps] Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# [gs-pip-deps] Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# [gs-pip-deps] Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# [gs-pip-deps] Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.3)
# [gs-pip-deps] Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (0.6.0)
# [gs-pip-deps] Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from plyfile) (2.0.2)
# [gs-pip-deps] Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.10.0+cu128)
# [gs-pip-deps] Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.25.0+cu128)
# [gs-pip-deps] Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# [gs-pip-deps] Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio) (11.3.0)
# [gs-pip-deps] Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.29.0)
# [gs-pip-deps] Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# [gs-pip-deps] Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (83.0.0)
# [gs-pip-deps] Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.14.0)
# [gs-pip-deps] Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.1)
# [gs-pip-deps] Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# [gs-pip-deps] Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# [gs-pip-deps] Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.9.4)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# [gs-pip-deps] Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.4.1)
# [gs-pip-deps] Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.3.83)
# [gs-pip-deps] Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.9.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.3.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# [gs-pip-deps] Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.5)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.5)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.1.3)
# [gs-pip-deps] Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.0)
# [gs-pip-deps] Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=0.4.0->lpips) (1.5.3)
# [gs-pip-deps] Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# [gs-pip-deps] Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# [gs-pip-deps] Downloading plyfile-1.1.4-py3-none-any.whl (36 kB)
# [gs-pip-deps] Installing collected packages: plyfile
# [gs-pip-deps] Successfully installed plyfile-1.1.4
# [gs-pip-deps] RETURN CODE = 0
# [gs-check-torch] START: bash -lc python3 -c "import torch; print(torch.__version__)"
# [gs-check-torch] still running...
# [gs-check-torch] 2.10.0+cu128
# [gs-check-torch] RETURN CODE = 0
# [diff_gaussian_rasterization] START: bash -lc cd "/content/gaussian-splatting/submodules/diff-gaussian-rasterization" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] Processing ./.
# [diff_gaussian_rasterization]   Preparing metadata (pyproject.toml): started
# [diff_gaussian_rasterization]   Preparing metadata (pyproject.toml): finished with status 'done'
# [diff_gaussian_rasterization] Building wheels for collected packages: diff_gaussian_rasterization
# [diff_gaussian_rasterization]   Building wheel for diff_gaussian_rasterization (pyproject.toml): started
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization]   Building wheel for diff_gaussian_rasterization (pyproject.toml): finished with status 'done'
# [diff_gaussian_rasterization]   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3812423 sha256=22d5f18bbb0681e044d373a3f16491bf74a5d84c7a3ec993e971185a0f0656a7
# [diff_gaussian_rasterization]   Stored in directory: /root/.cache/pip/wheels/01/e0/e8/f40a1cd6a1d5760cbd3036081bdad5b36c41fc11c786d4a404
# [diff_gaussian_rasterization] Successfully built diff_gaussian_rasterization
# [diff_gaussian_rasterization] Installing collected packages: diff_gaussian_rasterization
# [diff_gaussian_rasterization] Successfully installed diff_gaussian_rasterization-0.0.0
# [diff_gaussian_rasterization] RETURN CODE = 0
# Installed: diff_gaussian_rasterization
# [simple_knn] START: bash -lc cd "/content/gaussian-splatting/submodules/simple-knn" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .
# [simple_knn] still running...
# [simple_knn] Processing ./.
# [simple_knn]   Preparing metadata (pyproject.toml): started
# [simple_knn]   Preparing metadata (pyproject.toml): finished with status 'done'
# [simple_knn] Building wheels for collected packages: simple_knn
# [simple_knn]   Building wheel for simple_knn (pyproject.toml): started
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn]   Building wheel for simple_knn (pyproject.toml): finished with status 'done'
# [simple_knn]   Created wheel for simple_knn: filename=simple_knn-0.0.0-cp312-cp312-linux_x86_64.whl size=3552526 sha256=ff2abd87736c79d5e35c05b89b7740d382d7f1faefcbada0628f8a53eb976042
# [simple_knn]   Stored in directory: /root/.cache/pip/wheels/0a/f2/1b/255828ebad94ea248378281b7926639d83ce4f394f0052800d
# [simple_knn] Successfully built simple_knn
# [simple_knn] Installing collected packages: simple_knn
# [simple_knn] Successfully installed simple_knn-0.0.0
# [simple_knn] RETURN CODE = 0
# Installed: simple_knn
# Gaussian Splatting minimal deps + extensions installed

# %%
# ==================================================
# CELL 4 - Quick import test for GS + eval packages
# ==================================================
import sys

sys.path.insert(0, str(GS_REPO))

import cv2
import diff_gaussian_rasterization
import lpips
import simple_knn

print("Imports OK")
print("GS_REPO =", GS_REPO)
# Out:
# Imports OK
# GS_REPO = /content/gaussian-splatting

# %%
# =====================================================
# CELL X - Thi nghiem A: cau hinh isolation run 2a_low_vram_off
# =====================================================
from pathlib import Path

ISOLATION_RUN_ID = "2a_low_vram_off"
LOW_VRAM_PROFILE_OVERRIDE = "0"
RESOLUTION_OVERRIDE = "-1"

isolation_root = PROJECT_DIR / 'pipeline' / 'work' / SCENE / 'trick_runs' / f'b2_isolation_{ISOLATION_RUN_ID}'
isolation_model_dir = isolation_root / 'gs_model'
isolation_render_dir = isolation_root / 'renders'
isolation_eval_csv = isolation_root / 'eval_metrics.csv'
isolation_root.mkdir(parents=True, exist_ok=True)

print('=== Thi nghiem A - isolation run:', ISOLATION_RUN_ID, '===')
print('LOW_VRAM_PROFILE override =', LOW_VRAM_PROFILE_OVERRIDE)
print('RESOLUTION override =', RESOLUTION_OVERRIDE)
print('KHONG dung --depths trong run nay (isolate rieng bien LOW_VRAM_PROFILE)')
print('isolation_model_dir =', isolation_model_dir)
print('isolation_render_dir =', isolation_render_dir)
print('isolation_eval_csv =', isolation_eval_csv)
# Out:
# === Thi nghiem A - isolation run: 2a_low_vram_off ===
# LOW_VRAM_PROFILE override = 0
# RESOLUTION override = -1
# KHONG dung --depths trong run nay (isolate rieng bien LOW_VRAM_PROFILE)
# isolation_model_dir = /content/project/pipeline/work/hcm0031/trick_runs/b2_isolation_2a_low_vram_off/gs_model
# isolation_render_dir = /content/project/pipeline/work/hcm0031/trick_runs/b2_isolation_2a_low_vram_off/renders
# isolation_eval_csv = /content/project/pipeline/work/hcm0031/trick_runs/b2_isolation_2a_low_vram_off/eval_metrics.csv

# %%
# ================================================
# CELL 5 - Run train + render + eval for B2 debug
# ================================================
import os
from pathlib import Path

assert PROJECT_DIR.exists(), PROJECT_DIR
assert DATASET_ROOT.exists(), DATASET_ROOT
assert COLMAP_BIN.exists(), COLMAP_BIN
assert GS_REPO.exists(), GS_REPO

env = os.environ.copy()
env['DATASET_ROOT'] = str(DATASET_ROOT)
env['COLMAP_BIN'] = str(COLMAP_BIN)
env['GS_REPO'] = str(GS_REPO)

env['RUN_DENSE'] = '0'
env['RUN_TRAIN'] = '1'
env['RUN_RENDER'] = '1'
env['RUN_EVAL'] = '1'
env['SOURCE_MODE'] = 'prepared'
env['ITERATION'] = '-1'
env['LOW_VRAM_PROFILE'] = LOW_VRAM_PROFILE_OVERRIDE
env['RESOLUTION'] = RESOLUTION_OVERRIDE
env['MODEL_DIR'] = str(isolation_model_dir)
env['RENDER_OUT_DIR'] = str(isolation_render_dir)
env['EVAL_OUT_CSV'] = str(isolation_eval_csv)

scene_root = PROJECT_DIR / 'pipeline' / 'work' / SCENE
log_files = [
    scene_root / 'train.log',
    scene_root / 'logs' / '05_render_b2_pilot.log',
    scene_root / 'logs' / '05_eval_b2_pilot.log',
    scene_root / 'logs' / '05_b2_pilot_summary.txt',
]

run_and_stream(
    ['bash', str(PROJECT_DIR / 'pipeline' / 'scripts' / '05_run_b2_pilot.sh'), SCENE],
    env=env,
    log_files=log_files,
    poll_seconds=15,
    label='b2-train-render-eval',
)

print('B2 train/render/eval done')
# Out:
# [b2-train-render-eval] START: bash /content/project/pipeline/scripts/05_run_b2_pilot.sh hcm0031
# [b2-train-render-eval] still running...
#
# --- 05_b2_pilot_summary.txt ---
# scene=hcm0031
# dataset_root=/content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set
# work_root=/content/project/pipeline/work
# run_dense=1
# run_train=0
# run_render=0
# run_eval=0
# source_mode=prepared
# model_dir=/content/project/pipeline/work/hcm0031/gs_model
# render_out_dir=/content/project/pipeline/work/hcm0031/renders_b2_pilot
# eval_out_csv=/content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# tower_bbox3d_json=/content/project/pipeline/work/hcm0031/tower_bbox3d.json
# skyline_top_frac=0.3
# dense_summary=/content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# render_log=/content/project/pipeline/work/hcm0031/logs/05_render_b2_pilot.log
# eval_log=/content/project/pipeline/work/hcm0031/logs/05_eval_b2_pilot.log
# --- end 05_b2_pilot_summary.txt ---
#
# [b2-train-render-eval] ===== Train 3DGS: scene=hcm0031 iterations=30000 antialiasing=1 exposure=1 =====
# [b2-train-render-eval] SOURCE_MODE=prepared
# [b2-train-render-eval] SOURCE_DIR=/content/project/pipeline/work/hcm0031/colmap/dense
# [b2-train-render-eval] TRAIN_GUI_IP=127.0.0.1
# [b2-train-render-eval] TRAIN_GUI_PORT=56535
Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:   1%|          | 170/30000 [00:14<39:39, 12.54it/s, Loss=0.1629078, Depth Loss=0.0000000]
# Training progress:   1%|          | 180/30000 [00:14<39:47, 12.49it/s, Loss=0.1629078, Depth Loss=0.0000000]
# Training progress:   1%|          | 180/30000 [00:15<39:47, 12.49it/s, Loss=0.1456004, Depth Loss=0.0000000]
# Training progress:   1%|          | 190/30000 [00:15<39:05, 12.71it/s, Loss=0.1456004, Depth Loss=0.0000000]
# Training progress:   1%|          | 190/30000 [00:16<39:05, 12.71it/s, Loss=0.1624577, Depth Loss=0.0000000]
# Training progress:   1%|          | 200/30000 [00:16<39:17, 12.64it/s, Loss=0.1624577, Depth Loss=0.0000000]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
#
# --- train.log ---
#
# Training progress:   1%|          | 200/30000 [00:17<39:17, 12.64it/s, Loss=0.3196594, Depth Loss=0.0000000]
# Training progress:   1%|          | 210/30000 [00:17<39:39, 12.52it/s, Loss=0.3196594, Depth Loss=0.0000000]
# Training progress:   1%|          | 210/30000 [00:17<39:39, 12.52it/s, Loss=0.2701474, Depth Loss=0.0000000]
# Training progress:   1%|          | 220/30000 [00:17<39:16, 12.64it/s, Loss=0.2701474, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:   1%|          | 220/30000 [00:18<39:16, 12.64it/s, Loss=0.2856360, Depth Loss=0.0000000]
# Training progress:   1%|          | 230/30000 [00:18<39:10, 12.67it/s, Loss=0.2856360, Depth Loss=0.0000000]
# Training progress:   1%|          | 230/30000 [00:19<39:10, 12.67it/s, Loss=0.2193718, Depth Loss=0.0000000]
# Training progress:   1%|          | 240/30000 [00:19<39:25, 12.58it/s, Loss=0.2193718, Depth Loss=0.0000000]
# Training progress:   1%|          | 240/30000 [00:20<39:25, 12.58it/s, Loss=0.2816852, Depth Loss=0.0000000]
# Training progress:   1%|          | 250/30000 [00:20<38:40, 12.82it/s, Loss=0.2816852, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:   1%|          | 250/30000 [00:21<38:40, 12.82it/s, Loss=0.2048289, Depth Loss=0.0000000]
# Training progress:   1%|          | 260/30000 [00:21<37:55, 13.07it/s, Loss=0.2048289, Depth Loss=0.0000000]
# Training progress:   1%|          | 260/30000 [00:21<37:55, 13.07it/s, Loss=0.2968558, Depth Loss=0.0000000]
# Training progress:   1%|          | 270/30000 [00:21<37:33, 13.19it/s, Loss=0.2968558, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:   1%|          | 270/30000 [00:22<37:33, 13.19it/s, Loss=0.2408115, Depth Loss=0.0000000]
# Training progress:   1%|          | 280/30000 [00:22<37:36, 13.17it/s, Loss=0.2408115, Depth Loss=0.0000000]
# Training progress:   1%|          | 280/30000 [00:23<37:36, 13.17it/s, Loss=0.2291609, Depth Loss=0.0000000]
# Training progress:   1%|          | 290/30000 [00:23<38:01, 13.02it/s, Loss=0.2291609, Depth Loss=0.0000000]
# Training progress:   1%|          | 290/30000 [00:24<38:01, 13.02it/s, Loss=0.1967375, Depth Loss=0.0000000]
# Training progress:   1%|          | 300/30000 [00:24<37:34, 13.17it/s, Loss=0.1967375, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:   1%|          | 300/30000 [00:24<37:34, 13.17it/s, Loss=0.1860643, Depth Loss=0.0000000]
# Training progress:   1%|          | 310/30000 [00:24<37:00, 13.37it/s, Loss=0.1860643, Depth Loss=0.0000000]
# Training progress:   1%|          | 310/30000 [00:25<37:00, 13.37it/s, Loss=0.2682800, Depth Loss=0.0000000]
# Training progress:   1%|          | 320/30000 [00:25<37:48, 13.08it/s, Loss=0.2682800, Depth Loss=0.0000000]
# Training progress:   1%|          | 320/30000 [00:26<37:48, 13.08it/s, Loss=0.1627072, Depth Loss=0.0000000]
# Training progress:   1%|          | 330/30000 [00:26<37:19, 13.25it/s, Loss=0.1627072, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:

# --- end train.log ---
#
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] [hcm0031] tiến độ: 30000/30000
# [b2-train-render-eval] Xong. Model dir: /content/project/pipeline/work/hcm0031/gs_model
# [b2-train-render-eval] Point cloud cuối: /content/project/pipeline/work/hcm0031/gs_model/point_cloud/iteration_30000/point_cloud.ply
# [b2-train-render-eval] Checkpoint resume: /content/project/pipeline/work/hcm0031/gs_model/chkpnt30000.pth
# [b2-train-render-eval] Lỗi: không thấy MODEL_DIR=/content/project/pipeline/work/hcm0031/trick_runs/b2_isolation_2a_low_vram_off/gs_model
# [b2-train-render-eval] RETURN CODE = 1
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_24/261086068.py in <cell line: 0>()
#      35 ]
#      36
# ---> 37 run_and_stream(
#      38     ['bash', str(PROJECT_DIR / 'pipeline' / 'scripts' / '05_run_b2_pilot.sh'), SCENE],
#      39     env=env,
#
# /tmp/ipykernel_24/3337907126.py in run_and_stream(cmd, env, cwd, log_files, poll_seconds, check, label)
#      96
#      97     if check and rc != 0:
# ---> 98         raise subprocess.CalledProcessError(rc, cmd)
#      99     return rc
#     100
#
# CalledProcessError: Command '['bash', '/content/project/pipeline/scripts/05_run_b2_pilot.sh', 'hcm0031']' returned non-zero exit status 1.

# %%
# =====================================================
# CELL X - Thi nghiem A: bao cao ket qua run 2a_low_vram_off
# =====================================================
import csv
from statistics import mean

BASELINE_SCORE = 0.6731
FAILED_RUN_SCORE_RANGE = (0.40, 0.41)  # tu downloads/B2_done.ipynb va B2_done 2 safe.ipynb

with open(isolation_eval_csv, newline='', encoding='utf-8') as f:
    rows = list(csv.DictReader(f))
assert rows, f'eval csv rong: {isolation_eval_csv}'

fields = ('psnr', 'ssim', 'lpips', 'score')
means = {k: mean(float(r[k]) for r in rows) for k in fields}

print('=== Ket qua run 2a_low_vram_off (full-image, n=%d) ===' % len(rows))
for k in fields:
    print(f'{k:>6} = {means[k]:.4f}')

score = means['score']
print()
print(f'So voi baseline (0.6731): delta = {score - BASELINE_SCORE:+.4f}')
print(f'So voi failed run cu (~0.40-0.41): delta = {score - FAILED_RUN_SCORE_RANGE[0]:+.4f}')

if '2a_low_vram_off' == '2a_low_vram_off':
    if score >= BASELINE_SCORE - 0.02:
        print('KET LUAN 2a: PHUC HOI ve gan baseline -> LOW_VRAM_PROFILE la nghi phan hop ly.')
    elif FAILED_RUN_SCORE_RANGE[0] - 0.05 <= score <= FAILED_RUN_SCORE_RANGE[1] + 0.05:
        print('KET LUAN 2a: VAN SAP diem nhu cu -> LOW_VRAM_PROFILE KHONG phai nguyen nhan chinh,')
        print('loi nam o ban than prepared source hoac noi khac. Dieu tra tiep source/parity.')
    else:
        print('KET LUAN 2a: ket qua nam ngoai ca 2 vung du doan, can xem log train truoc khi ket luan.')
else:
    if FAILED_RUN_SCORE_RANGE[0] - 0.05 <= score <= FAILED_RUN_SCORE_RANGE[1] + 0.05:
        print('KET LUAN 2b: TAI LAP duoc vung sap diem ~0.40 -> xac nhan cau hinh nay that su gay loi,')
        print('cung co nhan qua cho ket luan cua run 2a.')
    else:
        print('KET LUAN 2b: KHONG tai lap duoc vung sap diem cu -> failed run truoc co the')
        print('do nguyen nhan khac (vd. state random, phien ban repo khac o thoi diem do), can than trong')
        print('khi dien giai run 2a.')

print()
print('CHI ket luan LOW_VRAM_PROFILE la nguyen nhan neu CA HAI run 2a va 2b deu khop du doan.')

# %%
# ==========================================
# CELL 6 - Read quick logs / output presence
# ==========================================
from pathlib import Path

scene_root = Path(WORKDIR) / "project" / "pipeline" / "work" / SCENE
for p in [
    scene_root / "eval_metrics_b2_pilot.csv",
    scene_root / "eval_metrics_b2_pilot_tower_crop.csv",
    scene_root / "eval_metrics_b2_pilot_skyline_crop.csv",
    scene_root / "logs" / "05_render_b2_pilot.log",
    scene_root / "logs" / "05_eval_b2_pilot.log",
]:
    print("\n====", p, "====")
    if p.exists():
        text = p.read_text(encoding="utf-8", errors="replace")
        print(text[-4000:])
    else:
        print("missing")

# %%
# ==================================================
# CELL 7 - Compare full-image / tower / skyline M0
# ==================================================
import pandas as pd
from pathlib import Path

SCENE = "hcm0031"
work_dir = Path(WORKDIR) / "project" / "pipeline" / "work" / SCENE

comparisons = [
    ("full_image", work_dir / "eval_metrics.csv", work_dir / "eval_metrics_b2_pilot.csv"),
    ("tower_crop", work_dir / "eval_metrics_m0_tower_crop.csv", work_dir / "eval_metrics_b2_pilot_tower_crop.csv"),
    ("skyline_crop", work_dir / "eval_metrics_m0_skyline_crop.csv", work_dir / "eval_metrics_b2_pilot_skyline_crop.csv"),
]

metric_candidates = ["psnr", "ssim", "lpips", "score"]


def pick_row(df, label):
    if len(df) == 1:
        return df.iloc[0]
    for key in ["image_name", "filename", "name"]:
        if key in df.columns:
            raise SystemExit(f"{label} co nhieu dong theo tung anh; can file tong hop 1 dong.")
    return df.iloc[0]


rows = []

for region, baseline_path, b2_path in comparisons:
    if not baseline_path.exists() or not b2_path.exists():
        rows.append(
            {
                "region": region,
                "status": "missing",
                "baseline_file": baseline_path.name,
                "b2_file": b2_path.name,
            }
        )
        continue

    baseline_df = pd.read_csv(baseline_path)
    b2_df = pd.read_csv(b2_path)

    base = pick_row(baseline_df, f"{region} baseline")
    b2 = pick_row(b2_df, f"{region} b2")

    row = {
        "region": region,
        "status": "ok",
        "baseline_file": baseline_path.name,
        "b2_file": b2_path.name,
    }

    for metric in metric_candidates:
        if metric in baseline_df.columns and metric in b2_df.columns:
            base_val = float(base[metric])
            b2_val = float(b2[metric])
            delta = b2_val - base_val

            if metric == "lpips":
                verdict = "better" if delta < 0 else "worse" if delta > 0 else "same"
            else:
                verdict = "better" if delta > 0 else "worse" if delta < 0 else "same"

            row[f"{metric}_base"] = base_val
            row[f"{metric}_b2"] = b2_val
            row[f"{metric}_delta"] = delta
            row[f"{metric}_verdict"] = verdict

    rows.append(row)

summary_df = pd.DataFrame(rows)

display_cols = ["region", "status"]
for metric in metric_candidates:
    display_cols += [
        f"{metric}_base",
        f"{metric}_b2",
        f"{metric}_delta",
        f"{metric}_verdict",
    ]

display_df = summary_df.reindex(columns=display_cols)

for col in display_df.columns:
    if col.endswith(("_base", "_b2", "_delta")):
        display_df[col] = display_df[col].map(lambda x: f"{x:.6f}" if pd.notna(x) else "")

print("So sanh baseline vs B2 cho 3 vung:")
print(display_df.to_string(index=False))

# %%
from pathlib import Path
import csv
import zipfile


SCENE = "hcm0031"
AUTO_DOWNLOAD = True
HEAVY_FILE_MB = 30

WORK_CANDIDATES = [
    Path(f"/content/project/pipeline/work/{SCENE}"),
    Path(f"/kaggle/working/project/pipeline/work/{SCENE}"),
    Path(f"/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/pipeline/work/{SCENE}"),
]


def find_scene_root() -> Path:
    for path in WORK_CANDIDATES:
        if path.exists():
            return path
    raise FileNotFoundError(f"Khong tim thay thu muc work cua scene {SCENE}")


def human_size(size_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    value = float(size_bytes)
    unit_idx = 0
    while value >= 1024 and unit_idx < len(units) - 1:
        value /= 1024
        unit_idx += 1
    return f"{value:.2f} {units[unit_idx]}"


def size_gb(size_bytes: int) -> float:
    return size_bytes / (1024 ** 3)


def ensure_parent(path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)


def write_manifest(rows: list[tuple[int, Path]], out_csv: Path) -> None:
    ensure_parent(out_csv)
    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["size_bytes", "size_human", "path"])
        for size, path in rows:
            writer.writerow([size, human_size(size), str(path)])


def build_zip_from_files(base_root: Path, files: list[Path], zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(files):
            zf.write(path, arcname=path.relative_to(base_root))
    return zip_path


def build_zip_from_dir(src_dir: Path, zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(src_dir.rglob("*")):
            if path.is_file():
                zf.write(path, arcname=path.relative_to(src_dir.parent))
    return zip_path


def download_paths(paths: list[Path]) -> None:
    if not AUTO_DOWNLOAD:
        return
    try:
        from google.colab import files
    except Exception:
        print("Khong phat hien google.colab, chi tao file, khong tu dong download.")
        return

    print("\n=== BAT DAU DOWNLOAD ===")
    for path in paths:
        print(path)
        files.download(str(path))


def gather_light_files(scene_root: Path) -> list[Path]:
    gs_model = scene_root / "gs_model"
    dense_sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"
    logs_dir = scene_root / "logs"

    candidates = [
        gs_model / "cfg_args",
        gs_model / "cameras.json",
        gs_model / "exposure.json",
        gs_model / "input.ply",
        gs_model / "pipeline_train_flags.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        logs_dir / "05_b2_pilot_summary.txt",
        logs_dir / "05_render_b2_pilot.log",
        logs_dir / "05_eval_b2_pilot.log",
        logs_dir / "04_colmap_dense_summary.txt",
        logs_dir / "04_stereo_fusion.log",
        scene_root / "train.log",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "03_train_3dgs.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "render_round1_test_poses.py",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "eval_round1_metrics.py",
        scene_root.parent.parent.parent / "trick" / SCENE / "default.env",
        dense_sparse0 / "cameras.bin",
        dense_sparse0 / "frames.bin",
        dense_sparse0 / "images.bin",
        dense_sparse0 / "points3D.bin",
        dense_sparse0 / "points3D.ply",
        dense_sparse0 / "rigs.bin",
        scene_root / "colmap" / "dense" / "fused.ply",
    ]

    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def gather_heavy_files(scene_root: Path) -> list[Path]:
    candidates = [
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "_curated_download" / "colmap_dense_images.zip",
        scene_root / "_curated_download" / "renders_images.zip",
    ]
    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def main() -> None:
    scene_root = find_scene_root()
    curated_root = scene_root / "_curated_download"
    curated_root.mkdir(parents=True, exist_ok=True)

    colmap_images_dir = scene_root / "colmap" / "dense" / "images"
    renders_dir = scene_root / "renders_b2_pilot"
    if not renders_dir.exists():
        renders_dir = scene_root / "renders"

    colmap_images_zip = curated_root / "colmap_dense_images.zip"
    renders_zip = curated_root / "renders_images.zip"
    light_zip = curated_root / f"{SCENE}_light_bundle.zip"

    if colmap_images_dir.exists():
        build_zip_from_dir(colmap_images_dir, colmap_images_zip)
    if renders_dir.exists():
        build_zip_from_dir(renders_dir, renders_zip)

    light_files = gather_light_files(scene_root)
    build_zip_from_files(scene_root.parent.parent.parent, light_files, light_zip)

    heavy_files = gather_heavy_files(scene_root)
    light_size = light_zip.stat().st_size if light_zip.exists() else 0
    light_rows = [(path.stat().st_size, path) for path in light_files]
    light_rows.sort(key=lambda item: (item[0], str(item[1])))
    heavy_rows = [(path.stat().st_size, path) for path in heavy_files]
    heavy_rows.sort(key=lambda item: (item[0], str(item[1])))

    light_manifest = curated_root / "light_bundle_manifest.csv"
    heavy_manifest = curated_root / "heavy_files_manifest.csv"
    write_manifest(light_rows, light_manifest)
    write_manifest(heavy_rows, heavy_manifest)

    print("=== CURATED DOWNLOAD PLAN ===")
    print("scene_root       :", scene_root)
    print("curated_root     :", curated_root)
    print("light_zip        :", light_zip)
    print("light_zip_size   :", human_size(light_size))
    print(f"light_zip_gb     : {size_gb(light_size):.3f} GB")
    print("light_file_count :", len(light_files))
    print("heavy_file_count :", len(heavy_rows))
    print("heavy_threshold  :", f">{HEAVY_FILE_MB} MB")
    print("light_manifest   :", light_manifest)
    print("heavy_manifest   :", heavy_manifest)

    print("\n=== HEAVY FILES ===")
    for size, path in heavy_rows:
        print(f"{human_size(size):>10}  {path}")

    total_bytes = light_size + sum(size for size, _ in heavy_rows)
    print("\n=== TOTAL ===")
    print("total_size       :", human_size(total_bytes))
    print(f"total_size_gb    : {size_gb(total_bytes):.3f} GB")

    download_paths([light_zip] + [path for _, path in heavy_rows])


if __name__ == "__main__":
    main()

# %%
from pathlib import Path
import csv
import os
import subprocess
import zipfile


SCENE = "hcm0031"
MODE = "reeval_latest"  # "package" | "reeval_latest"
AUTO_DOWNLOAD = False
INCLUDE_RENDERS_ARCHIVE = True
PSNR_MAX = 30.0

DATASET_ROOT = os.environ.get("DATASET_ROOT", "")

WORK_CANDIDATES = [
    Path(f"/content/project/pipeline/work/{SCENE}"),
    Path(f"/kaggle/working/project/pipeline/work/{SCENE}"),
    Path(f"/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/pipeline/work/{SCENE}"),
]

GS_REPO_CANDIDATES = [
    Path("/content/gaussian-splatting"),
    Path("/content/project/gaussian-splatting"),
    Path("/content/project/submodules/gaussian-splatting"),
    Path("/kaggle/working/gaussian-splatting"),
    Path("/kaggle/working/project/gaussian-splatting"),
    Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/gaussian-splatting"),
]

DATASET_ROOT_CANDIDATES = [
    Path("/content/project/Dataset/VAI_NVS_DATA/phase1/public_set"),
    Path("/content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set"),
    Path("/kaggle/working/project/Dataset/VAI_NVS_DATA/phase1/public_set"),
    Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/Dataset/VAI_NVS_DATA/phase1/public_set"),
]


def find_scene_root() -> Path:
    for path in WORK_CANDIDATES:
        if path.exists():
            return path
    raise FileNotFoundError(f"Khong tim thay thu muc work cua scene {SCENE}")


def find_gs_repo() -> Path:
    env_path = os.environ.get("GS_REPO", "")
    if env_path:
        env_repo = Path(env_path)
        if (env_repo / "train.py").exists():
            return env_repo

    for path in GS_REPO_CANDIDATES:
        if (path / "train.py").exists():
            os.environ["GS_REPO"] = str(path)
            return path

    raise FileNotFoundError(
        "Khong tu dong tim thay GS_REPO. Hay set tay, vi du: "
        "os.environ['GS_REPO'] = '/content/gaussian-splatting'"
    )


def find_dataset_root() -> Path:
    env_path = DATASET_ROOT or os.environ.get("DATASET_ROOT", "")
    if env_path:
        env_root = Path(env_path)
        if (env_root / SCENE / "test" / "test_poses.csv").exists():
            return env_root

    for path in DATASET_ROOT_CANDIDATES:
        if (path / SCENE / "test" / "test_poses.csv").exists():
            os.environ["DATASET_ROOT"] = str(path)
            return path

    search_bases = [
        Path("/content"),
        Path("/content/_dataset_round1_raw"),
        Path("/kaggle/working"),
        Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin"),
    ]
    for base in search_bases:
        if not base.exists():
            continue
        for path in base.rglob("public_set"):
            if (path / SCENE / "test" / "test_poses.csv").exists():
                os.environ["DATASET_ROOT"] = str(path)
                return path

    raise FileNotFoundError(
        "Khong tu dong tim thay Dataset/VAI_NVS_DATA/phase1/public_set co "
        f"scene {SCENE} va file test/test_poses.csv"
    )


def human_size(size_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    value = float(size_bytes)
    unit_idx = 0
    while value >= 1024 and unit_idx < len(units) - 1:
        value /= 1024
        unit_idx += 1
    return f"{value:.2f} {units[unit_idx]}"


def size_gb(size_bytes: int) -> float:
    return size_bytes / (1024 ** 3)


def ensure_parent(path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)


def build_zip_from_files(base_root: Path, files: list[Path], zip_path: Path) -> None:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(files):
            zf.write(path, arcname=path.relative_to(base_root))


def build_zip_from_dir(src_dir: Path, zip_path: Path) -> None:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(src_dir.rglob("*")):
            if path.is_file():
                zf.write(path, arcname=path.relative_to(src_dir.parent))


def download_paths(paths: list[Path]) -> None:
    if not AUTO_DOWNLOAD:
        return
    try:
        from google.colab import files
    except Exception:
        print("Khong phat hien google.colab, chi tao file, khong tu dong download.")
        return

    print("\n=== BAT DAU DOWNLOAD ===")
    for path in paths:
        print(path)
        files.download(str(path))


def project_root_from_scene(scene_root: Path) -> Path:
    return scene_root.parent.parent.parent


def gather_minimal_light_files(scene_root: Path) -> list[Path]:
    project_root = project_root_from_scene(scene_root)
    gs_model = scene_root / "gs_model"
    sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"

    candidates = [
        gs_model / "cfg_args",
        gs_model / "cameras.json",
        gs_model / "exposure.json",
        gs_model / "pipeline_train_flags.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        project_root / "pipeline" / "scripts" / "03_train_3dgs.sh",
        project_root / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        project_root / "pipeline" / "scripts" / "render_round1_test_poses.py",
        project_root / "pipeline" / "scripts" / "eval_round1_metrics.py",
        project_root / "trick" / SCENE / "default.env",
        sparse0 / "cameras.bin",
        sparse0 / "frames.bin",
        sparse0 / "images.bin",
        sparse0 / "points3D.bin",
        sparse0 / "points3D.ply",
        sparse0 / "rigs.bin",
    ]
    return [path for path in candidates if path.exists() and path.is_file()]


def package_b2_minimal(scene_root: Path) -> None:
    curated_root = scene_root / "_curated_b2_minimal"
    curated_root.mkdir(parents=True, exist_ok=True)

    project_root = project_root_from_scene(scene_root)
    light_files = gather_minimal_light_files(scene_root)
    light_zip = curated_root / f"{SCENE}_b2_light.zip"
    build_zip_from_files(project_root, light_files, light_zip)

    heavy_files = [
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
    ]
    heavy_files = [path for path in heavy_files if path.exists() and path.is_file()]

    archives = []
    dense_images_dir = scene_root / "colmap" / "dense" / "images"
    if dense_images_dir.exists():
        dense_images_zip = curated_root / "colmap_dense_images.zip"
        build_zip_from_dir(dense_images_dir, dense_images_zip)
        archives.append(dense_images_zip)

    renders_dir = scene_root / "renders_b2_pilot"
    if not renders_dir.exists():
        renders_dir = scene_root / "renders"
    if INCLUDE_RENDERS_ARCHIVE and renders_dir.exists():
        renders_zip = curated_root / "renders_images.zip"
        build_zip_from_dir(renders_dir, renders_zip)
        archives.append(renders_zip)

    print("=== B2 MINIMAL PACKAGE ===")
    print("scene_root        :", scene_root)
    print("curated_root      :", curated_root)
    print("light_zip         :", light_zip)
    print("light_zip_size    :", human_size(light_zip.stat().st_size))
    print(f"light_zip_gb      : {size_gb(light_zip.stat().st_size):.3f} GB")

    print("\n=== KEEP ===")
    print(light_zip)
    for path in archives:
        print(path)
    for path in heavy_files:
        print(path)

    print("\n=== KHONG CAN TAI ===")
    print("colmap/dense/stereo/depth_maps/*")
    print("colmap/dense/stereo/normal_maps/*")
    print("colmap/dense/fused.ply.vis")
    print("gs_model/events.out.tfevents*")
    print("train.log")
    print("gs_model/input.ply")
    print("logs/*")
    print("_download_ready/all_filtered/* neu da co bo curated moi")

    all_downloads = [light_zip] + archives + heavy_files
    total_bytes = sum(path.stat().st_size for path in all_downloads)
    print("\n=== TOTAL DOWNLOAD ===")
    print("count             :", len(all_downloads))
    print("total_size        :", human_size(total_bytes))
    print(f"total_size_gb     : {size_gb(total_bytes):.3f} GB")

    download_paths(all_downloads)


def find_latest_iteration(scene_root: Path) -> int:
    point_cloud_root = scene_root / "gs_model" / "point_cloud"
    iterations = []
    for path in point_cloud_root.glob("iteration_*"):
        if path.is_dir():
            try:
                iterations.append(int(path.name.split("_")[-1]))
            except ValueError:
                continue
    if not iterations:
        raise FileNotFoundError(f"Khong tim thay iteration_* trong {point_cloud_root}")
    return max(iterations)


def validate_reeval_prereqs(project_root: Path) -> None:
    gs_repo_path = find_gs_repo()
    dataset_root = find_dataset_root()
    dataset_scene_root = dataset_root / SCENE
    test_poses_csv = dataset_scene_root / "test" / "test_poses.csv"
    test_images_dir = dataset_scene_root / "test" / "images"
    if not test_poses_csv.exists():
        raise FileNotFoundError(f"Khong thay test_poses.csv: {test_poses_csv}")
    if not test_images_dir.exists():
        raise FileNotFoundError(f"Khong thay test/images: {test_images_dir}")

    scripts_dir = project_root / "pipeline" / "scripts"
    for script_name in ["render_round1_test_poses.py", "eval_round1_metrics.py"]:
        script_path = scripts_dir / script_name
        if not script_path.exists():
            raise FileNotFoundError(f"Khong thay script: {script_path}")


def reevaluate_latest_scene(scene_root: Path) -> None:
    project_root = project_root_from_scene(scene_root)
    validate_reeval_prereqs(project_root)
    gs_repo_path = find_gs_repo()
    dataset_root = find_dataset_root()
    scripts_dir = project_root / "pipeline" / "scripts"
    logs_dir = scene_root / "logs"
    logs_dir.mkdir(parents=True, exist_ok=True)

    latest_iter = find_latest_iteration(scene_root)
    model_dir = scene_root / "gs_model"
    render_out_dir = scene_root / f"renders_b2_latest_iter_{latest_iter}"
    eval_out_csv = scene_root / f"eval_metrics_b2_latest_iter_{latest_iter}.csv"
    render_log = logs_dir / f"05_render_b2_latest_iter_{latest_iter}.log"
    eval_log = logs_dir / f"05_eval_b2_latest_iter_{latest_iter}.log"

    render_cmd = [
        "python3",
        str(scripts_dir / "render_round1_test_poses.py"),
        "--scene",
        SCENE,
        "--dataset_root",
        str(dataset_root),
        "--model_dir",
        str(model_dir),
        "--iteration",
        str(latest_iter),
        "--out_dir",
        str(render_out_dir),
    ]
    eval_cmd = [
        "python3",
        str(scripts_dir / "eval_round1_metrics.py"),
        "--scene",
        SCENE,
        "--dataset_root",
        str(dataset_root),
        "--renders_dir",
        str(render_out_dir),
        "--out_csv",
        str(eval_out_csv),
        "--psnr_max",
        str(PSNR_MAX),
    ]

    print("=== REEVAL LATEST SCENE ===")
    print("scene             :", SCENE)
    print("scene_root        :", scene_root)
    print("dataset_root      :", dataset_root)
    print("gs_repo           :", gs_repo_path)
    print("latest_iteration  :", latest_iter)
    print("render_out_dir    :", render_out_dir)
    print("eval_out_csv      :", eval_out_csv)
    print("psnr_max          :", PSNR_MAX)

    env = os.environ.copy()
    with open(render_log, "w", encoding="utf-8") as f:
        subprocess.run(render_cmd, check=True, env=env, stdout=f, stderr=subprocess.STDOUT)
    with open(eval_log, "w", encoding="utf-8") as f:
        subprocess.run(eval_cmd, check=True, env=env, stdout=f, stderr=subprocess.STDOUT)

    print("render_log        :", render_log)
    print("eval_log          :", eval_log)

    if not eval_out_csv.exists():
        raise FileNotFoundError(f"Khong thay file eval csv: {eval_out_csv}")

    with open(eval_out_csv, newline="", encoding="utf-8") as f:
        rows = list(csv.DictReader(f))
    if not rows:
        raise RuntimeError("CSV eval rong, khong co metric nao.")

    psnr_vals = [float(row["psnr"]) for row in rows]
    ssim_vals = [float(row["ssim"]) for row in rows]
    lpips_vals = [float(row["lpips"]) for row in rows]
    score_vals = [float(row["score"]) for row in rows]

    print("\n=== EVAL SUMMARY ===")
    print("images            :", len(rows))
    print(f"PSNR mean         : {sum(psnr_vals) / len(psnr_vals):.4f}")
    print(f"SSIM mean         : {sum(ssim_vals) / len(ssim_vals):.4f}")
    print(f"LPIPS mean        : {sum(lpips_vals) / len(lpips_vals):.4f}")
    print(f"Score mean        : {sum(score_vals) / len(score_vals):.4f}")
    print(f"PSNR min          : {min(psnr_vals):.4f}")
    print(f"SSIM min          : {min(ssim_vals):.4f}")
    print(f"LPIPS max         : {max(lpips_vals):.4f}")
    print(f"Score min         : {min(score_vals):.4f}")

    worst_rows = sorted(rows, key=lambda row: float(row["score"]))[:10]
    print("\n=== TOP 10 ANH TE NHAT ===")
    for idx, row in enumerate(worst_rows, start=1):
        print(
            f"{idx:>2}. {row['image']} | "
            f"score={float(row['score']):.4f} | "
            f"psnr={float(row['psnr']):.4f} | "
            f"ssim={float(row['ssim']):.4f} | "
            f"lpips={float(row['lpips']):.4f}"
        )


def main() -> None:
    scene_root = find_scene_root()
    if MODE == "package":
        package_b2_minimal(scene_root)
        return
    if MODE == "reeval_latest":
        reevaluate_latest_scene(scene_root)
        return
    raise ValueError(f"MODE khong hop le: {MODE}")


if __name__ == "__main__":
    main()
