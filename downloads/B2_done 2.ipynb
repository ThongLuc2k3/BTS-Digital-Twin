# %% [markdown]
# # BTS Digital Twin - B2 Done 2 - Depth + No Low VRAM (`hcm0031`)
#
# Notebook này chạy pilot `B2` trên `round1 public_set/hcm0031`.
#
# Mặc định notebook sẽ:
#
# - clone repo hiện tại
# - cài `colmap` + `pycolmap`
# - tự dò `Dataset/VAI_NVS_DATA/phase1/public_set`
# - chạy `patch_match_stereo` + `stereo_fusion`
# - đóng gói artifact để tải về
#
# Nếu muốn đi tiếp tới `render/eval`, bật thêm `RUN_RENDER=1` và cung cấp `GS_REPO_URL`.

# %%
from pathlib import Path
import subprocess
import threading
import time

REPO_URL = 'https://github.com/ThongLuc2k3/BTS-Digital-Twin.git'
REPO_BRANCH = 'coordination/round1-status'
GITHUB_TOKEN = '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'
WORKDIR = '/content' if Path('/content').exists() else '/kaggle/working'

SCENE = 'hcm0031'
DATASET_ROOT_OVERRIDE = ''
DATASET_URL = 'https://drive.google.com/file/d/1GUflBBz4hrVtkMcHLfLMwUYk4HsJkXFu/view?usp=drive_link'
KAGGLE_DATASET = ''
KAGGLE_USERNAME = ''
KAGGLE_KEY = ''

RUN_DENSE = '1'
RUN_TRAIN = '1'
RUN_RENDER = '1'
RUN_EVAL = '1'

COLMAP_BIN_OVERRIDE = ''
BUILD_COLMAP_CUDA_IF_NEEDED = True
COLMAP_CUDA_ARCH = '75'

GS_REPO_URL = ''
GS_REPO_BRANCH = 'main'

PATCH_MATCH_MAX_IMAGE_SIZE = '1600'
PATCH_MATCH_GPU_INDEX = '0'
PATCH_MATCH_CACHE_SIZE = '8'


def run_and_stream(cmd, *, env=None, cwd=None, log_files=None, poll_seconds=15, check=True, label='cmd'):
    log_files = [Path(p) for p in (log_files or [])]
    print(f'[{label}] START:', ' '.join(map(str, cmd)), flush=True)
    proc = subprocess.Popen(
        cmd,
        cwd=cwd,
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )

    def _pump_stdout():
        assert proc.stdout is not None
        for line in proc.stdout:
            print(f'[{label}] {line.rstrip()}', flush=True)

    reader = threading.Thread(target=_pump_stdout, daemon=True)
    reader.start()

    offsets = {}
    last_heartbeat = 0.0
    try:
        while proc.poll() is None:
            now = time.time()
            if now - last_heartbeat >= poll_seconds:
                print(f'[{label}] still running...', flush=True)
                last_heartbeat = now
            for path in log_files:
                if not path.exists():
                    continue
                prev = offsets.get(path, 0)
                size = path.stat().st_size
                if size <= prev:
                    continue
                with path.open('r', encoding='utf-8', errors='replace') as f:
                    f.seek(prev)
                    chunk = f.read()
                offsets[path] = size
                if chunk.strip():
                    print(f'\n--- {path.name} ---', flush=True)
                    print(chunk.rstrip(), flush=True)
                    print(f'--- end {path.name} ---\n', flush=True)
            time.sleep(2)
    finally:
        rc = proc.wait()
        reader.join(timeout=5)
        for path in log_files:
            if path.exists():
                prev = offsets.get(path, 0)
                size = path.stat().st_size
                if size > prev:
                    with path.open('r', encoding='utf-8', errors='replace') as f:
                        f.seek(prev)
                        chunk = f.read()
                    if chunk.strip():
                        print(f'\n--- {path.name} (final) ---', flush=True)
                        print(chunk.rstrip(), flush=True)
                        print(f'--- end {path.name} ---\n', flush=True)
        print(f'[{label}] RETURN CODE =', rc, flush=True)

    if check and rc != 0:
        raise subprocess.CalledProcessError(rc, cmd)
    return rc


Path(WORKDIR).mkdir(parents=True, exist_ok=True)
print('Config ok')
print('WORKDIR =', WORKDIR)
print('PATCH_MATCH_MAX_IMAGE_SIZE =', PATCH_MATCH_MAX_IMAGE_SIZE)
print('PATCH_MATCH_CACHE_SIZE =', PATCH_MATCH_CACHE_SIZE)
# Out:
# Config ok
# WORKDIR = /content
# PATCH_MATCH_MAX_IMAGE_SIZE = 1600
# PATCH_MATCH_CACHE_SIZE = 8

# %%
import os
import subprocess

clone_url = REPO_URL
if GITHUB_TOKEN and 'github.com' in REPO_URL:
    clone_url = REPO_URL.replace('https://', f'https://{GITHUB_TOKEN}@')

project_dir = f'{WORKDIR}/project'
subprocess.run(['bash', '-lc', f'rm -rf "{project_dir}"'], check=True)
subprocess.run([
    'git', 'clone', '--depth', '1', '-b', REPO_BRANCH, clone_url, project_dir
], check=True)
print('Cloned repo ->', project_dir)
# Out:
# Cloned repo -> /content/project

# %%
import subprocess

subprocess.run([
    'bash', '-lc',
    'apt-get update && apt-get install -y colmap && python3 -m pip install --upgrade pip && python3 -m pip install pycolmap lpips'
], check=True)

subprocess.run(['bash', '-lc', 'colmap -h | head -n 5'], check=True)
subprocess.run(['python3', '-c', 'import pycolmap; print(pycolmap.__version__)'], check=True)
print('Installed colmap + pycolmap + lpips')
# Out:
# Installed colmap + pycolmap + lpips

# %% [markdown]
# ## CUDA / COLMAP check
#
# `patch_match_stereo` cua COLMAP bat buoc can ban `colmap` duoc build voi CUDA.
#
# Neu `colmap -h` in ra `without CUDA` thi khong duoc chay tiep bang `/usr/bin/colmap` hien tai.
#
# Cell mau ngay ben duoi se build `COLMAP` co CUDA trong notebook, verify lai, roi dat `COLMAP_BIN` moi de cell `B2` phia sau dung thang binary do.

# %%
import shutil
import subprocess
from pathlib import Path

print('==== nvidia-smi ====')
subprocess.run(['bash', '-lc', 'nvidia-smi'], check=False)

print('\n==== colmap help ====')
help_proc = subprocess.run(
    ['bash', '-lc', 'colmap -h | head -n 20'],
    text=True,
    capture_output=True,
    check=False,
)
print(help_proc.stdout)
print(help_proc.stderr)

colmap_path = shutil.which('colmap')
print('COLMAP path =', colmap_path)
colmap_bin_for_b2 = COLMAP_BIN_OVERRIDE or (colmap_path or '')

if colmap_path is None:
    raise SystemExit('Khong tim thay colmap trong PATH.')

full_help = (help_proc.stdout or '') + '\n' + (help_proc.stderr or '')
if 'without CUDA' in full_help:
    print('COLMAP hien tai without CUDA. Hay chay cell build COLMAP CUDA ngay ben duoi.')
else:
    print('COLMAP co CUDA support. Co the tiep tuc dense stereo.')

cuda_colmap_guess = Path(WORKDIR) / 'project' / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
if cuda_colmap_guess.exists():
    colmap_bin_for_b2 = str(cuda_colmap_guess)
    print('Tim thay COLMAP CUDA da build san:', colmap_bin_for_b2)

print('COLMAP_BIN se dung cho B2 =', colmap_bin_for_b2)
# Out:
# ==== nvidia-smi ====
#
# ==== colmap help ====
# COLMAP 3.7 -- Structure-from-Motion and Multi-View Stereo
#               (Commit Unknown on Unknown without CUDA)
#
# Usage:
#   colmap [command] [options]
#
# Documentation:
#   https://colmap.github.io/
#
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
#
#
#
# COLMAP path = /usr/bin/colmap
# COLMAP hien tai without CUDA. Hay chay cell build COLMAP CUDA ngay ben duoi.
# COLMAP_BIN se dung cho B2 = /usr/bin/colmap

# %%
import os
import shutil
import subprocess
from pathlib import Path

project_dir = Path(WORKDIR) / 'project'
build_script = project_dir / 'pipeline' / 'scripts' / 'build_colmap_cuda_notebook.sh'
cuda_colmap_bin = project_dir / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
build_log = Path(WORKDIR) / 'colmap_cuda_build.log'

need_build = BUILD_COLMAP_CUDA_IF_NEEDED
if COLMAP_BIN_OVERRIDE:
    colmap_bin_for_b2 = COLMAP_BIN_OVERRIDE
    need_build = False
    print('Dung COLMAP_BIN_OVERRIDE =', colmap_bin_for_b2)
elif cuda_colmap_bin.exists():
    colmap_bin_for_b2 = str(cuda_colmap_bin)
    need_build = False
    print('Tai su dung COLMAP CUDA da build =', colmap_bin_for_b2)
else:
    base_colmap = shutil.which('colmap') or ''
    help_proc = subprocess.run(
        ['bash', '-lc', 'colmap -h | head -n 20'],
        text=True,
        capture_output=True,
        check=False,
    )
    help_text = (help_proc.stdout or '') + '\n' + (help_proc.stderr or '')
    if base_colmap and 'without CUDA' not in help_text:
        colmap_bin_for_b2 = base_colmap
        need_build = False
        print('COLMAP san co da co CUDA =', colmap_bin_for_b2)

if need_build:
    assert build_script.exists(), f'Khong thay script build: {build_script}'
    env = os.environ.copy()
    env['CMAKE_CUDA_ARCHITECTURES'] = COLMAP_CUDA_ARCH
    env['GUI_ENABLED'] = 'OFF'
    env['BLAS_BACKEND'] = 'auto'
    run_and_stream(
        ['bash', str(build_script)],
        cwd=str(project_dir),
        env=env,
        log_files=[build_log],
        poll_seconds=20,
        label='build-colmap-cuda',
    )
    assert cuda_colmap_bin.exists(), f'Build xong nhung khong thay binary: {cuda_colmap_bin}'
    colmap_bin_for_b2 = str(cuda_colmap_bin)

verify_proc = subprocess.run(
    ['bash', '-lc', f'"{colmap_bin_for_b2}" -h | head -n 20'],
    text=True,
    capture_output=True,
    check=False,
)
print(verify_proc.stdout)
print(verify_proc.stderr)
verify_text = (verify_proc.stdout or '') + '\n' + (verify_proc.stderr or '')
if 'without CUDA' in verify_text:
    raise SystemExit('COLMAP_BIN moi van without CUDA. Khong duoc chay B2.')

print('COLMAP CUDA verify PASS')
print('COLMAP_BIN se dung cho B2 =', colmap_bin_for_b2)
# Out:
# [build-colmap-cuda] START: bash /content/project/pipeline/scripts/build_colmap_cuda_notebook.sh
# [build-colmap-cuda] still running...
# [build-colmap-cuda] Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# [build-colmap-cuda] Hit:2 https://cli.github.com/packages stable InRelease
# [build-colmap-cuda] Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# [build-colmap-cuda] Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# [build-colmap-cuda] Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# [build-colmap-cuda] Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# [build-colmap-cuda] Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# [build-colmap-cuda] Reading package lists...
# [build-colmap-cuda] W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# [build-colmap-cuda] Reading package lists...
# [build-colmap-cuda] Building dependency tree...
# [build-colmap-cuda] Reading state information...
# [build-colmap-cuda] build-essential is already the newest version (12.9ubuntu3).
# [build-colmap-cuda] cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# [build-colmap-cuda] git is already the newest version (1:2.34.1-1ubuntu1.17).
# [build-colmap-cuda] The following additional packages will be installed:
# [build-colmap-cuda]   curl googletest gstreamer1.0-plugins-base libboost-atomic1.74-dev
# [build-colmap-cuda]   libboost-atomic1.74.0 libboost-chrono1.74-dev libboost-chrono1.74.0
# [build-colmap-cuda]   libboost-date-time1.74-dev libboost-date-time1.74.0
# [build-colmap-cuda]   libboost-filesystem1.74.0 libboost-graph1.74-dev libboost-graph1.74.0
# [build-colmap-cuda]   libboost-iostreams1.74.0 libboost-program-options1.74-dev
# [build-colmap-cuda]   libboost-program-options1.74.0 libboost-regex1.74-dev libboost-regex1.74.0
# [build-colmap-cuda]   libboost-serialization1.74-dev libboost-serialization1.74.0
# [build-colmap-cuda]   libboost-system1.74-dev libboost-system1.74.0 libboost-test1.74-dev
# [build-colmap-cuda]   libboost-test1.74.0 libboost-thread-dev libboost-thread1.74-dev
# [build-colmap-cuda]   libboost-thread1.74.0 libbtf1 libcdparanoia0 libcharls2 libcurl4 libdcmtk16
# [build-colmap-cuda]   libegl-dev libexif12 libgdcm3.0 libgflags-dev libgl-dev libgles-dev libgles1
# [build-colmap-cuda]   libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libgmp-dev libgmpxx4ldbl
# [build-colmap-cuda]   libgphoto2-6 libgphoto2-l10n libgphoto2-port12 libgraphblas-dev
# [build-colmap-cuda]   libgraphblas6 libgstreamer-plugins-base1.0-0 libilmbase-dev libklu1 libldl2
# [build-colmap-cuda]   liblog4cplus-2.0.5 libmongoose2 libmpfr-dev libopencolorio1v5
# [build-colmap-cuda]   libopencv-core4.5d libopencv-imgcodecs4.5d libopencv-imgproc4.5d
# [build-colmap-cuda]   libopencv-videoio4.5d libopenimageio-doc libopenimageio2.2 libopenvdb8.1
# [build-colmap-cuda]   liborc-0.4-0 librbio2 libsliplu1 libsocket++1 libsqlite3-0 libsquish0
# [build-colmap-cuda]   libssl3 libtbb12 libtbb2 libtbbmalloc2 libtinyxml2.6.2v5 libumfpack5
# [build-colmap-cuda]   libunwind-dev libvisual-0.4-0 libyaml-cpp0.7
# [build-colmap-cuda] Suggested packages:
# [build-colmap-cuda]   gvfs libmpfi-dev libntl-dev libtbb-dev libcurl4-doc libidn11-dev
# [build-colmap-cuda]   libldap2-dev librtmp-dev libeigen3-doc libmpfrc++-dev gmp-doc libgmp10-doc
# [build-colmap-cuda]   gphoto2 libvisual-0.4-plugins libmpfr-doc sqlite3-doc libssl-doc
# [build-colmap-cuda] The following NEW packages will be installed:
# [build-colmap-cuda]   googletest gstreamer1.0-plugins-base libboost-atomic1.74-dev
# [build-colmap-cuda]   libboost-atomic1.74.0 libboost-chrono1.74-dev libboost-chrono1.74.0
# [build-colmap-cuda]   libboost-date-time1.74-dev libboost-date-time1.74.0
# [build-colmap-cuda]   libboost-filesystem1.74.0 libboost-graph-dev libboost-graph1.74-dev
# [build-colmap-cuda]   libboost-graph1.74.0 libboost-iostreams1.74.0 libboost-program-options-dev
# [build-colmap-cuda]   libboost-program-options1.74-dev libboost-program-options1.74.0
# [build-colmap-cuda]   libboost-regex1.74-dev libboost-regex1.74.0 libboost-serialization1.74-dev
# [build-colmap-cuda]   libboost-serialization1.74.0 libboost-system-dev libboost-system1.74-dev
# [build-colmap-cuda]   libboost-system1.74.0 libboost-test1.74-dev libboost-test1.74.0
# [build-colmap-cuda]   libboost-thread-dev libboost-thread1.74-dev libboost-thread1.74.0 libbtf1
# [build-colmap-cuda]   libcdparanoia0 libceres-dev libcgal-dev libcharls2 libdcmtk16 libegl-dev
# [build-colmap-cuda]   libeigen3-dev libexif12 libgdcm3.0 libgflags-dev libgl-dev libgl1-mesa-dev
# [build-colmap-cuda]   libgles-dev libgles1 libglew-dev libglu1-mesa libglu1-mesa-dev
# [build-colmap-cuda]   libglvnd-core-dev libglvnd-dev libglx-dev libgmock-dev libgmp-dev
# [build-colmap-cuda]   libgmpxx4ldbl libgoogle-glog-dev libgphoto2-6 libgphoto2-l10n
# [build-colmap-cuda]   libgphoto2-port12 libgraphblas-dev libgraphblas6
# [build-colmap-cuda]   libgstreamer-plugins-base1.0-0 libgtest-dev libilmbase-dev libklu1 libldl2
# [build-colmap-cuda]   liblog4cplus-2.0.5 libmetis-dev libmongoose2 libmpfr-dev libopencolorio1v5
# [build-colmap-cuda]   libopencv-core4.5d libopencv-imgcodecs4.5d libopencv-imgproc4.5d
# [build-colmap-cuda]   libopencv-videoio4.5d libopenexr-dev libopengl-dev libopenimageio-dev
# [build-colmap-cuda]   libopenimageio-doc libopenimageio2.2 libopenvdb8.1 liborc-0.4-0 librbio2
# [build-colmap-cuda]   libsliplu1 libsocket++1 libsquish0 libsuitesparse-dev libtbb12 libtbb2
# [build-colmap-cuda]   libtbbmalloc2 libtinyxml2.6.2v5 libumfpack5 libunwind-dev libvisual-0.4-0
# [build-colmap-cuda]   libyaml-cpp0.7 ninja-build openimageio-tools
# [build-colmap-cuda] The following packages will be upgraded:
# [build-colmap-cuda]   curl libcurl4 libcurl4-openssl-dev libsqlite3-0 libsqlite3-dev libssl-dev
# [build-colmap-cuda]   libssl3
# [build-colmap-cuda] 7 upgraded, 94 newly installed, 0 to remove and 154 not upgraded.
# [build-colmap-cuda] Need to get 68.0 MB of archives.
# [build-colmap-cuda] After this operation, 394 MB of additional disk space will be used.
# [build-colmap-cuda] Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl-dev amd64 3.0.2-0ubuntu1.25 [2,377 kB]
# [build-colmap-cuda] Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-core4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,184 kB]
# [build-colmap-cuda] Get:3 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgproc4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,412 kB]
# [build-colmap-cuda] Get:4 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgcodecs4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [148 kB]
# [build-colmap-cuda] Get:5 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-videoio4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [213 kB]
# [build-colmap-cuda] Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl3 amd64 3.0.2-0ubuntu1.25 [1,906 kB]
# [build-colmap-cuda] Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-dev amd64 3.37.2-2ubuntu0.7 [847 kB]
# [build-colmap-cuda] Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-0 amd64 3.37.2-2ubuntu0.7 [643 kB]
# [build-colmap-cuda] Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4-openssl-dev amd64 7.81.0-1ubuntu1.25 [387 kB]
# [build-colmap-cuda] Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 curl amd64 7.81.0-1ubuntu1.25 [194 kB]
# [build-colmap-cuda] Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4 amd64 7.81.0-1ubuntu1.25 [291 kB]
# [build-colmap-cuda] Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 googletest all 1.11.0-3 [541 kB]
# [build-colmap-cuda] Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# [build-colmap-cuda] Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# [build-colmap-cuda] Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.6 [848 kB]
# [build-colmap-cuda] Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# [build-colmap-cuda] Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.6 [712 kB]
# [build-colmap-cuda] Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-atomic1.74.0 amd64 1.74.0-14ubuntu3 [224 kB]
# [build-colmap-cuda] Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-atomic1.74-dev amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-chrono1.74.0 amd64 1.74.0-14ubuntu3 [232 kB]
# [build-colmap-cuda] Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-chrono1.74-dev amd64 1.74.0-14ubuntu3 [239 kB]
# [build-colmap-cuda] Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-date-time1.74.0 amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-serialization1.74.0 amd64 1.74.0-14ubuntu3 [327 kB]
# [build-colmap-cuda] Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-serialization1.74-dev amd64 1.74.0-14ubuntu3 [375 kB]
# [build-colmap-cuda] Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-date-time1.74-dev amd64 1.74.0-14ubuntu3 [226 kB]
# [build-colmap-cuda] Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-filesystem1.74.0 amd64 1.74.0-14ubuntu3 [264 kB]
# [build-colmap-cuda] Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-regex1.74.0 amd64 1.74.0-14ubuntu3 [511 kB]
# [build-colmap-cuda] Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74.0 amd64 1.74.0-14ubuntu3 [304 kB]
# [build-colmap-cuda] Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-regex1.74-dev amd64 1.74.0-14ubuntu3 [596 kB]
# [build-colmap-cuda] Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74.0 amd64 1.74.0-14ubuntu3 [446 kB]
# [build-colmap-cuda] Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74-dev amd64 1.74.0-14ubuntu3 [564 kB]
# [build-colmap-cuda] Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74-dev amd64 1.74.0-14ubuntu3 [335 kB]
# [build-colmap-cuda] Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph-dev amd64 1.74.0.3ubuntu7 [3,348 B]
# [build-colmap-cuda] Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-iostreams1.74.0 amd64 1.74.0-14ubuntu3 [245 kB]
# [build-colmap-cuda] Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options1.74.0 amd64 1.74.0-14ubuntu3 [311 kB]
# [build-colmap-cuda] Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options1.74-dev amd64 1.74.0-14ubuntu3 [380 kB]
# [build-colmap-cuda] Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-program-options-dev amd64 1.74.0.3ubuntu7 [3,266 B]
# [build-colmap-cuda] Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-system1.74.0 amd64 1.74.0-14ubuntu3 [221 kB]
# [build-colmap-cuda] Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-system1.74-dev amd64 1.74.0-14ubuntu3 [218 kB]
# [build-colmap-cuda] Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-system-dev amd64 1.74.0.3ubuntu7 [3,390 B]
# [build-colmap-cuda] Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74.0 amd64 1.74.0-14ubuntu3 [262 kB]
# [build-colmap-cuda] Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74-dev amd64 1.74.0-14ubuntu3 [272 kB]
# [build-colmap-cuda] Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread-dev amd64 1.74.0.3ubuntu7 [3,266 B]
# [build-colmap-cuda] Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbtf1 amd64 1:5.10.1+dfsg-4build1 [12.1 kB]
# [build-colmap-cuda] Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags-dev amd64 2.2.2-2 [93.7 kB]
# [build-colmap-cuda] Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunwind-dev amd64 1.3.2-2build2.1 [1,883 kB]
# [build-colmap-cuda] Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog-dev amd64 0.5.0+really0.4.0-2 [91.9 kB]
# [build-colmap-cuda] Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeigen3-dev all 3.4.0-2ubuntu2 [1,056 kB]
# [build-colmap-cuda] Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libklu1 amd64 1:5.10.1+dfsg-4build1 [77.6 kB]
# [build-colmap-cuda] Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldl2 amd64 1:5.10.1+dfsg-4build1 [11.7 kB]
# [build-colmap-cuda] Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmongoose2 amd64 1:5.10.1+dfsg-4build1 [33.5 kB]
# [build-colmap-cuda] Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libumfpack5 amd64 1:5.10.1+dfsg-4build1 [250 kB]
# [build-colmap-cuda] Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 librbio2 amd64 1:5.10.1+dfsg-4build1 [26.6 kB]
# [build-colmap-cuda] Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsliplu1 amd64 1:5.10.1+dfsg-4build1 [37.1 kB]
# [build-colmap-cuda] Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsuitesparse-dev amd64 1:5.10.1+dfsg-4build1 [1,058 kB]
# [build-colmap-cuda] Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres-dev amd64 2.0.0+dfsg1-5 [1,177 kB]
# [build-colmap-cuda] still running...
# [build-colmap-cuda] Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmpxx4ldbl amd64 2:6.2.1+dfsg-3ubuntu1 [9,580 B]
# [build-colmap-cuda] Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp-dev amd64 2:6.2.1+dfsg-3ubuntu1 [337 kB]
# [build-colmap-cuda] Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmpfr-dev amd64 4.1.0-3build3 [271 kB]
# [build-colmap-cuda] Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcgal-dev amd64 5.4-1 [4,784 kB]
# [build-colmap-cuda] Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcharls2 amd64 2.3.4-1 [87.0 kB]
# [build-colmap-cuda] Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdcmtk16 amd64 3.6.6-5 [5,434 kB]
# [build-colmap-cuda] Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# [build-colmap-cuda] Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# [build-colmap-cuda] Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# [build-colmap-cuda] Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libexif12 amd64 0.6.24-1ubuntu0.22.04.1 [92.7 kB]
# [build-colmap-cuda] Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsocket++1 amd64 1.12.13+git20131030.5d039ba-1 [84.3 kB]
# [build-colmap-cuda] Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgdcm3.0 amd64 3.0.10-1build2 [1,830 kB]
# [build-colmap-cuda] Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# [build-colmap-cuda] Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# [build-colmap-cuda] Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# [build-colmap-cuda] Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# [build-colmap-cuda] Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# [build-colmap-cuda] Get:74 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.4 [7,012 B]
# [build-colmap-cuda] Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# [build-colmap-cuda] Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# [build-colmap-cuda] Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# [build-colmap-cuda] Get:78 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgtest-dev amd64 1.11.0-3 [250 kB]
# [build-colmap-cuda] Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgmock-dev amd64 1.11.0-3 [128 kB]
# [build-colmap-cuda] Get:80 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-port12 amd64 2.5.27-1ubuntu0.1 [57.9 kB]
# [build-colmap-cuda] Get:81 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-6 amd64 2.5.27-1ubuntu0.1 [727 kB]
# [build-colmap-cuda] Get:82 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgphoto2-l10n all 2.5.27-1ubuntu0.1 [14.4 kB]
# [build-colmap-cuda] Get:83 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas6 amd64 6.1.4+dfsg-2 [20.1 MB]
# [build-colmap-cuda] Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphblas-dev amd64 6.1.4+dfsg-2 [54.4 kB]
# [build-colmap-cuda] Get:85 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase-dev amd64 2.5.7-2 [78.4 kB]
# [build-colmap-cuda] Get:86 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblog4cplus-2.0.5 amd64 2.0.5-3 [184 kB]
# [build-colmap-cuda] Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis-dev amd64 5.1.0.dfsg-7build2 [5,818 B]
# [build-colmap-cuda] Get:88 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinyxml2.6.2v5 amd64 2.6.2-6ubuntu0.22.04.1 [33.2 kB]
# [build-colmap-cuda] Get:89 http://archive.ubuntu.com/ubuntu jammy/main amd64 libyaml-cpp0.7 amd64 0.7.0+dfsg-8build1 [97.7 kB]
# [build-colmap-cuda] Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopencolorio1v5 amd64 1.1.1~dfsg0-7.1build1 [362 kB]
# [build-colmap-cuda] Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbbmalloc2 amd64 2021.5.0-7ubuntu2 [49.6 kB]
# [build-colmap-cuda] Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb12 amd64 2021.5.0-7ubuntu2 [84.8 kB]
# [build-colmap-cuda] Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr-dev amd64 2.5.7-1 [73.3 kB]
# [build-colmap-cuda] still running...
# [build-colmap-cuda] Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio-doc all 2.2.18.0+dfsg-1ubuntu2 [2,794 kB]
# [build-colmap-cuda] Get:95 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb2 amd64 2020.3-1ubuntu3 [101 kB]
# [build-colmap-cuda] Get:96 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenvdb8.1 amd64 8.1.0-3build1 [793 kB]
# [build-colmap-cuda] Get:97 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsquish0 amd64 1.15-1build1 [19.6 kB]
# [build-colmap-cuda] Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio2.2 amd64 2.2.18.0+dfsg-1ubuntu2 [2,305 kB]
# [build-colmap-cuda] Get:99 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ninja-build amd64 1.10.1-1 [111 kB]
# [build-colmap-cuda] Get:100 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenimageio-dev amd64 2.2.18.0+dfsg-1ubuntu2 [384 kB]
# [build-colmap-cuda] Get:101 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openimageio-tools amd64 2.2.18.0+dfsg-1ubuntu2 [495 kB]
# [build-colmap-cuda] debconf: unable to initialize frontend: Dialog
# [build-colmap-cuda] debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 101.)
# [build-colmap-cuda] debconf: falling back to frontend: Readline
# [build-colmap-cuda] debconf: unable to initialize frontend: Readline
# [build-colmap-cuda] debconf: (This frontend requires a controlling tty.)
# [build-colmap-cuda] debconf: falling back to frontend: Teletype
# [build-colmap-cuda] dpkg-preconfigure: unable to re-open stdin:
# [build-colmap-cuda] Fetched 68.0 MB in 36s (1,907 kB/s)
# [build-colmap-cuda] (Reading database ...
# [build-colmap-cuda] (Reading database ... 5%
# [build-colmap-cuda] (Reading database ... 10%
# [build-colmap-cuda] (Reading database ... 15%
# [build-colmap-cuda] (Reading database ... 20%
# [build-colmap-cuda] (Reading database ... 25%
# [build-colmap-cuda] (Reading database ... 30%
# [build-colmap-cuda] (Reading database ... 35%
# [build-colmap-cuda] (Reading database ... 40%
# [build-colmap-cuda] (Reading database ... 45%
# [build-colmap-cuda] (Reading database ... 50%
# [build-colmap-cuda] (Reading database ... 55%
# [build-colmap-cuda] (Reading database ... 60%
# [build-colmap-cuda] (Reading database ... 65%
# [build-colmap-cuda] (Reading database ... 70%
# [build-colmap-cuda] (Reading database ... 75%
# [build-colmap-cuda] (Reading database ... 80%
# [build-colmap-cuda] (Reading database ... 85%
# [build-colmap-cuda] (Reading database ... 90%
# [build-colmap-cuda] (Reading database ... 95%
# [build-colmap-cuda] (Reading database ... 100%
# [build-colmap-cuda] (Reading database ... 123747 files and directories currently installed.)
# [build-colmap-cuda] Preparing to unpack .../libssl-dev_3.0.2-0ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libssl-dev:amd64 (3.0.2-0ubuntu1.25) over (3.0.2-0ubuntu1.23) ...
# [build-colmap-cuda] Preparing to unpack .../libssl3_3.0.2-0ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libssl3:amd64 (3.0.2-0ubuntu1.25) over (3.0.2-0ubuntu1.23) ...
# [build-colmap-cuda] Setting up libssl3:amd64 (3.0.2-0ubuntu1.25) ...
# [build-colmap-cuda] debconf: unable to initialize frontend: Dialog
# [build-colmap-cuda] debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# [build-colmap-cuda] debconf: falling back to frontend: Readline
# [build-colmap-cuda] (Reading database ...
# [build-colmap-cuda] (Reading database ... 5%
# [build-colmap-cuda] (Reading database ... 10%
# [build-colmap-cuda] (Reading database ... 15%
# [build-colmap-cuda] (Reading database ... 20%
# [build-colmap-cuda] (Reading database ... 25%
# [build-colmap-cuda] (Reading database ... 30%
# [build-colmap-cuda] (Reading database ... 35%
# [build-colmap-cuda] (Reading database ... 40%
# [build-colmap-cuda] (Reading database ... 45%
# [build-colmap-cuda] (Reading database ... 50%
# [build-colmap-cuda] (Reading database ... 55%
# [build-colmap-cuda] (Reading database ... 60%
# [build-colmap-cuda] (Reading database ... 65%
# [build-colmap-cuda] (Reading database ... 70%
# [build-colmap-cuda] (Reading database ... 75%
# [build-colmap-cuda] (Reading database ... 80%
# [build-colmap-cuda] (Reading database ... 85%
# [build-colmap-cuda] (Reading database ... 90%
# [build-colmap-cuda] (Reading database ... 95%
# [build-colmap-cuda] (Reading database ... 100%
# [build-colmap-cuda] (Reading database ... 123747 files and directories currently installed.)
# [build-colmap-cuda] Preparing to unpack .../00-libsqlite3-dev_3.37.2-2ubuntu0.7_amd64.deb ...
# [build-colmap-cuda] Unpacking libsqlite3-dev:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# [build-colmap-cuda] Preparing to unpack .../01-libsqlite3-0_3.37.2-2ubuntu0.7_amd64.deb ...
# [build-colmap-cuda] Unpacking libsqlite3-0:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# [build-colmap-cuda] Preparing to unpack .../02-libcurl4-openssl-dev_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Preparing to unpack .../03-curl_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking curl (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Preparing to unpack .../04-libcurl4_7.81.0-1ubuntu1.25_amd64.deb ...
# [build-colmap-cuda] Unpacking libcurl4:amd64 (7.81.0-1ubuntu1.25) over (7.81.0-1ubuntu1.24) ...
# [build-colmap-cuda] Selecting previously unselected package googletest.
# [build-colmap-cuda] Preparing to unpack .../05-googletest_1.11.0-3_all.deb ...
# [build-colmap-cuda] Unpacking googletest (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libcdparanoia0:amd64.
# [build-colmap-cuda] Preparing to unpack .../06-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# [build-colmap-cuda] Selecting previously unselected package liborc-0.4-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../07-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../08-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.6_amd64.deb ...
# [build-colmap-cuda] Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# [build-colmap-cuda] Selecting previously unselected package libvisual-0.4-0:amd64.
# [build-colmap-cuda] Preparing to unpack .../09-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# [build-colmap-cuda] Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# [build-colmap-cuda] Preparing to unpack .../10-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.6_amd64.deb ...
# [build-colmap-cuda] Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.6) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-atomic1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../11-libboost-atomic1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-atomic1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-atomic1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../12-libboost-atomic1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-atomic1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-chrono1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../13-libboost-chrono1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-chrono1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-chrono1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../14-libboost-chrono1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-chrono1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-date-time1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../15-libboost-date-time1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-date-time1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-serialization1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../16-libboost-serialization1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-serialization1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-serialization1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../17-libboost-serialization1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-serialization1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-date-time1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../18-libboost-date-time1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-date-time1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-filesystem1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../19-libboost-filesystem1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-filesystem1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-regex1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../20-libboost-regex1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-regex1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../21-libboost-graph1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-regex1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../22-libboost-regex1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-regex1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-test1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../23-libboost-test1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-test1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-test1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../24-libboost-test1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-test1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../25-libboost-graph1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-graph-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../26-libboost-graph-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-graph-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-iostreams1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../27-libboost-iostreams1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../28-libboost-program-options1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../29-libboost-program-options1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-program-options-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../30-libboost-program-options-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-program-options-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-system1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../31-libboost-system1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-system1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-system1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../32-libboost-system1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-system1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-system-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../33-libboost-system-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-system-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread1.74.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../34-libboost-thread1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread1.74-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../35-libboost-thread1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libboost-thread-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../36-libboost-thread-dev_1.74.0.3ubuntu7_amd64.deb ...
# [build-colmap-cuda] Unpacking libboost-thread-dev:amd64 (1.74.0.3ubuntu7) ...
# [build-colmap-cuda] Selecting previously unselected package libbtf1:amd64.
# [build-colmap-cuda] Preparing to unpack .../37-libbtf1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libbtf1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libgflags-dev.
# [build-colmap-cuda] Preparing to unpack .../38-libgflags-dev_2.2.2-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgflags-dev (2.2.2-2) ...
# [build-colmap-cuda] Selecting previously unselected package libunwind-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../39-libunwind-dev_1.3.2-2build2.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libunwind-dev:amd64 (1.3.2-2build2.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgoogle-glog-dev.
# [build-colmap-cuda] Preparing to unpack .../40-libgoogle-glog-dev_0.5.0+really0.4.0-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgoogle-glog-dev (0.5.0+really0.4.0-2) ...
# [build-colmap-cuda] Selecting previously unselected package libeigen3-dev.
# [build-colmap-cuda] Preparing to unpack .../41-libeigen3-dev_3.4.0-2ubuntu2_all.deb ...
# [build-colmap-cuda] Unpacking libeigen3-dev (3.4.0-2ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libklu1:amd64.
# [build-colmap-cuda] Preparing to unpack .../42-libklu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libklu1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libldl2:amd64.
# [build-colmap-cuda] Preparing to unpack .../43-libldl2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libldl2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libmongoose2:amd64.
# [build-colmap-cuda] Preparing to unpack .../44-libmongoose2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libmongoose2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libumfpack5:amd64.
# [build-colmap-cuda] Preparing to unpack .../45-libumfpack5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libumfpack5:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package librbio2:amd64.
# [build-colmap-cuda] Preparing to unpack .../46-librbio2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking librbio2:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsliplu1:amd64.
# [build-colmap-cuda] Preparing to unpack .../47-libsliplu1_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsliplu1:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsuitesparse-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../48-libsuitesparse-dev_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsuitesparse-dev:amd64 (1:5.10.1+dfsg-4build1) ...
# [build-colmap-cuda] Selecting previously unselected package libceres-dev.
# [build-colmap-cuda] Preparing to unpack .../49-libceres-dev_2.0.0+dfsg1-5_amd64.deb ...
# [build-colmap-cuda] Unpacking libceres-dev (2.0.0+dfsg1-5) ...
# [build-colmap-cuda] Selecting previously unselected package libgmpxx4ldbl:amd64.
# [build-colmap-cuda] Preparing to unpack .../50-libgmpxx4ldbl_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# [build-colmap-cuda] Selecting previously unselected package libgmp-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../51-libgmp-dev_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmp-dev:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# [build-colmap-cuda] Selecting previously unselected package libmpfr-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../52-libmpfr-dev_4.1.0-3build3_amd64.deb ...
# [build-colmap-cuda] Unpacking libmpfr-dev:amd64 (4.1.0-3build3) ...
# [build-colmap-cuda] Selecting previously unselected package libcgal-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../53-libcgal-dev_5.4-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libcgal-dev:amd64 (5.4-1) ...
# [build-colmap-cuda] Selecting previously unselected package libcharls2:amd64.
# [build-colmap-cuda] Preparing to unpack .../54-libcharls2_2.3.4-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libcharls2:amd64 (2.3.4-1) ...
# [build-colmap-cuda] Selecting previously unselected package libdcmtk16.
# [build-colmap-cuda] Preparing to unpack .../55-libdcmtk16_3.6.6-5_amd64.deb ...
# [build-colmap-cuda] Unpacking libdcmtk16 (3.6.6-5) ...
# [build-colmap-cuda] Selecting previously unselected package libglx-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../56-libglx-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglx-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../57-libgl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libegl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../58-libegl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libegl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libexif12:amd64.
# [build-colmap-cuda] Preparing to unpack .../59-libexif12_0.6.24-1ubuntu0.22.04.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libexif12:amd64 (0.6.24-1ubuntu0.22.04.1) ...
# [build-colmap-cuda] Selecting previously unselected package libsocket++1:amd64.
# [build-colmap-cuda] Preparing to unpack .../60-libsocket++1_1.12.13+git20131030.5d039ba-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsocket++1:amd64 (1.12.13+git20131030.5d039ba-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgdcm3.0:amd64.
# [build-colmap-cuda] Preparing to unpack .../61-libgdcm3.0_3.0.10-1build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgdcm3.0:amd64 (3.0.10-1build2) ...
# [build-colmap-cuda] Selecting previously unselected package libgles1:amd64.
# [build-colmap-cuda] Preparing to unpack .../62-libgles1_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgles1:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgles-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../63-libgles-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgles-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglvnd-core-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../64-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopengl-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../65-libopengl-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglvnd-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../66-libglvnd-dev_1.4.0-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# [build-colmap-cuda] Selecting previously unselected package libgl1-mesa-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../67-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.4_amd64.deb ...
# [build-colmap-cuda] Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.4) ...
# [build-colmap-cuda] Selecting previously unselected package libglu1-mesa:amd64.
# [build-colmap-cuda] Preparing to unpack .../68-libglu1-mesa_9.0.2-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglu1-mesa-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../69-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# [build-colmap-cuda] Selecting previously unselected package libglew-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../70-libglew-dev_2.2.0-4_amd64.deb ...
# [build-colmap-cuda] Unpacking libglew-dev:amd64 (2.2.0-4) ...
# [build-colmap-cuda] Selecting previously unselected package libgtest-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../71-libgtest-dev_1.11.0-3_amd64.deb ...
# [build-colmap-cuda] Unpacking libgtest-dev:amd64 (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libgmock-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../72-libgmock-dev_1.11.0-3_amd64.deb ...
# [build-colmap-cuda] Unpacking libgmock-dev:amd64 (1.11.0-3) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-port12:amd64.
# [build-colmap-cuda] Preparing to unpack .../73-libgphoto2-port12_2.5.27-1ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-port12:amd64 (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-6:amd64.
# [build-colmap-cuda] Preparing to unpack .../74-libgphoto2-6_2.5.27-1ubuntu0.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-6:amd64 (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgphoto2-l10n.
# [build-colmap-cuda] Preparing to unpack .../75-libgphoto2-l10n_2.5.27-1ubuntu0.1_all.deb ...
# [build-colmap-cuda] Unpacking libgphoto2-l10n (2.5.27-1ubuntu0.1) ...
# [build-colmap-cuda] Selecting previously unselected package libgraphblas6:amd64.
# [build-colmap-cuda] Preparing to unpack .../76-libgraphblas6_6.1.4+dfsg-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgraphblas6:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Selecting previously unselected package libgraphblas-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../77-libgraphblas-dev_6.1.4+dfsg-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libgraphblas-dev:amd64 (6.1.4+dfsg-2) ...
# [build-colmap-cuda] Selecting previously unselected package libilmbase-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../78-libilmbase-dev_2.5.7-2_amd64.deb ...
# [build-colmap-cuda] Unpacking libilmbase-dev:amd64 (2.5.7-2) ...
# [build-colmap-cuda] Selecting previously unselected package liblog4cplus-2.0.5:amd64.
# [build-colmap-cuda] Preparing to unpack .../79-liblog4cplus-2.0.5_2.0.5-3_amd64.deb ...
# [build-colmap-cuda] Unpacking liblog4cplus-2.0.5:amd64 (2.0.5-3) ...
# [build-colmap-cuda] Selecting previously unselected package libmetis-dev.
# [build-colmap-cuda] Preparing to unpack .../80-libmetis-dev_5.1.0.dfsg-7build2_amd64.deb ...
# [build-colmap-cuda] Unpacking libmetis-dev (5.1.0.dfsg-7build2) ...
# [build-colmap-cuda] Selecting previously unselected package libtinyxml2.6.2v5:amd64.
# [build-colmap-cuda] Preparing to unpack .../81-libtinyxml2.6.2v5_2.6.2-6ubuntu0.22.04.1_amd64.deb ...
# [build-colmap-cuda] Unpacking libtinyxml2.6.2v5:amd64 (2.6.2-6ubuntu0.22.04.1) ...
# [build-colmap-cuda] Selecting previously unselected package libyaml-cpp0.7:amd64.
# [build-colmap-cuda] Preparing to unpack .../82-libyaml-cpp0.7_0.7.0+dfsg-8build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libyaml-cpp0.7:amd64 (0.7.0+dfsg-8build1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencolorio1v5.
# [build-colmap-cuda] Preparing to unpack .../83-libopencolorio1v5_1.1.1~dfsg0-7.1build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencolorio1v5 (1.1.1~dfsg0-7.1build1) ...
# [build-colmap-cuda] Selecting previously unselected package libtbbmalloc2:amd64.
# [build-colmap-cuda] Preparing to unpack .../84-libtbbmalloc2_2021.5.0-7ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbbmalloc2:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libtbb12:amd64.
# [build-colmap-cuda] Preparing to unpack .../85-libtbb12_2021.5.0-7ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbb12:amd64 (2021.5.0-7ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-core4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../86-libopencv-core4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-core4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-imgproc4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../87-libopencv-imgproc4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-imgproc4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-imgcodecs4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../88-libopencv-imgcodecs4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-imgcodecs4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopencv-videoio4.5d:amd64.
# [build-colmap-cuda] Preparing to unpack .../89-libopencv-videoio4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopencv-videoio4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenexr-dev.
# [build-colmap-cuda] Preparing to unpack .../90-libopenexr-dev_2.5.7-1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenexr-dev (2.5.7-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio-doc.
# [build-colmap-cuda] Preparing to unpack .../91-libopenimageio-doc_2.2.18.0+dfsg-1ubuntu2_all.deb ...
# [build-colmap-cuda] Unpacking libopenimageio-doc (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package libtbb2:amd64.
# [build-colmap-cuda] Preparing to unpack .../92-libtbb2_2020.3-1ubuntu3_amd64.deb ...
# [build-colmap-cuda] Unpacking libtbb2:amd64 (2020.3-1ubuntu3) ...
# [build-colmap-cuda] Selecting previously unselected package libopenvdb8.1.
# [build-colmap-cuda] Preparing to unpack .../93-libopenvdb8.1_8.1.0-3build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenvdb8.1 (8.1.0-3build1) ...
# [build-colmap-cuda] Selecting previously unselected package libsquish0:amd64.
# [build-colmap-cuda] Preparing to unpack .../94-libsquish0_1.15-1build1_amd64.deb ...
# [build-colmap-cuda] Unpacking libsquish0:amd64 (1.15-1build1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio2.2:amd64.
# [build-colmap-cuda] Preparing to unpack .../95-libopenimageio2.2_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenimageio2.2:amd64 (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package ninja-build.
# [build-colmap-cuda] Preparing to unpack .../96-ninja-build_1.10.1-1_amd64.deb ...
# [build-colmap-cuda] Unpacking ninja-build (1.10.1-1) ...
# [build-colmap-cuda] Selecting previously unselected package libopenimageio-dev:amd64.
# [build-colmap-cuda] Preparing to unpack .../97-libopenimageio-dev_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking libopenimageio-dev:amd64 (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Selecting previously unselected package openimageio-tools.
# [build-colmap-cuda] Preparing to unpack .../98-openimageio-tools_2.2.18.0+dfsg-1ubuntu2_amd64.deb ...
# [build-colmap-cuda] Unpacking openimageio-tools (2.2.18.0+dfsg-1ubuntu2) ...
# [build-colmap-cuda] Setting up libboost-chrono1.74.0:amd64 (1.74.0-14ubuntu3) ...
# ...
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/VLFeat/scalespace.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Factor.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Array.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PlyFile.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrixInterface.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MarchingCubes.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartition.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonReconClientServer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrixInterface.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MergePlyClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/ParameterPack.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BinaryNode.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Geometry.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PlyFile.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.client.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularTree.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BlockedVector.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Window.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyExceptions.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Reconstructors.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/CmdLineParser.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyAtomic.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PNG.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularGrid.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PPolynomial.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularTree.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MyMiscellany.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Extrapolator.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Allocator.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PPolynomial.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Rasterizer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonReconClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/JPEG.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.WeightedSamples.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Reconstructors.streams.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/VertexFactory.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Rasterizer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Image.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrix.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.2D.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.System.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MAT.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.server.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.imp.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/RegularGrid.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/LinearSolvers.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PoissonRecon.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Ply.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MAT.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Socket.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.Initialize.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Geometry.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartitionClientServer.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Socket.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/VertexFactory.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/CmdLineParser.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SparseMatrix.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartition.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/DataStream.imp.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MergePlyClientServer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Window.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointExtent.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PNG.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PreProcessor.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Array.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointPartitionClientServer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Polynomial.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Polynomial.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BSplineData.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/SurfaceTrimmer.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Ply.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/MultiThreading.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/JPEG.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.Evaluation.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/NestedVector.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.SortedTreeNodes.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/BSplineData.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/FEMTree.LevelSet.3D.inl
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/Streams.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/include/colmap/thirdparty/PoissonRecon/PointExtent.h
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindGlew.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindDependencies.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindGlog.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindMetis.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindCHOLMOD.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/Findonnxruntime.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/share/colmap/cmake/FindCryptoPP.cmake
# [build-colmap-cuda] -- Installing: /content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda] -- Set non-toolchain portion of runtime path of "/content/project/.local/colmap-cuda/bin/colmap" to "$ORIGIN/../lib"
# [build-colmap-cuda] COLMAP 4.2.0.dev0 (Commit fff58c7 on 2026-07-23 with CUDA)
# [build-colmap-cuda] Usage:
# [build-colmap-cuda]   colmap [command] [options]
# [build-colmap-cuda] Documentation:
# [build-colmap-cuda]   https://colmap.github.io/
# [build-colmap-cuda] Example usage:
# [build-colmap-cuda]   colmap help [ -h, --help ]
# [build-colmap-cuda]   colmap gui
# [build-colmap-cuda]   colmap gui -h [ --help ]
# [build-colmap-cuda]   colmap automatic_reconstructor -h [ --help ]
# [build-colmap-cuda]   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
# [build-colmap-cuda]   colmap feature_extractor --image_path IMAGES --database_path DATABASE
# [build-colmap-cuda]   colmap exhaustive_matcher --database_path DATABASE
# [build-colmap-cuda]   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
# [build-colmap-cuda]   ...
# [build-colmap-cuda] Available commands:
# [build-colmap-cuda]   help
# [build-colmap-cuda]   version
# [build-colmap-cuda]   gui
# [build-colmap-cuda]   automatic_reconstructor
# [build-colmap-cuda]   bundle_adjuster
# [build-colmap-cuda]   color_extractor
# [build-colmap-cuda]   database_cleaner
# [build-colmap-cuda]   database_creator
# [build-colmap-cuda]   database_merger
# [build-colmap-cuda]   advancing_front_mesher
# [build-colmap-cuda]   delaunay_mesher
# [build-colmap-cuda]   exhaustive_matcher
# [build-colmap-cuda]   feature_extractor
# [build-colmap-cuda]   feature_importer
# [build-colmap-cuda]   geometric_verifier
# [build-colmap-cuda]   global_mapper
# [build-colmap-cuda]   guided_geometric_verifier
# [build-colmap-cuda]   hierarchical_mapper
# [build-colmap-cuda]   image_deleter
# [build-colmap-cuda]   image_filterer
# [build-colmap-cuda]   image_rectifier
# [build-colmap-cuda]   image_registrator
# [build-colmap-cuda]   image_undistorter
# [build-colmap-cuda]   image_undistorter_standalone
# [build-colmap-cuda]   mapper
# [build-colmap-cuda]   matches_importer
# [build-colmap-cuda]   mesh_simplifier
# [build-colmap-cuda]   mesh_texturer
# [build-colmap-cuda]   model_aligner
# [build-colmap-cuda]   model_analyzer
# [build-colmap-cuda]   model_clusterer
# [build-colmap-cuda]   model_comparer
# [build-colmap-cuda]   model_converter
# [build-colmap-cuda]   model_cropper
# [build-colmap-cuda]   model_merger
# [build-colmap-cuda]   model_orientation_aligner
# [build-colmap-cuda]   model_splitter
# [build-colmap-cuda]   model_transformer
# [build-colmap-cuda]   patch_match_stereo
# [build-colmap-cuda]   point_filtering
# [build-colmap-cuda]   point_triangulator
# [build-colmap-cuda]   pose_prior_mapper
# [build-colmap-cuda]   poisson_mesher
# [build-colmap-cuda]   project_generator
# [build-colmap-cuda]   rig_configurator
# [build-colmap-cuda]   rotation_averager
# [build-colmap-cuda]   sequential_matcher
# [build-colmap-cuda]   spatial_matcher
# [build-colmap-cuda]   stereo_fusion
# [build-colmap-cuda]   transitive_matcher
# [build-colmap-cuda]   view_graph_calibrator
# [build-colmap-cuda]   vocab_tree_builder
# [build-colmap-cuda]   vocab_tree_matcher
# [build-colmap-cuda]   vocab_tree_retriever
# [build-colmap-cuda]
# [build-colmap-cuda] COLMAP CUDA build hoàn tất.
# [build-colmap-cuda] COLMAP_BIN=/content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda] Ví dụ chạy B2:
# [build-colmap-cuda]   export COLMAP_BIN=/content/project/.local/colmap-cuda/bin/colmap
# [build-colmap-cuda]   bash pipeline/scripts/05_run_b2_pilot.sh hcm0031
# [build-colmap-cuda] RETURN CODE = 0
# COLMAP 4.2.0.dev0 (Commit fff58c7 on 2026-07-23 with CUDA)
# Usage:
#   colmap [command] [options]
# Documentation:
#   https://colmap.github.io/
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
# Available commands:
#   help
#   version
#   gui
#   automatic_reconstructor
#
#
# COLMAP CUDA verify PASS
# COLMAP_BIN se dung cho B2 = /content/project/.local/colmap-cuda/bin/colmap

# %% [markdown]
# Cell tren la mau dung cho Colab/Kaggle: neu `colmap` cai san la CPU-only thi no se build `COLMAP` co CUDA, verify lai, roi luu duong dan vao bien `colmap_bin_for_b2` de cell chay `B2` ben duoi dung thang binary moi.

# %%
import os
assert colmap_bin_for_b2, 'COLMAP_BIN cho B2 dang rong. Hay chay cell verify/build COLMAP truoc.'
os.environ['COLMAP_BIN'] = colmap_bin_for_b2
print('Exported COLMAP_BIN =', os.environ['COLMAP_BIN'])
# Out:
# Exported COLMAP_BIN = /content/project/.local/colmap-cuda/bin/colmap

# %%
import os
import re
import subprocess
from pathlib import Path

downloads_dir = Path(WORKDIR) / 'downloads'
downloads_dir.mkdir(parents=True, exist_ok=True)

if DATASET_URL:
    archive_path = downloads_dir / 'dataset_round1.zip'
    if 'drive.google.com' in DATASET_URL:
        subprocess.run(['python3', '-m', 'pip', 'install', 'gdown'], check=True)
        m = re.search(r'/d/([^/]+)', DATASET_URL)
        file_id = m.group(1) if m else ''
        assert file_id, 'Khong trich duoc file id tu Google Drive link'
        subprocess.run(['gdown', '--fuzzy', f'https://drive.google.com/uc?id={file_id}', '-O', str(archive_path)], check=True)
    else:
        subprocess.run(['bash', '-lc', f'wget -O "{archive_path}" "{DATASET_URL}"'], check=True)
    raw_dir = Path(WORKDIR) / '_dataset_round1_raw'
    subprocess.run(['bash', '-lc', f'rm -rf "{raw_dir}" && mkdir -p "{raw_dir}" && unzip -q "{archive_path}" -d "{raw_dir}"'], check=True)
    print('Da tai va giai nen dataset tu DATASET_URL ->', raw_dir)
elif KAGGLE_DATASET:
    if KAGGLE_USERNAME and KAGGLE_KEY:
        kaggle_dir = Path.home() / '.kaggle'
        kaggle_dir.mkdir(parents=True, exist_ok=True)
        (kaggle_dir / 'kaggle.json').write_text('{"username":"' + KAGGLE_USERNAME + '","key":"' + KAGGLE_KEY + '"}', encoding='utf-8')
        os.chmod(kaggle_dir / 'kaggle.json', 0o600)
    subprocess.run(['python3', '-m', 'pip', 'install', 'kaggle'], check=True)
    archive_path = downloads_dir / 'dataset_round1.zip'
    subprocess.run(['bash', '-lc', f'kaggle datasets download -d "{KAGGLE_DATASET}" -p "{downloads_dir}" -f "{archive_path.name}" || kaggle datasets download -d "{KAGGLE_DATASET}" -p "{downloads_dir}"'], check=True)
    if not archive_path.exists():
        zips = sorted(downloads_dir.glob('*.zip'))
        assert zips, 'Kaggle download xong nhung khong thay file zip'
        archive_path = zips[0]
    raw_dir = Path(WORKDIR) / '_dataset_round1_raw'
    subprocess.run(['bash', '-lc', f'rm -rf "{raw_dir}" && mkdir -p "{raw_dir}" && unzip -q "{archive_path}" -d "{raw_dir}"'], check=True)
    print('Da tai va giai nen dataset tu KAGGLE_DATASET ->', raw_dir)
else:
    print('Khong co DATASET_URL/KAGGLE_DATASET. Notebook se thu tu do dataset san co.')
# Out:
# Da tai va giai nen dataset tu DATASET_URL -> /content/_dataset_round1_raw

# %%
from pathlib import Path

expected_scene = SCENE
dataset_root = None

if DATASET_ROOT_OVERRIDE:
    p = Path(DATASET_ROOT_OVERRIDE)
    if (p / expected_scene / 'train' / 'images').is_dir() and (p / expected_scene / 'test' / 'images').is_dir():
        dataset_root = p

workdir_path = Path(WORKDIR)
candidates = [
    workdir_path / '_dataset_round1_raw',
    workdir_path / 'project' / 'Dataset' / 'VAI_NVS_DATA' / 'phase1' / 'public_set',
    workdir_path,
    Path('/kaggle/input'),
]

if dataset_root is None:
    for base in candidates:
        if not base.exists():
            continue
        if base.name == 'public_set' and (base / expected_scene / 'train' / 'images').is_dir():
            dataset_root = base
            break
        for p in base.rglob('public_set'):
            if (p / expected_scene / 'train' / 'images').is_dir() and (p / expected_scene / 'test' / 'images').is_dir():
                dataset_root = p
                break
        if dataset_root is not None:
            break

assert dataset_root is not None, 'Khong tim thay Dataset/VAI_NVS_DATA/phase1/public_set co scene hcm0031'
print('DATASET_ROOT =', dataset_root)
# Out:
# DATASET_ROOT = /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set

# %%
import shutil
import subprocess
from pathlib import Path

need_gs_repo = RUN_TRAIN == '1' or RUN_RENDER == '1' or RUN_EVAL == '1'
GS_REPO_URL = "https://github.com/graphdeco-inria/gaussian-splatting.git"
GS_REPO_BRANCH = "main"

gs_repo = ''

if need_gs_repo:
    assert GS_REPO_URL, 'Can GS_REPO_URL neu RUN_TRAIN=1 hoac RUN_RENDER=1 hoac RUN_EVAL=1'
    gs_clone_url = GS_REPO_URL
    if GITHUB_TOKEN and 'github.com' in GS_REPO_URL:
        gs_clone_url = GS_REPO_URL.replace('https://', f'https://{GITHUB_TOKEN}@')
    gs_repo_dir = Path(WORKDIR) / 'gs_repo'
    if gs_repo_dir.exists():
        shutil.rmtree(gs_repo_dir)
    subprocess.run([
        'git', 'clone', '--depth', '1', '-b', GS_REPO_BRANCH, gs_clone_url, str(gs_repo_dir)
    ], check=True)
    gs_repo = str(gs_repo_dir)
    print('GS_REPO =', gs_repo)
else:
    print('Khong can GS_REPO cho dense-only pilot')
# Out:
# Khong can GS_REPO cho dense-only pilot

# %%
# ==============================================
# CELL X - Patch train script for extra GS args
# ==============================================
from pathlib import Path

project_dir = Path(WORKDIR) / 'project'
train_script = project_dir / 'pipeline' / 'scripts' / '03_train_3dgs.sh'
text = train_script.read_text(encoding='utf-8')

if 'TRAIN_EXTRA_ARGS_RAW="${TRAIN_EXTRA_ARGS_RAW:-}"' not in text:
    text = text.replace(
        'CHECKPOINT_ITERATIONS_OVERRIDE="${CHECKPOINT_ITERATIONS_OVERRIDE:-}"\n',
        'CHECKPOINT_ITERATIONS_OVERRIDE="${CHECKPOINT_ITERATIONS_OVERRIDE:-}"\n'
        'TRAIN_EXTRA_ARGS_RAW="${TRAIN_EXTRA_ARGS_RAW:-}"\n',
        1,
    )

if 'read -r -a TRAIN_EXTRA_ARGS' not in text:
    text = text.replace(
        'EXTRA_ARGS=()\n',
        'TRAIN_EXTRA_ARGS=()\n'
        'if [[ -n "$TRAIN_EXTRA_ARGS_RAW" ]]; then\n'
        '  read -r -a TRAIN_EXTRA_ARGS <<< "$TRAIN_EXTRA_ARGS_RAW"\n'
        'fi\n\n'
        'EXTRA_ARGS=()\n',
        1,
    )

if '"${TRAIN_EXTRA_ARGS[@]}" \\' not in text:
    text = text.replace(
        '  --resolution "$RESOLUTION" \\\n'
        '  "${EXTRA_ARGS[@]}" \\\n',
        '  --resolution "$RESOLUTION" \\\n'
        '  "${TRAIN_EXTRA_ARGS[@]}" \\\n'
        '  "${EXTRA_ARGS[@]}" \\\n',
        1,
    )

train_script.write_text(text, encoding='utf-8')
print('Patched train script for TRAIN_EXTRA_ARGS_RAW:', train_script)

# %%
# =====================================================
# CELL X - Configure depth supervision / train profile
# =====================================================
from pathlib import Path

ENABLE_DEPTH_SUPERVISION = True
DISABLE_LOW_VRAM_PROFILE = True
SAFE_DENSIFY_OVERRIDE = False

project_dir = Path(WORKDIR) / 'project'
scene_root = project_dir / 'pipeline' / 'work' / SCENE
depth_maps_dir = scene_root / 'colmap' / 'dense' / 'stereo' / 'depth_maps'

extra_train_env = {}
if gs_repo:
    gs_repo_path = Path(gs_repo)
    support_files = [
        gs_repo_path / 'train.py',
        gs_repo_path / 'arguments' / '__init__.py',
        gs_repo_path / 'scene' / '__init__.py',
    ]
    support_text = '\n'.join(
        p.read_text(encoding='utf-8', errors='ignore')
        for p in support_files
        if p.exists()
    )
    if 'depths' not in support_text:
        raise SystemExit(
            'GS_REPO clone hien tai khong lo ro support --depths; notebook nay dung de bat depth supervision that nen se dung som.'
        )
    if ENABLE_DEPTH_SUPERVISION:
        assert depth_maps_dir.exists(), f'Khong thay depth_maps: {depth_maps_dir}'
        extra_train_env['TRAIN_EXTRA_ARGS_RAW'] = f'--depths {depth_maps_dir}'
        print('Depth supervision args =', extra_train_env['TRAIN_EXTRA_ARGS_RAW'])
    if DISABLE_LOW_VRAM_PROFILE:
        extra_train_env['LOW_VRAM_PROFILE'] = '0'
        print('LOW_VRAM_PROFILE override = 0')
    elif SAFE_DENSIFY_OVERRIDE:
        extra_train_env['LOW_VRAM_PROFILE'] = '1'
        extra_train_env['DENSIFY_UNTIL_ITER'] = '15000'
        extra_train_env['DENSIFY_FROM_ITER'] = '500'
        extra_train_env['DENSIFICATION_INTERVAL'] = '100'
        extra_train_env['PERCENT_DENSE'] = '0.01'
        extra_train_env['OPACITY_RESET_INTERVAL'] = '3000'
        print('SAFE densify overrides =', {
            k: extra_train_env[k]
            for k in [
                'LOW_VRAM_PROFILE',
                'DENSIFY_UNTIL_ITER',
                'DENSIFY_FROM_ITER',
                'DENSIFICATION_INTERVAL',
                'PERCENT_DENSE',
                'OPACITY_RESET_INTERVAL',
            ]
        })
else:
    print('gs_repo rong, se bo qua config depth/train cho den khi clone GS repo.')

extra_train_env

# %%
import os
from pathlib import Path

env = os.environ.copy()
env['DATASET_ROOT'] = str(dataset_root)
env['COLMAP_BIN'] = colmap_bin_for_b2
env['RUN_DENSE'] = RUN_DENSE
env['RUN_TRAIN'] = RUN_TRAIN
env['RUN_RENDER'] = RUN_RENDER
env['RUN_EVAL'] = RUN_EVAL
env['PATCH_MATCH_MAX_IMAGE_SIZE'] = PATCH_MATCH_MAX_IMAGE_SIZE
env['PATCH_MATCH_GPU_INDEX'] = PATCH_MATCH_GPU_INDEX
env['PATCH_MATCH_CACHE_SIZE'] = PATCH_MATCH_CACHE_SIZE
if gs_repo:
    env['GS_REPO'] = gs_repo
env.update(extra_train_env)

scene_root = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
log_dir = scene_root / 'logs'
log_files = [
    log_dir / '04_patch_match_stereo.log',
    log_dir / '04_stereo_fusion.log',
    log_dir / '04_colmap_dense_summary.txt',
    log_dir / '05_b2_pilot_summary.txt',
]
if RUN_TRAIN == '1':
    log_files.append(scene_root / 'train.log')
if RUN_RENDER == '1':
    log_files.append(log_dir / '05_render_b2_pilot.log')
if RUN_EVAL == '1':
    log_files.append(log_dir / '05_eval_b2_pilot.log')

run_and_stream(
    ['bash', f'{WORKDIR}/project/pipeline/scripts/05_run_b2_pilot.sh', SCENE],
    env=env,
    log_files=log_files,
    poll_seconds=15,
    label='b2-pilot',
)
print('B2 pilot done')
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# I0723 15:35:13.988269 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:35:13.988271 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:35:13.988274 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:35:13.988277 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:35:13.988281 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:35:13.988282 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:35:13.988286 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:35:13.988288 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:35:13.988291 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:35:13.988293 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:35:13.988296 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:35:13.988299 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:35:13.988301 18817 patch_match_options.cc:63] filter: 1
# I0723 15:35:13.988304 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:35:13.988307 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:35:13.988310 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:35:13.988312 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:35:13.988315 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:35:13.988317 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:35:13.988319 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:35:13.988322 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:35:14.250365 18817 cudacc.cc:51] Initialization: 0.1158s
# I0723 15:35:15.072549 18817 cudacc.cc:51]  Sweep 1: 0.8221s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:16.109902 18817 cudacc.cc:51]  Sweep 2: 1.0373s
# I0723 15:35:16.913367 18817 cudacc.cc:51]  Sweep 3: 0.8034s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:17.912081 18817 cudacc.cc:51]  Sweep 4: 0.9987s
# I0723 15:35:17.912133 18817 cudacc.cc:51] Iteration 1: 3.6617s
# I0723 15:35:18.688155 18817 cudacc.cc:51]  Sweep 1: 0.7760s
# I0723 15:35:19.665534 18817 cudacc.cc:51]  Sweep 2: 0.9773s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:20.421782 18817 cudacc.cc:51]  Sweep 3: 0.7562s
# I0723 15:35:21.369165 18817 cudacc.cc:51]  Sweep 4: 0.9473s
# I0723 15:35:21.369232 18817 cudacc.cc:51] Iteration 2: 3.4571s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:22.114780 18817 cudacc.cc:51]  Sweep 1: 0.7455s
# I0723 15:35:23.051306 18817 cudacc.cc:51]  Sweep 2: 0.9365s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:23.779134 18817 cudacc.cc:51]  Sweep 3: 0.7277s
# I0723 15:35:24.689654 18817 cudacc.cc:51]  Sweep 4: 0.9104s
# I0723 15:35:24.689721 18817 cudacc.cc:51] Iteration 3: 3.3205s
# I0723 15:35:25.409857 18817 cudacc.cc:51]  Sweep 1: 0.7201s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:26.310396 18817 cudacc.cc:51]  Sweep 2: 0.9005s
# I0723 15:35:27.017525 18817 cudacc.cc:51]  Sweep 3: 0.7071s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:27.894025 18817 cudacc.cc:51]  Sweep 4: 0.8764s
# I0723 15:35:27.894078 18817 cudacc.cc:51] Iteration 4: 3.2044s
# I0723 15:35:28.600940 18817 cudacc.cc:51]  Sweep 1: 0.7068s
# I0723 15:35:29.471601 18817 cudacc.cc:51]  Sweep 2: 0.8706s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:30.171329 18817 cudacc.cc:51]  Sweep 3: 0.6996s
# I0723 15:35:30.962244 18817 cudacc.cc:51]  Sweep 4: 0.7908s
# I0723 15:35:30.962301 18817 cudacc.cc:51] Iteration 5: 3.0682s
# I0723 15:35:30.962314 18817 cudacc.cc:51] Total: 16.8280s
# I0723 15:35:30.962321 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160002_0289_V.JPG
# I0723 15:35:31.118749 18817 patch_match.cc:416] === Processing view 163 / 200 for DJI_20241227160005_0292_V.JPG ===
# I0723 15:35:31.118928 18817 patch_match.cc:466] Reading inputs...
# I0723 15:35:31.205654 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:35:31.205696 18817 patch_match.cc:57] ref_image_idx: 162
# I0723 15:35:31.205704 18817 patch_match.cc:64] src_image_idxs: 134 157 182 153 143 146 159 137 189 190 142 145 158 169 139 141 180 164 193 135
# I0723 15:35:31.205708 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:35:31.205710 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:35:31.205713 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:35:31.205716 18817 patch_match_options.cc:49] depth_min: 5.19088
# I0723 15:35:31.205729 18817 patch_match_options.cc:50] depth_max: 19.9373
# I0723 15:35:31.205734 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:35:31.205735 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:35:31.205739 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:35:31.205741 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:35:31.205744 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:35:31.205746 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:35:31.205749 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:35:31.205752 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:35:31.205755 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:35:31.205757 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:35:31.205760 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:35:31.205762 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:35:31.205765 18817 patch_match_options.cc:63] filter: 1
# I0723 15:35:31.205767 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:35:31.205770 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:35:31.205773 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:35:31.205776 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:35:31.205778 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:35:31.205781 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:35:31.205783 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:35:31.205785 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:35:31.463196 18817 cudacc.cc:51] Initialization: 0.1193s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:32.302350 18817 cudacc.cc:51]  Sweep 1: 0.8391s
# I0723 15:35:33.347142 18817 cudacc.cc:51]  Sweep 2: 1.0447s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:34.163017 18817 cudacc.cc:51]  Sweep 3: 0.8158s
# I0723 15:35:35.176815 18817 cudacc.cc:51]  Sweep 4: 1.0137s
# I0723 15:35:35.176987 18817 cudacc.cc:51] Iteration 1: 3.7138s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:35.960888 18817 cudacc.cc:51]  Sweep 1: 0.7838s
# I0723 15:35:36.942826 18817 cudacc.cc:51]  Sweep 2: 0.9818s
# I0723 15:35:37.713195 18817 cudacc.cc:51]  Sweep 3: 0.7703s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:38.674698 18817 cudacc.cc:51]  Sweep 4: 0.9614s
# I0723 15:35:38.674754 18817 cudacc.cc:51] Iteration 2: 3.4977s
# I0723 15:35:39.428643 18817 cudacc.cc:51]  Sweep 1: 0.7539s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:40.368527 18817 cudacc.cc:51]  Sweep 2: 0.9398s
# I0723 15:35:41.109052 18817 cudacc.cc:51]  Sweep 3: 0.7404s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:42.032948 18817 cudacc.cc:51]  Sweep 4: 0.9238s
# I0723 15:35:42.033005 18817 cudacc.cc:51] Iteration 3: 3.3583s
# I0723 15:35:42.764664 18817 cudacc.cc:51]  Sweep 1: 0.7316s
# I0723 15:35:43.670397 18817 cudacc.cc:51]  Sweep 2: 0.9057s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:44.393052 18817 cudacc.cc:51]  Sweep 3: 0.7226s
# I0723 15:35:45.287585 18817 cudacc.cc:51]  Sweep 4: 0.8945s
# I0723 15:35:45.287652 18817 cudacc.cc:51] Iteration 4: 3.2547s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:46.007498 18817 cudacc.cc:51]  Sweep 1: 0.7198s
# I0723 15:35:46.884074 18817 cudacc.cc:51]  Sweep 2: 0.8765s
# I0723 15:35:47.593669 18817 cudacc.cc:51]  Sweep 3: 0.7095s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:48.398022 18817 cudacc.cc:51]  Sweep 4: 0.8043s
# I0723 15:35:48.398087 18817 cudacc.cc:51] Iteration 5: 3.1104s
# I0723 15:35:48.398102 18817 cudacc.cc:51] Total: 17.0544s
# I0723 15:35:48.398113 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160005_0292_V.JPG
# I0723 15:35:48.632067 18817 patch_match.cc:416] === Processing view 164 / 200 for DJI_20241227160008_0295_V.JPG ===
# I0723 15:35:48.632331 18817 patch_match.cc:466] Reading inputs...
# I0723 15:35:48.724918 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:35:48.724961 18817 patch_match.cc:57] ref_image_idx: 163
# I0723 15:35:48.724972 18817 patch_match.cc:64] src_image_idxs: 165 136 138 183 144 187 181 182 169 191 159 188 148 147 186 160 174 145 171 142
# I0723 15:35:48.724978 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:35:48.724982 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:35:48.724985 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:35:48.724989 18817 patch_match_options.cc:49] depth_min: 4.97589
# I0723 15:35:48.725003 18817 patch_match_options.cc:50] depth_max: 19.5338
# I0723 15:35:48.725009 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:35:48.725013 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:35:48.725016 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:35:48.725020 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:35:48.725025 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:35:48.725028 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:35:48.725033 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:35:48.725037 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:35:48.725041 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:35:48.725044 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:35:48.725049 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:35:48.725052 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:35:48.725056 18817 patch_match_options.cc:63] filter: 1
# I0723 15:35:48.725060 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:35:48.725064 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:35:48.725068 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:35:48.725071 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:35:48.725075 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:35:48.725080 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:35:48.725082 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:35:48.725086 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:35:49.019485 18817 cudacc.cc:51] Initialization: 0.1223s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:49.851084 18817 cudacc.cc:51]  Sweep 1: 0.8315s
# I0723 15:35:50.895304 18817 cudacc.cc:51]  Sweep 2: 1.0442s
# I0723 15:35:51.707662 18817 cudacc.cc:51]  Sweep 3: 0.8123s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:52.719084 18817 cudacc.cc:51]  Sweep 4: 1.0114s
# I0723 15:35:52.719177 18817 cudacc.cc:51] Iteration 1: 3.6997s
# I0723 15:35:53.493531 18817 cudacc.cc:51]  Sweep 1: 0.7743s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:54.472568 18817 cudacc.cc:51]  Sweep 2: 0.9790s
# I0723 15:35:55.240077 18817 cudacc.cc:51]  Sweep 3: 0.7674s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:56.196816 18817 cudacc.cc:51]  Sweep 4: 0.9567s
# I0723 15:35:56.196875 18817 cudacc.cc:51] Iteration 2: 3.4777s
# I0723 15:35:56.937130 18817 cudacc.cc:51]  Sweep 1: 0.7402s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:35:57.873770 18817 cudacc.cc:51]  Sweep 2: 0.9366s
# I0723 15:35:58.613445 18817 cudacc.cc:51]  Sweep 3: 0.7396s
# I0723 15:35:59.531728 18817 cudacc.cc:51]  Sweep 4: 0.9182s
# I0723 15:35:59.531798 18817 cudacc.cc:51] Iteration 3: 3.3349s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:00.250808 18817 cudacc.cc:51]  Sweep 1: 0.7190s
# I0723 15:36:01.150699 18817 cudacc.cc:51]  Sweep 2: 0.8998s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:01.876919 18817 cudacc.cc:51]  Sweep 3: 0.7261s
# I0723 15:36:02.761684 18817 cudacc.cc:51]  Sweep 4: 0.8847s
# I0723 15:36:02.761754 18817 cudacc.cc:51] Iteration 4: 3.2300s
# I0723 15:36:03.466804 18817 cudacc.cc:51]  Sweep 1: 0.7050s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:04.334641 18817 cudacc.cc:51]  Sweep 2: 0.8678s
# I0723 15:36:05.043200 18817 cudacc.cc:51]  Sweep 3: 0.7085s
# I0723 15:36:05.839358 18817 cudacc.cc:51]  Sweep 4: 0.7961s
# I0723 15:36:05.839412 18817 cudacc.cc:51] Iteration 5: 3.0777s
# I0723 15:36:05.839426 18817 cudacc.cc:51] Total: 16.9424s
# I0723 15:36:05.839433 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160008_0295_V.JPG
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:06.026850 18817 patch_match.cc:416] === Processing view 165 / 200 for DJI_20241227160004_0291_V.JPG ===
# I0723 15:36:06.027022 18817 patch_match.cc:466] Reading inputs...
# I0723 15:36:06.115065 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:36:06.115121 18817 patch_match.cc:57] ref_image_idx: 164
# I0723 15:36:06.115130 18817 patch_match.cc:64] src_image_idxs: 189 140 153 197 139 158 159 134 9 154 141 180 179 143 157 162 193 135 190 161
# I0723 15:36:06.115134 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:36:06.115137 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:36:06.115140 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:36:06.115144 18817 patch_match_options.cc:49] depth_min: 5.12439
# I0723 15:36:06.115154 18817 patch_match_options.cc:50] depth_max: 20.4716
# I0723 15:36:06.115159 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:36:06.115162 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:36:06.115164 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:36:06.115168 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:36:06.115172 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:36:06.115176 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:36:06.115181 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:36:06.115185 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:36:06.115187 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:36:06.115190 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:36:06.115193 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:36:06.115196 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:36:06.115199 18817 patch_match_options.cc:63] filter: 1
# I0723 15:36:06.115202 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:36:06.115206 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:36:06.115208 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:36:06.115211 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:36:06.115214 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:36:06.115216 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:36:06.115219 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:36:06.115222 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:36:06.378192 18817 cudacc.cc:51] Initialization: 0.1247s
# I0723 15:36:07.217891 18817 cudacc.cc:51]  Sweep 1: 0.8396s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:08.266561 18817 cudacc.cc:51]  Sweep 2: 1.0486s
# I0723 15:36:09.085822 18817 cudacc.cc:51]  Sweep 3: 0.8192s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:10.098760 18817 cudacc.cc:51]  Sweep 4: 1.0129s
# I0723 15:36:10.098856 18817 cudacc.cc:51] Iteration 1: 3.7206s
# I0723 15:36:10.875667 18817 cudacc.cc:51]  Sweep 1: 0.7768s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:11.865312 18817 cudacc.cc:51]  Sweep 2: 0.9896s
# I0723 15:36:12.634344 18817 cudacc.cc:51]  Sweep 3: 0.7690s
# I0723 15:36:13.592272 18817 cudacc.cc:51]  Sweep 4: 0.9579s
# I0723 15:36:13.592346 18817 cudacc.cc:51] Iteration 2: 3.4935s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:14.339001 18817 cudacc.cc:51]  Sweep 1: 0.7466s
# I0723 15:36:15.287338 18817 cudacc.cc:51]  Sweep 2: 0.9482s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:16.031622 18817 cudacc.cc:51]  Sweep 3: 0.7442s
# I0723 15:36:16.956050 18817 cudacc.cc:51]  Sweep 4: 0.9243s
# I0723 15:36:16.956115 18817 cudacc.cc:51] Iteration 3: 3.3638s
# I0723 15:36:17.683215 18817 cudacc.cc:51]  Sweep 1: 0.7271s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:18.589516 18817 cudacc.cc:51]  Sweep 2: 0.9062s
# I0723 15:36:19.314124 18817 cudacc.cc:51]  Sweep 3: 0.7245s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:20.207558 18817 cudacc.cc:51]  Sweep 4: 0.8934s
# I0723 15:36:20.207629 18817 cudacc.cc:51] Iteration 4: 3.2515s
# I0723 15:36:20.921039 18817 cudacc.cc:51]  Sweep 1: 0.7134s
# I0723 15:36:21.800617 18817 cudacc.cc:51]  Sweep 2: 0.8795s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:22.515142 18817 cudacc.cc:51]  Sweep 3: 0.7145s
# I0723 15:36:23.318773 18817 cudacc.cc:51]  Sweep 4: 0.8035s
# I0723 15:36:23.318832 18817 cudacc.cc:51] Iteration 5: 3.1112s
# I0723 15:36:23.318846 18817 cudacc.cc:51] Total: 17.0655s
# I0723 15:36:23.318853 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160004_0291_V.JPG
# I0723 15:36:23.479207 18817 patch_match.cc:416] === Processing view 166 / 200 for DJI_20241227160009_0296_V.JPG ===
# I0723 15:36:23.479377 18817 patch_match.cc:466] Reading inputs...
# I0723 15:36:23.569397 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:36:23.569443 18817 patch_match.cc:57] ref_image_idx: 165
# I0723 15:36:23.569451 18817 patch_match.cc:64] src_image_idxs: 172 138 132 171 183 144 163 169 181 168 136 149 188 191 160 147 186 148 174 145
# I0723 15:36:23.569455 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:36:23.569458 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:36:23.569460 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:36:23.569463 18817 patch_match_options.cc:49] depth_min: 4.94128
# I0723 15:36:23.569474 18817 patch_match_options.cc:50] depth_max: 20.9912
# I0723 15:36:23.569478 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:36:23.569481 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:36:23.569483 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:36:23.569486 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:36:23.569489 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:36:23.569491 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:36:23.569494 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:36:23.569497 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:36:23.569499 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:36:23.569502 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:36:23.569504 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:36:23.569507 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:36:23.569509 18817 patch_match_options.cc:63] filter: 1
# I0723 15:36:23.569512 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:36:23.569514 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:36:23.569517 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:36:23.569519 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:36:23.569522 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:36:23.569525 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:36:23.569526 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:36:23.569530 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:36:23.849438 18817 cudacc.cc:51] Initialization: 0.1204s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:24.672359 18817 cudacc.cc:51]  Sweep 1: 0.8229s
# I0723 15:36:25.717198 18817 cudacc.cc:51]  Sweep 2: 1.0448s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:26.528548 18817 cudacc.cc:51]  Sweep 3: 0.8113s
# I0723 15:36:27.530066 18817 cudacc.cc:51]  Sweep 4: 1.0014s
# I0723 15:36:27.530125 18817 cudacc.cc:51] Iteration 1: 3.6807s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:28.295516 18817 cudacc.cc:51]  Sweep 1: 0.7654s
# I0723 15:36:29.274365 18817 cudacc.cc:51]  Sweep 2: 0.9788s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:30.039433 18817 cudacc.cc:51]  Sweep 3: 0.7650s
# I0723 15:36:30.990679 18817 cudacc.cc:51]  Sweep 4: 0.9512s
# I0723 15:36:30.990736 18817 cudacc.cc:51] Iteration 2: 3.4606s
# I0723 15:36:31.729034 18817 cudacc.cc:51]  Sweep 1: 0.7383s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:32.668058 18817 cudacc.cc:51]  Sweep 2: 0.9390s
# I0723 15:36:33.407248 18817 cudacc.cc:51]  Sweep 3: 0.7391s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:34.322526 18817 cudacc.cc:51]  Sweep 4: 0.9152s
# I0723 15:36:34.322626 18817 cudacc.cc:51] Iteration 3: 3.3319s
# I0723 15:36:35.041410 18817 cudacc.cc:51]  Sweep 1: 0.7187s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:35.944067 18817 cudacc.cc:51]  Sweep 2: 0.9026s
# I0723 15:36:36.668326 18817 cudacc.cc:51]  Sweep 3: 0.7242s
# I0723 15:36:37.552030 18817 cudacc.cc:51]  Sweep 4: 0.8836s
# I0723 15:36:37.552081 18817 cudacc.cc:51] Iteration 4: 3.2294s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:38.253950 18817 cudacc.cc:51]  Sweep 1: 0.7018s
# I0723 15:36:39.127971 18817 cudacc.cc:51]  Sweep 2: 0.8740s
# I0723 15:36:39.838039 18817 cudacc.cc:51]  Sweep 3: 0.7100s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:40.631376 18817 cudacc.cc:51]  Sweep 4: 0.7932s
# I0723 15:36:40.631438 18817 cudacc.cc:51] Iteration 5: 3.0794s
# I0723 15:36:40.631453 18817 cudacc.cc:51] Total: 16.9026s
# I0723 15:36:40.631460 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160009_0296_V.JPG
# I0723 15:36:40.853740 18817 patch_match.cc:416] === Processing view 167 / 200 for DJI_20241227160012_0299_V.JPG ===
# I0723 15:36:40.853953 18817 patch_match.cc:466] Reading inputs...
# I0723 15:36:40.958916 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:36:40.958956 18817 patch_match.cc:57] ref_image_idx: 166
# I0723 15:36:40.958968 18817 patch_match.cc:64] src_image_idxs: 192 177 148 167 195 155 168 160 151 132 171 170 174 176 150 191 133 149 175 194
# I0723 15:36:40.958974 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:36:40.958981 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:36:40.958985 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:36:40.958990 18817 patch_match_options.cc:49] depth_min: 5.12921
# I0723 15:36:40.959005 18817 patch_match_options.cc:50] depth_max: 18.125
# I0723 15:36:40.959012 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:36:40.959017 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:36:40.959021 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:36:40.959028 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:36:40.959033 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:36:40.959038 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:36:40.959044 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:36:40.959049 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:36:40.959055 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:36:40.959059 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:36:40.959064 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:36:40.959070 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:36:40.959075 18817 patch_match_options.cc:63] filter: 1
# I0723 15:36:40.959079 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:36:40.959085 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:36:40.959091 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:36:40.959095 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:36:40.959101 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:36:40.959105 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:36:40.959110 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:36:40.959115 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:36:41.252179 18817 cudacc.cc:51] Initialization: 0.1191s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:42.062913 18817 cudacc.cc:51]  Sweep 1: 0.8106s
# I0723 15:36:43.121091 18817 cudacc.cc:51]  Sweep 2: 1.0581s
# I0723 15:36:43.926007 18817 cudacc.cc:51]  Sweep 3: 0.8048s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:44.943919 18817 cudacc.cc:51]  Sweep 4: 1.0179s
# I0723 15:36:44.944003 18817 cudacc.cc:51] Iteration 1: 3.6918s
# I0723 15:36:45.707096 18817 cudacc.cc:51]  Sweep 1: 0.7629s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:46.704265 18817 cudacc.cc:51]  Sweep 2: 0.9971s
# I0723 15:36:47.468623 18817 cudacc.cc:51]  Sweep 3: 0.7643s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:48.432804 18817 cudacc.cc:51]  Sweep 4: 0.9641s
# I0723 15:36:48.432857 18817 cudacc.cc:51] Iteration 2: 3.4887s
# I0723 15:36:49.167941 18817 cudacc.cc:51]  Sweep 1: 0.7351s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:50.122529 18817 cudacc.cc:51]  Sweep 2: 0.9545s
# I0723 15:36:50.863431 18817 cudacc.cc:51]  Sweep 3: 0.7408s
# I0723 15:36:51.789085 18817 cudacc.cc:51]  Sweep 4: 0.9256s
# I0723 15:36:51.789160 18817 cudacc.cc:51] Iteration 3: 3.3563s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:52.505577 18817 cudacc.cc:51]  Sweep 1: 0.7164s
# I0723 15:36:53.424495 18817 cudacc.cc:51]  Sweep 2: 0.9188s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:54.149875 18817 cudacc.cc:51]  Sweep 3: 0.7253s
# I0723 15:36:55.045136 18817 cudacc.cc:51]  Sweep 4: 0.8952s
# I0723 15:36:55.045212 18817 cudacc.cc:51] Iteration 4: 3.2561s
# I0723 15:36:55.743687 18817 cudacc.cc:51]  Sweep 1: 0.6984s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:56.636111 18817 cudacc.cc:51]  Sweep 2: 0.8922s
# I0723 15:36:57.347663 18817 cudacc.cc:51]  Sweep 3: 0.7115s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:36:58.150130 18817 cudacc.cc:51]  Sweep 4: 0.8024s
# I0723 15:36:58.150195 18817 cudacc.cc:51] Iteration 5: 3.1050s
# I0723 15:36:58.150211 18817 cudacc.cc:51] Total: 17.0173s
# I0723 15:36:58.150219 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160012_0299_V.JPG
# I0723 15:36:58.317327 18817 patch_match.cc:416] === Processing view 168 / 200 for DJI_20241227160013_0300_V.JPG ===
# I0723 15:36:58.317502 18817 patch_match.cc:466] Reading inputs...
# I0723 15:36:58.404152 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:36:58.404199 18817 patch_match.cc:57] ref_image_idx: 167
# I0723 15:36:58.404207 18817 patch_match.cc:64] src_image_idxs: 149 178 133 168 155 194 170 185 156 152 173 175 150 176 192 195 166 148 177 151
# I0723 15:36:58.404211 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:36:58.404215 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:36:58.404217 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:36:58.404220 18817 patch_match_options.cc:49] depth_min: 5.09405
# I0723 15:36:58.404232 18817 patch_match_options.cc:50] depth_max: 19.8473
# I0723 15:36:58.404237 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:36:58.404239 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:36:58.404242 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:36:58.404245 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:36:58.404249 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:36:58.404253 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:36:58.404255 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:36:58.404258 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:36:58.404261 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:36:58.404264 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:36:58.404266 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:36:58.404269 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:36:58.404273 18817 patch_match_options.cc:63] filter: 1
# I0723 15:36:58.404275 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:36:58.404278 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:36:58.404281 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:36:58.404284 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:36:58.404286 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:36:58.404289 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:36:58.404291 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:36:58.404294 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:36:58.659513 18817 cudacc.cc:51] Initialization: 0.1182s
# I0723 15:36:59.476027 18817 cudacc.cc:51]  Sweep 1: 0.8164s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:00.534979 18817 cudacc.cc:51]  Sweep 2: 1.0589s
# I0723 15:37:01.339887 18817 cudacc.cc:51]  Sweep 3: 0.8048s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:02.357504 18817 cudacc.cc:51]  Sweep 4: 1.0175s
# I0723 15:37:02.357555 18817 cudacc.cc:51] Iteration 1: 3.6980s
# I0723 15:37:03.124459 18817 cudacc.cc:51]  Sweep 1: 0.7669s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:04.114794 18817 cudacc.cc:51]  Sweep 2: 0.9903s
# I0723 15:37:04.874856 18817 cudacc.cc:51]  Sweep 3: 0.7600s
# I0723 15:37:05.836763 18817 cudacc.cc:51]  Sweep 4: 0.9618s
# I0723 15:37:05.836819 18817 cudacc.cc:51] Iteration 2: 3.4793s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:06.572546 18817 cudacc.cc:51]  Sweep 1: 0.7357s
# I0723 15:37:07.517802 18817 cudacc.cc:51]  Sweep 2: 0.9452s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:08.252889 18817 cudacc.cc:51]  Sweep 3: 0.7350s
# I0723 15:37:09.175773 18817 cudacc.cc:51]  Sweep 4: 0.9228s
# I0723 15:37:09.175837 18817 cudacc.cc:51] Iteration 3: 3.3390s
# I0723 15:37:09.892868 18817 cudacc.cc:51]  Sweep 1: 0.7170s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:10.801561 18817 cudacc.cc:51]  Sweep 2: 0.9086s
# I0723 15:37:11.516032 18817 cudacc.cc:51]  Sweep 3: 0.7144s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:12.402009 18817 cudacc.cc:51]  Sweep 4: 0.8859s
# I0723 15:37:12.402068 18817 cudacc.cc:51] Iteration 4: 3.2262s
# I0723 15:37:13.100203 18817 cudacc.cc:51]  Sweep 1: 0.6981s
# I0723 15:37:13.979712 18817 cudacc.cc:51]  Sweep 2: 0.8794s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:14.680655 18817 cudacc.cc:51]  Sweep 3: 0.7009s
# I0723 15:37:15.478596 18817 cudacc.cc:51]  Sweep 4: 0.7979s
# I0723 15:37:15.478659 18817 cudacc.cc:51] Iteration 5: 3.0766s
# I0723 15:37:15.478674 18817 cudacc.cc:51] Total: 16.9375s
# I0723 15:37:15.478681 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160013_0300_V.JPG
# I0723 15:37:15.627565 18817 patch_match.cc:416] === Processing view 169 / 200 for DJI_20241227160011_0298_V.JPG ===
# I0723 15:37:15.627750 18817 patch_match.cc:466] Reading inputs...
# I0723 15:37:15.714529 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:37:15.714576 18817 patch_match.cc:57] ref_image_idx: 168
# I0723 15:37:15.714625 18817 patch_match.cc:64] src_image_idxs: 155 194 165 176 166 195 163 150 167 172 188 149 175 160 174 148 171 132 133 191
# I0723 15:37:15.714633 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:37:15.714643 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:37:15.714646 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:37:15.714649 18817 patch_match_options.cc:49] depth_min: 4.73054
# I0723 15:37:15.714661 18817 patch_match_options.cc:50] depth_max: 18.6354
# I0723 15:37:15.714665 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:37:15.714668 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:37:15.714671 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:37:15.714674 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:37:15.714679 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:37:15.714681 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:37:15.714684 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:37:15.714687 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:37:15.714690 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:37:15.714694 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:37:15.714695 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:37:15.714699 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:37:15.714701 18817 patch_match_options.cc:63] filter: 1
# I0723 15:37:15.714704 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:37:15.714707 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:37:15.714710 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:37:15.714713 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:37:15.714716 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:37:15.714718 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:37:15.714721 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:37:15.714736 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:37:15.984300 18817 cudacc.cc:51] Initialization: 0.1195s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:16.802486 18817 cudacc.cc:51]  Sweep 1: 0.8181s
# I0723 15:37:17.861913 18817 cudacc.cc:51]  Sweep 2: 1.0594s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:18.667578 18817 cudacc.cc:51]  Sweep 3: 0.8056s
# I0723 15:37:19.682282 18817 cudacc.cc:51]  Sweep 4: 1.0146s
# I0723 15:37:19.682345 18817 cudacc.cc:51] Iteration 1: 3.6980s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:20.455891 18817 cudacc.cc:51]  Sweep 1: 0.7735s
# I0723 15:37:21.448279 18817 cudacc.cc:51]  Sweep 2: 0.9923s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:22.213148 18817 cudacc.cc:51]  Sweep 3: 0.7648s
# I0723 15:37:23.172374 18817 cudacc.cc:51]  Sweep 4: 0.9591s
# I0723 15:37:23.172423 18817 cudacc.cc:51] Iteration 2: 3.4901s
# I0723 15:37:23.909454 18817 cudacc.cc:51]  Sweep 1: 0.7370s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:24.858781 18817 cudacc.cc:51]  Sweep 2: 0.9493s
# I0723 15:37:25.597864 18817 cudacc.cc:51]  Sweep 3: 0.7390s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:26.518484 18817 cudacc.cc:51]  Sweep 4: 0.9206s
# I0723 15:37:26.518535 18817 cudacc.cc:51] Iteration 3: 3.3461s
# I0723 15:37:27.236570 18817 cudacc.cc:51]  Sweep 1: 0.7180s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:28.150689 18817 cudacc.cc:51]  Sweep 2: 0.9141s
# I0723 15:37:28.872063 18817 cudacc.cc:51]  Sweep 3: 0.7213s
# I0723 15:37:29.760257 18817 cudacc.cc:51]  Sweep 4: 0.8881s
# I0723 15:37:29.760315 18817 cudacc.cc:51] Iteration 4: 3.2418s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:30.458148 18817 cudacc.cc:51]  Sweep 1: 0.6978s
# I0723 15:37:31.338477 18817 cudacc.cc:51]  Sweep 2: 0.8803s
# I0723 15:37:32.047734 18817 cudacc.cc:51]  Sweep 3: 0.7092s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:32.841250 18817 cudacc.cc:51]  Sweep 4: 0.7935s
# I0723 15:37:32.841308 18817 cudacc.cc:51] Iteration 5: 3.0810s
# I0723 15:37:32.841321 18817 cudacc.cc:51] Total: 16.9767s
# I0723 15:37:32.841328 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160011_0298_V.JPG
# I0723 15:37:32.989936 18817 patch_match.cc:416] === Processing view 170 / 200 for DJI_20241227160007_0294_V.JPG ===
# I0723 15:37:32.990178 18817 patch_match.cc:466] Reading inputs...
# I0723 15:37:33.099396 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:37:33.099442 18817 patch_match.cc:57] ref_image_idx: 169
# I0723 15:37:33.099455 18817 patch_match.cc:64] src_image_idxs: 138 144 182 136 146 159 147 141 180 162 183 186 189 163 137 145 158 187 181 142
# I0723 15:37:33.099462 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:37:33.099466 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:37:33.099470 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:37:33.099474 18817 patch_match_options.cc:49] depth_min: 4.78493
# I0723 15:37:33.099489 18817 patch_match_options.cc:50] depth_max: 19.3771
# I0723 15:37:33.099496 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:37:33.099501 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:37:33.099505 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:37:33.099510 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:37:33.099516 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:37:33.099529 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:37:33.099534 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:37:33.099539 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:37:33.099545 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:37:33.099548 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:37:33.099553 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:37:33.099558 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:37:33.099563 18817 patch_match_options.cc:63] filter: 1
# I0723 15:37:33.099567 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:37:33.099572 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:37:33.099577 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:37:33.099597 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:37:33.099602 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:37:33.099620 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:37:33.099624 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:37:33.099627 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:37:33.391251 18817 cudacc.cc:51] Initialization: 0.1184s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:34.215862 18817 cudacc.cc:51]  Sweep 1: 0.8245s
# I0723 15:37:35.262202 18817 cudacc.cc:51]  Sweep 2: 1.0463s
# I0723 15:37:36.063133 18817 cudacc.cc:51]  Sweep 3: 0.8008s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:37.074456 18817 cudacc.cc:51]  Sweep 4: 1.0112s
# I0723 15:37:37.074510 18817 cudacc.cc:51] Iteration 1: 3.6832s
# I0723 15:37:37.845701 18817 cudacc.cc:51]  Sweep 1: 0.7712s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:38.827705 18817 cudacc.cc:51]  Sweep 2: 0.9819s
# I0723 15:37:39.587458 18817 cudacc.cc:51]  Sweep 3: 0.7597s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:40.545948 18817 cudacc.cc:51]  Sweep 4: 0.9584s
# I0723 15:37:40.546010 18817 cudacc.cc:51] Iteration 2: 3.4715s
# I0723 15:37:41.285734 18817 cudacc.cc:51]  Sweep 1: 0.7397s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:42.224506 18817 cudacc.cc:51]  Sweep 2: 0.9387s
# I0723 15:37:42.960165 18817 cudacc.cc:51]  Sweep 3: 0.7356s
# I0723 15:37:43.880890 18817 cudacc.cc:51]  Sweep 4: 0.9207s
# I0723 15:37:43.880937 18817 cudacc.cc:51] Iteration 3: 3.3349s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:44.599694 18817 cudacc.cc:51]  Sweep 1: 0.7187s
# I0723 15:37:45.505208 18817 cudacc.cc:51]  Sweep 2: 0.9055s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:46.223510 18817 cudacc.cc:51]  Sweep 3: 0.7182s
# I0723 15:37:47.109242 18817 cudacc.cc:51]  Sweep 4: 0.8857s
# I0723 15:37:47.109314 18817 cudacc.cc:51] Iteration 4: 3.2284s
# I0723 15:37:47.814572 18817 cudacc.cc:51]  Sweep 1: 0.7052s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:48.692384 18817 cudacc.cc:51]  Sweep 2: 0.8777s
# I0723 15:37:49.396303 18817 cudacc.cc:51]  Sweep 3: 0.7038s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:50.195262 18817 cudacc.cc:51]  Sweep 4: 0.7989s
# I0723 15:37:50.195319 18817 cudacc.cc:51] Iteration 5: 3.0860s
# I0723 15:37:50.195335 18817 cudacc.cc:51] Total: 16.9226s
# I0723 15:37:50.195343 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160007_0294_V.JPG
# I0723 15:37:50.343896 18817 patch_match.cc:416] === Processing view 171 / 200 for DJI_20241227160014_0301_V.JPG ===
# I0723 15:37:50.344066 18817 patch_match.cc:466] Reading inputs...
# I0723 15:37:50.431301 18817 patch_match.cc:56] --- PatchMatch::Problem ---
# I0723 15:37:50.431344 18817 patch_match.cc:57] ref_image_idx: 170
# I0723 15:37:50.431352 18817 patch_match.cc:64] src_image_idxs: 196 167 185 156 179 150 192 198 168 194 176 166 155 184 151 177 178 152 173 154
# I0723 15:37:50.431357 18817 patch_match_options.cc:46] --- PatchMatchOptions ---
# I0723 15:37:50.431360 18817 patch_match_options.cc:47] max_image_size: 1600
# I0723 15:37:50.431363 18817 patch_match_options.cc:48] gpu_index: 0
# I0723 15:37:50.431365 18817 patch_match_options.cc:49] depth_min: 5.14922
# I0723 15:37:50.431377 18817 patch_match_options.cc:50] depth_max: 19.7066
# I0723 15:37:50.431382 18817 patch_match_options.cc:51] window_radius: 5
# I0723 15:37:50.431384 18817 patch_match_options.cc:52] window_step: 1
# I0723 15:37:50.431387 18817 patch_match_options.cc:53] sigma_spatial: 5
# I0723 15:37:50.431391 18817 patch_match_options.cc:54] sigma_color: 0.2
# I0723 15:37:50.431394 18817 patch_match_options.cc:55] num_samples: 15
# I0723 15:37:50.431397 18817 patch_match_options.cc:56] ncc_sigma: 0.6
# I0723 15:37:50.431401 18817 patch_match_options.cc:57] min_triangulation_angle: 1
# I0723 15:37:50.431403 18817 patch_match_options.cc:58] incident_angle_sigma: 0.9
# I0723 15:37:50.431406 18817 patch_match_options.cc:59] num_iterations: 5
# I0723 15:37:50.431409 18817 patch_match_options.cc:60] geom_consistency: 1
# I0723 15:37:50.431411 18817 patch_match_options.cc:61] geom_consistency_regularizer: 0.3
# I0723 15:37:50.431414 18817 patch_match_options.cc:62] geom_consistency_max_cost: 3
# I0723 15:37:50.431417 18817 patch_match_options.cc:63] filter: 1
# I0723 15:37:50.431420 18817 patch_match_options.cc:64] filter_min_ncc: 0.1
# I0723 15:37:50.431424 18817 patch_match_options.cc:65] filter_min_triangulation_angle: 3
# I0723 15:37:50.431427 18817 patch_match_options.cc:66] filter_min_num_consistent: 2
# I0723 15:37:50.431429 18817 patch_match_options.cc:67] filter_geom_consistency_max_cost: 1
# I0723 15:37:50.431449 18817 patch_match_options.cc:68] write_consistency_graph: 0
# I0723 15:37:50.431452 18817 patch_match_options.cc:69] allow_missing_files: 0
# I0723 15:37:50.431453 18817 patch_match_options.cc:70] num_threads: -1
# I0723 15:37:50.431456 18817 patch_match.cc:129] --- PatchMatch::Run ---
# I0723 15:37:50.692534 18817 cudacc.cc:51] Initialization: 0.1200s
# I0723 15:37:51.512718 18817 cudacc.cc:51]  Sweep 1: 0.8201s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:52.572162 18817 cudacc.cc:51]  Sweep 2: 1.0594s
# I0723 15:37:53.376555 18817 cudacc.cc:51]  Sweep 3: 0.8043s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:54.398010 18817 cudacc.cc:51]  Sweep 4: 1.0213s
# I0723 15:37:54.398061 18817 cudacc.cc:51] Iteration 1: 3.7055s
# I0723 15:37:55.167572 18817 cudacc.cc:51]  Sweep 1: 0.7695s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:56.164587 18817 cudacc.cc:51]  Sweep 2: 0.9969s
# I0723 15:37:56.926016 18817 cudacc.cc:51]  Sweep 3: 0.7613s
# I0723 15:37:57.889796 18817 cudacc.cc:51]  Sweep 4: 0.9637s
# I0723 15:37:57.889848 18817 cudacc.cc:51] Iteration 2: 3.4918s
# --- end 04_patch_match_stereo.log ---
#
# [b2-pilot] still running...
#
# --- 04_patch_match_stereo.log ---
# I0723 15:37:58.629753 18817 cudacc.cc:51]  Sweep 1: 0.7399s
# I0723 15:37:59.585856 18817 cudacc.cc:51]  Sweep 2: 0.9560s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:38:00.323944 18817 cudacc.cc:51]  Sweep 3: 0.7367s
# I0723 15:38:01.252348 18817 cudacc.cc:51]  Sweep 4: 0.9283s
# I0723 15:38:01.252418 18817 cudacc.cc:51] Iteration 3: 3.3626s
# I0723 15:38:01.976178 18817 cudacc.cc:51]  Sweep 1: 0.7237s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:38:02.891993 18817 cudacc.cc:51]  Sweep 2: 0.9157s
# I0723 15:38:03.612227 18817 cudacc.cc:51]  Sweep 3: 0.7202s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:38:04.511292 18817 cudacc.cc:51]  Sweep 4: 0.8990s
# I0723 15:38:04.511344 18817 cudacc.cc:51] Iteration 4: 3.2589s
# I0723 15:38:05.220431 18817 cudacc.cc:51]  Sweep 1: 0.7090s
# I0723 15:38:06.106702 18817 cudacc.cc:51]  Sweep 2: 0.8862s
# --- end 04_patch_match_stereo.log ---
#
#
# --- 04_patch_match_stereo.log ---
# I0723 15:38:06.814700 18817 cudacc.cc:51]  Sweep 3: 0.7079s
# I0723 15:38:07.620023 18817 cudacc.cc:51]  Sweep 4: 0.8053s
# I0723 15:38:07.620077 18817 cudacc.cc:51] Iteration 5: 3.1087s
# I0723 15:38:07.620092 18817 cudacc.cc:51] Total: 17.0477s
# I0723 15:38:07.620100 18817 patch_match.cc:525]
# Writing geometric output for DJI_20241227160014_0301_V.JPG
# ...
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:14.677235 42738 fusion.cc:310]  in 1.559s (3538845 points)
# I0723 15:54:14.677289 42738 fusion.cc:283] Fusing image [128/200] with index 70
# I0723 15:54:15.641320 42738 fusion.cc:310]  in 0.964s (3553354 points)
# I0723 15:54:15.641398 42738 fusion.cc:283] Fusing image [129/200] with index 73
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:16.770197 42738 fusion.cc:310]  in 1.129s (3570146 points)
# I0723 15:54:16.770246 42738 fusion.cc:283] Fusing image [130/200] with index 72
# I0723 15:54:17.717628 42738 fusion.cc:310]  in 0.947s (3583709 points)
# I0723 15:54:17.717689 42738 fusion.cc:283] Fusing image [131/200] with index 76
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:18.824958 42738 fusion.cc:310]  in 1.107s (3598567 points)
# I0723 15:54:18.825016 42738 fusion.cc:283] Fusing image [132/200] with index 75
# I0723 15:54:19.942021 42738 fusion.cc:310]  in 1.117s (3613751 points)
# I0723 15:54:19.942086 42738 fusion.cc:283] Fusing image [133/200] with index 74
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:20.979863 42738 fusion.cc:310]  in 1.038s (3630295 points)
# I0723 15:54:20.979916 42738 fusion.cc:283] Fusing image [134/200] with index 54
# I0723 15:54:21.989791 42738 fusion.cc:310]  in 1.010s (3645066 points)
# I0723 15:54:21.989876 42738 fusion.cc:283] Fusing image [135/200] with index 53
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:23.180472 42738 fusion.cc:310]  in 1.191s (3660560 points)
# I0723 15:54:23.180526 42738 fusion.cc:283] Fusing image [136/200] with index 56
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:24.460453 42738 fusion.cc:310]  in 1.280s (3687260 points)
# I0723 15:54:24.460517 42738 fusion.cc:283] Fusing image [137/200] with index 55
# I0723 15:54:26.270999 42738 fusion.cc:310]  in 1.811s (3702004 points)
# I0723 15:54:26.271061 42738 fusion.cc:283] Fusing image [138/200] with index 57
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:28.067615 42738 fusion.cc:310]  in 1.797s (3715473 points)
# I0723 15:54:28.067821 42738 fusion.cc:283] Fusing image [139/200] with index 59
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:28.845710 42738 fusion.cc:310]  in 0.778s (3721038 points)
# I0723 15:54:28.845767 42738 fusion.cc:283] Fusing image [140/200] with index 58
# I0723 15:54:29.436190 42738 fusion.cc:310]  in 0.590s (3722802 points)
# I0723 15:54:29.436256 42738 fusion.cc:283] Fusing image [141/200] with index 60
# I0723 15:54:29.945174 42738 fusion.cc:310]  in 0.509s (3723483 points)
# I0723 15:54:29.945232 42738 fusion.cc:283] Fusing image [142/200] with index 61
# I0723 15:54:30.404944 42738 fusion.cc:310]  in 0.460s (3723483 points)
# I0723 15:54:30.405001 42738 fusion.cc:283] Fusing image [143/200] with index 51
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:31.284644 42738 fusion.cc:310]  in 0.880s (3728716 points)
# I0723 15:54:31.284710 42738 fusion.cc:283] Fusing image [144/200] with index 52
# I0723 15:54:31.856511 42738 fusion.cc:310]  in 0.572s (3731218 points)
# I0723 15:54:31.856554 42738 fusion.cc:283] Fusing image [145/200] with index 81
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:34.363948 42738 fusion.cc:310]  in 2.507s (3796535 points)
# I0723 15:54:34.364001 42738 fusion.cc:283] Fusing image [146/200] with index 82
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:36.141386 42738 fusion.cc:310]  in 1.777s (3838087 points)
# I0723 15:54:36.141446 42738 fusion.cc:283] Fusing image [147/200] with index 80
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:37.700294 42738 fusion.cc:310]  in 1.559s (3870964 points)
# I0723 15:54:37.700347 42738 fusion.cc:283] Fusing image [148/200] with index 79
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:39.908365 42738 fusion.cc:310]  in 2.208s (3904665 points)
# I0723 15:54:39.908529 42738 fusion.cc:283] Fusing image [149/200] with index 78
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:42.315645 42738 fusion.cc:310]  in 2.407s (3934155 points)
# I0723 15:54:42.315699 42738 fusion.cc:283] Fusing image [150/200] with index 77
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:44.040318 42738 fusion.cc:310]  in 1.725s (3967144 points)
# I0723 15:54:44.040385 42738 fusion.cc:283] Fusing image [151/200] with index 102
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:45.773691 42738 fusion.cc:310]  in 1.733s (4002682 points)
# I0723 15:54:45.773770 42738 fusion.cc:283] Fusing image [152/200] with index 103
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:47.441668 42738 fusion.cc:310]  in 1.668s (4031571 points)
# I0723 15:54:47.441720 42738 fusion.cc:283] Fusing image [153/200] with index 100
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:48.834125 42738 fusion.cc:310]  in 1.392s (4057226 points)
# I0723 15:54:48.834190 42738 fusion.cc:283] Fusing image [154/200] with index 99
# I0723 15:54:50.128759 42738 fusion.cc:310]  in 1.295s (4081033 points)
# I0723 15:54:50.128810 42738 fusion.cc:283] Fusing image [155/200] with index 101
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:51.496711 42738 fusion.cc:310]  in 1.368s (4107444 points)
# I0723 15:54:51.496764 42738 fusion.cc:283] Fusing image [156/200] with index 98
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:53.258854 42738 fusion.cc:310]  in 1.762s (4131262 points)
# I0723 15:54:53.258919 42738 fusion.cc:283] Fusing image [157/200] with index 97
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:55.632194 42738 fusion.cc:310]  in 2.373s (4154668 points)
# I0723 15:54:55.632251 42738 fusion.cc:283] Fusing image [158/200] with index 94
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:54:57.134152 42738 fusion.cc:310]  in 1.502s (4178292 points)
# I0723 15:54:57.134215 42738 fusion.cc:283] Fusing image [159/200] with index 96
# I0723 15:54:58.453426 42738 fusion.cc:310]  in 1.319s (4204162 points)
# I0723 15:54:58.453486 42738 fusion.cc:283] Fusing image [160/200] with index 95
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:00.129534 42738 fusion.cc:310]  in 1.676s (4245721 points)
# I0723 15:55:00.129598 42738 fusion.cc:283] Fusing image [161/200] with index 93
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:01.486709 42738 fusion.cc:310]  in 1.357s (4277888 points)
# I0723 15:55:01.486763 42738 fusion.cc:283] Fusing image [162/200] with index 92
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:02.712893 42738 fusion.cc:310]  in 1.226s (4305330 points)
# I0723 15:55:02.712949 42738 fusion.cc:283] Fusing image [163/200] with index 91
# I0723 15:55:03.925885 42738 fusion.cc:310]  in 1.213s (4330980 points)
# I0723 15:55:03.925983 42738 fusion.cc:283] Fusing image [164/200] with index 90
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:05.184377 42738 fusion.cc:310]  in 1.258s (4357264 points)
# I0723 15:55:05.184435 42738 fusion.cc:283] Fusing image [165/200] with index 89
# I0723 15:55:06.390794 42738 fusion.cc:310]  in 1.206s (4381160 points)
# I0723 15:55:06.390851 42738 fusion.cc:283] Fusing image [166/200] with index 88
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:08.394856 42738 fusion.cc:310]  in 2.004s (4403629 points)
# I0723 15:55:08.394917 42738 fusion.cc:283] Fusing image [167/200] with index 86
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:10.049295 42738 fusion.cc:310]  in 1.654s (4420374 points)
# I0723 15:55:10.049376 42738 fusion.cc:283] Fusing image [168/200] with index 87
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:11.102543 42738 fusion.cc:310]  in 1.053s (4435233 points)
# I0723 15:55:11.102634 42738 fusion.cc:283] Fusing image [169/200] with index 85
# I0723 15:55:12.003229 42738 fusion.cc:310]  in 0.901s (4449223 points)
# I0723 15:55:12.003290 42738 fusion.cc:283] Fusing image [170/200] with index 84
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:12.786749 42738 fusion.cc:310]  in 0.783s (4459409 points)
# I0723 15:55:12.786813 42738 fusion.cc:283] Fusing image [171/200] with index 83
# I0723 15:55:13.435696 42738 fusion.cc:310]  in 0.649s (4466752 points)
# I0723 15:55:13.435752 42738 fusion.cc:283] Fusing image [172/200] with index 130
# I0723 15:55:14.174784 42738 fusion.cc:310]  in 0.739s (4474460 points)
# I0723 15:55:14.174849 42738 fusion.cc:283] Fusing image [173/200] with index 131
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:14.814791 42738 fusion.cc:310]  in 0.640s (4477500 points)
# I0723 15:55:14.814841 42738 fusion.cc:283] Fusing image [174/200] with index 129
# I0723 15:55:15.348284 42738 fusion.cc:310]  in 0.533s (4479028 points)
# I0723 15:55:15.348367 42738 fusion.cc:283] Fusing image [175/200] with index 128
# I0723 15:55:15.822937 42738 fusion.cc:310]  in 0.475s (4480013 points)
# I0723 15:55:15.822995 42738 fusion.cc:283] Fusing image [176/200] with index 127
# I0723 15:55:16.281563 42738 fusion.cc:310]  in 0.459s (4480941 points)
# I0723 15:55:16.281653 42738 fusion.cc:283] Fusing image [177/200] with index 126
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:16.732851 42738 fusion.cc:310]  in 0.451s (4481707 points)
# I0723 15:55:16.732901 42738 fusion.cc:283] Fusing image [178/200] with index 125
# I0723 15:55:17.156971 42738 fusion.cc:310]  in 0.424s (4482394 points)
# I0723 15:55:17.157025 42738 fusion.cc:283] Fusing image [179/200] with index 124
# I0723 15:55:17.602315 42738 fusion.cc:310]  in 0.445s (4482988 points)
# I0723 15:55:17.602367 42738 fusion.cc:283] Fusing image [180/200] with index 123
# I0723 15:55:18.042157 42738 fusion.cc:310]  in 0.440s (4483566 points)
# I0723 15:55:18.042217 42738 fusion.cc:283] Fusing image [181/200] with index 122
# I0723 15:55:18.482504 42738 fusion.cc:310]  in 0.440s (4484002 points)
# I0723 15:55:18.482556 42738 fusion.cc:283] Fusing image [182/200] with index 121
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:18.912562 42738 fusion.cc:310]  in 0.430s (4484309 points)
# I0723 15:55:18.912631 42738 fusion.cc:283] Fusing image [183/200] with index 120
# I0723 15:55:19.427556 42738 fusion.cc:310]  in 0.515s (4485727 points)
# I0723 15:55:19.427654 42738 fusion.cc:283] Fusing image [184/200] with index 119
# I0723 15:55:19.872685 42738 fusion.cc:310]  in 0.445s (4486745 points)
# I0723 15:55:19.872727 42738 fusion.cc:283] Fusing image [185/200] with index 118
# I0723 15:55:20.558758 42738 fusion.cc:310]  in 0.686s (4487716 points)
# I0723 15:55:20.558818 42738 fusion.cc:283] Fusing image [186/200] with index 117
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] still running...
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:21.456249 42738 fusion.cc:310]  in 0.897s (4488987 points)
# I0723 15:55:21.456512 42738 fusion.cc:283] Fusing image [187/200] with index 116
# I0723 15:55:22.341707 42738 fusion.cc:310]  in 0.885s (4490603 points)
# I0723 15:55:22.341773 42738 fusion.cc:283] Fusing image [188/200] with index 115
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:23.225338 42738 fusion.cc:310]  in 0.884s (4492054 points)
# I0723 15:55:23.225397 42738 fusion.cc:283] Fusing image [189/200] with index 114
# I0723 15:55:23.842861 42738 fusion.cc:310]  in 0.617s (4493277 points)
# I0723 15:55:23.842918 42738 fusion.cc:283] Fusing image [190/200] with index 113
# I0723 15:55:24.261456 42738 fusion.cc:310]  in 0.419s (4494349 points)
# I0723 15:55:24.261545 42738 fusion.cc:283] Fusing image [191/200] with index 112
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:24.712011 42738 fusion.cc:310]  in 0.450s (4495556 points)
# I0723 15:55:24.712066 42738 fusion.cc:283] Fusing image [192/200] with index 111
# I0723 15:55:25.133899 42738 fusion.cc:310]  in 0.422s (4496574 points)
# I0723 15:55:25.133955 42738 fusion.cc:283] Fusing image [193/200] with index 110
# I0723 15:55:25.613451 42738 fusion.cc:310]  in 0.480s (4497431 points)
# I0723 15:55:25.613504 42738 fusion.cc:283] Fusing image [194/200] with index 109
# I0723 15:55:26.009660 42738 fusion.cc:310]  in 0.396s (4497990 points)
# I0723 15:55:26.009712 42738 fusion.cc:283] Fusing image [195/200] with index 108
# I0723 15:55:26.438702 42738 fusion.cc:310]  in 0.429s (4498862 points)
# I0723 15:55:26.438760 42738 fusion.cc:283] Fusing image [196/200] with index 107
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:26.853258 42738 fusion.cc:310]  in 0.415s (4499448 points)
# I0723 15:55:26.853300 42738 fusion.cc:283] Fusing image [197/200] with index 106
# I0723 15:55:27.314935 42738 fusion.cc:310]  in 0.462s (4499960 points)
# I0723 15:55:27.315001 42738 fusion.cc:283] Fusing image [198/200] with index 105
# I0723 15:55:27.737926 42738 fusion.cc:310]  in 0.423s (4499968 points)
# I0723 15:55:27.738009 42738 fusion.cc:283] Fusing image [199/200] with index 104
# I0723 15:55:28.072489 42738 fusion.cc:310]  in 0.334s (4499968 points)
# I0723 15:55:28.072562 42738 fusion.cc:283] Fusing image [200/200] with index 199
# --- end 04_stereo_fusion.log ---
#
#
# --- 04_stereo_fusion.log ---
# I0723 15:55:28.749104 42738 fusion.cc:310]  in 0.677s (4499968 points)
# I0723 15:55:29.391271 42738 fusion.cc:337] Number of fused points: 4499968
# I0723 15:55:29.391316 42738 timer.cc:90] Elapsed time: 8.918 [minutes]
# I0723 15:55:30.415791 42738 mvs.cc:370] Writing output: "/content/project/pipeline/work/hcm0031/colmap/dense/fused.ply"
# --- end 04_stereo_fusion.log ---
#
# [b2-pilot] COLMAP dense pilot xong: scene=hcm0031
# [b2-pilot] PatchMatch: 5841s | StereoFusion: 542s
# [b2-pilot] Depth maps: 400 | Normal maps: 400 | Consistency graphs: 0
# [b2-pilot] Fused PLY: /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# [b2-pilot] Summary: /content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# [b2-pilot] B2 pilot workflow xong: scene=hcm0031
# [b2-pilot] Summary: /content/project/pipeline/work/hcm0031/logs/05_b2_pilot_summary.txt
#
# --- 04_colmap_dense_summary.txt (final) ---
# scene=hcm0031
# dense_dir=/content/project/pipeline/work/hcm0031/colmap/dense
# colmap_bin=/content/project/.local/colmap-cuda/bin/colmap
# patch_match_seconds=5841
# stereo_fusion_seconds=542
# depth_map_files=400
# normal_map_files=400
# consistency_graph_files=0
# fused_ply=/content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# fused_ply_bytes=121499371
# patch_log=/content/project/pipeline/work/hcm0031/logs/04_patch_match_stereo.log
# fusion_log=/content/project/pipeline/work/hcm0031/logs/04_stereo_fusion.log
# --- end 04_colmap_dense_summary.txt ---
#
#
# --- 05_b2_pilot_summary.txt (final) ---
# scene=hcm0031
# dataset_root=/content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set
# work_root=/content/project/pipeline/work
# run_dense=1
# run_train=0
# run_render=0
# run_eval=0
# source_mode=prepared
# model_dir=/content/project/pipeline/work/hcm0031/gs_model
# render_out_dir=/content/project/pipeline/work/hcm0031/renders_b2_pilot
# eval_out_csv=/content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# tower_bbox3d_json=/content/project/pipeline/work/hcm0031/tower_bbox3d.json
# skyline_top_frac=0.3
# dense_summary=/content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# render_log=/content/project/pipeline/work/hcm0031/logs/05_render_b2_pilot.log
# eval_log=/content/project/pipeline/work/hcm0031/logs/05_eval_b2_pilot.log
# --- end 05_b2_pilot_summary.txt ---
#
# [b2-pilot] RETURN CODE = 0
# B2 pilot done

# %%
from pathlib import Path
work_dir = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
logs_dir = work_dir / 'logs'

for p in [
    logs_dir / '04_colmap_dense_summary.txt',
    logs_dir / '04_patch_match_stereo.log',
    logs_dir / '04_stereo_fusion.log',
    work_dir / 'colmap' / 'dense' / 'fused.ply',
    work_dir / 'eval_metrics_b2_pilot.csv',
    work_dir / 'eval_metrics_b2_pilot_tower_crop.csv',
    work_dir / 'eval_metrics_b2_pilot_skyline_crop.csv',
]:
    print(('OK  ' if p.exists() else 'MISS'), p)
# Out:
# OK   /content/project/pipeline/work/hcm0031/logs/04_colmap_dense_summary.txt
# OK   /content/project/pipeline/work/hcm0031/logs/04_patch_match_stereo.log
# OK   /content/project/pipeline/work/hcm0031/logs/04_stereo_fusion.log
# OK   /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_tower_crop.csv
# MISS /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_skyline_crop.csv

# %%
import subprocess
from pathlib import Path

scene_root = Path(WORKDIR) / 'project' / 'pipeline' / 'work' / SCENE
artifact_dir = Path(WORKDIR) / 'b2_pilot_artifacts'
artifact_dir.mkdir(parents=True, exist_ok=True)

subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_colmap_dense_summary.txt" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_patch_match_stereo.log" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/04_stereo_fusion.log" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/logs/05_b2_pilot_summary.txt" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/colmap/dense/fused.ply" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot_tower_crop.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)
subprocess.run(['bash', '-lc', f'cp -f "{scene_root}/eval_metrics_b2_pilot_skyline_crop.csv" "{artifact_dir}/" 2>/dev/null || true'], check=True)

subprocess.run(['bash', '-lc', f'cd "{WORKDIR}" && zip -r b2_pilot_artifacts.zip b2_pilot_artifacts >/dev/null'], check=True)
print('Artifact zip:', Path(WORKDIR) / 'b2_pilot_artifacts.zip')
# Out:
# Artifact zip: /content/b2_pilot_artifacts.zip

# %%
from pathlib import Path

zip_candidates = [
    Path(WORKDIR) / 'b2_pilot_artifacts.zip',
    Path('b2_pilot_artifacts.zip').resolve(),
]
zip_path = next((p for p in zip_candidates if p.exists()), None)
assert zip_path is not None, 'Khong tim thay b2_pilot_artifacts.zip de download'
print('Zip san sang:', zip_path)
print('Notebook dang chay tren Kaggle. Hay tai thu cong file nay tu sidebar:', zip_path)
# Out:
# Zip san sang: /content/b2_pilot_artifacts.zip
# Notebook dang chay tren Kaggle. Hay tai thu cong file nay tu sidebar: /content/b2_pilot_artifacts.zip

# %%
# =========================
# CELL 1 - Config + checks
# =========================
from pathlib import Path

WORKDIR = '/content' if Path('/content').exists() else '/kaggle/working'
SCENE = 'hcm0031'
PROJECT_DIR = Path(WORKDIR) / 'project'
DATASET_ROOT = Path(WORKDIR) / '_dataset_round1_raw' / 'VAI_NVS_DATA' / 'phase1' / 'public_set'
COLMAP_BIN = PROJECT_DIR / '.local' / 'colmap-cuda' / 'bin' / 'colmap'
GS_REPO = Path(WORKDIR) / 'gaussian-splatting'
GS_REPO_BRANCH = 'main'

checks = [
    PROJECT_DIR,
    DATASET_ROOT,
    COLMAP_BIN,
    PROJECT_DIR / 'pipeline' / 'work' / SCENE / 'colmap' / 'dense' / 'fused.ply',
]
for p in checks:
    print(p, 'OK' if p.exists() else 'MISS')
# Out:
# /content/project OK
# /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set OK
# /content/project/.local/colmap-cuda/bin/colmap OK
# /content/project/pipeline/work/hcm0031/colmap/dense/fused.ply OK

# %%
# ======================================
# CELL 2 - Clone GS repo only if missing
# ======================================
import subprocess

GS_REPO_URL = "https://github.com/graphdeco-inria/gaussian-splatting.git"

if GS_REPO.exists():
    print("GS_REPO da ton tai:", GS_REPO)
else:
    subprocess.run(
        ["git", "clone", "--depth", "1", "-b", GS_REPO_BRANCH, GS_REPO_URL, str(GS_REPO)],
        check=True,
    )
    print("Cloned:", GS_REPO)
# Out:
# Cloned: /content/gaussian-splatting

# %%
# ======================================================
# CELL 3 - Install minimal GS deps + CUDA extensions
# ======================================================
from pathlib import Path

assert GS_REPO.exists(), GS_REPO

run_and_stream(
    ['bash', '-lc', f'cd "{GS_REPO}" && git submodule update --init --recursive'],
    label='gs-submodules',
)

run_and_stream(
    ['bash', '-lc', 'python3 -m pip install --upgrade pip setuptools wheel ninja'],
    label='gs-pip-core',
)

run_and_stream(
    ['bash', '-lc', 'python3 -m pip install plyfile tqdm lpips opencv-python imageio imageio-ffmpeg'],
    label='gs-pip-deps',
)

run_and_stream(
    ['bash', '-lc', 'python3 -c "import torch; print(torch.__version__)"'],
    label='gs-check-torch',
)

build_logs_dir = Path(WORKDIR) / 'gs_build_logs'
build_logs_dir.mkdir(parents=True, exist_ok=True)

build_steps = [
    (
        'diff_gaussian_rasterization',
        GS_REPO / 'submodules' / 'diff-gaussian-rasterization',
        build_logs_dir / 'diff_gaussian_rasterization.log',
    ),
    (
        'simple_knn',
        GS_REPO / 'submodules' / 'simple-knn',
        build_logs_dir / 'simple_knn.log',
    ),
]

for name, src_dir, log_path in build_steps:
    assert src_dir.exists(), src_dir
    run_and_stream(
        ['bash', '-lc', f'cd "{src_dir}" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .'],
        log_files=[log_path],
        poll_seconds=20,
        label=name,
    )
    print(f'Installed: {name}')

print('Gaussian Splatting minimal deps + extensions installed')
# Out:
# [gs-submodules] START: bash -lc cd "/content/gaussian-splatting" && git submodule update --init --recursive
# [gs-submodules] still running...
# [gs-submodules] Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core.git) registered for path 'SIBR_viewers'
# [gs-submodules] Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization.git) registered for path 'submodules/diff-gaussian-rasterization'
# [gs-submodules] Submodule 'submodules/fused-ssim' (https://github.com/rahul-goel/fused-ssim.git) registered for path 'submodules/fused-ssim'
# [gs-submodules] Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# [gs-submodules] Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/diff-gaussian-rasterization'...
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/fused-ssim'...
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/simple-knn'...
# [gs-submodules] Submodule path 'SIBR_viewers': checked out 'd8856f60c5384cc1975439193bb627d77d917d77'
# [gs-submodules] Submodule path 'submodules/diff-gaussian-rasterization': checked out '9c5c2028f6fbee2be239bc4c9421ff894fe4fbe0'
# [gs-submodules] Submodule 'third_party/glm' (https://github.com/g-truc/glm.git) registered for path 'submodules/diff-gaussian-rasterization/third_party/glm'
# [gs-submodules] Cloning into '/content/gaussian-splatting/submodules/diff-gaussian-rasterization/third_party/glm'...
# [gs-submodules] still running...
# [gs-submodules] Submodule path 'submodules/diff-gaussian-rasterization/third_party/glm': checked out '5c46b9c07008ae65cb81ab79cd677ecc1934b903'
# [gs-submodules] Submodule path 'submodules/fused-ssim': checked out '1272e21a282342e89537159e4bad508b19b34157'
# [gs-submodules] Submodule path 'submodules/simple-knn': checked out '86710c2d4b46680c02301765dd79e465819c8f19'
# [gs-submodules] RETURN CODE = 0
# [gs-pip-core] START: bash -lc python3 -m pip install --upgrade pip setuptools wheel ninja
# [gs-pip-core] still running...
# [gs-pip-core] Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.1.2)
# [gs-pip-core] Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# [gs-pip-core] Collecting setuptools
# [gs-pip-core]   Downloading setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# [gs-pip-core] Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.47.0)
# [gs-pip-core] Collecting ninja
# [gs-pip-core]   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# [gs-pip-core] Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.2)
# [gs-pip-core] Downloading setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# [gs-pip-core]    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.8 MB/s  0:00:00
# [gs-pip-core] Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# [gs-pip-core] Installing collected packages: setuptools, ninja
# [gs-pip-core]   Attempting uninstall: setuptools
# [gs-pip-core]     Found existing installation: setuptools 75.2.0
# [gs-pip-core]     Uninstalling setuptools-75.2.0:
# [gs-pip-core]       Successfully uninstalled setuptools-75.2.0
# [gs-pip-core]
# [gs-pip-core] ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# [gs-pip-core] ipython 7.34.0 requires jedi>=0.16, which is not installed.
# [gs-pip-core] torch 2.11.0+cu128 requires setuptools<82, but you have setuptools 83.0.0 which is incompatible.
# [gs-pip-core] Successfully installed ninja-1.13.0 setuptools-83.0.0
# [gs-pip-core] RETURN CODE = 0
# [gs-pip-deps] START: bash -lc python3 -m pip install plyfile tqdm lpips opencv-python imageio imageio-ffmpeg
# [gs-pip-deps] still running...
# [gs-pip-deps] Collecting plyfile
# [gs-pip-deps]   Downloading plyfile-1.1.4-py3-none-any.whl.metadata (43 kB)
# [gs-pip-deps] Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# [gs-pip-deps] Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# [gs-pip-deps] Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (5.0.0.93)
# [gs-pip-deps] Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.3)
# [gs-pip-deps] Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (0.6.0)
# [gs-pip-deps] Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from plyfile) (2.0.2)
# [gs-pip-deps] Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.11.0+cu128)
# [gs-pip-deps] Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.26.0+cu128)
# [gs-pip-deps] Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# [gs-pip-deps] Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio) (11.3.0)
# [gs-pip-deps] Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.29.7)
# [gs-pip-deps] Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.16.0)
# [gs-pip-deps] Collecting setuptools<82 (from torch>=0.4.0->lpips)
# [gs-pip-deps]   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# [gs-pip-deps] Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.14.0)
# [gs-pip-deps] Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.1)
# [gs-pip-deps] Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# [gs-pip-deps] Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# [gs-pip-deps] Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.1)
# [gs-pip-deps] Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.9.7)
# [gs-pip-deps] Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.19.0.56)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# [gs-pip-deps] Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.28.9)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.5)
# [gs-pip-deps] Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6.0)
# [gs-pip-deps] Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.4.1)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (11.3.3.83)
# [gs-pip-deps] Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (1.13.1.3)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (10.3.9.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (11.7.3.90)
# [gs-pip-deps] Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.5.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.93)
# [gs-pip-deps] Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.0->lpips) (12.8.90)
# [gs-pip-deps] Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=0.4.0->lpips) (1.5.6)
# [gs-pip-deps] Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# [gs-pip-deps] Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# [gs-pip-deps] Downloading plyfile-1.1.4-py3-none-any.whl (36 kB)
# [gs-pip-deps] Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# [gs-pip-deps]    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.0 MB/s  0:00:00
# [gs-pip-deps] Installing collected packages: setuptools, plyfile
# [gs-pip-deps]   Attempting uninstall: setuptools
# [gs-pip-deps]     Found existing installation: setuptools 83.0.0
# [gs-pip-deps]     Uninstalling setuptools-83.0.0:
# [gs-pip-deps]       Successfully uninstalled setuptools-83.0.0
# [gs-pip-deps]
# [gs-pip-deps] ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# [gs-pip-deps] ipython 7.34.0 requires jedi>=0.16, which is not installed.
# [gs-pip-deps] Successfully installed plyfile-1.1.4 setuptools-81.0.0
# [gs-pip-deps] RETURN CODE = 0
# [gs-check-torch] START: bash -lc python3 -c "import torch; print(torch.__version__)"
# [gs-check-torch] still running...
# [gs-check-torch] 2.11.0+cu128
# [gs-check-torch] RETURN CODE = 0
# [diff_gaussian_rasterization] START: bash -lc cd "/content/gaussian-splatting/submodules/diff-gaussian-rasterization" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] Processing ./.
# [diff_gaussian_rasterization]   Preparing metadata (pyproject.toml): started
# [diff_gaussian_rasterization]   Preparing metadata (pyproject.toml): finished with status 'done'
# [diff_gaussian_rasterization] Building wheels for collected packages: diff_gaussian_rasterization
# [diff_gaussian_rasterization]   Building wheel for diff_gaussian_rasterization (pyproject.toml): started
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization] still running...
# [diff_gaussian_rasterization]   Building wheel for diff_gaussian_rasterization (pyproject.toml): finished with status 'done'
# [diff_gaussian_rasterization]   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3816789 sha256=4edd17048bed2598598f75056b2124059a788f9b32c8667df076d90843e9ad0c
# [diff_gaussian_rasterization]   Stored in directory: /root/.cache/pip/wheels/01/e0/e8/f40a1cd6a1d5760cbd3036081bdad5b36c41fc11c786d4a404
# [diff_gaussian_rasterization] Successfully built diff_gaussian_rasterization
# [diff_gaussian_rasterization] Installing collected packages: diff_gaussian_rasterization
# [diff_gaussian_rasterization] Successfully installed diff_gaussian_rasterization-0.0.0
# [diff_gaussian_rasterization] RETURN CODE = 0
# Installed: diff_gaussian_rasterization
# [simple_knn] START: bash -lc cd "/content/gaussian-splatting/submodules/simple-knn" && MAX_JOBS=2 python3 -m pip install --no-build-isolation .
# [simple_knn] still running...
# [simple_knn] Processing ./.
# [simple_knn]   Preparing metadata (pyproject.toml): started
# [simple_knn]   Preparing metadata (pyproject.toml): finished with status 'done'
# [simple_knn] Building wheels for collected packages: simple_knn
# [simple_knn]   Building wheel for simple_knn (pyproject.toml): started
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn] still running...
# [simple_knn]   Building wheel for simple_knn (pyproject.toml): finished with status 'done'
# [simple_knn]   Created wheel for simple_knn: filename=simple_knn-0.0.0-cp312-cp312-linux_x86_64.whl size=3555553 sha256=7df3c30e8afa4b8f5afbc55b7cf9b6dd9adef774adbbf17473b73273b9527fbc
# [simple_knn]   Stored in directory: /root/.cache/pip/wheels/0a/f2/1b/255828ebad94ea248378281b7926639d83ce4f394f0052800d
# [simple_knn] Successfully built simple_knn
# [simple_knn] Installing collected packages: simple_knn
# [simple_knn] Successfully installed simple_knn-0.0.0
# [simple_knn] RETURN CODE = 0
# Installed: simple_knn
# Gaussian Splatting minimal deps + extensions installed

# %%
# ==================================================
# CELL 4 - Quick import test for GS + eval packages
# ==================================================
import sys

sys.path.insert(0, str(GS_REPO))

import cv2
import diff_gaussian_rasterization
import lpips
import simple_knn

print("Imports OK")
print("GS_REPO =", GS_REPO)
# Out:
# Imports OK
# GS_REPO = /content/gaussian-splatting

# %%
# ================================================
# CELL 5 - Run train + render + eval for B2 debug
# ================================================
import os
from pathlib import Path

assert PROJECT_DIR.exists(), PROJECT_DIR
assert DATASET_ROOT.exists(), DATASET_ROOT
assert COLMAP_BIN.exists(), COLMAP_BIN
assert GS_REPO.exists(), GS_REPO

env = os.environ.copy()
env['DATASET_ROOT'] = str(DATASET_ROOT)
env['COLMAP_BIN'] = str(COLMAP_BIN)
env['GS_REPO'] = str(GS_REPO)
env.update(extra_train_env)

env['RUN_DENSE'] = '0'
env['RUN_TRAIN'] = '1'
env['RUN_RENDER'] = '1'
env['RUN_EVAL'] = '1'
env['SOURCE_MODE'] = 'prepared'
env['ITERATION'] = '-1'

scene_root = PROJECT_DIR / 'pipeline' / 'work' / SCENE
log_files = [
    scene_root / 'train.log',
    scene_root / 'logs' / '05_render_b2_pilot.log',
    scene_root / 'logs' / '05_eval_b2_pilot.log',
    scene_root / 'logs' / '05_b2_pilot_summary.txt',
]

run_and_stream(
    ['bash', str(PROJECT_DIR / 'pipeline' / 'scripts' / '05_run_b2_pilot.sh'), SCENE],
    env=env,
    log_files=log_files,
    poll_seconds=15,
    label='b2-train-render-eval',
)

print('B2 train/render/eval done')
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Training progress:  31%|███       | 9310/30000 [02:13<04:53, 70.45it/s, Loss=0.0675080, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9320/30000 [02:13<04:55, 70.07it/s, Loss=0.0675080, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9320/30000 [02:13<04:55, 70.07it/s, Loss=0.0690539, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9330/30000 [02:13<04:58, 69.14it/s, Loss=0.0690539, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9330/30000 [02:13<04:58, 69.14it/s, Loss=0.0770670, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9340/30000 [02:13<04:55, 70.01it/s, Loss=0.0770670, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9340/30000 [02:14<04:55, 70.01it/s, Loss=0.0601561, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9350/30000 [02:14<04:48, 71.58it/s, Loss=0.0601561, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9350/30000 [02:14<04:48, 71.58it/s, Loss=0.0526125, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9360/30000 [02:14<04:42, 73.18it/s, Loss=0.0526125, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9360/30000 [02:14<04:42, 73.18it/s, Loss=0.0638665, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9370/30000 [02:14<04:38, 73.97it/s, Loss=0.0638665, Depth Loss=0.0000000]
# Training progress:  31%|███       | 9370/30000 [02:14<04:38, 73.97it/s, Loss=0.0530755, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9380/30000 [02:14<04:35, 74.73it/s, Loss=0.0530755, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9380/30000 [02:14<04:35, 74.73it/s, Loss=0.0632096, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9390/30000 [02:14<04:37, 74.31it/s, Loss=0.0632096, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9390/30000 [02:14<04:37, 74.31it/s, Loss=0.0695003, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9400/30000 [02:14<04:36, 74.43it/s, Loss=0.0695003, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9400/30000 [02:14<04:36, 74.43it/s, Loss=0.0883227, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9410/30000 [02:14<04:29, 76.31it/s, Loss=0.0883227, Depth Loss=0.0000000]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
#
# --- train.log ---
#
# Training progress:  31%|███▏      | 9410/30000 [02:14<04:29, 76.31it/s, Loss=0.0599212, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9420/30000 [02:14<04:36, 74.56it/s, Loss=0.0599212, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9420/30000 [02:15<04:36, 74.56it/s, Loss=0.0668173, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9430/30000 [02:15<04:40, 73.41it/s, Loss=0.0668173, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9430/30000 [02:15<04:40, 73.41it/s, Loss=0.0658681, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9440/30000 [02:15<04:39, 73.54it/s, Loss=0.0658681, Depth Loss=0.0000000]
# Training progress:  31%|███▏      | 9440/30000 [02:15<04:39, 73.54it/s, Loss=0.0666114, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9450/30000 [02:15<04:37, 73.97it/s, Loss=0.0666114, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9450/30000 [02:15<04:37, 73.97it/s, Loss=0.0649461, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9460/30000 [02:15<04:37, 73.98it/s, Loss=0.0649461, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9460/30000 [02:15<04:37, 73.98it/s, Loss=0.0539828, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9470/30000 [02:15<04:35, 74.49it/s, Loss=0.0539828, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9470/30000 [02:15<04:35, 74.49it/s, Loss=0.1019343, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9480/30000 [02:15<04:33, 75.15it/s, Loss=0.1019343, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9480/30000 [02:15<04:33, 75.15it/s, Loss=0.0649821, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9490/30000 [02:15<04:33, 74.97it/s, Loss=0.0649821, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9490/30000 [02:16<04:33, 74.97it/s, Loss=0.0669071, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9500/30000 [02:16<04:37, 73.91it/s, Loss=0.0669071, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9500/30000 [02:16<04:37, 73.91it/s, Loss=0.0800390, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9510/30000 [02:16<04:32, 75.19it/s, Loss=0.0800390, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9510/30000 [02:16<04:32, 75.19it/s, Loss=0.0600942, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9520/30000 [02:16<04:31, 75.37it/s, Loss=0.0600942, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9520/30000 [02:16<04:31, 75.37it/s, Loss=0.0772174, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9530/30000 [02:16<04:32, 75.17it/s, Loss=0.0772174, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9530/30000 [02:16<04:32, 75.17it/s, Loss=0.0808537, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9540/30000 [02:16<04:32, 75.08it/s, Loss=0.0808537, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9540/30000 [02:16<04:32, 75.08it/s, Loss=0.0821880, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9550/30000 [02:16<04:32, 74.95it/s, Loss=0.0821880, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9550/30000 [02:16<04:32, 74.95it/s, Loss=0.0695241, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9560/30000 [02:16<04:33, 74.85it/s, Loss=0.0695241, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  32%|███▏      | 9560/30000 [02:16<04:33, 74.85it/s, Loss=0.0557670, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9570/30000 [02:16<04:38, 73.26it/s, Loss=0.0557670, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9570/30000 [02:17<04:38, 73.26it/s, Loss=0.0722566, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9580/30000 [02:17<04:35, 74.14it/s, Loss=0.0722566, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9580/30000 [02:17<04:35, 74.14it/s, Loss=0.0642030, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9590/30000 [02:17<04:29, 75.68it/s, Loss=0.0642030, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9590/30000 [02:17<04:29, 75.68it/s, Loss=0.0637178, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9600/30000 [02:17<04:30, 75.41it/s, Loss=0.0637178, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9600/30000 [02:17<04:30, 75.41it/s, Loss=0.0525090, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9610/30000 [02:17<04:29, 75.60it/s, Loss=0.0525090, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9610/30000 [02:17<04:29, 75.60it/s, Loss=0.0698261, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9620/30000 [02:17<04:30, 75.33it/s, Loss=0.0698261, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9620/30000 [02:17<04:30, 75.33it/s, Loss=0.0840236, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9630/30000 [02:17<04:29, 75.67it/s, Loss=0.0840236, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9630/30000 [02:17<04:29, 75.67it/s, Loss=0.0822839, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9640/30000 [02:17<04:28, 75.77it/s, Loss=0.0822839, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9640/30000 [02:18<04:28, 75.77it/s, Loss=0.0580634, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9650/30000 [02:18<04:34, 74.04it/s, Loss=0.0580634, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9650/30000 [02:18<04:34, 74.04it/s, Loss=0.0705809, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9660/30000 [02:18<04:29, 75.46it/s, Loss=0.0705809, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9660/30000 [02:18<04:29, 75.46it/s, Loss=0.0686093, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9670/30000 [02:18<04:28, 75.61it/s, Loss=0.0686093, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9670/30000 [02:18<04:28, 75.61it/s, Loss=0.0675949, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9680/30000 [02:18<04:29, 75.32it/s, Loss=0.0675949, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9680/30000 [02:18<04:29, 75.32it/s, Loss=0.0708537, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9690/30000 [02:18<04:28, 75.66it/s, Loss=0.0708537, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9690/30000 [02:18<04:28, 75.66it/s, Loss=0.0702077, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9700/30000 [02:18<04:24, 76.65it/s, Loss=0.0702077, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9700/30000 [02:18<04:24, 76.65it/s, Loss=0.0589255, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9710/30000 [02:18<04:25, 76.35it/s, Loss=0.0589255, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  32%|███▏      | 9710/30000 [02:18<04:25, 76.35it/s, Loss=0.0652217, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9720/30000 [02:18<04:25, 76.33it/s, Loss=0.0652217, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9720/30000 [02:19<04:25, 76.33it/s, Loss=0.0611254, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9730/30000 [02:19<04:32, 74.38it/s, Loss=0.0611254, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9730/30000 [02:19<04:32, 74.38it/s, Loss=0.0516320, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9740/30000 [02:19<04:30, 74.85it/s, Loss=0.0516320, Depth Loss=0.0000000]
# Training progress:  32%|███▏      | 9740/30000 [02:19<04:30, 74.85it/s, Loss=0.0739179, Depth Loss=0.0000000]
# Training progress:  32%|███▎      | 9750/30000 [02:19<04:30, 74.75it/s, Loss=0.0739179, Depth Loss=0.0000000]
# Training progress:  32%|███▎      | 9750/30000 [02:19<04:30, 74.75it/s, Loss=0.0692467, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9760/30000 [02:19<04:29, 75.12it/s, Loss=0.0692467, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9760/30000 [02:19<04:29, 75.12it/s, Loss=0.0593751, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9770/30000 [02:19<04:28, 75.21it/s, Loss=0.0593751, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9770/30000 [02:19<04:28, 75.21it/s, Loss=0.0600306, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9780/30000 [02:19<04:26, 75.86it/s, Loss=0.0600306, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9780/30000 [02:19<04:26, 75.86it/s, Loss=0.0812285, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9790/30000 [02:19<04:22, 77.06it/s, Loss=0.0812285, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9790/30000 [02:20<04:22, 77.06it/s, Loss=0.0738961, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9800/30000 [02:20<04:24, 76.29it/s, Loss=0.0738961, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9800/30000 [02:20<04:24, 76.29it/s, Loss=0.0746881, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9810/30000 [02:20<04:26, 75.80it/s, Loss=0.0746881, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9810/30000 [02:20<04:26, 75.80it/s, Loss=0.0692002, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9820/30000 [02:20<04:27, 75.36it/s, Loss=0.0692002, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9820/30000 [02:20<04:27, 75.36it/s, Loss=0.0622314, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9830/30000 [02:20<04:26, 75.67it/s, Loss=0.0622314, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9830/30000 [02:20<04:26, 75.67it/s, Loss=0.0793578, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9840/30000 [02:20<04:22, 76.80it/s, Loss=0.0793578, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9840/30000 [02:20<04:22, 76.80it/s, Loss=0.0593252, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9850/30000 [02:20<04:22, 76.63it/s, Loss=0.0593252, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9850/30000 [02:20<04:22, 76.63it/s, Loss=0.0722117, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9860/30000 [02:20<04:22, 76.79it/s, Loss=0.0722117, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  33%|███▎      | 9860/30000 [02:20<04:22, 76.79it/s, Loss=0.0677070, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9870/30000 [02:20<04:22, 76.66it/s, Loss=0.0677070, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9870/30000 [02:21<04:22, 76.66it/s, Loss=0.0687853, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9880/30000 [02:21<04:21, 77.01it/s, Loss=0.0687853, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9880/30000 [02:21<04:21, 77.01it/s, Loss=0.0677216, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9890/30000 [02:21<04:22, 76.75it/s, Loss=0.0677216, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9890/30000 [02:21<04:22, 76.75it/s, Loss=0.0626665, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9900/30000 [02:21<04:25, 75.58it/s, Loss=0.0626665, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9900/30000 [02:21<04:25, 75.58it/s, Loss=0.0771603, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9910/30000 [02:21<04:27, 75.21it/s, Loss=0.0771603, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9910/30000 [02:21<04:27, 75.21it/s, Loss=0.0697789, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9920/30000 [02:21<04:30, 74.37it/s, Loss=0.0697789, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9920/30000 [02:21<04:30, 74.37it/s, Loss=0.0736443, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9930/30000 [02:21<04:27, 75.05it/s, Loss=0.0736443, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9930/30000 [02:21<04:27, 75.05it/s, Loss=0.0663873, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9940/30000 [02:21<04:24, 75.85it/s, Loss=0.0663873, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9940/30000 [02:21<04:24, 75.85it/s, Loss=0.0605400, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9950/30000 [02:21<04:26, 75.27it/s, Loss=0.0605400, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9950/30000 [02:22<04:26, 75.27it/s, Loss=0.0699166, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9960/30000 [02:22<04:23, 76.10it/s, Loss=0.0699166, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9960/30000 [02:22<04:23, 76.10it/s, Loss=0.0636270, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9970/30000 [02:22<04:28, 74.58it/s, Loss=0.0636270, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9970/30000 [02:22<04:28, 74.58it/s, Loss=0.0592686, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9980/30000 [02:22<04:27, 74.73it/s, Loss=0.0592686, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9980/30000 [02:22<04:27, 74.73it/s, Loss=0.0554427, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9990/30000 [02:22<04:27, 74.83it/s, Loss=0.0554427, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 9990/30000 [02:22<04:27, 74.83it/s, Loss=0.0629703, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10000/30000 [02:22<04:28, 74.45it/s, Loss=0.0629703, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  33%|███▎      | 10000/30000 [02:25<04:28, 74.45it/s, Loss=0.0520913, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10010/30000 [02:25<26:39, 12.50it/s, Loss=0.0520913, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10010/30000 [02:25<26:39, 12.50it/s, Loss=0.0513155, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10020/30000 [02:25<20:09, 16.52it/s, Loss=0.0513155, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10020/30000 [02:25<20:09, 16.52it/s, Loss=0.0643065, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10030/30000 [02:25<15:31, 21.44it/s, Loss=0.0643065, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10030/30000 [02:25<15:31, 21.44it/s, Loss=0.0670132, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10040/30000 [02:25<12:11, 27.30it/s, Loss=0.0670132, Depth Loss=0.0000000]
# Training progress:  33%|███▎      | 10040/30000 [02:25<12:11, 27.30it/s, Loss=0.0683649, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10050/30000 [02:25<09:55, 33.51it/s, Loss=0.0683649, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10050/30000 [02:25<09:55, 33.51it/s, Loss=0.0557932, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10060/30000 [02:25<08:25, 39.43it/s, Loss=0.0557932, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10060/30000 [02:25<08:25, 39.43it/s, Loss=0.0612440, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10070/30000 [02:25<07:16, 45.64it/s, Loss=0.0612440, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10070/30000 [02:25<07:16, 45.64it/s, Loss=0.0688057, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10080/30000 [02:25<06:24, 51.81it/s, Loss=0.0688057, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10080/30000 [02:26<06:24, 51.81it/s, Loss=0.0567778, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10090/30000 [02:26<05:52, 56.50it/s, Loss=0.0567778, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10090/30000 [02:26<05:52, 56.50it/s, Loss=0.0600252, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10100/30000 [02:26<05:39, 58.67it/s, Loss=0.0600252, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10100/30000 [02:26<05:39, 58.67it/s, Loss=0.0736832, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10110/30000 [02:26<05:23, 61.40it/s, Loss=0.0736832, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10110/30000 [02:26<05:23, 61.40it/s, Loss=0.0810223, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10120/30000 [02:26<05:18, 62.35it/s, Loss=0.0810223, Depth Loss=0.0000000]
# Training progress:  34%|███▎      | 10120/30000 [02:26<05:18, 62.35it/s, Loss=0.0739463, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10130/30000 [02:26<05:02, 65.76it/s, Loss=0.0739463, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10130/30000 [02:26<05:02, 65.76it/s, Loss=0.0639655, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10140/30000 [02:26<04:53, 67.74it/s, Loss=0.0639655, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  34%|███▍      | 10140/30000 [02:27<04:53, 67.74it/s, Loss=0.0650916, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10150/30000 [02:27<04:49, 68.48it/s, Loss=0.0650916, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10150/30000 [02:27<04:49, 68.48it/s, Loss=0.0639788, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10160/30000 [02:27<04:39, 70.86it/s, Loss=0.0639788, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10160/30000 [02:27<04:39, 70.86it/s, Loss=0.0732063, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10170/30000 [02:27<04:35, 72.06it/s, Loss=0.0732063, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10170/30000 [02:27<04:35, 72.06it/s, Loss=0.0594318, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10180/30000 [02:27<04:32, 72.79it/s, Loss=0.0594318, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10180/30000 [02:27<04:32, 72.79it/s, Loss=0.0622899, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10190/30000 [02:27<04:28, 73.86it/s, Loss=0.0622899, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10190/30000 [02:27<04:28, 73.86it/s, Loss=0.0621578, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10200/30000 [02:27<04:27, 74.05it/s, Loss=0.0621578, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10200/30000 [02:27<04:27, 74.05it/s, Loss=0.0674372, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10210/30000 [02:27<04:24, 74.73it/s, Loss=0.0674372, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10210/30000 [02:27<04:24, 74.73it/s, Loss=0.0622067, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10220/30000 [02:27<04:24, 74.78it/s, Loss=0.0622067, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10220/30000 [02:28<04:24, 74.78it/s, Loss=0.0833617, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10230/30000 [02:28<04:22, 75.42it/s, Loss=0.0833617, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10230/30000 [02:28<04:22, 75.42it/s, Loss=0.0791198, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10240/30000 [02:28<04:21, 75.60it/s, Loss=0.0791198, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10240/30000 [02:28<04:21, 75.60it/s, Loss=0.0660449, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10250/30000 [02:28<04:20, 75.70it/s, Loss=0.0660449, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10250/30000 [02:28<04:20, 75.70it/s, Loss=0.0510861, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10260/30000 [02:28<04:20, 75.78it/s, Loss=0.0510861, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10260/30000 [02:28<04:20, 75.78it/s, Loss=0.0643779, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10270/30000 [02:28<04:22, 75.04it/s, Loss=0.0643779, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10270/30000 [02:28<04:22, 75.04it/s, Loss=0.0732948, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10280/30000 [02:28<04:27, 73.65it/s, Loss=0.0732948, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10280/30000 [02:28<04:27, 73.65it/s, Loss=0.0635621, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10290/30000 [02:28<04:23, 74.70it/s, Loss=0.0635621, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  34%|███▍      | 10290/30000 [02:29<04:23, 74.70it/s, Loss=0.0696229, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10300/30000 [02:29<04:28, 73.40it/s, Loss=0.0696229, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10300/30000 [02:29<04:28, 73.40it/s, Loss=0.0642035, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10310/30000 [02:29<04:23, 74.70it/s, Loss=0.0642035, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10310/30000 [02:29<04:23, 74.70it/s, Loss=0.0605261, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10320/30000 [02:29<04:21, 75.20it/s, Loss=0.0605261, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10320/30000 [02:29<04:21, 75.20it/s, Loss=0.0672741, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10330/30000 [02:29<04:19, 75.76it/s, Loss=0.0672741, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10330/30000 [02:29<04:19, 75.76it/s, Loss=0.0720233, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10340/30000 [02:29<04:18, 76.11it/s, Loss=0.0720233, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10340/30000 [02:29<04:18, 76.11it/s, Loss=0.0762267, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10350/30000 [02:29<04:18, 75.89it/s, Loss=0.0762267, Depth Loss=0.0000000]
# Training progress:  34%|███▍      | 10350/30000 [02:29<04:18, 75.89it/s, Loss=0.0538396, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10360/30000 [02:29<04:22, 74.84it/s, Loss=0.0538396, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10360/30000 [02:29<04:22, 74.84it/s, Loss=0.0605719, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10370/30000 [02:29<04:21, 74.96it/s, Loss=0.0605719, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10370/30000 [02:30<04:21, 74.96it/s, Loss=0.0661515, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10380/30000 [02:30<04:16, 76.44it/s, Loss=0.0661515, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10380/30000 [02:30<04:16, 76.44it/s, Loss=0.0715428, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10390/30000 [02:30<04:16, 76.47it/s, Loss=0.0715428, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10390/30000 [02:30<04:16, 76.47it/s, Loss=0.0746069, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10400/30000 [02:30<04:18, 75.81it/s, Loss=0.0746069, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10400/30000 [02:30<04:18, 75.81it/s, Loss=0.0563838, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10410/30000 [02:30<04:12, 77.50it/s, Loss=0.0563838, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10410/30000 [02:30<04:12, 77.50it/s, Loss=0.0627518, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10420/30000 [02:30<04:19, 75.39it/s, Loss=0.0627518, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10420/30000 [02:30<04:19, 75.39it/s, Loss=0.0557553, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10430/30000 [02:30<04:16, 76.34it/s, Loss=0.0557553, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10430/30000 [02:30<04:16, 76.34it/s, Loss=0.0588419, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10440/30000 [02:30<04:16, 76.12it/s, Loss=0.0588419, Depth Loss=0.0000000]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
#
# --- train.log ---
#
# Training progress:  35%|███▍      | 10440/30000 [02:30<04:16, 76.12it/s, Loss=0.0623859, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10450/30000 [02:30<04:18, 75.56it/s, Loss=0.0623859, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10450/30000 [02:31<04:18, 75.56it/s, Loss=0.0661459, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10460/30000 [02:31<04:19, 75.35it/s, Loss=0.0661459, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10460/30000 [02:31<04:19, 75.35it/s, Loss=0.0593482, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10470/30000 [02:31<04:21, 74.82it/s, Loss=0.0593482, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10470/30000 [02:31<04:21, 74.82it/s, Loss=0.0653976, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10480/30000 [02:31<04:16, 76.04it/s, Loss=0.0653976, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10480/30000 [02:31<04:16, 76.04it/s, Loss=0.0598378, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10490/30000 [02:31<04:17, 75.74it/s, Loss=0.0598378, Depth Loss=0.0000000]
# Training progress:  35%|███▍      | 10490/30000 [02:31<04:17, 75.74it/s, Loss=0.0730123, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10500/30000 [02:31<04:18, 75.33it/s, Loss=0.0730123, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10500/30000 [02:31<04:18, 75.33it/s, Loss=0.0571628, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10510/30000 [02:31<04:15, 76.35it/s, Loss=0.0571628, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10510/30000 [02:31<04:15, 76.35it/s, Loss=0.0623461, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10520/30000 [02:31<04:15, 76.16it/s, Loss=0.0623461, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10520/30000 [02:32<04:15, 76.16it/s, Loss=0.0591185, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10530/30000 [02:32<04:16, 75.78it/s, Loss=0.0591185, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10530/30000 [02:32<04:16, 75.78it/s, Loss=0.0658769, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10540/30000 [02:32<04:16, 75.93it/s, Loss=0.0658769, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10540/30000 [02:32<04:16, 75.93it/s, Loss=0.0749903, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10550/30000 [02:32<04:15, 76.06it/s, Loss=0.0749903, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10550/30000 [02:32<04:15, 76.06it/s, Loss=0.0741342, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10560/30000 [02:32<04:12, 77.03it/s, Loss=0.0741342, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10560/30000 [02:32<04:12, 77.03it/s, Loss=0.0722536, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10570/30000 [02:32<04:10, 77.48it/s, Loss=0.0722536, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10570/30000 [02:32<04:10, 77.48it/s, Loss=0.0594010, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10580/30000 [02:32<04:15, 76.00it/s, Loss=0.0594010, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10580/30000 [02:32<04:15, 76.00it/s, Loss=0.0614789, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10590/30000 [02:32<04:19, 74.88it/s, Loss=0.0614789, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  35%|███▌      | 10590/30000 [02:32<04:19, 74.88it/s, Loss=0.0570006, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10600/30000 [02:32<04:24, 73.43it/s, Loss=0.0570006, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10600/30000 [02:33<04:24, 73.43it/s, Loss=0.0736674, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10610/30000 [02:33<04:20, 74.55it/s, Loss=0.0736674, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10610/30000 [02:33<04:20, 74.55it/s, Loss=0.0678987, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10620/30000 [02:33<04:16, 75.53it/s, Loss=0.0678987, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10620/30000 [02:33<04:16, 75.53it/s, Loss=0.0591122, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10630/30000 [02:33<04:16, 75.39it/s, Loss=0.0591122, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10630/30000 [02:33<04:16, 75.39it/s, Loss=0.0584175, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10640/30000 [02:33<04:16, 75.43it/s, Loss=0.0584175, Depth Loss=0.0000000]
# Training progress:  35%|███▌      | 10640/30000 [02:33<04:16, 75.43it/s, Loss=0.0608446, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10650/30000 [02:33<04:10, 77.23it/s, Loss=0.0608446, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10650/30000 [02:33<04:10, 77.23it/s, Loss=0.0561638, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10660/30000 [02:33<04:16, 75.50it/s, Loss=0.0561638, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10660/30000 [02:33<04:16, 75.50it/s, Loss=0.0704788, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10670/30000 [02:33<04:19, 74.42it/s, Loss=0.0704788, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10670/30000 [02:34<04:19, 74.42it/s, Loss=0.0522507, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10680/30000 [02:34<04:20, 74.29it/s, Loss=0.0522507, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10680/30000 [02:34<04:20, 74.29it/s, Loss=0.0489070, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10690/30000 [02:34<04:19, 74.50it/s, Loss=0.0489070, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10690/30000 [02:34<04:19, 74.50it/s, Loss=0.0541023, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10700/30000 [02:34<04:21, 73.89it/s, Loss=0.0541023, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10700/30000 [02:34<04:21, 73.89it/s, Loss=0.0784507, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10710/30000 [02:34<04:19, 74.43it/s, Loss=0.0784507, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10710/30000 [02:34<04:19, 74.43it/s, Loss=0.0594607, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10720/30000 [02:34<04:15, 75.45it/s, Loss=0.0594607, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10720/30000 [02:34<04:15, 75.45it/s, Loss=0.0535950, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10730/30000 [02:34<04:14, 75.78it/s, Loss=0.0535950, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10730/30000 [02:34<04:14, 75.78it/s, Loss=0.0602941, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10740/30000 [02:34<04:17, 74.86it/s, Loss=0.0602941, Depth Loss=0.0000000]
# --- end train.log ---
#
# [b2-train-render-eval] [hcm0031] tiến độ: 10870/30000
#
# --- train.log ---
#
# Training progress:  36%|███▌      | 10740/30000 [02:34<04:17, 74.86it/s, Loss=0.0689540, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10750/30000 [02:34<04:16, 74.93it/s, Loss=0.0689540, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10750/30000 [02:35<04:16, 74.93it/s, Loss=0.0700141, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10760/30000 [02:35<04:15, 75.35it/s, Loss=0.0700141, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10760/30000 [02:35<04:15, 75.35it/s, Loss=0.0544076, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10770/30000 [02:35<04:17, 74.73it/s, Loss=0.0544076, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10770/30000 [02:35<04:17, 74.73it/s, Loss=0.0668422, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10780/30000 [02:35<04:15, 75.26it/s, Loss=0.0668422, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10780/30000 [02:35<04:15, 75.26it/s, Loss=0.0694242, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10790/30000 [02:35<04:14, 75.36it/s, Loss=0.0694242, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10790/30000 [02:35<04:14, 75.36it/s, Loss=0.0622135, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10800/30000 [02:35<04:12, 76.12it/s, Loss=0.0622135, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10800/30000 [02:35<04:12, 76.12it/s, Loss=0.0628499, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10810/30000 [02:35<04:16, 74.88it/s, Loss=0.0628499, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10810/30000 [02:35<04:16, 74.88it/s, Loss=0.0537481, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10820/30000 [02:35<04:15, 75.08it/s, Loss=0.0537481, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10820/30000 [02:36<04:15, 75.08it/s, Loss=0.0614294, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10830/30000 [02:36<04:14, 75.31it/s, Loss=0.0614294, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10830/30000 [02:36<04:14, 75.31it/s, Loss=0.0538765, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10840/30000 [02:36<04:14, 75.16it/s, Loss=0.0538765, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10840/30000 [02:36<04:14, 75.16it/s, Loss=0.0643482, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10850/30000 [02:36<04:12, 75.75it/s, Loss=0.0643482, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10850/30000 [02:36<04:12, 75.75it/s, Loss=0.0581797, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10860/30000 [02:36<04:13, 75.60it/s, Loss=0.0581797, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10860/30000 [02:36<04:13, 75.60it/s, Loss=0.0581621, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10870/30000 [02:36<04:09, 76.53it/s, Loss=0.0581621, Depth Loss=0.0000000]
# Training progress:  36%|███▌      | 10870/30000 [02:36<04:09, 76.53it/s, Loss=0.0795735, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10880/30000 [02:36<04:31, 70.33it/s, Loss=0.0795735, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10880/30000 [02:36<04:31, 70.33it/s, Loss=0.0745536, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10890/30000 [02:36<04:42, 67.54it/s, Loss=0.0745536, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  36%|███▋      | 10890/30000 [02:37<04:42, 67.54it/s, Loss=0.0537925, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10900/30000 [02:37<04:49, 65.99it/s, Loss=0.0537925, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10900/30000 [02:37<04:49, 65.99it/s, Loss=0.0701527, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10910/30000 [02:37<04:51, 65.49it/s, Loss=0.0701527, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10910/30000 [02:37<04:51, 65.49it/s, Loss=0.0655909, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10920/30000 [02:37<04:43, 67.20it/s, Loss=0.0655909, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10920/30000 [02:37<04:43, 67.20it/s, Loss=0.0739769, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10930/30000 [02:37<04:34, 69.48it/s, Loss=0.0739769, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10930/30000 [02:37<04:34, 69.48it/s, Loss=0.0579742, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10940/30000 [02:37<04:30, 70.39it/s, Loss=0.0579742, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10940/30000 [02:37<04:30, 70.39it/s, Loss=0.0614323, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10950/30000 [02:37<04:26, 71.58it/s, Loss=0.0614323, Depth Loss=0.0000000]
# Training progress:  36%|███▋      | 10950/30000 [02:37<04:26, 71.58it/s, Loss=0.0641728, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10960/30000 [02:37<04:29, 70.52it/s, Loss=0.0641728, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10960/30000 [02:38<04:29, 70.52it/s, Loss=0.0537142, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10970/30000 [02:38<04:26, 71.42it/s, Loss=0.0537142, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10970/30000 [02:38<04:26, 71.42it/s, Loss=0.0723506, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10980/30000 [02:38<04:24, 71.87it/s, Loss=0.0723506, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10980/30000 [02:38<04:24, 71.87it/s, Loss=0.0578976, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10990/30000 [02:38<04:22, 72.42it/s, Loss=0.0578976, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 10990/30000 [02:38<04:22, 72.42it/s, Loss=0.0688359, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11000/30000 [02:38<04:21, 72.68it/s, Loss=0.0688359, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11000/30000 [02:38<04:21, 72.68it/s, Loss=0.0614983, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11010/30000 [02:38<04:23, 71.94it/s, Loss=0.0614983, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11010/30000 [02:38<04:23, 71.94it/s, Loss=0.0624585, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11020/30000 [02:38<04:25, 71.44it/s, Loss=0.0624585, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11020/30000 [02:38<04:25, 71.44it/s, Loss=0.0544964, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11030/30000 [02:38<04:25, 71.57it/s, Loss=0.0544964, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  37%|███▋      | 11030/30000 [02:38<04:25, 71.57it/s, Loss=0.0579280, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11040/30000 [02:39<04:34, 68.96it/s, Loss=0.0579280, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11040/30000 [02:39<04:34, 68.96it/s, Loss=0.0632991, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11050/30000 [02:39<04:38, 67.94it/s, Loss=0.0632991, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11050/30000 [02:39<04:38, 67.94it/s, Loss=0.0572348, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11060/30000 [02:39<04:44, 66.49it/s, Loss=0.0572348, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11060/30000 [02:39<04:44, 66.49it/s, Loss=0.0607123, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11070/30000 [02:39<04:43, 66.75it/s, Loss=0.0607123, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11070/30000 [02:39<04:43, 66.75it/s, Loss=0.0696931, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11080/30000 [02:39<04:34, 69.01it/s, Loss=0.0696931, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11080/30000 [02:39<04:34, 69.01it/s, Loss=0.0675914, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11090/30000 [02:39<04:27, 70.64it/s, Loss=0.0675914, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11090/30000 [02:39<04:27, 70.64it/s, Loss=0.0655891, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11100/30000 [02:39<04:23, 71.74it/s, Loss=0.0655891, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11100/30000 [02:39<04:23, 71.74it/s, Loss=0.0669169, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11110/30000 [02:39<04:19, 72.69it/s, Loss=0.0669169, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11110/30000 [02:40<04:19, 72.69it/s, Loss=0.0714358, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11120/30000 [02:40<04:13, 74.35it/s, Loss=0.0714358, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11120/30000 [02:40<04:13, 74.35it/s, Loss=0.0770490, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11130/30000 [02:40<04:10, 75.25it/s, Loss=0.0770490, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11130/30000 [02:40<04:10, 75.25it/s, Loss=0.0597095, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11140/30000 [02:40<04:11, 75.07it/s, Loss=0.0597095, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11140/30000 [02:40<04:11, 75.07it/s, Loss=0.0586342, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11150/30000 [02:40<04:10, 75.25it/s, Loss=0.0586342, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11150/30000 [02:40<04:10, 75.25it/s, Loss=0.0569235, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11160/30000 [02:40<04:10, 75.31it/s, Loss=0.0569235, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11160/30000 [02:40<04:10, 75.31it/s, Loss=0.0606766, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11170/30000 [02:40<04:09, 75.42it/s, Loss=0.0606766, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11170/30000 [02:40<04:09, 75.42it/s, Loss=0.0778334, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11180/30000 [02:40<04:08, 75.67it/s, Loss=0.0778334, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  37%|███▋      | 11180/30000 [02:41<04:08, 75.67it/s, Loss=0.0798677, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11190/30000 [02:41<04:14, 73.98it/s, Loss=0.0798677, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11190/30000 [02:41<04:14, 73.98it/s, Loss=0.0589618, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11200/30000 [02:41<04:14, 73.73it/s, Loss=0.0589618, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11200/30000 [02:41<04:14, 73.73it/s, Loss=0.0674257, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11210/30000 [02:41<04:11, 74.61it/s, Loss=0.0674257, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11210/30000 [02:41<04:11, 74.61it/s, Loss=0.0618164, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11220/30000 [02:41<04:12, 74.45it/s, Loss=0.0618164, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11220/30000 [02:41<04:12, 74.45it/s, Loss=0.0625915, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11230/30000 [02:41<04:08, 75.43it/s, Loss=0.0625915, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11230/30000 [02:41<04:08, 75.43it/s, Loss=0.0663079, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11240/30000 [02:41<04:10, 75.00it/s, Loss=0.0663079, Depth Loss=0.0000000]
# Training progress:  37%|███▋      | 11240/30000 [02:41<04:10, 75.00it/s, Loss=0.0471046, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11250/30000 [02:41<04:11, 74.57it/s, Loss=0.0471046, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11250/30000 [02:41<04:11, 74.57it/s, Loss=0.0682531, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11260/30000 [02:41<04:10, 74.91it/s, Loss=0.0682531, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11260/30000 [02:42<04:10, 74.91it/s, Loss=0.0599361, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11270/30000 [02:42<04:10, 74.75it/s, Loss=0.0599361, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11270/30000 [02:42<04:10, 74.75it/s, Loss=0.0509711, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11280/30000 [02:42<04:07, 75.61it/s, Loss=0.0509711, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11280/30000 [02:42<04:07, 75.61it/s, Loss=0.0738066, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11290/30000 [02:42<04:04, 76.59it/s, Loss=0.0738066, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11290/30000 [02:42<04:04, 76.59it/s, Loss=0.0610854, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11300/30000 [02:42<04:04, 76.42it/s, Loss=0.0610854, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11300/30000 [02:42<04:04, 76.42it/s, Loss=0.0691651, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11310/30000 [02:42<04:06, 75.84it/s, Loss=0.0691651, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11310/30000 [02:42<04:06, 75.84it/s, Loss=0.0691740, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11320/30000 [02:42<04:08, 75.29it/s, Loss=0.0691740, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11320/30000 [02:42<04:08, 75.29it/s, Loss=0.0676425, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11330/30000 [02:42<04:06, 75.73it/s, Loss=0.0676425, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  38%|███▊      | 11330/30000 [02:43<04:06, 75.73it/s, Loss=0.0607998, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11340/30000 [02:43<04:11, 74.22it/s, Loss=0.0607998, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11340/30000 [02:43<04:11, 74.22it/s, Loss=0.0576335, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11350/30000 [02:43<04:12, 73.81it/s, Loss=0.0576335, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11350/30000 [02:43<04:12, 73.81it/s, Loss=0.0565414, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11360/30000 [02:43<04:11, 74.03it/s, Loss=0.0565414, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11360/30000 [02:43<04:11, 74.03it/s, Loss=0.0597877, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11370/30000 [02:43<04:13, 73.55it/s, Loss=0.0597877, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11370/30000 [02:43<04:13, 73.55it/s, Loss=0.0530029, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11380/30000 [02:43<04:11, 74.00it/s, Loss=0.0530029, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11380/30000 [02:43<04:11, 74.00it/s, Loss=0.0589216, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11390/30000 [02:43<04:10, 74.25it/s, Loss=0.0589216, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11390/30000 [02:43<04:10, 74.25it/s, Loss=0.0622190, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11400/30000 [02:43<04:08, 74.77it/s, Loss=0.0622190, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11400/30000 [02:43<04:08, 74.77it/s, Loss=0.0637483, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11410/30000 [02:43<04:12, 73.56it/s, Loss=0.0637483, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11410/30000 [02:44<04:12, 73.56it/s, Loss=0.0616912, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11420/30000 [02:44<04:14, 73.04it/s, Loss=0.0616912, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11420/30000 [02:44<04:14, 73.04it/s, Loss=0.0600037, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11430/30000 [02:44<04:12, 73.43it/s, Loss=0.0600037, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11430/30000 [02:44<04:12, 73.43it/s, Loss=0.0695506, Depth Loss=0.0000000]
# Training progress:  38%|███▊      | 11440/30000 [02:44<04:12, 73.51it/s, Loss=0.0695506, Depth Loss=0.0000000]
# ...
# Training progress:  98%|█████████▊| 29480/30000 [07:00<00:07, 70.16it/s, Loss=0.0330703, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29490/30000 [07:00<00:07, 69.64it/s, Loss=0.0330703, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29490/30000 [07:00<00:07, 69.64it/s, Loss=0.0533915, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29500/30000 [07:00<00:07, 69.84it/s, Loss=0.0533915, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29500/30000 [07:00<00:07, 69.84it/s, Loss=0.0487875, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29510/30000 [07:00<00:06, 70.09it/s, Loss=0.0487875, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29510/30000 [07:01<00:06, 70.09it/s, Loss=0.0278175, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29520/30000 [07:01<00:06, 70.24it/s, Loss=0.0278175, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29520/30000 [07:01<00:06, 70.24it/s, Loss=0.0373421, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29530/30000 [07:01<00:06, 71.02it/s, Loss=0.0373421, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29530/30000 [07:01<00:06, 71.02it/s, Loss=0.0341179, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29540/30000 [07:01<00:06, 71.78it/s, Loss=0.0341179, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29540/30000 [07:01<00:06, 71.78it/s, Loss=0.0306260, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29550/30000 [07:01<00:06, 71.58it/s, Loss=0.0306260, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 29550/30000 [07:01<00:06, 71.58it/s, Loss=0.0311649, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29560/30000 [07:01<00:06, 69.77it/s, Loss=0.0311649, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29560/30000 [07:01<00:06, 69.77it/s, Loss=0.0511139, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29570/30000 [07:01<00:06, 70.55it/s, Loss=0.0511139, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  99%|█████████▊| 29570/30000 [07:01<00:06, 70.55it/s, Loss=0.0429260, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29580/30000 [07:01<00:05, 70.38it/s, Loss=0.0429260, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29580/30000 [07:02<00:05, 70.38it/s, Loss=0.0279952, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29590/30000 [07:02<00:05, 69.77it/s, Loss=0.0279952, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29590/30000 [07:02<00:05, 69.77it/s, Loss=0.0370717, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29600/30000 [07:02<00:05, 69.35it/s, Loss=0.0370717, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29600/30000 [07:02<00:05, 69.35it/s, Loss=0.0271956, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29610/30000 [07:02<00:05, 69.08it/s, Loss=0.0271956, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29610/30000 [07:02<00:05, 69.08it/s, Loss=0.0278772, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29620/30000 [07:02<00:05, 69.45it/s, Loss=0.0278772, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 29620/30000 [07:02<00:05, 69.45it/s, Loss=0.0326875, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29630/30000 [07:02<00:05, 68.35it/s, Loss=0.0326875, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29630/30000 [07:02<00:05, 68.35it/s, Loss=0.0374174, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29640/30000 [07:02<00:05, 68.10it/s, Loss=0.0374174, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29640/30000 [07:02<00:05, 68.10it/s, Loss=0.0343325, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29650/30000 [07:02<00:05, 68.75it/s, Loss=0.0343325, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29650/30000 [07:03<00:05, 68.75it/s, Loss=0.0351053, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29660/30000 [07:03<00:04, 69.58it/s, Loss=0.0351053, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29660/30000 [07:03<00:04, 69.58it/s, Loss=0.0315873, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29670/30000 [07:03<00:04, 70.23it/s, Loss=0.0315873, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29670/30000 [07:03<00:04, 70.23it/s, Loss=0.0362998, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29680/30000 [07:03<00:04, 70.47it/s, Loss=0.0362998, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29680/30000 [07:03<00:04, 70.47it/s, Loss=0.0297324, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29690/30000 [07:03<00:04, 69.91it/s, Loss=0.0297324, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29690/30000 [07:03<00:04, 69.91it/s, Loss=0.0266175, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29700/30000 [07:03<00:04, 69.27it/s, Loss=0.0266175, Depth Loss=0.0000000]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
#
# --- train.log ---
#
# Training progress:  99%|█████████▉| 29700/30000 [07:03<00:04, 69.27it/s, Loss=0.0317016, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29710/30000 [07:03<00:04, 67.70it/s, Loss=0.0317016, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29710/30000 [07:03<00:04, 67.70it/s, Loss=0.0329039, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29720/30000 [07:03<00:04, 68.34it/s, Loss=0.0329039, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29720/30000 [07:04<00:04, 68.34it/s, Loss=0.0350694, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29730/30000 [07:04<00:03, 68.66it/s, Loss=0.0350694, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29730/30000 [07:04<00:03, 68.66it/s, Loss=0.0340328, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29740/30000 [07:04<00:03, 70.30it/s, Loss=0.0340328, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29740/30000 [07:04<00:03, 70.30it/s, Loss=0.0301613, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29750/30000 [07:04<00:03, 70.43it/s, Loss=0.0301613, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29750/30000 [07:04<00:03, 70.43it/s, Loss=0.0522655, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29760/30000 [07:04<00:03, 71.57it/s, Loss=0.0522655, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29760/30000 [07:04<00:03, 71.57it/s, Loss=0.0374414, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29770/30000 [07:04<00:03, 69.73it/s, Loss=0.0374414, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29770/30000 [07:04<00:03, 69.73it/s, Loss=0.0403674, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29780/30000 [07:04<00:03, 70.60it/s, Loss=0.0403674, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29780/30000 [07:04<00:03, 70.60it/s, Loss=0.0447487, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29790/30000 [07:04<00:02, 70.81it/s, Loss=0.0447487, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29790/30000 [07:05<00:02, 70.81it/s, Loss=0.0482338, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29800/30000 [07:05<00:02, 71.37it/s, Loss=0.0482338, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29800/30000 [07:05<00:02, 71.37it/s, Loss=0.0384466, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29810/30000 [07:05<00:02, 71.62it/s, Loss=0.0384466, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29810/30000 [07:05<00:02, 71.62it/s, Loss=0.0309078, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29820/30000 [07:05<00:02, 72.63it/s, Loss=0.0309078, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29820/30000 [07:05<00:02, 72.63it/s, Loss=0.0319751, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29830/30000 [07:05<00:02, 71.12it/s, Loss=0.0319751, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29830/30000 [07:05<00:02, 71.12it/s, Loss=0.0313418, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 29840/30000 [07:05<00:02, 67.82it/s, Loss=0.0313418, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress:  99%|█████████▉| 29840/30000 [07:05<00:02, 67.82it/s, Loss=0.0394940, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29850/30000 [07:05<00:02, 66.76it/s, Loss=0.0394940, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29850/30000 [07:05<00:02, 66.76it/s, Loss=0.0396432, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29860/30000 [07:05<00:02, 64.17it/s, Loss=0.0396432, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29860/30000 [07:06<00:02, 64.17it/s, Loss=0.0361749, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29870/30000 [07:06<00:02, 63.77it/s, Loss=0.0361749, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29870/30000 [07:06<00:02, 63.77it/s, Loss=0.0425935, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29880/30000 [07:06<00:01, 64.80it/s, Loss=0.0425935, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29880/30000 [07:06<00:01, 64.80it/s, Loss=0.0393166, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29890/30000 [07:06<00:01, 66.16it/s, Loss=0.0393166, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29890/30000 [07:06<00:01, 66.16it/s, Loss=0.0410787, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29900/30000 [07:06<00:01, 67.38it/s, Loss=0.0410787, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29900/30000 [07:06<00:01, 67.38it/s, Loss=0.0327510, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29910/30000 [07:06<00:01, 67.40it/s, Loss=0.0327510, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29910/30000 [07:06<00:01, 67.40it/s, Loss=0.0307844, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29920/30000 [07:06<00:01, 67.86it/s, Loss=0.0307844, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29920/30000 [07:06<00:01, 67.86it/s, Loss=0.0473758, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29930/30000 [07:06<00:01, 67.84it/s, Loss=0.0473758, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29930/30000 [07:07<00:01, 67.84it/s, Loss=0.0335209, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29940/30000 [07:07<00:00, 67.27it/s, Loss=0.0335209, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29940/30000 [07:07<00:00, 67.27it/s, Loss=0.0292671, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29950/30000 [07:07<00:00, 67.39it/s, Loss=0.0292671, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29950/30000 [07:07<00:00, 67.39it/s, Loss=0.0297543, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29960/30000 [07:07<00:00, 67.21it/s, Loss=0.0297543, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29960/30000 [07:07<00:00, 67.21it/s, Loss=0.0429832, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29970/30000 [07:07<00:00, 67.39it/s, Loss=0.0429832, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29970/30000 [07:07<00:00, 67.39it/s, Loss=0.0395570, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29980/30000 [07:07<00:00, 67.41it/s, Loss=0.0395570, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# Training progress: 100%|█████████▉| 29980/30000 [07:07<00:00, 67.41it/s, Loss=0.0349473, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29990/30000 [07:07<00:00, 65.05it/s, Loss=0.0349473, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 29990/30000 [07:08<00:00, 65.05it/s, Loss=0.0391128, Depth Loss=0.0000000]
# Training progress: 100%|██████████| 30000/30000 [07:08<00:00, 64.37it/s, Loss=0.0391128, Depth Loss=0.0000000]
# Training progress: 100%|██████████| 30000/30000 [07:08<00:00, 70.09it/s, Loss=0.0391128, Depth Loss=0.0000000]
# --- end train.log ---
#
#
# --- train.log ---
#
# [ITER 2000] Saving Gaussians [23/07 16:01:49]
#
# [ITER 2000] Saving Checkpoint [23/07 16:01:50]
#
# [ITER 4000] Saving Gaussians [23/07 16:02:17]
#
# [ITER 4000] Saving Checkpoint [23/07 16:02:19]
#
# [ITER 6000] Saving Gaussians [23/07 16:02:46]
#
# [ITER 6000] Saving Checkpoint [23/07 16:02:48]
#
# [ITER 8000] Saving Gaussians [23/07 16:03:15]
#
# [ITER 8000] Saving Checkpoint [23/07 16:03:17]
#
# [ITER 10000] Saving Gaussians [23/07 16:03:44]
#
# [ITER 10000] Saving Checkpoint [23/07 16:03:45]
#
# [ITER 12000] Saving Gaussians [23/07 16:04:13]
#
# [ITER 12000] Saving Checkpoint [23/07 16:04:15]
#
# [ITER 15000] Saving Gaussians [23/07 16:04:56]
#
# [ITER 15000] Saving Checkpoint [23/07 16:04:57]
#
# [ITER 30000] Evaluating train: L1 0.024194936454296115 PSNR 29.3651668548584 [23/07 16:08:29]
#
# [ITER 30000] Saving Gaussians [23/07 16:08:29]
#
# [ITER 30000] Saving Checkpoint [23/07 16:08:31]
#
# Training complete. [23/07 16:08:31]
# --- end train.log ---
#
# [b2-train-render-eval] still running...
# [b2-train-render-eval] [hcm0031] tiến độ: 30000/30000
# [b2-train-render-eval] Xong. Model dir: /content/project/pipeline/work/hcm0031/gs_model
# [b2-train-render-eval] Point cloud cuối: /content/project/pipeline/work/hcm0031/gs_model/point_cloud/iteration_30000/point_cloud.ply
# [b2-train-render-eval] Checkpoint resume: /content/project/pipeline/work/hcm0031/gs_model/chkpnt30000.pth
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
# [b2-train-render-eval] still running...
#
# --- 05_render_b2_pilot.log ---
# Render 50 pose | scene=hcm0031 | iteration=30000 | sh_degree=3 | antialiasing=True
#   10/50 -> DJI_20241227155557_0125_V.png
#   20/50 -> DJI_20241227155345_0025_V.png
#   30/50 -> DJI_20241227155547_0115_V.png
#   40/50 -> DJI_20241227155352_0032_V.png
#   50/50 -> DJI_20241227155507_0089_V.png
# --- end 05_render_b2_pilot.log ---
#
#
# --- 05_eval_b2_pilot.log ---
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#
#   0%|          | 0.00/233M [00:00<?, ?B/s]
#   8%|▊         | 17.8M/233M [00:00<00:01, 185MB/s]
#  15%|█▌        | 36.0M/233M [00:00<00:01, 188MB/s]
#  23%|██▎       | 54.4M/233M [00:00<00:00, 190MB/s]
#  31%|███       | 72.5M/233M [00:00<00:00, 184MB/s]
#  39%|███▊      | 90.1M/233M [00:00<00:00, 168MB/s]
#  46%|████▌     | 108M/233M [00:00<00:00, 172MB/s]
#  54%|█████▎    | 125M/233M [00:00<00:00, 176MB/s]
#  61%|██████    | 142M/233M [00:00<00:00, 175MB/s]
#  68%|██████▊   | 160M/233M [00:00<00:00, 177MB/s]
#  76%|███████▌  | 178M/233M [00:01<00:00, 180MB/s]
# --- end 05_eval_b2_pilot.log ---
#
#
# --- 05_eval_b2_pilot.log ---
#
#  84%|████████▎ | 195M/233M [00:01<00:00, 169MB/s]
#  92%|█████████▏| 215M/233M [00:01<00:00, 180MB/s]
# 100%|██████████| 233M/233M [00:01<00:00, 180MB/s]
# --- end 05_eval_b2_pilot.log ---
#
# [b2-train-render-eval] still running...
#
# --- 05_eval_b2_pilot.log ---
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# Scene: hcm0031
# Images: 50
# PSNR mean : 10.5509
# SSIM mean : 0.3614
# LPIPS mean: 0.4226
# Score mean: 0.4027
# Saved CSV : /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv
# --- end 05_eval_b2_pilot.log ---
#
# [b2-train-render-eval] B2 pilot workflow xong: scene=hcm0031
# [b2-train-render-eval] Summary: /content/project/pipeline/work/hcm0031/logs/05_b2_pilot_summary.txt
# [b2-train-render-eval] RETURN CODE = 0
# B2 train/render/eval done

# %%
# ==========================================
# CELL 6 - Read quick logs / output presence
# ==========================================
from pathlib import Path

scene_root = Path(WORKDIR) / "project" / "pipeline" / "work" / SCENE
for p in [
    scene_root / "eval_metrics_b2_pilot.csv",
    scene_root / "eval_metrics_b2_pilot_tower_crop.csv",
    scene_root / "eval_metrics_b2_pilot_skyline_crop.csv",
    scene_root / "logs" / "05_render_b2_pilot.log",
    scene_root / "logs" / "05_eval_b2_pilot.log",
]:
    print("\n====", p, "====")
    if p.exists():
        text = p.read_text(encoding="utf-8", errors="replace")
        print(text[-4000:])
    else:
        print("missing")
# Out:
# ==== /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv ====
# 19,0.35331526,0.5362350940704346,0.3582245906025149
# DJI_20241227155416_0044_V,11.655977217485166,0.38398674,0.5059895515441895,0.3827360620983222
# DJI_20241227155417_0045_V,11.463806401115752,0.39307094,0.4947057068347931,0.38882184249414264
# DJI_20241227155431_0059_V,10.717463643972911,0.34737694,0.5041640400886536,0.36685223669782185
# DJI_20241227155432_0060_V,10.523165908953736,0.33822593,0.5048595070838928,0.3626629748791527
# DJI_20241227155433_0061_V,10.397243373022963,0.3350562,0.506301760673523,0.3603796236063629
# DJI_20241227155438_0066_V,10.349754185641117,0.3381184,0.535761833190918,0.3492292981813211
# DJI_20241227155450_0072_V,12.005915437389136,0.3938613,0.45677831768989563,0.4074825656071229
# DJI_20241227155507_0089_V,10.587665862825908,0.35308567,0.46740400791168213,0.3824900891005242
# DJI_20241227155533_0101_V,11.077157858637111,0.3760881,0.4264844059944153,0.40869562151209793
# DJI_20241227155536_0104_V,11.14131173496778,0.35978565,0.4457862377166748,0.3964690662029585
# DJI_20241227155543_0111_V,11.204901747793642,0.35457358,0.4677838385105133,0.386487951355521
# DJI_20241227155545_0113_V,11.308556335094476,0.3436736,0.4869992136955261,0.37615374050690475
# DJI_20241227155546_0114_V,11.101058380595095,0.32905757,0.5057210326194763,0.36303520951742674
# DJI_20241227155547_0115_V,11.174817093047107,0.33746937,0.518790602684021,0.360773469256357
# DJI_20241227155552_0120_V,11.434700120478569,0.3597397,0.4612933099269867,0.3920128108798844
# DJI_20241227155556_0124_V,10.807470310382685,0.34276745,0.48967066407203674,0.37180680530460264
# DJI_20241227155557_0125_V,11.04820865509174,0.33562306,0.47219160199165344,0.37809953678353203
# DJI_20241227155715_0174_V,10.15974293342265,0.4056529,0.36388447880744934,0.4371005421990772
# DJI_20241227155730_0189_V,10.494720942692828,0.42945766,0.3373855948448181,0.4568513751442246
# DJI_20241227155740_0199_V,10.875265940129236,0.43133652,0.3741309344768524,0.44500017848074125
# DJI_20241227155741_0200_V,10.701883364110783,0.41878536,0.37220871448516846,0.4409634383224821
# DJI_20241227155753_0204_V,10.193469542566016,0.40727994,0.3697366714477539,0.4354501212734167
# DJI_20241227155754_0205_V,10.013679549951304,0.3971096,0.3711813688278198,0.4307424121252236
# DJI_20241227155809_0220_V,10.199594850545257,0.4051354,0.36761268973350525,0.43569313499453743
# DJI_20241227155810_0221_V,10.053454725191322,0.39901522,0.38458824157714844,0.4261900120272954
# DJI_20241227155847_0234_V,10.4139632181411,0.37399352,0.3559887409210205,0.43228634369139973
# DJI_20241227155849_0236_V,10.516731802947819,0.3644456,0.39804768562316895,0.4132150045891255
# DJI_20241227155850_0237_V,10.425925567734076,0.35589674,0.36238235235214233,0.4243716318308582
# DJI_20241227155906_0247_V,9.805888027413816,0.3380563,0.41566920280456543,0.39398452693500596
# DJI_20241227155912_0253_V,10.146097379795116,0.3490173,0.3656438887119293,0.41932422541303277
# DJI_20241227155914_0255_V,10.198439193688202,0.36995324,0.3760610818862915,0.4217521848256729
# DJI_20241227155915_0256_V,10.344267374646384,0.35153088,0.3807428479194641,0.41522774390203787
# DJI_20241227155927_0264_V,10.11489715379929,0.3544743,0.4123906195163727,0.40207543290868136
# DJI_20241227155930_0267_V,10.563624325237885,0.34458372,0.4135275185108185,0.40134586347843537
# DJI_20241227155946_0279_V,10.322703823959273,0.31305286,0.41186994314193726,0.3911041254133906
# DJI_20241227155948_0281_V,10.25714384391814,0.33360443,0.41758614778518677,0.39458974640815914
# DJI_20241227155954_0287_V,10.199172927600957,0.33353505,0.385908305644989,0.4068922319034506
# DJI_20241227160006_0293_V,10.173934958216401,0.3245109,0.42176517844200134,0.3896908060421756
# DJI_20241227160018_0304_V,10.285189819088492,0.32060412,0.3976704478263855,0.3988241915211136
# DJI_20241227160031_0313_V,10.605106189145605,0.31384996,0.3918784558773041,0.4010342325824139
# DJI_20241227160044_0321_V,10.144304529335537,0.30419207,0.43073570728302,0.3798291760415223
# DJI_20241227160048_0325_V,10.126135578379564,0.30731884,0.3997569978237152,0.3930496682561966
#
#
# ==== /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_tower_crop.csv ====
# missing
#
# ==== /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot_skyline_crop.csv ====
# missing
#
# ==== /content/project/pipeline/work/hcm0031/logs/05_render_b2_pilot.log ====
# Render 50 pose | scene=hcm0031 | iteration=30000 | sh_degree=3 | antialiasing=True
#   10/50 -> DJI_20241227155557_0125_V.png
#   20/50 -> DJI_20241227155345_0025_V.png
#   30/50 -> DJI_20241227155547_0115_V.png
#   40/50 -> DJI_20241227155352_0032_V.png
#   50/50 -> DJI_20241227155507_0089_V.png
#
#
# ==== /content/project/pipeline/work/hcm0031/logs/05_eval_b2_pilot.log ====
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#
#   0%|          | 0.00/233M [00:00<?, ?B/s]
#   8%|▊         | 17.8M/233M [00:00<00:01, 185MB/s]
#  15%|█▌        | 36.0M/233M [00:00<00:01, 188MB/s]
#  23%|██▎       | 54.4M/233M [00:00<00:00, 190MB/s]
#  31%|███       | 72.5M/233M [00:00<00:00, 184MB/s]
#  39%|███▊      | 90.1M/233M [00:00<00:00, 168MB/s]
#  46%|████▌     | 108M/233M [00:00<00:00, 172MB/s]
#  54%|█████▎    | 125M/233M [00:00<00:00, 176MB/s]
#  61%|██████    | 142M/233M [00:00<00:00, 175MB/s]
#  68%|██████▊   | 160M/233M [00:00<00:00, 177MB/s]
#  76%|███████▌  | 178M/233M [00:01<00:00, 180MB/s]
#  84%|████████▎ | 195M/233M [00:01<00:00, 169MB/s]
#  92%|█████████▏| 215M/233M [00:01<00:00, 180MB/s]
# 100%|██████████| 233M/233M [00:01<00:00, 180MB/s]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# Scene: hcm0031
# Images: 50
# PSNR mean : 10.5509
# SSIM mean : 0.3614
# LPIPS mean: 0.4226
# Score mean: 0.4027
# Saved CSV : /content/project/pipeline/work/hcm0031/eval_metrics_b2_pilot.csv

# %%
# ==================================================
# CELL 7 - Compare full-image / tower / skyline M0
# ==================================================
import pandas as pd
from pathlib import Path

SCENE = "hcm0031"
work_dir = Path(WORKDIR) / "project" / "pipeline" / "work" / SCENE

comparisons = [
    ("full_image", work_dir / "eval_metrics.csv", work_dir / "eval_metrics_b2_pilot.csv"),
    ("tower_crop", work_dir / "eval_metrics_m0_tower_crop.csv", work_dir / "eval_metrics_b2_pilot_tower_crop.csv"),
    ("skyline_crop", work_dir / "eval_metrics_m0_skyline_crop.csv", work_dir / "eval_metrics_b2_pilot_skyline_crop.csv"),
]

metric_candidates = ["psnr", "ssim", "lpips", "score"]


def pick_row(df, label):
    if len(df) == 1:
        return df.iloc[0]
    for key in ["image_name", "filename", "name"]:
        if key in df.columns:
            raise SystemExit(f"{label} co nhieu dong theo tung anh; can file tong hop 1 dong.")
    return df.iloc[0]


rows = []

for region, baseline_path, b2_path in comparisons:
    if not baseline_path.exists() or not b2_path.exists():
        rows.append(
            {
                "region": region,
                "status": "missing",
                "baseline_file": baseline_path.name,
                "b2_file": b2_path.name,
            }
        )
        continue

    baseline_df = pd.read_csv(baseline_path)
    b2_df = pd.read_csv(b2_path)

    base = pick_row(baseline_df, f"{region} baseline")
    b2 = pick_row(b2_df, f"{region} b2")

    row = {
        "region": region,
        "status": "ok",
        "baseline_file": baseline_path.name,
        "b2_file": b2_path.name,
    }

    for metric in metric_candidates:
        if metric in baseline_df.columns and metric in b2_df.columns:
            base_val = float(base[metric])
            b2_val = float(b2[metric])
            delta = b2_val - base_val

            if metric == "lpips":
                verdict = "better" if delta < 0 else "worse" if delta > 0 else "same"
            else:
                verdict = "better" if delta > 0 else "worse" if delta < 0 else "same"

            row[f"{metric}_base"] = base_val
            row[f"{metric}_b2"] = b2_val
            row[f"{metric}_delta"] = delta
            row[f"{metric}_verdict"] = verdict

    rows.append(row)

summary_df = pd.DataFrame(rows)

display_cols = ["region", "status"]
for metric in metric_candidates:
    display_cols += [
        f"{metric}_base",
        f"{metric}_b2",
        f"{metric}_delta",
        f"{metric}_verdict",
    ]

display_df = summary_df.reindex(columns=display_cols)

for col in display_df.columns:
    if col.endswith(("_base", "_b2", "_delta")):
        display_df[col] = display_df[col].map(lambda x: f"{x:.6f}" if pd.notna(x) else "")

print("So sanh baseline vs B2 cho 3 vung:")
print(display_df.to_string(index=False))
# Out:
# So sanh baseline vs B2 cho 3 vung:
#       region  status psnr_base psnr_b2 psnr_delta  psnr_verdict ssim_base ssim_b2 ssim_delta  ssim_verdict lpips_base lpips_b2 lpips_delta  lpips_verdict score_base score_b2 score_delta  score_verdict
#   full_image missing                                        NaN                                        NaN                                            NaN                                            NaN
#   tower_crop missing                                        NaN                                        NaN                                            NaN                                            NaN
# skyline_crop missing                                        NaN                                        NaN                                            NaN                                            NaN

# %%
from pathlib import Path
import csv
import zipfile


SCENE = "hcm0031"
AUTO_DOWNLOAD = True
HEAVY_FILE_MB = 30

WORK_CANDIDATES = [
    Path(f"/content/project/pipeline/work/{SCENE}"),
    Path(f"/kaggle/working/project/pipeline/work/{SCENE}"),
    Path(f"/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/pipeline/work/{SCENE}"),
]


def find_scene_root() -> Path:
    for path in WORK_CANDIDATES:
        if path.exists():
            return path
    raise FileNotFoundError(f"Khong tim thay thu muc work cua scene {SCENE}")


def human_size(size_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    value = float(size_bytes)
    unit_idx = 0
    while value >= 1024 and unit_idx < len(units) - 1:
        value /= 1024
        unit_idx += 1
    return f"{value:.2f} {units[unit_idx]}"


def size_gb(size_bytes: int) -> float:
    return size_bytes / (1024 ** 3)


def ensure_parent(path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)


def write_manifest(rows: list[tuple[int, Path]], out_csv: Path) -> None:
    ensure_parent(out_csv)
    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["size_bytes", "size_human", "path"])
        for size, path in rows:
            writer.writerow([size, human_size(size), str(path)])


def build_zip_from_files(base_root: Path, files: list[Path], zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(files):
            zf.write(path, arcname=path.relative_to(base_root))
    return zip_path


def build_zip_from_dir(src_dir: Path, zip_path: Path) -> Path:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(src_dir.rglob("*")):
            if path.is_file():
                zf.write(path, arcname=path.relative_to(src_dir.parent))
    return zip_path


def download_paths(paths: list[Path]) -> None:
    if not AUTO_DOWNLOAD:
        return
    try:
        from google.colab import files
    except Exception:
        print("Khong phat hien google.colab, chi tao file, khong tu dong download.")
        return

    print("\n=== BAT DAU DOWNLOAD ===")
    for path in paths:
        print(path)
        files.download(str(path))


def gather_light_files(scene_root: Path) -> list[Path]:
    gs_model = scene_root / "gs_model"
    dense_sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"
    logs_dir = scene_root / "logs"

    candidates = [
        gs_model / "cfg_args",
        gs_model / "cameras.json",
        gs_model / "exposure.json",
        gs_model / "input.ply",
        gs_model / "pipeline_train_flags.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        logs_dir / "05_b2_pilot_summary.txt",
        logs_dir / "05_render_b2_pilot.log",
        logs_dir / "05_eval_b2_pilot.log",
        logs_dir / "04_colmap_dense_summary.txt",
        logs_dir / "04_stereo_fusion.log",
        scene_root / "train.log",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "03_train_3dgs.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "render_round1_test_poses.py",
        scene_root.parent.parent.parent / "pipeline" / "scripts" / "eval_round1_metrics.py",
        scene_root.parent.parent.parent / "trick" / SCENE / "default.env",
        dense_sparse0 / "cameras.bin",
        dense_sparse0 / "frames.bin",
        dense_sparse0 / "images.bin",
        dense_sparse0 / "points3D.bin",
        dense_sparse0 / "points3D.ply",
        dense_sparse0 / "rigs.bin",
        scene_root / "colmap" / "dense" / "fused.ply",
    ]

    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def gather_heavy_files(scene_root: Path) -> list[Path]:
    candidates = [
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "_curated_download" / "colmap_dense_images.zip",
        scene_root / "_curated_download" / "renders_images.zip",
    ]
    files = [path for path in candidates if path.exists() and path.is_file()]
    return sorted(set(files), key=lambda p: (p.stat().st_size, str(p)))


def main() -> None:
    scene_root = find_scene_root()
    curated_root = scene_root / "_curated_download"
    curated_root.mkdir(parents=True, exist_ok=True)

    colmap_images_dir = scene_root / "colmap" / "dense" / "images"
    renders_dir = scene_root / "renders_b2_pilot"
    if not renders_dir.exists():
        renders_dir = scene_root / "renders"

    colmap_images_zip = curated_root / "colmap_dense_images.zip"
    renders_zip = curated_root / "renders_images.zip"
    light_zip = curated_root / f"{SCENE}_light_bundle.zip"

    if colmap_images_dir.exists():
        build_zip_from_dir(colmap_images_dir, colmap_images_zip)
    if renders_dir.exists():
        build_zip_from_dir(renders_dir, renders_zip)

    light_files = gather_light_files(scene_root)
    build_zip_from_files(scene_root.parent.parent.parent, light_files, light_zip)

    heavy_files = gather_heavy_files(scene_root)
    light_size = light_zip.stat().st_size if light_zip.exists() else 0
    light_rows = [(path.stat().st_size, path) for path in light_files]
    light_rows.sort(key=lambda item: (item[0], str(item[1])))
    heavy_rows = [(path.stat().st_size, path) for path in heavy_files]
    heavy_rows.sort(key=lambda item: (item[0], str(item[1])))

    light_manifest = curated_root / "light_bundle_manifest.csv"
    heavy_manifest = curated_root / "heavy_files_manifest.csv"
    write_manifest(light_rows, light_manifest)
    write_manifest(heavy_rows, heavy_manifest)

    print("=== CURATED DOWNLOAD PLAN ===")
    print("scene_root       :", scene_root)
    print("curated_root     :", curated_root)
    print("light_zip        :", light_zip)
    print("light_zip_size   :", human_size(light_size))
    print(f"light_zip_gb     : {size_gb(light_size):.3f} GB")
    print("light_file_count :", len(light_files))
    print("heavy_file_count :", len(heavy_rows))
    print("heavy_threshold  :", f">{HEAVY_FILE_MB} MB")
    print("light_manifest   :", light_manifest)
    print("heavy_manifest   :", heavy_manifest)

    print("\n=== HEAVY FILES ===")
    for size, path in heavy_rows:
        print(f"{human_size(size):>10}  {path}")

    total_bytes = light_size + sum(size for size, _ in heavy_rows)
    print("\n=== TOTAL ===")
    print("total_size       :", human_size(total_bytes))
    print(f"total_size_gb    : {size_gb(total_bytes):.3f} GB")

    download_paths([light_zip] + [path for _, path in heavy_rows])


if __name__ == "__main__":
    main()
# Out:
# === CURATED DOWNLOAD PLAN ===
# scene_root       : /content/project/pipeline/work/hcm0031
# curated_root     : /content/project/pipeline/work/hcm0031/_curated_download
# light_zip        : /content/project/pipeline/work/hcm0031/_curated_download/hcm0031_light_bundle.zip
# light_zip_size   : 149.34 MB
# light_zip_gb     : 0.146 GB
# light_file_count : 24
# heavy_file_count : 4
# heavy_threshold  : >30 MB
# light_manifest   : /content/project/pipeline/work/hcm0031/_curated_download/light_bundle_manifest.csv
# heavy_manifest   : /content/project/pipeline/work/hcm0031/_curated_download/heavy_files_manifest.csv
#
# === HEAVY FILES ===
#   34.78 MB  /content/project/pipeline/work/hcm0031/gs_model/point_cloud/iteration_30000/point_cloud.ply
#   82.19 MB  /content/project/pipeline/work/hcm0031/_curated_download/renders_images.zip
#  100.99 MB  /content/project/pipeline/work/hcm0031/gs_model/chkpnt30000.pth
#  151.18 MB  /content/project/pipeline/work/hcm0031/_curated_download/colmap_dense_images.zip
#
# === TOTAL ===
# total_size       : 518.48 MB
# total_size_gb    : 0.506 GB
#
# === BAT DAU DOWNLOAD ===
# /content/project/pipeline/work/hcm0031/_curated_download/hcm0031_light_bundle.zip
# /content/project/pipeline/work/hcm0031/gs_model/point_cloud/iteration_30000/point_cloud.ply
# /content/project/pipeline/work/hcm0031/_curated_download/renders_images.zip
# /content/project/pipeline/work/hcm0031/gs_model/chkpnt30000.pth
# /content/project/pipeline/work/hcm0031/_curated_download/colmap_dense_images.zip

# %%
from pathlib import Path
import csv
import os
import subprocess
import zipfile


SCENE = "hcm0031"
MODE = "reeval_latest"  # "package" | "reeval_latest"
AUTO_DOWNLOAD = False
INCLUDE_RENDERS_ARCHIVE = True
PSNR_MAX = 30.0

DATASET_ROOT = os.environ.get("DATASET_ROOT", "")

WORK_CANDIDATES = [
    Path(f"/content/project/pipeline/work/{SCENE}"),
    Path(f"/kaggle/working/project/pipeline/work/{SCENE}"),
    Path(f"/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/pipeline/work/{SCENE}"),
]

GS_REPO_CANDIDATES = [
    Path("/content/gaussian-splatting"),
    Path("/content/project/gaussian-splatting"),
    Path("/content/project/submodules/gaussian-splatting"),
    Path("/kaggle/working/gaussian-splatting"),
    Path("/kaggle/working/project/gaussian-splatting"),
    Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/gaussian-splatting"),
]

DATASET_ROOT_CANDIDATES = [
    Path("/content/project/Dataset/VAI_NVS_DATA/phase1/public_set"),
    Path("/content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set"),
    Path("/kaggle/working/project/Dataset/VAI_NVS_DATA/phase1/public_set"),
    Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin/Dataset/VAI_NVS_DATA/phase1/public_set"),
]


def find_scene_root() -> Path:
    for path in WORK_CANDIDATES:
        if path.exists():
            return path
    raise FileNotFoundError(f"Khong tim thay thu muc work cua scene {SCENE}")


def find_gs_repo() -> Path:
    env_path = os.environ.get("GS_REPO", "")
    if env_path:
        env_repo = Path(env_path)
        if (env_repo / "train.py").exists():
            return env_repo

    for path in GS_REPO_CANDIDATES:
        if (path / "train.py").exists():
            os.environ["GS_REPO"] = str(path)
            return path

    raise FileNotFoundError(
        "Khong tu dong tim thay GS_REPO. Hay set tay, vi du: "
        "os.environ['GS_REPO'] = '/content/gaussian-splatting'"
    )


def find_dataset_root() -> Path:
    env_path = DATASET_ROOT or os.environ.get("DATASET_ROOT", "")
    if env_path:
        env_root = Path(env_path)
        if (env_root / SCENE / "test" / "test_poses.csv").exists():
            return env_root

    for path in DATASET_ROOT_CANDIDATES:
        if (path / SCENE / "test" / "test_poses.csv").exists():
            os.environ["DATASET_ROOT"] = str(path)
            return path

    search_bases = [
        Path("/content"),
        Path("/content/_dataset_round1_raw"),
        Path("/kaggle/working"),
        Path("/home/thongluc/Khóa Luận Tốt Nghiệp/BTS Digital Twin"),
    ]
    for base in search_bases:
        if not base.exists():
            continue
        for path in base.rglob("public_set"):
            if (path / SCENE / "test" / "test_poses.csv").exists():
                os.environ["DATASET_ROOT"] = str(path)
                return path

    raise FileNotFoundError(
        "Khong tu dong tim thay Dataset/VAI_NVS_DATA/phase1/public_set co "
        f"scene {SCENE} va file test/test_poses.csv"
    )


def human_size(size_bytes: int) -> str:
    units = ["B", "KB", "MB", "GB", "TB"]
    value = float(size_bytes)
    unit_idx = 0
    while value >= 1024 and unit_idx < len(units) - 1:
        value /= 1024
        unit_idx += 1
    return f"{value:.2f} {units[unit_idx]}"


def size_gb(size_bytes: int) -> float:
    return size_bytes / (1024 ** 3)


def ensure_parent(path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)


def build_zip_from_files(base_root: Path, files: list[Path], zip_path: Path) -> None:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(files):
            zf.write(path, arcname=path.relative_to(base_root))


def build_zip_from_dir(src_dir: Path, zip_path: Path) -> None:
    ensure_parent(zip_path)
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for path in sorted(src_dir.rglob("*")):
            if path.is_file():
                zf.write(path, arcname=path.relative_to(src_dir.parent))


def download_paths(paths: list[Path]) -> None:
    if not AUTO_DOWNLOAD:
        return
    try:
        from google.colab import files
    except Exception:
        print("Khong phat hien google.colab, chi tao file, khong tu dong download.")
        return

    print("\n=== BAT DAU DOWNLOAD ===")
    for path in paths:
        print(path)
        files.download(str(path))


def project_root_from_scene(scene_root: Path) -> Path:
    return scene_root.parent.parent.parent


def gather_minimal_light_files(scene_root: Path) -> list[Path]:
    project_root = project_root_from_scene(scene_root)
    gs_model = scene_root / "gs_model"
    sparse0 = scene_root / "colmap" / "dense" / "sparse" / "0"

    candidates = [
        gs_model / "cfg_args",
        gs_model / "cameras.json",
        gs_model / "exposure.json",
        gs_model / "pipeline_train_flags.json",
        scene_root / "eval_metrics_b2_pilot.csv",
        project_root / "pipeline" / "scripts" / "03_train_3dgs.sh",
        project_root / "pipeline" / "scripts" / "05_run_b2_pilot.sh",
        project_root / "pipeline" / "scripts" / "render_round1_test_poses.py",
        project_root / "pipeline" / "scripts" / "eval_round1_metrics.py",
        project_root / "trick" / SCENE / "default.env",
        sparse0 / "cameras.bin",
        sparse0 / "frames.bin",
        sparse0 / "images.bin",
        sparse0 / "points3D.bin",
        sparse0 / "points3D.ply",
        sparse0 / "rigs.bin",
    ]
    return [path for path in candidates if path.exists() and path.is_file()]


def package_b2_minimal(scene_root: Path) -> None:
    curated_root = scene_root / "_curated_b2_minimal"
    curated_root.mkdir(parents=True, exist_ok=True)

    project_root = project_root_from_scene(scene_root)
    light_files = gather_minimal_light_files(scene_root)
    light_zip = curated_root / f"{SCENE}_b2_light.zip"
    build_zip_from_files(project_root, light_files, light_zip)

    heavy_files = [
        scene_root / "gs_model" / "chkpnt30000.pth",
        scene_root / "gs_model" / "point_cloud" / "iteration_30000" / "point_cloud.ply",
    ]
    heavy_files = [path for path in heavy_files if path.exists() and path.is_file()]

    archives = []
    dense_images_dir = scene_root / "colmap" / "dense" / "images"
    if dense_images_dir.exists():
        dense_images_zip = curated_root / "colmap_dense_images.zip"
        build_zip_from_dir(dense_images_dir, dense_images_zip)
        archives.append(dense_images_zip)

    renders_dir = scene_root / "renders_b2_pilot"
    if not renders_dir.exists():
        renders_dir = scene_root / "renders"
    if INCLUDE_RENDERS_ARCHIVE and renders_dir.exists():
        renders_zip = curated_root / "renders_images.zip"
        build_zip_from_dir(renders_dir, renders_zip)
        archives.append(renders_zip)

    print("=== B2 MINIMAL PACKAGE ===")
    print("scene_root        :", scene_root)
    print("curated_root      :", curated_root)
    print("light_zip         :", light_zip)
    print("light_zip_size    :", human_size(light_zip.stat().st_size))
    print(f"light_zip_gb      : {size_gb(light_zip.stat().st_size):.3f} GB")

    print("\n=== KEEP ===")
    print(light_zip)
    for path in archives:
        print(path)
    for path in heavy_files:
        print(path)

    print("\n=== KHONG CAN TAI ===")
    print("colmap/dense/stereo/depth_maps/*")
    print("colmap/dense/stereo/normal_maps/*")
    print("colmap/dense/fused.ply.vis")
    print("gs_model/events.out.tfevents*")
    print("train.log")
    print("gs_model/input.ply")
    print("logs/*")
    print("_download_ready/all_filtered/* neu da co bo curated moi")

    all_downloads = [light_zip] + archives + heavy_files
    total_bytes = sum(path.stat().st_size for path in all_downloads)
    print("\n=== TOTAL DOWNLOAD ===")
    print("count             :", len(all_downloads))
    print("total_size        :", human_size(total_bytes))
    print(f"total_size_gb     : {size_gb(total_bytes):.3f} GB")

    download_paths(all_downloads)


def find_latest_iteration(scene_root: Path) -> int:
    point_cloud_root = scene_root / "gs_model" / "point_cloud"
    iterations = []
    for path in point_cloud_root.glob("iteration_*"):
        if path.is_dir():
            try:
                iterations.append(int(path.name.split("_")[-1]))
            except ValueError:
                continue
    if not iterations:
        raise FileNotFoundError(f"Khong tim thay iteration_* trong {point_cloud_root}")
    return max(iterations)


def validate_reeval_prereqs(project_root: Path) -> None:
    gs_repo_path = find_gs_repo()
    dataset_root = find_dataset_root()
    dataset_scene_root = dataset_root / SCENE
    test_poses_csv = dataset_scene_root / "test" / "test_poses.csv"
    test_images_dir = dataset_scene_root / "test" / "images"
    if not test_poses_csv.exists():
        raise FileNotFoundError(f"Khong thay test_poses.csv: {test_poses_csv}")
    if not test_images_dir.exists():
        raise FileNotFoundError(f"Khong thay test/images: {test_images_dir}")

    scripts_dir = project_root / "pipeline" / "scripts"
    for script_name in ["render_round1_test_poses.py", "eval_round1_metrics.py"]:
        script_path = scripts_dir / script_name
        if not script_path.exists():
            raise FileNotFoundError(f"Khong thay script: {script_path}")


def reevaluate_latest_scene(scene_root: Path) -> None:
    project_root = project_root_from_scene(scene_root)
    validate_reeval_prereqs(project_root)
    gs_repo_path = find_gs_repo()
    dataset_root = find_dataset_root()
    scripts_dir = project_root / "pipeline" / "scripts"
    logs_dir = scene_root / "logs"
    logs_dir.mkdir(parents=True, exist_ok=True)

    latest_iter = find_latest_iteration(scene_root)
    model_dir = scene_root / "gs_model"
    render_out_dir = scene_root / f"renders_b2_latest_iter_{latest_iter}"
    eval_out_csv = scene_root / f"eval_metrics_b2_latest_iter_{latest_iter}.csv"
    render_log = logs_dir / f"05_render_b2_latest_iter_{latest_iter}.log"
    eval_log = logs_dir / f"05_eval_b2_latest_iter_{latest_iter}.log"

    render_cmd = [
        "python3",
        str(scripts_dir / "render_round1_test_poses.py"),
        "--scene",
        SCENE,
        "--dataset_root",
        str(dataset_root),
        "--model_dir",
        str(model_dir),
        "--iteration",
        str(latest_iter),
        "--out_dir",
        str(render_out_dir),
    ]
    eval_cmd = [
        "python3",
        str(scripts_dir / "eval_round1_metrics.py"),
        "--scene",
        SCENE,
        "--dataset_root",
        str(dataset_root),
        "--renders_dir",
        str(render_out_dir),
        "--out_csv",
        str(eval_out_csv),
        "--psnr_max",
        str(PSNR_MAX),
    ]

    print("=== REEVAL LATEST SCENE ===")
    print("scene             :", SCENE)
    print("scene_root        :", scene_root)
    print("dataset_root      :", dataset_root)
    print("gs_repo           :", gs_repo_path)
    print("latest_iteration  :", latest_iter)
    print("render_out_dir    :", render_out_dir)
    print("eval_out_csv      :", eval_out_csv)
    print("psnr_max          :", PSNR_MAX)

    env = os.environ.copy()
    with open(render_log, "w", encoding="utf-8") as f:
        subprocess.run(render_cmd, check=True, env=env, stdout=f, stderr=subprocess.STDOUT)
    with open(eval_log, "w", encoding="utf-8") as f:
        subprocess.run(eval_cmd, check=True, env=env, stdout=f, stderr=subprocess.STDOUT)

    print("render_log        :", render_log)
    print("eval_log          :", eval_log)

    if not eval_out_csv.exists():
        raise FileNotFoundError(f"Khong thay file eval csv: {eval_out_csv}")

    with open(eval_out_csv, newline="", encoding="utf-8") as f:
        rows = list(csv.DictReader(f))
    if not rows:
        raise RuntimeError("CSV eval rong, khong co metric nao.")

    psnr_vals = [float(row["psnr"]) for row in rows]
    ssim_vals = [float(row["ssim"]) for row in rows]
    lpips_vals = [float(row["lpips"]) for row in rows]
    score_vals = [float(row["score"]) for row in rows]

    print("\n=== EVAL SUMMARY ===")
    print("images            :", len(rows))
    print(f"PSNR mean         : {sum(psnr_vals) / len(psnr_vals):.4f}")
    print(f"SSIM mean         : {sum(ssim_vals) / len(ssim_vals):.4f}")
    print(f"LPIPS mean        : {sum(lpips_vals) / len(lpips_vals):.4f}")
    print(f"Score mean        : {sum(score_vals) / len(score_vals):.4f}")
    print(f"PSNR min          : {min(psnr_vals):.4f}")
    print(f"SSIM min          : {min(ssim_vals):.4f}")
    print(f"LPIPS max         : {max(lpips_vals):.4f}")
    print(f"Score min         : {min(score_vals):.4f}")

    worst_rows = sorted(rows, key=lambda row: float(row["score"]))[:10]
    print("\n=== TOP 10 ANH TE NHAT ===")
    for idx, row in enumerate(worst_rows, start=1):
        print(
            f"{idx:>2}. {row['image']} | "
            f"score={float(row['score']):.4f} | "
            f"psnr={float(row['psnr']):.4f} | "
            f"ssim={float(row['ssim']):.4f} | "
            f"lpips={float(row['lpips']):.4f}"
        )


def main() -> None:
    scene_root = find_scene_root()
    if MODE == "package":
        package_b2_minimal(scene_root)
        return
    if MODE == "reeval_latest":
        reevaluate_latest_scene(scene_root)
        return
    raise ValueError(f"MODE khong hop le: {MODE}")


if __name__ == "__main__":
    main()
# Out:
# === REEVAL LATEST SCENE ===
# scene             : hcm0031
# scene_root        : /content/project/pipeline/work/hcm0031
# dataset_root      : /content/_dataset_round1_raw/VAI_NVS_DATA/phase1/public_set
# gs_repo           : /content/gaussian-splatting
# latest_iteration  : 30000
# render_out_dir    : /content/project/pipeline/work/hcm0031/renders_b2_latest_iter_30000
# eval_out_csv      : /content/project/pipeline/work/hcm0031/eval_metrics_b2_latest_iter_30000.csv
# psnr_max          : 30.0
# render_log        : /content/project/pipeline/work/hcm0031/logs/05_render_b2_latest_iter_30000.log
# eval_log          : /content/project/pipeline/work/hcm0031/logs/05_eval_b2_latest_iter_30000.log
#
# === EVAL SUMMARY ===
# images            : 50
# PSNR mean         : 10.5509
# SSIM mean         : 0.3614
# LPIPS mean        : 0.4226
# Score mean        : 0.4449
# PSNR min          : 9.8059
# SSIM min          : 0.3042
# LPIPS max         : 0.5362
# Score min         : 0.3906
#
# === TOP 10 ANH TE NHAT ===
#  1. DJI_20241227155438_0066_V | score=0.3906 | psnr=10.3498 | ssim=0.3381 | lpips=0.5358
#  2. DJI_20241227155433_0061_V | score=0.4020 | psnr=10.3972 | ssim=0.3351 | lpips=0.5063
#  3. DJI_20241227155413_0041_V | score=0.4027 | psnr=11.1207 | ssim=0.3533 | lpips=0.5362
#  4. DJI_20241227155411_0039_V | score=0.4035 | psnr=10.8707 | ssim=0.3549 | lpips=0.5291
#  5. DJI_20241227155432_0060_V | score=0.4048 | psnr=10.5232 | ssim=0.3382 | lpips=0.5049
#  6. DJI_20241227155547_0115_V | score=0.4055 | psnr=11.1748 | ssim=0.3375 | lpips=0.5188
#  7. DJI_20241227155546_0114_V | score=0.4074 | psnr=11.1011 | ssim=0.3291 | lpips=0.5057
#  8. DJI_20241227155431_0059_V | score=0.4097 | psnr=10.7175 | ssim=0.3474 | lpips=0.5042
#  9. DJI_20241227155556_0124_V | score=0.4150 | psnr=10.8075 | ssim=0.3428 | lpips=0.4897
# 10. DJI_20241227160044_0321_V | score=0.4204 | psnr=10.1443 | ssim=0.3042 | lpips=0.4307
